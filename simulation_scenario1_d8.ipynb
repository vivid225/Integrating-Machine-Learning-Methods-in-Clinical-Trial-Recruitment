# %%
import numpy as np
import pandas as pd
import random
import time
from itertools import product
from scipy.stats import norm, binomtest
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression, Lasso, Ridge

from sklearn import linear_model, svm, naive_bayes, ensemble
from sklearn.model_selection import cross_validate, train_test_split, RepeatedStratifiedKFold
from sklearn.utils import class_weight
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, f1_score, roc_auc_score
from xgboost import XGBClassifier
# from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score, accuracy_score, classification_report, confusion_matrix, roc_auc_score, matthews_corrcoef

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ## Read functions

# %%
# %run functions_scenario1.ipynb

# %% [markdown]
# ## Scenario 1

# %% [markdown]
# ## Logistic regression

# %%
def ensemble_model_fit(data, data_pred):
    X_train, X_test, y_train, y_test = train_test_split(
        data.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1),
        data['response'],
        test_size=0.2,
        random_state=0
    )

    # Define the VotingClassifier with the individual classifiers
    voting_classifier = ensemble.VotingClassifier(
        estimators=[
            ('LR', linear_model.LogisticRegression(max_iter=200, random_state=0))
#             ('Ridge', linear_model.LogisticRegression(penalty='l2', solver='lbfgs', max_iter=200, random_state=0))
                    # ('SVM', svm.SVC(kernel='linear', C=1.0, random_state=0, probability=True, class_weight='balanced'))
#                     ('RF', ensemble.RandomForestClassifier(n_estimators=200, criterion='gini', random_state=0))
                    # ('XGB', XGBClassifier(n_estimators=50, learning_rate=0.1, random_state=0))
                   ],
        voting='soft'
    )

    # Define the hyperparameter grid to search
    # Best Hyperparameters: {'LR__C': 0.01, 'RF__n_estimators': 50, 'XGB__n_estimators': 50}
    param_grid = {
        # 'NB__alpha': [0.01, 0.05, 0.1],  # '__' is used to specify hyperparameters for individual classifiers
        'LR__C': [0.01] # [0.01, 0.05, 0.1]
        # 'Ridge__C': [0.01]
        # 'SVM__C': [0.01, 0.05, 0.1]
#         'RF__n_estimators': [50] # [10, 30, 50]
        # 'XGB__n_estimators': [50]
    }

    # Create a GridSearchCV object
    # custom_scorer_auc = make_scorer(roc_auc_score, needs_proba=True)
    grid_search = GridSearchCV(voting_classifier, param_grid, cv=10, scoring='roc_auc')

    # Perform the grid search on the training data
    grid_search.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = grid_search.best_params_

    # Train the final VotingClassifier with the best hyperparameters on the full training set
    final_voting_classifier = grid_search.best_estimator_
    final_voting_classifier.fit(X_train, y_train)

    # Predict probabilities instead of binary outcomes on the test set
    y_pred_proba_test = final_voting_classifier.predict_proba(X_test)
    y_pred_test = final_voting_classifier.predict(X_test)
    X_dt = data_pred.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1)
    y_pred = final_voting_classifier.predict_proba(X_dt)

    return y_pred

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import train_test_split

# def ensemble_model_fit(data, data_pred):
#     # Split the data into training and testing sets
#     X_train, X_test, y_train, y_test = train_test_split(
#         data.drop(['recruitment_plan', 'plan_response_rate', 'group_size','response'], axis=1),
#         data['response'],
#         test_size=0.2,
#         random_state=0
#     )

#     # Define the Logistic Regression model
#     logistic_regression = LogisticRegression(C=0.01, max_iter=200,random_state=0)

#     # Fit the Logistic Regression model on the training data
#     logistic_regression.fit(X_train, y_train)

#     # Print out the coefficients of the logistic regression model
#     print("Coefficients:", logistic_regression.coef_)
#     print("Intercept:", logistic_regression.intercept_)
#     print("Coefficients shape:", logistic_regression.coef_.shape)

#     # Predict probabilities instead of binary outcomes on the test set
#     y_pred_proba_test = logistic_regression.predict_proba(X_test)
#     y_pred_test = logistic_regression.predict(X_test)

#     # You can also predict probabilities for the prediction data (data_pred)
#     X_dt = data_pred.drop(['recruitment_plan', 'plan_response_rate', 'group_size','response'], axis=1)
#     y_pred = logistic_regression.predict_proba(X_dt)

#     return y_pred

# # Call the function
# # ensemble_model_fit(data, data_pred)

# %% [markdown]
# ### Simulation starts

# %%
n_sim = 100
# create a list of random seeds
random.seed(42)
random_seeds = [random.randint(1, 100000) for _ in range(n_sim)]

design_list = [5,8,10]
patient_n_list = [5468,680,170] # n_patient_per_plan

n_design = 8
n_patient_per_plan = 680
n_rounds = 6
total_n = n_patient_per_plan * (2**n_design)

## sample size determination
beta = 0.2
power = 1 - beta
alpha = 0.05
delta = 0.01 # effect size

## early stopping
epsilon = 0.001

# %%
rr_dict = {"step{}_rr".format(r): [] for r in range(1, n_rounds + 1)}
plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
sample_size_dict = {"step{}_sample_size".format(r): [] for r in range(1, n_rounds + 1)}
last_round_sample_size = []
random_rr_dict = {"step{}_random_max_rr".format(r): [] for r in range(1, n_rounds + 1)}
random_rr_dict.update({
    "step{}_random_mean_rr".format(r): [] for r in range(1, n_rounds + 1)
})

stopping_dict = {"early_stopping": [],
                 "early_stopping_plan":[],
                 "early_stopping_orr":[],
                 "early_stopping_size":[]}
final_plan_number = []
highest_rr_overall = []

better_chance = []

orr_total = []
orr_total_adaptive = []



i = 0

for seed in random_seeds:
    i += 1
    print(i)

    print([f"{key}: {len(value)}" for key, value in rr_dict.items()])



    event_list = 0
    event_list_adaptive = 0
    max_rr = []

    # step 1:
    ## Generate dataset
    dt_design_5 = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed)
    print("empirical response rate", dt_design_5['response'].mean())
    ## save for benchmark results
    maxidx = np.argmax(dt_design_5['plan_response_rate'])
    random_rr_dict['step1_random_max_rr'].append(dt_design_5.iloc[maxidx,6])
    random_rr_dict['step1_random_mean_rr'].append(dt_design_5['plan_response_rate'].mean())

    ## Ensemble modelling:
    y_pred = ensemble_model_fit(data=dt_design_5, data_pred = dt_design_5)

    ## select recruitment plan
    pred_df = pd.DataFrame(np.hstack((dt_design_5,  y_pred[:, 1].reshape(-1, 1))),
                             columns=list(dt_design_5.columns) + ['predicted_response_rate'])
    pred_df_rr = pred_df.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

    x = pred_df_rr['predicted_response_rate'].values
    if len(x) <= 10:
        best_k = 2
    else:
        best_k = kmeans_fit(data = x)['best_k']
    kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

    merged_df = pd.merge(pred_df_rr, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
    cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
    highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
    highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)


    p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))
    highest_cluster['p_vec'] = p_vec_next
    highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

    # highest_cluster = pred_df_rr

    # highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')
    # highest_cluster['cluster_number'] = highest_cluster['recruitment_plan']

    ## prepare to chance of better performance:
    temp = dt_design_5[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
    event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print("step1", np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print(temp)
    p0 = (temp['plan_response_rate'].mean())

    rr_dict["step1_rr"].append(dt_design_5['plan_response_rate'].mean())
    sample_size_dict["step1_sample_size"].append(len(dt_design_5))

    for round in range(2, n_rounds+1):

        rr_dict["step"+str(round)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))
        plan_number_dict["step"+str(round)+"_plan_number"].append(len(p_vec_next))

        ## when it comes to the last round:
        if round == n_rounds:

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            if round == 2: # if the last round is round 2
                remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
            else:
                remaining_size -= len(dt_design_5_step2up)

            print("remaining size for last Round " + str(round) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            ## data generation, combine previous data:
            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, 
                                                          design_number = n_design, n_rounds = n_rounds,
                                                          n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(0)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(len(temp), temp['plan_response_rate'].mean())
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break



        ## If haven't reached the last round:
        ## check remaining sample size:
        if round == 2:
            remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
        else:
            remaining_size -= len(dt_design_5_step2up)

        print("remaining size for Round " + str(round) + ": " + str(remaining_size))

        ## determine whether move on to step 2:
        if len(highest_cluster) == 1: # if there is only one plan left

            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size) # record the last round sample size
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(1)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        ## sample size determination:
        if round == 2:
            dt_design_5_step2up_overall = dt_design_5
        orr_1 = dt_design_5_step2up_overall['response'].mean() # observed overall response rates for previous rounds
        orr_2 = orr_1 + delta
        n_1 = len(dt_design_5_step2up_overall)

        size_step2up = sample_size_calc(orr_1, n_1, delta=delta, alpha=alpha, power=power) # total size for dataset
        if size_step2up > 0 and size_step2up < 1000:
            size_step2up = 1000 # if size in [0,1000], then it is 1000 for this round.
        elif size_step2up >= 1000:
            size_step2up = min(size_step2up, int(total_n/n_rounds)) # dataset size capped by the n_patient_per_plan
        else:
        # if size_step2up <= 0:
            # the process stops at this step
            print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up) + 'lt 0, break')
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(1)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up))

        sample_size_dict["step"+str(round)+"_sample_size"].append(size_step2up)

        ## save benchmark results for last round:
        dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                            n_patient_per_plan = n_patient_per_plan, seed=seed+round)
        maxidx = np.argmax(dt_benchmark['plan_response_rate'])
        random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
        random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

        ## data generation, combine previous data:
        dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                  design_number = n_design, n_rounds = n_rounds,
                                                  n_patient_per_plan = n_patient_per_plan, size = int(size_step2up), seed=seed)

        plan_list = dt_design_5_step2up['recruitment_plan'].unique()
        if round == 2:
            supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)]
        else:
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
        dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
        dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

        ## Ensemble model fitting:
        dt_design_5_step2up.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)
        y_pred2up = ensemble_model_fit(data = dt_design_5_step2up_overall, data_pred = dt_design_5_step2up)
        pred_df_step2up = pd.DataFrame(np.hstack((dt_design_5_step2up,  y_pred2up[:, 1].reshape(-1, 1))),
                                    columns=list(dt_design_5_step2up.columns) + ['predicted_response_rate'])
        pred_df_rr_step2up = pred_df_step2up.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

        ## select recruitment plans:
        x = pred_df_rr_step2up['predicted_response_rate'].values

        if len(x) <= 10:
            best_k = 2
        else:
            best_k = kmeans_fit(data = x)['best_k']
        kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

        ## match the cluster results back to the original data
        highest_cluster_previous = highest_cluster # save previous cluster results

        merged_df = pd.merge(pred_df_rr_step2up, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
        cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
        highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
        highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)

        # p_vec_previous = p_vec_next # save p_vec of previous round
        p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))

        highest_cluster['p_vec'] = p_vec_next

        highest_cluster = pd.merge(highest_cluster, dt_design_5_step2up[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

        ## prepare to chance of better performance:
        temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
        event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print(temp)

        ## check early stopping predicted ORR:
        orr_df = pd.merge(highest_cluster_previous, highest_cluster[['recruitment_plan','predicted_response_rate','p_vec']], on='recruitment_plan', how='left')
        orr_df.fillna(0, inplace=True)
        p_orr_1 = np.dot(np.array(orr_df['p_vec_x']), np.array(orr_df['predicted_response_rate_y']))
        p_orr_2 = np.dot(np.array(orr_df['p_vec_y']), np.array(orr_df['predicted_response_rate_y']))
        print("orr termination", p_orr_1, p_orr_2, p_orr_2 - p_orr_1)

        if (p_orr_2 - p_orr_1 < epsilon):
            # step 3 use the same strategy of step2
            print(i, p_orr_1, p_orr_2, "early stop at Round " + str(round))
            rr_dict["step"+str(round+1)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                                n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round+1)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round+1)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            ### update remaining size:
            remaining_size -= len(dt_design_5_step2up)
            print("early stop, remaining size for Round" + str(round + 1) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            for r in range(round+2, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, 
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(1)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            for r in range(round+2, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round+1), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break
# Out:
# 1
# ['step1_rr: 0', 'step2_rr: 0', 'step3_rr: 0', 'step4_rr: 0', 'step5_rr: 0', 'step6_rr: 0']
# empirical response rate 0.08033738938053098
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6033.300486728156
# orr termination 0.014725589015834982 0.11147800144402928 0.0967524124281943
# remaining size for Round 3: 139119
# Calculated size for Round 3: 7147.899498956526
# orr termination 0.01682047213391656 0.10826677752910902 0.09144630539519245
# remaining size for Round 4: 131972
# Calculated size for Round 4: 11311.931237719911
# orr termination 0.048024379741658324 0.09556690308233944 0.04754252334068111
# remaining size for Round 5: 120661
# Calculated size for Round 5: 8395.521511779181
# orr termination 0.053172906326330566 0.10436151084985593 0.05118860452352536
# remaining size for last Round 6: 112266
# 2
# ['step1_rr: 1', 'step2_rr: 1', 'step3_rr: 1', 'step4_rr: 1', 'step5_rr: 1', 'step6_rr: 1']
# empirical response rate 0.07836698008849557
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5889.708525120337
# orr termination 0.022439773431888268 0.07951207097291998 0.057072297541031713
# remaining size for Round 3: 139263
# Calculated size for Round 3: 6491.370400712403
# orr termination 0.00702545653576604 0.0846818101389928 0.07765635360322676
# remaining size for Round 4: 132772
# Calculated size for Round 4: 7302.664530333396
# orr termination 0.041971064295150205 0.08300555217950448 0.04103448788435427
# remaining size for Round 5: 125470
# 3
# ['step1_rr: 2', 'step2_rr: 2', 'step3_rr: 2', 'step4_rr: 2', 'step5_rr: 2', 'step6_rr: 2']
# empirical response rate 0.030593196902654867
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2570.7668488803606
# orr termination 0.010431183505667088 0.034288347547230404 0.023857164041563315
# remaining size for Round 3: 142582
# Calculated size for Round 3: 2664.6870668091915
# orr termination 0.003191362941381544 0.04764925075097666 0.044457887809595115
# remaining size for Round 4: 139918
# Calculated size for Round 4: 4185.082587889708
# orr termination 0.05950554511812069 0.08986649914647243 0.030360954028351747
# remaining size for Round 5: 135733
# Calculated size for Round 5: -630787.9638416836lt 0, break
# 4
# ['step1_rr: 3', 'step2_rr: 3', 'step3_rr: 3', 'step4_rr: 3', 'step5_rr: 3', 'step6_rr: 3']
# empirical response rate 0.06011476769911504
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4584.554843390879
# orr termination 0.028348593548717684 0.06224227087413449 0.0338936773254168
# remaining size for Round 3: 140568
# Calculated size for Round 3: 4869.11100062842
# orr termination 0.036100330053046095 0.07404158842879917 0.03794125837575307
# remaining size for Round 4: 135699
# Calculated size for Round 4: 6701.711286577272
# orr termination 0.00804318836658092 0.08773761821625661 0.07969442984967569
# remaining size for Round 5: 128998
# Calculated size for Round 5: 7865.807634202976
# orr termination 0.04702477080327388 0.0939933534739957 0.04696858267072183
# remaining size for last Round 6: 121133
# 5
# ['step1_rr: 4', 'step2_rr: 4', 'step3_rr: 4', 'step4_rr: 4', 'step5_rr: 4', 'step6_rr: 4']
# empirical response rate 0.09029314159292036
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6766.704057464664
# orr termination 0.061352615678450975 0.0900318788361247 0.02867926315767373
# remaining size for Round 3: 138386
# Calculated size for Round 3: 6563.007683281972
# orr termination 0.06911237939524398 0.09584434506875432 0.02673196567351034
# remaining size for Round 4: 131823
# Calculated size for Round 4: 7097.692132278566
# orr termination 0.017214014994441574 0.11081194441158043 0.09359792941713886
# remaining size for Round 5: 124726
# Calculated size for Round 5: 7913.6205614928585
# orr termination 0.015149924137245214 0.09983362831323701 0.0846837041759918
# remaining size for last Round 6: 116813
# 6
# ['step1_rr: 5', 'step2_rr: 5', 'step3_rr: 5', 'step4_rr: 5', 'step5_rr: 5', 'step6_rr: 5']
# empirical response rate 0.04362555309734513
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3444.8125679843447
# orr termination 0.008198174593213795 0.05434086822315491 0.04614269362994112
# remaining size for Round 3: 141708
# Calculated size for Round 3: 5702.534575599655
# orr termination 0.03341644606520612 0.08376461862977977 0.05034817256457365
# remaining size for Round 4: 136006
# Calculated size for Round 4: 15885.614092091942
# orr termination 0.047739025159140226 0.09501925335670433 0.047280228197564104
# remaining size for Round 5: 120121
# 7
# ['step1_rr: 6', 'step2_rr: 6', 'step3_rr: 6', 'step4_rr: 6', 'step5_rr: 6', 'step6_rr: 6']
# empirical response rate 0.04355641592920354
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3440.1132258982107
# orr termination 0.03777306953362787 0.07008079377252904 0.03230772423890117
# remaining size for Round 3: 141712
# Calculated size for Round 3: 6391.329539609031
# orr termination 0.011338251680522285 0.07823677709302486 0.06689852541250257
# remaining size for Round 4: 135321
# Calculated size for Round 4: 6682.348660352336
# orr termination 0.0324888557593814 0.08179641560006193 0.049307559840680526
# remaining size for Round 5: 128639
# Calculated size for Round 5: 9833.502921535199
# orr termination 0.04584794997722711 0.0915034311043468 0.045655481127119694
# remaining size for last Round 6: 118806
# 8
# ['step1_rr: 7', 'step2_rr: 7', 'step3_rr: 7', 'step4_rr: 7', 'step5_rr: 7', 'step6_rr: 7']
# empirical response rate 0.08030282079646017
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6030.776854562427
# orr termination 0.023278153963719614 0.09849043065827978 0.07521227669456017
# remaining size for Round 3: 139122
# Calculated size for Round 3: 7827.388424854051
# orr termination 0.015713295013062276 0.11709839310087841 0.10138509808781614
# remaining size for Round 4: 131295
# Calculated size for Round 4: 10542.028245366526
# orr termination 0.060846860964683044 0.09387355410466675 0.0330266931399837
# remaining size for Round 5: 120753
# Calculated size for Round 5: 9312.118840327348
# orr termination 0.04622453420700762 0.0912638216300807 0.04503928742307309
# remaining size for last Round 6: 111441
# 9
# ['step1_rr: 8', 'step2_rr: 8', 'step3_rr: 8', 'step4_rr: 8', 'step5_rr: 8', 'step6_rr: 8']
# empirical response rate 0.04777378318584071
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3727.99035410021
# orr termination 0.012508111876910427 0.045239715426002275 0.032731603549091846
# remaining size for Round 3: 141425
# Calculated size for Round 3: 3528.022950312441
# orr termination 0.017643222505981555 0.0477813503138202 0.030138127807838644
# remaining size for Round 4: 137897
# Calculated size for Round 4: 4433.518673202175
# orr termination 0.00823496253685675 0.06746657330116507 0.059231610764308315
# remaining size for Round 5: 133464
# Calculated size for Round 5: 6329.912972825066
# orr termination 0.0447467898775139 0.08924736523622107 0.04450057535870717
# remaining size for last Round 6: 127135
# 10
# ['step1_rr: 9', 'step2_rr: 9', 'step3_rr: 9', 'step4_rr: 9', 'step5_rr: 9', 'step6_rr: 9']
# empirical response rate 0.043037887168141595
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3404.8893784747597
# orr termination 0.009442050762343402 0.055408362297349745 0.04596631153500634
# remaining size for Round 3: 141748
# Calculated size for Round 3: 5588.673459324691
# orr termination 0.04869066012742862 0.06893465027863788 0.020243990151209257
# remaining size for Round 4: 136160
# Calculated size for Round 4: 9946.618082247463
# orr termination 0.049531270154361304 0.0848251047314747 0.035293834577113395
# remaining size for Round 5: 126214
# Calculated size for Round 5: 7294.343235130779
# orr termination 0.05812301874134173 0.08639198485675405 0.028268966115412318
# remaining size for last Round 6: 118920
# 11
# ['step1_rr: 10', 'step2_rr: 10', 'step3_rr: 10', 'step4_rr: 10', 'step5_rr: 10', 'step6_rr: 10']
# empirical response rate 0.03297842920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2728.965581830211
# orr termination 0.0025603828598725928 0.04154029442209928 0.03897991156222669
# remaining size for Round 3: 142424
# Calculated size for Round 3: 3567.611814541365
# orr termination 0.05307608508663847 0.07898547213383136 0.025909387047192894
# remaining size for Round 4: 138857
# Calculated size for Round 4: -72260.4738920903lt 0, break
# 12
# ['step1_rr: 11', 'step2_rr: 11', 'step3_rr: 11', 'step4_rr: 11', 'step5_rr: 11', 'step6_rr: 11']
# empirical response rate 0.034603152654867256
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2837.1791262040406
# orr termination 0.00962685049269408 0.04342156161740496 0.03379471112471088
# remaining size for Round 3: 142315
# Calculated size for Round 3: 4960.177233890004
# orr termination 0.057698869230091335 0.07795486571956566 0.02025599648947432
# remaining size for Round 4: 137355
# Calculated size for Round 4: 15255.265298109985
# orr termination 0.05484040106487344 0.08280994582656266 0.027969544761689225
# remaining size for Round 5: 122100
# Calculated size for Round 5: 6722.632476567337
# orr termination 0.044147328456301656 0.08494588320557146 0.04079855474926981
# remaining size for last Round 6: 115378
# 13
# ['step1_rr: 12', 'step2_rr: 12', 'step3_rr: 12', 'step4_rr: 12', 'step5_rr: 12', 'step6_rr: 12']
# empirical response rate 0.04124032079646018
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3283.0700374646344
# orr termination 0.008304028844925595 0.04527274871730317 0.03696871987237758
# remaining size for Round 3: 141869
# Calculated size for Round 3: 3430.5172517256397
# orr termination 0.04880698890024422 0.06307641721386908 0.014269428313624863
# remaining size for Round 4: 138439
# Calculated size for Round 4: 8866.997734858744
# orr termination 0.005366146331028198 0.09148904005830663 0.08612289372727844
# remaining size for Round 5: 129573
# 14
# ['step1_rr: 13', 'step2_rr: 13', 'step3_rr: 13', 'step4_rr: 13', 'step5_rr: 13', 'step6_rr: 13']
# empirical response rate 0.07079646017699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5342.870662026109
# orr termination 0.030573109355132563 0.06103372007467502 0.03046061071954246
# remaining size for Round 3: 139810
# 15
# ['step1_rr: 14', 'step2_rr: 14', 'step3_rr: 14', 'step4_rr: 14', 'step5_rr: 14', 'step6_rr: 14']
# empirical response rate 0.03135370575221239
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2621.120723895575
# orr termination 0.01728892104912861 0.04434838001197444 0.027059458962845832
# remaining size for Round 3: 142531
# Calculated size for Round 3: 3429.7196101139625
# orr termination 0.029636383686294114 0.04882060881206584 0.019184225125771726
# remaining size for Round 4: 139102
# Calculated size for Round 4: 4231.97417405995
# orr termination 0.01465958231705976 0.049109544636029616 0.03444996231896986
# remaining size for Round 5: 134871
# Calculated size for Round 5: 4145.717547749574
# orr termination 0.005767902332480788 0.07262871573653597 0.06686081340405518
# remaining size for last Round 6: 130726
# 16
# ['step1_rr: 15', 'step2_rr: 15', 'step3_rr: 15', 'step4_rr: 15', 'step5_rr: 15', 'step6_rr: 15']
# empirical response rate 0.07231747787610619
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5452.116013979351
# orr termination 0.019726529719418212 0.0768004141821456 0.05707388446272739
# remaining size for Round 3: 139700
# Calculated size for Round 3: 6380.545089683597
# orr termination 0.013522488780359053 0.09665254714659349 0.08313005836623444
# remaining size for Round 4: 133320
# Calculated size for Round 4: 9683.138106715638
# orr termination 0.06135354271981982 0.09150496962486933 0.03015142690504951
# remaining size for Round 5: 123637
# Calculated size for Round 5: 9758.692232260126
# orr termination 0.045068053096958216 0.09172458191955106 0.046656528822592844
# remaining size for last Round 6: 113879
# 17
# ['step1_rr: 16', 'step2_rr: 16', 'step3_rr: 16', 'step4_rr: 16', 'step5_rr: 16', 'step6_rr: 16']
# empirical response rate 0.02900304203539823
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2465.7425695144257
# orr termination 0.01428356363076784 0.03505114553190625 0.020767581901138407
# remaining size for Round 3: 142687
# Calculated size for Round 3: 3326.1255881533366
# orr termination 0.014441823091517066 0.03904618475969178 0.024604361668174715
# remaining size for Round 4: 139361
# Calculated size for Round 4: 4010.586024554027
# orr termination 0.02313931671888133 0.04235590483850378 0.01921658811962245
# remaining size for Round 5: 135351
# Calculated size for Round 5: 4680.4331595738
# orr termination 0.01040230498628276 0.0610163167071671 0.05061401172088434
# remaining size for last Round 6: 130671
# 18
# ['step1_rr: 17', 'step2_rr: 17', 'step3_rr: 17', 'step4_rr: 17', 'step5_rr: 17', 'step6_rr: 17']
# empirical response rate 0.038682245575221236
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3110.4883281384073
# orr termination 0.021371019519248868 0.04787725582380696 0.026506236304558093
# remaining size for Round 3: 142042
# Calculated size for Round 3: 3763.627917893522
# orr termination 0.007759650830524385 0.05530131677703398 0.0475416659465096
# remaining size for Round 4: 138279
# Calculated size for Round 4: 4870.310606251278
# orr termination 0.040525364091826485 0.07129076349716582 0.03076539940533933
# remaining size for Round 5: 133409
# Calculated size for Round 5: 12071.505360331417
# orr termination 0.022151041394734915 0.08663796643595066 0.06448692504121575
# remaining size for last Round 6: 121338
# 19
# ['step1_rr: 18', 'step2_rr: 18', 'step3_rr: 18', 'step4_rr: 18', 'step5_rr: 18', 'step6_rr: 18']
# empirical response rate 0.04860342920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3784.913012723484
# orr termination 0.010566801639417877 0.058368693123940614 0.04780189148452274
# remaining size for Round 3: 141368
# Calculated size for Round 3: 5370.88820801027
# orr termination 0.0575858601363657 0.065381838927204 0.007795978790838307
# remaining size for Round 4: 135998
# Calculated size for Round 4: 8682.891969305738
# orr termination 0.021867386296631836 0.08303238587488382 0.061164999578251986
# remaining size for Round 5: 127316
# Calculated size for Round 5: 6860.343554343312
# orr termination 0.045322490839669966 0.09169068407586173 0.04636819323619176
# remaining size for last Round 6: 120456
# 20
# ['step1_rr: 19', 'step2_rr: 19', 'step3_rr: 19', 'step4_rr: 19', 'step5_rr: 19', 'step6_rr: 19']
# empirical response rate 0.09053512168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6784.692301555903
# orr termination 0.021936519124619268 0.11695069352537105 0.09501417440075177
# remaining size for Round 3: 138368
# Calculated size for Round 3: 9394.948206567804
# orr termination 0.007229822183076881 0.12822972994411763 0.12099990776104075
# remaining size for Round 4: 128974
# 21
# ['step1_rr: 20', 'step2_rr: 20', 'step3_rr: 20', 'step4_rr: 20', 'step5_rr: 20', 'step6_rr: 20']
# empirical response rate 0.04127488938053098
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3285.4084707208544
# orr termination 0.028169820068022662 0.05047272618391023 0.022302906115887568
# remaining size for Round 3: 141867
# Calculated size for Round 3: 4450.681554190168
# orr termination 0.004816019672953685 0.06390161825017918 0.05908559857722549
# remaining size for Round 4: 137417
# Calculated size for Round 4: 5376.489640931377
# orr termination 0.023464863302182233 0.06961270809797487 0.04614784479579264
# remaining size for Round 5: 132041
# 22
# ['step1_rr: 21', 'step2_rr: 21', 'step3_rr: 21', 'step4_rr: 21', 'step5_rr: 21', 'step6_rr: 21']
# empirical response rate 0.09153761061946902
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6859.296443568507
# orr termination 0.024376515545222268 0.09768927484083646 0.07331275929561419
# remaining size for Round 3: 138293
# Calculated size for Round 3: 6729.085436915234
# orr termination 0.0324124458844921 0.11142115748345538 0.07900871159896328
# remaining size for Round 4: 131564
# Calculated size for Round 4: 10238.600901120104
# orr termination 0.051401077167699684 0.10177636141395896 0.050375284246259276
# remaining size for Round 5: 121326
# Calculated size for Round 5: 9576.919192670575
# orr termination 0.061177331196240206 0.10767196141267543 0.046494630216435226
# remaining size for last Round 6: 111750
# 23
# ['step1_rr: 22', 'step2_rr: 22', 'step3_rr: 22', 'step4_rr: 22', 'step5_rr: 22', 'step6_rr: 22']
# empirical response rate 0.11189850663716815
# remaining size for Round 2: 145152
# Calculated size for Round 2: 8402.348985484643
# orr termination 0.022491431738249655 0.14022729731872502 0.11773586558047536
# remaining size for Round 3: 136750
# Calculated size for Round 3: 10963.4971467573
# orr termination 0.05115403024420781 0.09277683654934259 0.04162280630513478
# remaining size for Round 4: 125787
# Calculated size for Round 4: 8037.650380962329
# orr termination 0.07433031287780693 0.09199963316083093 0.017669320283023995
# remaining size for Round 5: 117750
# Calculated size for Round 5: 7901.449143008994
# orr termination 0.0804890518815634 0.09071576967993633 0.010226717798372933
# remaining size for last Round 6: 109849
# 24
# ['step1_rr: 23', 'step2_rr: 23', 'step3_rr: 23', 'step4_rr: 23', 'step5_rr: 23', 'step6_rr: 23']
# empirical response rate 0.06201603982300885
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4718.387240976126
# orr termination 0.019024120285525838 0.08245528954158234 0.06343116925605649
# remaining size for Round 3: 140434
# Calculated size for Round 3: 6327.01826632648
# orr termination 0.07176318223434415 0.07666112369348514 0.004897941459140992
# remaining size for Round 4: 134107
# Calculated size for Round 4: 8269.043055435695
# orr termination 0.06825367818274977 0.07213407310474071 0.0038803949219909373
# remaining size for Round 5: 125838
# Calculated size for Round 5: 6048.867406811166
# orr termination 0.013811256194199859 0.08655357249368772 0.07274231629948787
# remaining size for last Round 6: 119790
# 25
# ['step1_rr: 24', 'step2_rr: 24', 'step3_rr: 24', 'step4_rr: 24', 'step5_rr: 24', 'step6_rr: 24']
# empirical response rate 0.05008987831858407
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3887.138480086987
# orr termination 0.005683942121193668 0.05623547461161372 0.05055153249042005
# remaining size for Round 3: 141265
# Calculated size for Round 3: 5179.563409623969
# orr termination 0.05214967165277064 0.07330631899125058 0.02115664733847994
# remaining size for Round 4: 136086
# Calculated size for Round 4: 11806.408869377767
# orr termination 0.04975884255882927 0.08244527626086426 0.03268643370203499
# remaining size for Round 5: 124280
# Calculated size for Round 5: 6945.043672995923
# orr termination 0.05763691406036879 0.08499289837783361 0.027355984317464818
# remaining size for last Round 6: 117335
# 26
# ['step1_rr: 25', 'step2_rr: 25', 'step3_rr: 25', 'step4_rr: 25', 'step5_rr: 25', 'step6_rr: 25']
# empirical response rate 0.03297842920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2728.965581830211
# orr termination 0.0030237472862993317 0.046605248218095946 0.043581500931796614
# remaining size for Round 3: 142424
# Calculated size for Round 3: 4556.691527270157
# orr termination 0.0396929843359616 0.060180720303219915 0.020487735967258315
# remaining size for Round 4: 137868
# Calculated size for Round 4: 9771.432366563056
# orr termination 0.04348682869922478 0.07907089481204399 0.03558406611281921
# remaining size for Round 5: 128097
# 27
# ['step1_rr: 26', 'step2_rr: 26', 'step3_rr: 26', 'step4_rr: 26', 'step5_rr: 26', 'step6_rr: 26']
# empirical response rate 0.033842643805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2786.4800847064803
# orr termination 0.012192983525463516 0.0307970436079703 0.018604060082506785
# remaining size for Round 3: 142366
# Calculated size for Round 3: 2936.2247769219875
# orr termination 0.014863934449537 0.041261213331572774 0.026397278882035774
# remaining size for Round 4: 139430
# Calculated size for Round 4: 4370.03599113398
# orr termination 0.02583050205005673 0.05893323704314046 0.033102734993083735
# remaining size for Round 5: 135060
# Calculated size for Round 5: 7631.848047695008
# orr termination 0.05850684728833554 0.0777644502456261 0.019257602957290565
# remaining size for last Round 6: 127429
# 28
# ['step1_rr: 27', 'step2_rr: 27', 'step3_rr: 27', 'step4_rr: 27', 'step5_rr: 27', 'step6_rr: 27']
# empirical response rate 0.06077157079646018
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4630.73167611316
# orr termination 0.035039739832926464 0.06602780863315347 0.030988068800227003
# remaining size for Round 3: 140522
# Calculated size for Round 3: 4841.4538771814905
# orr termination 0.028749461592041906 0.06242052391520502 0.033671062323163116
# remaining size for Round 4: 135681
# Calculated size for Round 4: 4931.583993228385
# orr termination 0.007103670268320405 0.06760392842954024 0.06050025816121984
# remaining size for Round 5: 130750
# Calculated size for Round 5: 5832.583804461504
# orr termination 0.04268138936491313 0.05374570388157919 0.011064314516666063
# remaining size for last Round 6: 124918
# 29
# ['step1_rr: 28', 'step2_rr: 28', 'step3_rr: 28', 'step4_rr: 28', 'step5_rr: 28', 'step6_rr: 28']
# empirical response rate 0.06277654867256637
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4772.059228563532
# orr termination 0.012922388738771964 0.08315245235843488 0.07023006361966291
# remaining size for Round 3: 140380
# Calculated size for Round 3: 7598.994585294884
# orr termination 0.05328215117695002 0.07599751345816705 0.02271536228121703
# remaining size for Round 4: 132782
# Calculated size for Round 4: 8337.892867909582
# orr termination 0.03424159329802289 0.07944080859174793 0.04519921529372504
# remaining size for Round 5: 124445
# Calculated size for Round 5: 6687.944193578222
# orr termination 0.030774074900659216 0.0913683951867964 0.06059432028613719
# remaining size for last Round 6: 117758
# 30
# ['step1_rr: 29', 'step2_rr: 29', 'step3_rr: 29', 'step4_rr: 29', 'step5_rr: 29', 'step6_rr: 29']
# empirical response rate 0.07840154867256637
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5892.22320205354
# orr termination 0.05443656936361722 0.09216631819635951 0.03772974883274229
# remaining size for Round 3: 139260
# Calculated size for Round 3: 8398.386676850309
# orr termination 0.006091189841320755 0.08802181781358295 0.0819306279722622
# remaining size for Round 4: 130862
# Calculated size for Round 4: 6963.732089599746
# orr termination 0.02922078213692005 0.08783898119187934 0.0586181990549593
# remaining size for Round 5: 123899
# 31
# ['step1_rr: 30', 'step2_rr: 30', 'step3_rr: 30', 'step4_rr: 30', 'step5_rr: 30', 'step6_rr: 30']
# empirical response rate 0.07701880530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5791.761187324277
# orr termination 0.04889422010049217 0.09191503757733124 0.04302081747683907
# remaining size for Round 3: 139361
# Calculated size for Round 3: 7046.97726899919
# orr termination 0.04949076698984605 0.09482690905665428 0.04533614206680823
# remaining size for Round 4: 132315
# Calculated size for Round 4: 7440.751418928159
# orr termination 0.03272502705545263 0.0946190419881363 0.061894014932683664
# remaining size for Round 5: 124875
# Calculated size for Round 5: 7706.976050221667
# orr termination 0.044302133409611213 0.09469494520236447 0.05039281179275326
# remaining size for last Round 6: 117169
# 32
# ['step1_rr: 31', 'step2_rr: 31', 'step3_rr: 31', 'step4_rr: 31', 'step5_rr: 31', 'step6_rr: 31']
# empirical response rate 0.08019911504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6023.206915866293
# orr termination 0.05071215961269656 0.08220930248561023 0.03149714287291367
# remaining size for Round 3: 139129
# Calculated size for Round 3: 12278.052910187476
# orr termination 0.051798724679836296 0.08221281994741325 0.030414095267576956
# remaining size for Round 4: 126851
# Calculated size for Round 4: 6728.226614386026
# orr termination 0.01824371750434281 0.08781174172102282 0.06956802421668001
# remaining size for Round 5: 120123
# 33
# ['step1_rr: 32', 'step2_rr: 32', 'step3_rr: 32', 'step4_rr: 32', 'step5_rr: 32', 'step6_rr: 32']
# empirical response rate 0.07892007743362832
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5929.962574211673
# orr termination 0.011451582291323191 0.09015097944138531 0.07869939715006212
# remaining size for Round 3: 139223
# Calculated size for Round 3: 7901.396912937501
# orr termination 0.06216854861510599 0.09353727674633784 0.03136872813123185
# remaining size for Round 4: 131322
# Calculated size for Round 4: 12886.61977803771
# orr termination 0.04840888957353573 0.09637072548003951 0.04796183590650378
# remaining size for Round 5: 118436
# Calculated size for Round 5: 7845.536250751475
# orr termination 0.06749817948314776 0.10023485242582028 0.03273667294267252
# remaining size for last Round 6: 110591
# 34
# ['step1_rr: 33', 'step2_rr: 33', 'step3_rr: 33', 'step4_rr: 33', 'step5_rr: 33', 'step6_rr: 33']
# empirical response rate 0.07159153761061947
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5399.937054375382
# orr termination 0.03702904628129339 0.08212166386396245 0.04509261758266907
# remaining size for Round 3: 139753
# Calculated size for Round 3: 7235.190658187739
# orr termination 0.01972795117494059 0.07721425749483013 0.05748630631988954
# remaining size for Round 4: 132518
# Calculated size for Round 4: 6548.782279535075
# orr termination 0.022419998966820787 0.08970957384410846 0.06728957487728768
# remaining size for Round 5: 125970
# Calculated size for Round 5: 9573.178288190578
# orr termination 0.05022562362123994 0.09922508531195698 0.04899946169071704
# remaining size for last Round 6: 116397
# 35
# ['step1_rr: 34', 'step2_rr: 34', 'step3_rr: 34', 'step4_rr: 34', 'step5_rr: 34', 'step6_rr: 34']
# empirical response rate 0.08182383849557522
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6141.967523856308
# orr termination 0.01399570194793024 0.07645112814755589 0.06245542619962565
# remaining size for Round 3: 139011
# Calculated size for Round 3: 5202.860579157778
# orr termination 0.043231606367509084 0.08159119738035386 0.03835959101284478
# remaining size for Round 4: 133809
# Calculated size for Round 4: 8625.249958717926
# orr termination 0.07649783165930775 0.08130987750243428 0.004812045843126528
# remaining size for Round 5: 125184
# Calculated size for Round 5: 7464.701075240893
# orr termination 0.054526455044347 0.09014581535694616 0.03561936031259916
# remaining size for last Round 6: 117720
# 36
# ['step1_rr: 35', 'step2_rr: 35', 'step3_rr: 35', 'step4_rr: 35', 'step5_rr: 35', 'step6_rr: 35']
# empirical response rate 0.04206996681415929
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3339.2384022405945
# orr termination 0.036494839771520966 0.05223685580178701 0.015742016030266044
# remaining size for Round 3: 141813
# Calculated size for Round 3: 4302.207990589194
# orr termination 0.03826376247292253 0.05263585700603167 0.014372094533109142
# remaining size for Round 4: 137511
# Calculated size for Round 4: 4599.575805240423
# orr termination 0.002445839056907002 0.05897322102059521 0.05652738196368821
# remaining size for Round 5: 132912
# Calculated size for Round 5: 4555.749731645183
# orr termination 0.04015545758927542 0.08025308411075115 0.04009762652147573
# remaining size for last Round 6: 128357
# 37
# ['step1_rr: 36', 'step2_rr: 36', 'step3_rr: 36', 'step4_rr: 36', 'step5_rr: 36', 'step6_rr: 36']
# empirical response rate 0.04580337389380531
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3593.182438999496
# orr termination 0.01661810206115596 0.06494830835616834 0.048330206295012376
# remaining size for Round 3: 141559
# Calculated size for Round 3: 5193.351526344017
# orr termination 0.006798353886243377 0.0723626364019856 0.06556428251574223
# remaining size for Round 4: 136366
# Calculated size for Round 4: 7228.702726943522
# orr termination 0.028349199315258176 0.08512349591552479 0.056774296600266616
# remaining size for Round 5: 129138
# 38
# ['step1_rr: 37', 'step2_rr: 37', 'step3_rr: 37', 'step4_rr: 37', 'step5_rr: 37', 'step6_rr: 37']
# empirical response rate 0.047912057522123894
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3737.4708232996927
# orr termination 0.016627014830309372 0.05994530051185367 0.0433182856815443
# remaining size for Round 3: 141415
# Calculated size for Round 3: 4542.963633662381
# orr termination 0.032733600276345746 0.06423080562627004 0.03149720534992429
# remaining size for Round 4: 136873
# Calculated size for Round 4: 6299.074305892517
# orr termination 0.036138462038782806 0.08351577473789973 0.04737731269911692
# remaining size for Round 5: 130574
# Calculated size for Round 5: 8268.513962727471
# orr termination 0.025020745667182643 0.10005540857370315 0.07503466290652051
# remaining size for last Round 6: 122306
# 39
# ['step1_rr: 38', 'step2_rr: 38', 'step3_rr: 38', 'step4_rr: 38', 'step5_rr: 38', 'step6_rr: 38']
# empirical response rate 0.07466814159292036
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5621.565807308865
# orr termination 0.026211855023906376 0.07197017471554168 0.0457583196916353
# remaining size for Round 3: 139531
# Calculated size for Round 3: 7898.926270635451
# orr termination 0.019956642337085675 0.07862121435258107 0.058664572015495395
# remaining size for Round 4: 131633
# Calculated size for Round 4: 7357.531908881871
# orr termination 0.04412917295452747 0.08823894318940287 0.044109770234875396
# remaining size for Round 5: 124276
# 40
# ['step1_rr: 39', 'step2_rr: 39', 'step3_rr: 39', 'step4_rr: 39', 'step5_rr: 39', 'step6_rr: 39']
# empirical response rate 0.06301852876106195
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4789.153321772453
# orr termination 0.037226356644874614 0.06863130309312118 0.03140494644824657
# remaining size for Round 3: 140363
# Calculated size for Round 3: 5351.257531722074
# orr termination 0.003004115161288917 0.08878927819007233 0.08578516302878342
# remaining size for Round 4: 135012
# Calculated size for Round 4: 6683.677769362192
# orr termination 0.049923441052711584 0.1008283857604914 0.050904944707779815
# remaining size for Round 5: 128329
# 41
# ['step1_rr: 40', 'step2_rr: 40', 'step3_rr: 40', 'step4_rr: 40', 'step5_rr: 40', 'step6_rr: 40']
# empirical response rate 0.0742878871681416
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5594.104185697372
# orr termination 0.004958616453979594 0.08115439095978719 0.0761957745058076
# remaining size for Round 3: 139558
# Calculated size for Round 3: 7759.6188734844145
# orr termination 0.04411614574707683 0.08823045932065825 0.044114313573581414
# remaining size for Round 4: 131799
# 42
# ['step1_rr: 41', 'step2_rr: 41', 'step3_rr: 41', 'step4_rr: 41', 'step5_rr: 41', 'step6_rr: 41']
# empirical response rate 0.05403069690265487
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4159.637779672868
# orr termination 0.010590527931756839 0.06031665003630231 0.04972612210454547
# remaining size for Round 3: 140993
# Calculated size for Round 3: 7735.985102550607
# orr termination 0.02374175869562502 0.0729711160056729 0.04922935731004788
# remaining size for Round 4: 133258
# 43
# ['step1_rr: 42', 'step2_rr: 42', 'step3_rr: 42', 'step4_rr: 42', 'step5_rr: 42', 'step6_rr: 42']
# empirical response rate 0.05517146017699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# orr termination 0.011974438920392258 0.06360531803449156 0.0516308791140993
# remaining size for Round 3: 140914
# Calculated size for Round 3: 5238.501172688422
# orr termination 0.004165445882120738 0.07957328732601361 0.07540784144389287
# remaining size for Round 4: 135676
# 44
# ['step1_rr: 43', 'step2_rr: 43', 'step3_rr: 43', 'step4_rr: 43', 'step5_rr: 43', 'step6_rr: 43']
# empirical response rate 0.04348727876106195
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3435.414549437817
# orr termination 0.02507817331430745 0.04655055296757159 0.021472379653264137
# remaining size for Round 3: 141717
# Calculated size for Round 3: 3590.2120066214393
# orr termination 0.004909320215748373 0.05286523125147648 0.047955911035728105
# remaining size for Round 4: 138127
# Calculated size for Round 4: 4024.2379821373347
# orr termination 0.03452785831274338 0.04508887259600233 0.010561014283258952
# remaining size for Round 5: 134103
# Calculated size for Round 5: 5405.190839437282
# orr termination 0.042776524890509295 0.05750998041379015 0.014733455523280856
# remaining size for last Round 6: 128698
# 45
# ['step1_rr: 44', 'step2_rr: 44', 'step3_rr: 44', 'step4_rr: 44', 'step5_rr: 44', 'step6_rr: 44']
# empirical response rate 0.052751659292035395
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4070.959200908221
# orr termination 0.0395640883898489 0.04867200631080212 0.009107917920953217
# remaining size for Round 3: 141082
# Calculated size for Round 3: 3823.2139400633737
# orr termination 0.030283175507531897 0.048829656537425666 0.018546481029893768
# remaining size for Round 4: 137259
# Calculated size for Round 4: 3719.5555034441177
# orr termination 0.02338050116436806 0.05431382663840159 0.030933325474033532
# remaining size for Round 5: 133540
# Calculated size for Round 5: 4169.391986182339
# orr termination 0.006992632874472056 0.06852324209719474 0.06153060922272268
# remaining size for last Round 6: 129371
# 46
# ['step1_rr: 45', 'step2_rr: 45', 'step3_rr: 45', 'step4_rr: 45', 'step5_rr: 45', 'step6_rr: 45']
# empirical response rate 0.08092505530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6076.226646023446
# orr termination 0.062037620183984205 0.10375498581653367 0.041717365632549464
# remaining size for Round 3: 139076
# Calculated size for Round 3: 10380.504440983543
# orr termination 0.02918238938334311 0.10851641740464894 0.07933402802130583
# remaining size for Round 4: 128696
# Calculated size for Round 4: 8427.58338660531
# orr termination 0.05027192069927897 0.09703780937312778 0.04676588867384881
# remaining size for Round 5: 120269
# Calculated size for Round 5: 8551.80738271094
# orr termination 0.04287820267284541 0.08754966648394286 0.04467146381109745
# remaining size for last Round 6: 111718
# 47
# ['step1_rr: 46', 'step2_rr: 46', 'step3_rr: 46', 'step4_rr: 46', 'step5_rr: 46', 'step6_rr: 46']
# empirical response rate 0.047428097345132744
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3704.3008047850903
# orr termination 0.005995116480795164 0.053837214186299436 0.04784209770550427
# remaining size for Round 3: 141448
# Calculated size for Round 3: 5476.864696577217
# orr termination 0.041910661902736346 0.056217842230534665 0.014307180327798319
# remaining size for Round 4: 135972
# Calculated size for Round 4: 7061.040607234011
# orr termination 0.0283375767096774 0.08042976073770047 0.05209218402802307
# remaining size for Round 5: 128911
# 48
# ['step1_rr: 47', 'step2_rr: 47', 'step3_rr: 47', 'step4_rr: 47', 'step5_rr: 47', 'step6_rr: 47']
# empirical response rate 0.0380945796460177
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3070.9700987965853
# orr termination 0.009414725304206204 0.05035835005715936 0.040943624752953156
# remaining size for Round 3: 142082
# Calculated size for Round 3: 5295.42852010797
# orr termination 0.03009798532407716 0.06905288792029553 0.038954902596218366
# remaining size for Round 4: 136787
# Calculated size for Round 4: 9457.46859869937
# orr termination 0.052841917838905156 0.07957803090469581 0.026736113065790656
# remaining size for Round 5: 127330
# Calculated size for Round 5: 7330.047632517416
# orr termination 0.04329344696078983 0.0815890811174427 0.03829563415665287
# remaining size for last Round 6: 120000
# 49
# ['step1_rr: 48', 'step2_rr: 48', 'step3_rr: 48', 'step4_rr: 48', 'step5_rr: 48', 'step6_rr: 48']
# empirical response rate 0.04846515486725664
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3775.4192631143214
# orr termination 0.0022893156697620354 0.040949291701562474 0.038659976031800436
# remaining size for Round 3: 141377
# Calculated size for Round 3: 3430.23990364857
# orr termination 0.012615676235193708 0.06356074066625915 0.050945064431065445
# remaining size for Round 4: 137947
# 50
# ['step1_rr: 49', 'step2_rr: 49', 'step3_rr: 49', 'step4_rr: 49', 'step5_rr: 49', 'step6_rr: 49']
# empirical response rate 0.03373893805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2779.5728369589106
# orr termination 0.005441538039870176 0.041055401570935256 0.035613863531065076
# remaining size for Round 3: 142373
# Calculated size for Round 3: 3585.534835173047
# orr termination 0.028383315024843835 0.05724781423174298 0.028864499206899145
# remaining size for Round 4: 138788
# Calculated size for Round 4: 14271.446937044953
# orr termination 0.053318863210916695 0.0796413370605313 0.0263224738496146
# remaining size for Round 5: 124517
# Calculated size for Round 5: 6577.364829391932
# orr termination 0.04219739586581129 0.08029503473401102 0.03809763886819973
# remaining size for last Round 6: 117940
# 51
# ['step1_rr: 50', 'step2_rr: 50', 'step3_rr: 50', 'step4_rr: 50', 'step5_rr: 50', 'step6_rr: 50']
# empirical response rate 0.04535398230088496
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3562.51238662459
# orr termination 0.010014411527048826 0.05002096958950487 0.04000655806245604
# remaining size for Round 3: 141590
# Calculated size for Round 3: 3690.1736190514457
# orr termination 0.004735394036218736 0.06958377068414107 0.06484837664792233
# remaining size for Round 4: 137900
# Calculated size for Round 4: 6893.123540466159
# orr termination 0.03929866970186341 0.07932470999035175 0.04002604028848834
# remaining size for Round 5: 131007
# 52
# ['step1_rr: 51', 'step2_rr: 51', 'step3_rr: 51', 'step4_rr: 51', 'step5_rr: 51', 'step6_rr: 51']
# empirical response rate 0.040860066371681415
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3257.3582653305953
# orr termination 0.01462221587132728 0.05726310584880076 0.04264088997747348
# remaining size for Round 3: 141895
# Calculated size for Round 3: 4497.054664192681
# orr termination 0.03457180223403922 0.050907032294258706 0.01633523006021949
# remaining size for Round 4: 137398
# Calculated size for Round 4: 5457.807270365111
# orr termination 0.017016891237156634 0.051107042691800324 0.03409015145464369
# remaining size for Round 5: 131941
# Calculated size for Round 5: 4429.5391920491775
# orr termination 0.035046506219224206 0.06116343326670077 0.026116927047476562
# remaining size for last Round 6: 127512
# 53
# ['step1_rr: 52', 'step2_rr: 52', 'step3_rr: 52', 'step4_rr: 52', 'step5_rr: 52', 'step6_rr: 52']
# empirical response rate 0.07584347345132743
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5706.570481819797
# orr termination 0.013337592178523677 0.08095652824999548 0.0676189360714718
# remaining size for Round 3: 139446
# Calculated size for Round 3: 10296.562690760711
# orr termination 0.03645389939370952 0.07302593093950906 0.036572031545799535
# remaining size for Round 4: 129150
# Calculated size for Round 4: 6571.43552888624
# orr termination 0.039332857842814165 0.08048399495081154 0.04115113710799738
# remaining size for Round 5: 122579
# 54
# ['step1_rr: 53', 'step2_rr: 53', 'step3_rr: 53', 'step4_rr: 53', 'step5_rr: 53', 'step6_rr: 53']
# empirical response rate 0.06319137168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4801.3683051580465
# orr termination 0.008362415481326687 0.07591713253918818 0.0675547170578615
# remaining size for Round 3: 140351
# Calculated size for Round 3: 7356.750770346516
# orr termination 0.0599199062803882 0.07964011946408514 0.01972021318369694
# remaining size for Round 4: 132995
# Calculated size for Round 4: 10194.228886283707
# orr termination 0.05449947681691948 0.0802828628916736 0.025783386074754125
# remaining size for Round 5: 122801
# Calculated size for Round 5: 6689.537106158891
# orr termination 0.04073111491374608 0.08090802831534219 0.04017691340159611
# remaining size for last Round 6: 116112
# 55
# ['step1_rr: 54', 'step2_rr: 54', 'step3_rr: 54', 'step4_rr: 54', 'step5_rr: 54', 'step6_rr: 54']
# empirical response rate 0.0351908185840708
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2876.4109738220563
# orr termination 0.005967810639825542 0.04954211943396312 0.043574308794137574
# remaining size for Round 3: 142276
# Calculated size for Round 3: 3661.510530120447
# orr termination 0.037651834253182394 0.05361808130772773 0.015966247054545336
# remaining size for Round 4: 138615
# Calculated size for Round 4: 7094.187779623235
# orr termination 0.028340299511036046 0.06541285322016113 0.037072553709125086
# remaining size for Round 5: 131521
# Calculated size for Round 5: 5831.007919324934
# orr termination 0.02489583025150255 0.07181199110935685 0.0469161608578543
# remaining size for last Round 6: 125690
# 56
# ['step1_rr: 55', 'step2_rr: 55', 'step3_rr: 55', 'step4_rr: 55', 'step5_rr: 55', 'step6_rr: 55']
# empirical response rate 0.04421321902654867
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3484.783847425881
# orr termination 0.011895230937494786 0.05371542166360237 0.041820190726107584
# remaining size for Round 3: 141668
# Calculated size for Round 3: 4098.610347069612
# orr termination 0.03443409142413188 0.06756120230124997 0.03312711087711809
# remaining size for Round 4: 137570
# Calculated size for Round 4: 7720.993035770307
# orr termination 0.0421098950885776 0.0870814354875126 0.044971540398935
# remaining size for Round 5: 129850
# Calculated size for Round 5: 8944.043271228833
# orr termination 0.07198876393566923 0.09538401114702848 0.023395247211359244
# remaining size for last Round 6: 120906
# 57
# ['step1_rr: 56', 'step2_rr: 56', 'step3_rr: 56', 'step4_rr: 56', 'step5_rr: 56', 'step6_rr: 56']
# empirical response rate 0.06319137168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4801.3683051580465
# orr termination 0.023992842442027415 0.06560066378002669 0.04160782133799927
# remaining size for Round 3: 140351
# Calculated size for Round 3: 4699.066243939747
# orr termination 0.0017306218660592333 0.07421600788673409 0.07248538602067485
# remaining size for Round 4: 135652
# Calculated size for Round 4: 5551.677705311481
# orr termination 0.029853076874133865 0.0600203868449312 0.030167309970797338
# remaining size for Round 5: 130101
# 58
# ['step1_rr: 57', 'step2_rr: 57', 'step3_rr: 57', 'step4_rr: 57', 'step5_rr: 57', 'step6_rr: 57']
# empirical response rate 0.058351769911504425
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4460.900082113275
# orr termination 0.02649852346094448 0.06882331745708353 0.04232479399613905
# remaining size for Round 3: 140692
# Calculated size for Round 3: 6350.340656466429
# orr termination 0.02427985084837741 0.07502559789340302 0.05074574704502561
# remaining size for Round 4: 134342
# Calculated size for Round 4: 6903.78852154969
# orr termination 0.018275779552772188 0.06359223356078685 0.04531645400801466
# remaining size for Round 5: 127439
# Calculated size for Round 5: 6111.101572744421
# orr termination 0.038284474716517886 0.07617950594854496 0.037895031232027074
# remaining size for last Round 6: 121328
# 59
# ['step1_rr: 58', 'step2_rr: 58', 'step3_rr: 58', 'step4_rr: 58', 'step5_rr: 58', 'step6_rr: 58']
# empirical response rate 0.03484513274336283
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2853.327576480575
# orr termination 0.005123958790887145 0.04066479680508452 0.03554083801419738
# remaining size for Round 3: 142299
# Calculated size for Round 3: 3650.8066542849156
# orr termination 0.03376099544531025 0.06115948483026486 0.027398489384954608
# remaining size for Round 4: 138649
# Calculated size for Round 4: 10460.484350367187
# orr termination 0.033060015391250384 0.08029226241485432 0.047232247023603936
# remaining size for Round 5: 128189
# Calculated size for Round 5: 6804.21372041014
# orr termination 0.04620970152976976 0.09228345605157565 0.046073754521805885
# remaining size for last Round 6: 121385
# 60
# ['step1_rr: 59', 'step2_rr: 59', 'step3_rr: 59', 'step4_rr: 59', 'step5_rr: 59', 'step6_rr: 59']
# empirical response rate 0.04473174778761062
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3520.0925493885147
# orr termination 0.003388941039202576 0.054439749244740904 0.051050808205538326
# remaining size for Round 3: 141632
# Calculated size for Round 3: 4466.179716143474
# orr termination 0.010995376888313388 0.05531054512746906 0.04431516823915567
# remaining size for Round 4: 137166
# 61
# ['step1_rr: 60', 'step2_rr: 60', 'step3_rr: 60', 'step4_rr: 60', 'step5_rr: 60', 'step6_rr: 60']
# empirical response rate 0.0829991703539823
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6228.098665219812
# orr termination 0.069361110470196 0.0909825585716775 0.021621448101481505
# remaining size for Round 3: 138924
# Calculated size for Round 3: 7758.211456296006
# orr termination 0.012699946899964438 0.10851421377673896 0.09581426687677452
# remaining size for Round 4: 131166
# Calculated size for Round 4: 7618.231359958234
# orr termination 0.03317144781978714 0.08848951623026133 0.05531806841047419
# remaining size for Round 5: 123548
# Calculated size for Round 5: 8690.610248495279
# orr termination 0.06272398950208949 0.09575093514851046 0.033026945646420974
# remaining size for last Round 6: 114858
# 62
# ['step1_rr: 61', 'step2_rr: 61', 'step3_rr: 61', 'step4_rr: 61', 'step5_rr: 61', 'step6_rr: 61']
# empirical response rate 0.06495436946902655
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4926.194977591092
# orr termination 0.04350890671811705 0.07304065766540346 0.02953175094728641
# remaining size for Round 3: 140226
# Calculated size for Round 3: 6306.869880362534
# orr termination 0.012077859025684 0.08948905016583207 0.07741119114014808
# remaining size for Round 4: 133920
# Calculated size for Round 4: 7335.060301790494
# orr termination 0.06737262254385687 0.08187184600759972 0.014499223463742855
# remaining size for Round 5: 126585
# Calculated size for Round 5: 9116.286724502736
# orr termination 0.05501656409303415 0.0845378737929702 0.029521309699936056
# remaining size for last Round 6: 117469
# 63
# ['step1_rr: 62', 'step2_rr: 62', 'step3_rr: 62', 'step4_rr: 62', 'step5_rr: 62', 'step6_rr: 62']
# empirical response rate 0.08472759955752213
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6355.095390744717
# orr termination 0.05941498839627944 0.09494796742164391 0.03553297902536447
# remaining size for Round 3: 138797
# Calculated size for Round 3: 10492.256965792982
# orr termination 0.01785052621320065 0.09225808875998016 0.07440756254677952
# remaining size for Round 4: 128305
# Calculated size for Round 4: 7080.425939165036
# orr termination 0.051022317386674045 0.10150153826002342 0.05047922087334938
# remaining size for Round 5: 121225
# Calculated size for Round 5: 11348.50248915372
# orr termination 0.05240907549771747 0.1023859461648719 0.04997687066715443
# remaining size for last Round 6: 109877
# 64
# ['step1_rr: 63', 'step2_rr: 63', 'step3_rr: 63', 'step4_rr: 63', 'step5_rr: 63', 'step6_rr: 63']
# empirical response rate 0.06993224557522124
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5280.93931401423
# orr termination 0.0502736087544519 0.06680810616430125 0.016534497409849344
# remaining size for Round 3: 139872
# Calculated size for Round 3: 12309.33381273783
# orr termination 0.03786853552979085 0.07569713068562636 0.03782859515583551
# remaining size for Round 4: 127563
# Calculated size for Round 4: 6169.510745212164
# orr termination 0.030953077960083113 0.0913778196072503 0.06042474164716719
# remaining size for Round 5: 121394
# 65
# ['step1_rr: 64', 'step2_rr: 64', 'step3_rr: 64', 'step4_rr: 64', 'step5_rr: 64', 'step6_rr: 64']
# empirical response rate 0.08856471238938053
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6638.439402074498
# orr termination 0.0258496086901594 0.09086206774006061 0.06501245904990122
# remaining size for Round 3: 138514
# Calculated size for Round 3: 6260.003114870894
# orr termination 0.030645270015335138 0.10398193130096006 0.07333666128562492
# remaining size for Round 4: 132254
# Calculated size for Round 4: 8366.614936024764
# orr termination 0.009854335738811507 0.09689361596466423 0.08703928022585272
# remaining size for Round 5: 123888
# Calculated size for Round 5: 9160.048946342835
# orr termination 0.03844247326122615 0.07750142628265674 0.039058953021430594
# remaining size for last Round 6: 114728
# 66
# ...
# remaining size for last Round 6: 121232
# 80
# ['step1_rr: 79', 'step2_rr: 79', 'step3_rr: 79', 'step4_rr: 79', 'step5_rr: 79', 'step6_rr: 79']
# empirical response rate 0.03277101769911504
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2715.177622674948
# orr termination 0.0041420145235807355 0.039648363062873136 0.0355063485392924
# remaining size for Round 3: 142437
# Calculated size for Round 3: 3342.628448769671
# orr termination 0.04140055825052623 0.062328217593058094 0.020927659342531865
# remaining size for Round 4: 139095
# Calculated size for Round 4: 15732.054128107186
# orr termination 0.070064171147726 0.0830930001800467 0.013028829032320693
# remaining size for Round 5: 123363
# Calculated size for Round 5: 6334.191994415388
# orr termination 0.0611925297697927 0.09607930497202208 0.03488677520222938
# remaining size for last Round 6: 117029
# 81
# ['step1_rr: 80', 'step2_rr: 80', 'step3_rr: 80', 'step4_rr: 80', 'step5_rr: 80', 'step6_rr: 80']
# empirical response rate 0.03723036504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3012.9425926886643
# orr termination 0.005463602794633314 0.05668248288046979 0.05121888008583647
# remaining size for Round 3: 142140
# Calculated size for Round 3: 7494.429524051839
# orr termination 0.03462200997856478 0.06983816640564552 0.035216156427080744
# remaining size for Round 4: 134646
# 82
# ['step1_rr: 81', 'step2_rr: 81', 'step3_rr: 81', 'step4_rr: 81', 'step5_rr: 81', 'step6_rr: 81']
# empirical response rate 0.0478083517699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3730.3602223395455
# orr termination 0.0395329736233396 0.061214437915750666 0.021681464292411065
# remaining size for Round 3: 141422
# Calculated size for Round 3: 4588.062009222833
# orr termination 0.022343015351048292 0.06420083942129778 0.04185782407024949
# remaining size for Round 4: 136834
# Calculated size for Round 4: 4955.0058310110935
# orr termination 0.008278869200574836 0.06827267388363153 0.0599938046830567
# remaining size for Round 5: 131879
# Calculated size for Round 5: 6077.501055736596
# orr termination 0.023869231497805843 0.09447106351049663 0.07060183201269078
# remaining size for last Round 6: 125802
# 83
# ['step1_rr: 82', 'step2_rr: 82', 'step3_rr: 82', 'step4_rr: 82', 'step5_rr: 82', 'step6_rr: 82']
# empirical response rate 0.08877212389380532
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6653.810492694055
# orr termination 0.020805050042020497 0.10566462398017099 0.0848595739381505
# remaining size for Round 3: 138499
# Calculated size for Round 3: 7887.351123070358
# orr termination 0.018884063781800454 0.10232325593207246 0.08343919215027201
# remaining size for Round 4: 130612
# Calculated size for Round 4: 9677.709318363306
# orr termination 0.04910407720450227 0.09771072431960645 0.04860664711510418
# remaining size for Round 5: 120935
# Calculated size for Round 5: 10678.030751545672
# orr termination 0.05463068589369485 0.108874429781042 0.05424374388734715
# remaining size for last Round 6: 110257
# 84
# ['step1_rr: 83', 'step2_rr: 83', 'step3_rr: 83', 'step4_rr: 83', 'step5_rr: 83', 'step6_rr: 83']
# empirical response rate 0.03854397123893805
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3101.1855865909392
# orr termination 0.007557307163791195 0.04683638309959377 0.03927907593580258
# remaining size for Round 3: 142051
# Calculated size for Round 3: 3373.288325360517
# orr termination 0.024606589184740117 0.06608766311651354 0.04148107393177342
# remaining size for Round 4: 138678
# Calculated size for Round 4: 8745.241652622506
# orr termination 0.050330314284683306 0.0910442991582684 0.04071398487358509
# remaining size for Round 5: 129933
# Calculated size for Round 5: 9052.46110516043
# orr termination 0.06397584021987957 0.10739292469940322 0.04341708447952365
# remaining size for last Round 6: 120881
# 85
# ['step1_rr: 84', 'step2_rr: 84', 'step3_rr: 84', 'step4_rr: 84', 'step5_rr: 84', 'step6_rr: 84']
# empirical response rate 0.036297013274336286
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2950.3899597530917
# orr termination 0.0011045787469195227 0.04043240175059797 0.03932782300367845
# remaining size for Round 3: 142202
# Calculated size for Round 3: 3080.3468808108737
# orr termination 0.018370961871974324 0.03678111712990753 0.018410155257933207
# remaining size for Round 4: 139122
# Calculated size for Round 4: 6229.641660639682
# orr termination 0.02457650409770876 0.048480365139908485 0.023903861042199725
# remaining size for Round 5: 132893
# 86
# ['step1_rr: 85', 'step2_rr: 85', 'step3_rr: 85', 'step4_rr: 85', 'step5_rr: 85', 'step6_rr: 85']
# empirical response rate 0.05935425884955752
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4531.161082702762
# orr termination 0.024049286194656926 0.05853020815049171 0.034480921955834784
# remaining size for Round 3: 140621
# Calculated size for Round 3: 4920.288761637603
# orr termination 0.02214230560668589 0.07316493008614186 0.05102262447945597
# remaining size for Round 4: 135701
# Calculated size for Round 4: 6497.314034680624
# orr termination 0.07222581850376394 0.09053937683953983 0.018313558335775887
# remaining size for Round 5: 129204
# Calculated size for Round 5: 10745.10915045468
# orr termination 0.04992719039299709 0.09748271783407297 0.047555527441075884
# remaining size for last Round 6: 118459
# 87
# ['step1_rr: 86', 'step2_rr: 86', 'step3_rr: 86', 'step4_rr: 86', 'step5_rr: 86', 'step6_rr: 86']
# empirical response rate 0.03125
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2614.249528775035
# orr termination 0.011149828146359887 0.039036743008965216 0.02788691486260533
# remaining size for Round 3: 142538
# Calculated size for Round 3: 3134.201807931271
# orr termination 0.015656496241930506 0.04614544884024456 0.030488952598314054
# remaining size for Round 4: 139404
# Calculated size for Round 4: 4843.358076046282
# orr termination 0.014109404469080274 0.06504248155085798 0.05093307708177771
# remaining size for Round 5: 134561
# Calculated size for Round 5: 7921.751408228277
# orr termination 0.03965778170708011 0.08092489499863983 0.04126711329155972
# remaining size for last Round 6: 126640
# 88
# ['step1_rr: 87', 'step2_rr: 87', 'step3_rr: 87', 'step4_rr: 87', 'step5_rr: 87', 'step6_rr: 87']
# empirical response rate 0.059596238938053096
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4548.141371331619
# orr termination 0.053031859747718 0.07493261426546188 0.021900754517743884
# remaining size for Round 3: 140604
# Calculated size for Round 3: 5741.9784758452515
# orr termination 0.01918809549041032 0.08978587511516115 0.07059777962475083
# remaining size for Round 4: 134863
# Calculated size for Round 4: 6387.360397821429
# orr termination 0.02841909402067526 0.09719886727805274 0.06877977325737748
# remaining size for Round 5: 128476
# Calculated size for Round 5: 9598.708419843895
# orr termination 0.08459846300057636 0.09933630678058072 0.014737843780004367
# remaining size for last Round 6: 118878
# 89
# ['step1_rr: 88', 'step2_rr: 88', 'step3_rr: 88', 'step4_rr: 88', 'step5_rr: 88', 'step6_rr: 88']
# empirical response rate 0.055689988938053096
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4275.017492939368
# orr termination 0.017999371503178353 0.05572418150644403 0.03772481000326568
# remaining size for Round 3: 140877
# Calculated size for Round 3: 4752.380201201703
# orr termination 0.022338252035333482 0.06538478168424183 0.04304652964890835
# remaining size for Round 4: 136125
# Calculated size for Round 4: 6304.0640834210335
# orr termination 0.020369431480185593 0.0747215267318147 0.05435209525162911
# remaining size for Round 5: 129821
# Calculated size for Round 5: 6999.924145813619
# orr termination 0.027167260182986975 0.08278579494433813 0.05561853476135116
# remaining size for last Round 6: 122822
# 90
# ['step1_rr: 89', 'step2_rr: 89', 'step3_rr: 89', 'step4_rr: 89', 'step5_rr: 89', 'step6_rr: 89']
# empirical response rate 0.06063329646017699
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4621.005307393422
# orr termination 0.04657628150630521 0.06985512234597077 0.02327884083966556
# remaining size for Round 3: 140531
# Calculated size for Round 3: 5931.965834902753
# orr termination 0.017648759245461894 0.08391891231463122 0.06627015306916934
# remaining size for Round 4: 134600
# Calculated size for Round 4: 6701.310332167807
# orr termination 0.011457434601929826 0.06924560110564207 0.05778816650371224
# remaining size for Round 5: 127899
# Calculated size for Round 5: 7012.200062428396
# orr termination 0.03498675945150374 0.06937764936344451 0.03439088991194077
# remaining size for last Round 6: 120887
# 91
# ['step1_rr: 90', 'step2_rr: 90', 'step3_rr: 90', 'step4_rr: 90', 'step5_rr: 90', 'step6_rr: 90']
# empirical response rate 0.06457411504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4899.235573728013
# orr termination 0.005155668024796868 0.06356671132471346 0.058411043299916594
# remaining size for Round 3: 140253
# Calculated size for Round 3: 4420.316379126449
# orr termination 0.004804784332211816 0.07741042354900819 0.07260563921679637
# remaining size for Round 4: 135833
# 92
# ['step1_rr: 91', 'step2_rr: 91', 'step3_rr: 91', 'step4_rr: 91', 'step5_rr: 91', 'step6_rr: 91']
# empirical response rate 0.049571349557522126
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3851.4435988971077
# orr termination 0.031736864797003765 0.05555818249417062 0.023821317697166854
# remaining size for Round 3: 141301
# Calculated size for Round 3: 4478.8491806225065
# orr termination 0.018628452512142 0.059511399468672885 0.040882946956530886
# remaining size for Round 4: 136823
# Calculated size for Round 4: 4749.7782626364915
# orr termination 0.008907288212918262 0.06592813567405689 0.05702084746113863
# remaining size for Round 5: 132074
# Calculated size for Round 5: 6494.488257277593
# orr termination 0.05327809862097146 0.08072866985759022 0.027450571236618766
# remaining size for last Round 6: 125580
# 93
# ['step1_rr: 92', 'step2_rr: 92', 'step3_rr: 92', 'step4_rr: 92', 'step5_rr: 92', 'step6_rr: 92']
# empirical response rate 0.05441095132743363
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4186.045338423161
# orr termination 0.017705662983115288 0.05782131685368877 0.04011565387057348
# remaining size for Round 3: 140966
# Calculated size for Round 3: 4216.682781449689
# orr termination 0.026497228631733663 0.06598723090246303 0.039490002270729366
# remaining size for Round 4: 136750
# Calculated size for Round 4: 6152.154360814076
# orr termination 0.042026721019497094 0.07036329529839407 0.02833657427889697
# remaining size for Round 5: 130598
# Calculated size for Round 5: 7220.092406887674
# orr termination 0.06050270736661115 0.0766408617860749 0.016138154419463757
# remaining size for last Round 6: 123378
# 94
# ['step1_rr: 93', 'step2_rr: 93', 'step3_rr: 93', 'step4_rr: 93', 'step5_rr: 93', 'step6_rr: 93']
# empirical response rate 0.05416897123893805
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4169.2382140388045
# orr termination 0.016253395078938863 0.06599021377169743 0.049736818692758575
# remaining size for Round 3: 140983
# Calculated size for Round 3: 5084.401620238621
# orr termination 0.016177888888036465 0.08352571463795948 0.06734782574992301
# remaining size for Round 4: 135899
# Calculated size for Round 4: 9210.263708104409
# orr termination 0.06697457874101585 0.08341957135095285 0.016444992609936995
# remaining size for Round 5: 126689
# Calculated size for Round 5: 8589.747348772413
# orr termination 0.04316606059407674 0.08834283438399121 0.04517677378991447
# remaining size for last Round 6: 118100
# 95
# ['step1_rr: 94', 'step2_rr: 94', 'step3_rr: 94', 'step4_rr: 94', 'step5_rr: 94', 'step6_rr: 94']
# empirical response rate 0.02623755530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2283.933061815767
# orr termination 0.008422428605072512 0.038520403939833636 0.030097975334761124
# remaining size for Round 3: 142869
# Calculated size for Round 3: 3951.853458997438
# orr termination 0.03924633198891474 0.05523008091631364 0.0159837489273989
# remaining size for Round 4: 138918
# Calculated size for Round 4: 8860.974928080812
# orr termination 0.03027310443644818 0.0727362767406958 0.04246317230424762
# remaining size for Round 5: 130058
# Calculated size for Round 5: 6639.710696989922
# orr termination 0.040316647385584534 0.07980478030541117 0.03948813291982664
# remaining size for last Round 6: 123419
# 96
# ['step1_rr: 95', 'step2_rr: 95', 'step3_rr: 95', 'step4_rr: 95', 'step5_rr: 95', 'step6_rr: 95']
# empirical response rate 0.05323561946902655
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4104.486625389775
# orr termination 0.010389321369511078 0.06463458572825352 0.05424526435874244
# remaining size for Round 3: 141048
# Calculated size for Round 3: 4690.488343921896
# orr termination 0.026418260620134495 0.08349527479473218 0.05707701417459768
# remaining size for Round 4: 136358
# Calculated size for Round 4: 10784.177199946076
# orr termination 0.03876086119458304 0.09147712421030785 0.05271626301572481
# remaining size for Round 5: 125574
# Calculated size for Round 5: 8159.122264425966
# orr termination 0.046016425784974356 0.09388806905832332 0.04787164327334897
# remaining size for last Round 6: 117415
# 97
# ['step1_rr: 96', 'step2_rr: 96', 'step3_rr: 96', 'step4_rr: 96', 'step5_rr: 96', 'step6_rr: 96']
# empirical response rate 0.06419386061946902
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4872.29596410143
# orr termination 0.010571349777426351 0.07826276516247546 0.06769141538504911
# remaining size for Round 3: 140280
# Calculated size for Round 3: 10820.994453490532
# orr termination 0.027537685370952348 0.08267709108707277 0.05513940571612043
# remaining size for Round 4: 129460
# 98
# ['step1_rr: 97', 'step2_rr: 97', 'step3_rr: 97', 'step4_rr: 97', 'step5_rr: 97', 'step6_rr: 97']
# empirical response rate 0.04079092920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3252.685563220233
# orr termination 0.0358019824561905 0.042773905778501244 0.0069719233223107455
# remaining size for Round 3: 141900
# Calculated size for Round 3: 4370.588981952903
# orr termination 0.016544490399715436 0.04510894548910162 0.02856445508938618
# remaining size for Round 4: 137530
# Calculated size for Round 4: 3740.8463249411193
# orr termination 0.01847533263838247 0.060596171679810226 0.04212083904142776
# remaining size for Round 5: 133790
# Calculated size for Round 5: 6586.3774283061575
# orr termination 0.037717880559242536 0.07533361648731335 0.03761573592807081
# remaining size for last Round 6: 127204
# 99
# ['step1_rr: 98', 'step2_rr: 98', 'step3_rr: 98', 'step4_rr: 98', 'step5_rr: 98', 'step6_rr: 98']
# empirical response rate 0.06236172566371682
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4742.773758541168
# orr termination 0.043763309780233725 0.07174181582091721 0.027978506040683485
# remaining size for Round 3: 140410
# Calculated size for Round 3: 6789.238883496692
# orr termination 0.009227572663389468 0.07723876405495064 0.06801119139156117
# remaining size for Round 4: 133621
# Calculated size for Round 4: 6228.54096390466
# orr termination 0.03726076000017446 0.093008397980969 0.05574763798079453
# remaining size for Round 5: 127393
# Calculated size for Round 5: 13119.114270273723
# orr termination 0.05175010550403042 0.09849720776249146 0.04674710225846104
# remaining size for last Round 6: 114274
# 100
# ['step1_rr: 99', 'step2_rr: 99', 'step3_rr: 99', 'step4_rr: 99', 'step5_rr: 99', 'step6_rr: 99']
# empirical response rate 0.06498893805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4928.646813703883
# orr termination 0.010455503896086868 0.06815491325097978 0.05769940935489291
# remaining size for Round 3: 140224
# Calculated size for Round 3: 5350.862704600502
# orr termination 0.011669915429057858 0.09348591179511775 0.08181599636605989
# remaining size for Round 4: 134874
# Calculated size for Round 4: 11964.996963266141
# orr termination 0.036377663656205005 0.07398757082739824 0.03760990717119323
# remaining size for Round 5: 122910

# %% [markdown]
# ### Results summary

# %%
rr_df = pd.DataFrame(rr_dict)
rr_df
# Out:
#     step1_rr  step2_rr  step3_rr  step4_rr  step5_rr  step6_rr
# 0   0.054396  0.055093  0.067340  0.071818  0.088876  0.093224
# 1   0.052528  0.056527  0.058389  0.071804  0.077267       NaN
# 2   0.053361  0.054350  0.064668  0.089932  0.095470       NaN
# 3   0.054444  0.057857  0.065938  0.068950  0.092704  0.092207
# 4   0.054870  0.056346  0.059123  0.062752  0.071879  0.083534
# ..       ...       ...       ...       ...       ...       ...
# 95  0.053512  0.054615  0.065485  0.081845  0.096527  0.099416
# 96  0.051957  0.055265  0.077009  0.080644       NaN       NaN
# 97  0.053364  0.057541  0.055709  0.066891  0.069075  0.081571
# 98  0.053413  0.057707  0.061738  0.078770  0.089874  0.092461
# 99  0.058045  0.063210  0.073099  0.066236  0.069999       NaN
#
# [100 rows x 6 columns]

# %%
# Calculate average rounds:
row_non_nan_counts = rr_df.count(axis=1)

print(f"{np.mean(row_non_nan_counts):.1f} ({np.std(row_non_nan_counts):.1f})")
# Out:
# 5.5 (0.8)

# %%
result_dict = {}
for key, values in rr_df.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"

for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_rr: 0.055 (0.002)
# step2_rr: 0.059 (0.003)
# step3_rr: 0.066 (0.008)
# step4_rr: 0.075 (0.010)
# step5_rr: 0.083 (0.011)
# step6_rr: 0.089 (0.009)

# %%
result_dict = np.array(orr_total) / total_n
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f} ({std_result:.3f})")
# Out:
# Mean: 0.080 (0.007)

# %%
print(np.mean(highest_true_rr))
print(np.std(highest_true_rr))
# Out:
# 0.09072550559684
# 0.008849269675613359

# %%
result_dict = np.array(orr_total_adaptive) / (145152)
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f} ({std_result:.3f})")
# Out:
# Mean: 0.085 (0.009)

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in plan_number_dict.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.1f} ({std_value:.1f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_plan_number: nan (nan)
# step2_plan_number: 97.5 (58.0)
# step3_plan_number: 32.8 (32.8)
# step4_plan_number: 12.3 (19.4)
# step5_plan_number: 4.8 (6.5)
# step6_plan_number: 2.4 (2.1)

# %%
means = {key: np.mean(values) for key, values in stopping_dict.items()}
means
# Out:
# {'early_stopping': 0.34,
#  'early_stopping_plan': 0.31,
#  'early_stopping_orr': 0.0,
#  'early_stopping_size': 0.03}

# %%
print(np.mean(last_round_sample_size), np.std(last_round_sample_size))
# Out:
# 123916.37 7556.113683177352

# %%
np.mean(better_chance)
# Out:
# 1.0

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in sample_size_dict.items():
    mean_value = np.nanmean(values)
    std_value = np.nanstd(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_sample_size: 28928.000 (0.000)
# step2_sample_size: 4284.361 (1344.789)
# step3_sample_size: 6962.253 (13535.521)
# step4_sample_size: 25468.076 (44424.187)
# step5_sample_size: 34325.470 (49842.262)
# step6_sample_size: 120480.318 (5930.894)

# %% [markdown]
# ## Random Forest

# %%
def ensemble_model_fit(data, data_pred):
    X_train, X_test, y_train, y_test = train_test_split(
        data.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1),
        data['response'],
        test_size=0.2,
        random_state=0
    )

    # Define the VotingClassifier with the individual classifiers
    voting_classifier = ensemble.VotingClassifier(
        estimators=[
            # ('LR', linear_model.LogisticRegression(max_iter=200, random_state=0))
#             ('Ridge', linear_model.LogisticRegression(penalty='l2', solver='lbfgs', max_iter=200, random_state=0))
                    # ('SVM', svm.SVC(kernel='linear', C=1.0, random_state=0, probability=True, class_weight='balanced'))
                    ('RF', ensemble.RandomForestClassifier(criterion='gini', random_state=0))
                    # ('XGB', XGBClassifier(n_estimators=50, learning_rate=0.1, random_state=0))
                   ],
        voting='soft'
    )

    # Define the hyperparameter grid to search
    # Best Hyperparameters: {'LR__C': 0.01, 'RF__n_estimators': 50, 'XGB__n_estimators': 50}
    param_grid = {
        # 'NB__alpha': [0.01, 0.05, 0.1],  # '__' is used to specify hyperparameters for individual classifiers
        # 'LR__C': [0.01] # [0.01, 0.05, 0.1]
        # 'Ridge__C': [0.01]
        # 'SVM__C': [0.01, 0.05, 0.1]
        'RF__n_estimators': [50] # [10, 30, 50]
        # 'XGB__n_estimators': [50]
    }

    # Create a GridSearchCV object
    # custom_scorer_auc = make_scorer(roc_auc_score, needs_proba=True)
    grid_search = GridSearchCV(voting_classifier, param_grid, cv=10, scoring='roc_auc')

    # Perform the grid search on the training data
    grid_search.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = grid_search.best_params_

    # Train the final VotingClassifier with the best hyperparameters on the full training set
    final_voting_classifier = grid_search.best_estimator_
    final_voting_classifier.fit(X_train, y_train)

    # Predict probabilities instead of binary outcomes on the test set
    y_pred_proba_test = final_voting_classifier.predict_proba(X_test)
    y_pred_test = final_voting_classifier.predict(X_test)
    X_dt = data_pred.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1)
    y_pred = final_voting_classifier.predict_proba(X_dt)

    return y_pred

# %% [markdown]
# ### Simulation starts

# %%
n_sim = 100
# create a list of random seeds
random.seed(42)
random_seeds = [random.randint(1, 100000) for _ in range(n_sim)]

design_list = [5,8,10]
patient_n_list = [5468,680,170] # n_patient_per_plan

n_design = 8
n_patient_per_plan = 680
n_rounds = 6
total_n = n_patient_per_plan * (2**n_design)

## sample size determination
beta = 0.2
power = 1 - beta
alpha = 0.05
delta = 0.01 # effect size

## early stopping
epsilon = 0.001

# %%
rr_dict = {"step{}_rr".format(r): [] for r in range(1, n_rounds + 1)}
plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
sample_size_dict = {"step{}_sample_size".format(r): [] for r in range(1, n_rounds + 1)}
last_round_sample_size = []
random_rr_dict = {"step{}_random_max_rr".format(r): [] for r in range(1, n_rounds + 1)}
random_rr_dict.update({
    "step{}_random_mean_rr".format(r): [] for r in range(1, n_rounds + 1)
})

stopping_dict = {"early_stopping": [],
                 "early_stopping_plan":[],
                 "early_stopping_orr":[],
                 "early_stopping_size":[]}
final_plan_number = []
highest_rr_overall = []

better_chance = []

orr_total = []
orr_total_adaptive = []



i = 0

for seed in random_seeds:
    i += 1
    print(i)

    print([f"{key}: {len(value)}" for key, value in rr_dict.items()])



    event_list = 0
    event_list_adaptive = 0
    max_rr = []

    # step 1:
    ## Generate dataset
    dt_design_5 = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed)
    print("empirical response rate", dt_design_5['response'].mean())
    ## save for benchmark results
    maxidx = np.argmax(dt_design_5['plan_response_rate'])
    random_rr_dict['step1_random_max_rr'].append(dt_design_5.iloc[maxidx,6])
    random_rr_dict['step1_random_mean_rr'].append(dt_design_5['plan_response_rate'].mean())

    ## Ensemble modelling:
    y_pred = ensemble_model_fit(data=dt_design_5, data_pred = dt_design_5)

    ## select recruitment plan
    pred_df = pd.DataFrame(np.hstack((dt_design_5,  y_pred[:, 1].reshape(-1, 1))),
                             columns=list(dt_design_5.columns) + ['predicted_response_rate'])
    pred_df_rr = pred_df.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

    x = pred_df_rr['predicted_response_rate'].values
    if len(x) <= 10:
        best_k = 2
    else:
        best_k = kmeans_fit(data = x)['best_k']
    kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

    merged_df = pd.merge(pred_df_rr, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
    cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
    highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
    highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)


    p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))
    highest_cluster['p_vec'] = p_vec_next
    highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

    # highest_cluster = pred_df_rr

    # highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')
    # highest_cluster['cluster_number'] = highest_cluster['recruitment_plan']

    ## prepare to chance of better performance:
    temp = dt_design_5[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
    event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print("step1", np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print(temp)
    p0 = (temp['plan_response_rate'].mean())

    rr_dict["step1_rr"].append(dt_design_5['plan_response_rate'].mean())
    sample_size_dict["step1_sample_size"].append(len(dt_design_5))

    for round in range(2, n_rounds+1):

        rr_dict["step"+str(round)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))
        plan_number_dict["step"+str(round)+"_plan_number"].append(len(p_vec_next))

        ## when it comes to the last round:
        if round == n_rounds:

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            if round == 2: # if the last round is round 2
                remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
            else:
                remaining_size -= len(dt_design_5_step2up)

            print("remaining size for last Round " + str(round) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            ## data generation, combine previous data:
            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, 
                                                          design_number = n_design, n_rounds = n_rounds,
                                                          n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(0)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(len(temp), temp['plan_response_rate'].mean())
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break



        ## If haven't reached the last round:
        ## check remaining sample size:
        if round == 2:
            remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
        else:
            remaining_size -= len(dt_design_5_step2up)

        print("remaining size for Round " + str(round) + ": " + str(remaining_size))

        ## determine whether move on to step 2:
        if len(highest_cluster) == 1: # if there is only one plan left

            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size) # record the last round sample size
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(1)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        ## sample size determination:
        if round == 2:
            dt_design_5_step2up_overall = dt_design_5
        orr_1 = dt_design_5_step2up_overall['response'].mean() # observed overall response rates for previous rounds
        orr_2 = orr_1 + delta
        n_1 = len(dt_design_5_step2up_overall)

        size_step2up = sample_size_calc(orr_1, n_1, delta=delta, alpha=alpha, power=power) # total size for dataset
        if size_step2up > 0 and size_step2up < 1000:
            size_step2up = 1000 # if size in [0,1000], then it is 1000 for this round.
        elif size_step2up >= 1000:
            size_step2up = min(size_step2up, int(total_n/n_rounds)) # dataset size capped by the n_patient_per_plan
        else:
        # if size_step2up <= 0:
            # the process stops at this step
            print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up) + 'lt 0, break')
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(1)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up))

        sample_size_dict["step"+str(round)+"_sample_size"].append(size_step2up)

        ## save benchmark results for last round:
        dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                            n_patient_per_plan = n_patient_per_plan, seed=seed+round)
        maxidx = np.argmax(dt_benchmark['plan_response_rate'])
        random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
        random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

        ## data generation, combine previous data:
        dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                  design_number = n_design, n_rounds = n_rounds,
                                                  n_patient_per_plan = n_patient_per_plan, size = int(size_step2up), seed=seed)

        plan_list = dt_design_5_step2up['recruitment_plan'].unique()
        if round == 2:
            supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)]
        else:
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
        dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
        dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

        ## Ensemble model fitting:
        dt_design_5_step2up.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)
        y_pred2up = ensemble_model_fit(data = dt_design_5_step2up_overall, data_pred = dt_design_5_step2up)
        pred_df_step2up = pd.DataFrame(np.hstack((dt_design_5_step2up,  y_pred2up[:, 1].reshape(-1, 1))),
                                    columns=list(dt_design_5_step2up.columns) + ['predicted_response_rate'])
        pred_df_rr_step2up = pred_df_step2up.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

        ## select recruitment plans:
        x = pred_df_rr_step2up['predicted_response_rate'].values

        if len(x) <= 10:
            best_k = 2
        else:
            best_k = kmeans_fit(data = x)['best_k']
        kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

        ## match the cluster results back to the original data
        highest_cluster_previous = highest_cluster # save previous cluster results

        merged_df = pd.merge(pred_df_rr_step2up, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
        cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
        highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
        highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)

        # p_vec_previous = p_vec_next # save p_vec of previous round
        p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))

        highest_cluster['p_vec'] = p_vec_next

        highest_cluster = pd.merge(highest_cluster, dt_design_5_step2up[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

        ## prepare to chance of better performance:
        temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
        event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print(temp)

        ## check early stopping predicted ORR:
        orr_df = pd.merge(highest_cluster_previous, highest_cluster[['recruitment_plan','predicted_response_rate','p_vec']], on='recruitment_plan', how='left')
        orr_df.fillna(0, inplace=True)
        p_orr_1 = np.dot(np.array(orr_df['p_vec_x']), np.array(orr_df['predicted_response_rate_y']))
        p_orr_2 = np.dot(np.array(orr_df['p_vec_y']), np.array(orr_df['predicted_response_rate_y']))
        print("orr termination", p_orr_1, p_orr_2, p_orr_2 - p_orr_1)

        if (p_orr_2 - p_orr_1 < epsilon):
            # step 3 use the same strategy of step2
            print(i, p_orr_1, p_orr_2, "early stop at Round " + str(round))
            rr_dict["step"+str(round+1)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                                n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round+1)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round+1)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            ### update remaining size:
            remaining_size -= len(dt_design_5_step2up)
            print("early stop, remaining size for Round" + str(round + 1) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            for r in range(round+2, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, 
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(1)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            for r in range(round+2, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round+1), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break
# Out:
# 1
# ['step1_rr: 0', 'step2_rr: 0', 'step3_rr: 0', 'step4_rr: 0', 'step5_rr: 0', 'step6_rr: 0']
# empirical response rate 0.08033738938053098
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6033.300486728156
# orr termination 0.009223193332805127 0.12785059795179773 0.11862740461899261
# remaining size for Round 3: 139119
# Calculated size for Round 3: 13263.057678056346
# orr termination 0.033152730648741725 0.09737827837345342 0.0642255477247117
# remaining size for Round 4: 125856
# 2
# ['step1_rr: 1', 'step2_rr: 1', 'step3_rr: 1', 'step4_rr: 1', 'step5_rr: 1', 'step6_rr: 1']
# empirical response rate 0.07836698008849557
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5889.708525120337
# orr termination 0.0076695015051424665 0.13878198831170474 0.13111248680656226
# remaining size for Round 3: 139263
# Calculated size for Round 3: 16526.742854230073
# orr termination 0.04716171787526958 0.09227884748221071 0.045117129606941135
# remaining size for Round 4: 122737
# 3
# ['step1_rr: 2', 'step2_rr: 2', 'step3_rr: 2', 'step4_rr: 2', 'step5_rr: 2', 'step6_rr: 2']
# empirical response rate 0.030593196902654867
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2570.7668488803606
# orr termination 0.012640331478299224 0.0909616500989633 0.07832131862066408
# remaining size for Round 3: 142582
# Calculated size for Round 3: 7220.4576825883905
# orr termination 0.047658479940473605 0.09170529850054832 0.04404681856007471
# remaining size for Round 4: 135362
# Calculated size for Round 4: 12747.576404064952
# orr termination 0.049514084301742325 0.09855063122734847 0.04903654692560615
# remaining size for Round 5: 122615
# Calculated size for Round 5: 8193.698260165882
# orr termination 0.04941736278341074 0.0957368880145459 0.04631952523113516
# remaining size for last Round 6: 114422
# 4
# ['step1_rr: 3', 'step2_rr: 3', 'step3_rr: 3', 'step4_rr: 3', 'step5_rr: 3', 'step6_rr: 3']
# empirical response rate 0.06011476769911504
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4584.554843390879
# orr termination 0.038064589587296596 0.10603563827891378 0.06797104869161719
# remaining size for Round 3: 140568
# Calculated size for Round 3: 10116.082725637805
# orr termination 0.01166041867497333 0.10597476702661163 0.0943143483516383
# remaining size for Round 4: 130452
# Calculated size for Round 4: 8983.346335805758
# orr termination 0.04857207058967267 0.09530678381764701 0.046734713227974345
# remaining size for Round 5: 121469
# 5
# ['step1_rr: 4', 'step2_rr: 4', 'step3_rr: 4', 'step4_rr: 4', 'step5_rr: 4', 'step6_rr: 4']
# empirical response rate 0.09029314159292036
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6766.704057464664
# orr termination 0.03935814523862434 0.13632801072167655 0.09696986548305221
# remaining size for Round 3: 138386
# Calculated size for Round 3: 9641.09596904277
# orr termination 0.014761692149349578 0.1362708515226312 0.1215091593732816
# remaining size for Round 4: 128745
# Calculated size for Round 4: 11556.619347523227
# orr termination 0.07672600847680543 0.10119395464083014 0.024467946164024715
# remaining size for Round 5: 117189
# Calculated size for Round 5: 9851.994973542724
# orr termination 0.03416222217952614 0.10141976128354492 0.06725753910401877
# remaining size for last Round 6: 107338
# 6
# ['step1_rr: 5', 'step2_rr: 5', 'step3_rr: 5', 'step4_rr: 5', 'step5_rr: 5', 'step6_rr: 5']
# empirical response rate 0.04362555309734513
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3444.8125679843447
# orr termination 0.012220982640934075 0.07300443641892336 0.060783453777989285
# remaining size for Round 3: 141708
# Calculated size for Round 3: 5290.033889416084
# orr termination 0.020278209650965995 0.09909321127871334 0.07881500162774735
# remaining size for Round 4: 136418
# Calculated size for Round 4: 17294.34126026829
# orr termination 0.0509606309151293 0.09725218267691703 0.04629155176178773
# remaining size for Round 5: 119124
# 7
# ['step1_rr: 6', 'step2_rr: 6', 'step3_rr: 6', 'step4_rr: 6', 'step5_rr: 6', 'step6_rr: 6']
# empirical response rate 0.04355641592920354
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3440.1132258982107
# orr termination 0.07518332548144119 0.08797033910483665 0.01278701362339546
# remaining size for Round 3: 141712
# Calculated size for Round 3: 6619.24458948359
# orr termination 0.03552202617390234 0.10321983709980993 0.0676978109259076
# remaining size for Round 4: 135093
# Calculated size for Round 4: 7293.90475211675
# orr termination 0.044651820036675303 0.08817833663813358 0.04352651660145828
# remaining size for Round 5: 127800
# Calculated size for Round 5: 7610.002456768213
# orr termination 0.0449551750675949 0.08110632633536652 0.03615115126777162
# remaining size for last Round 6: 120190
# 8
# ['step1_rr: 7', 'step2_rr: 7', 'step3_rr: 7', 'step4_rr: 7', 'step5_rr: 7', 'step6_rr: 7']
# empirical response rate 0.08030282079646017
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6030.776854562427
# orr termination 0.07791837051317142 0.15397043773592256 0.07605206722275114
# remaining size for Round 3: 139122
# Calculated size for Round 3: 14692.38725184898
# orr termination 0.021490562406437253 0.1413305003367239 0.11983993793028665
# remaining size for Round 4: 124430
# Calculated size for Round 4: 10912.708162375598
# orr termination 0.06725091210714355 0.11122594046760909 0.04397502836046553
# remaining size for Round 5: 113518
# Calculated size for Round 5: 11424.857134710615
# orr termination 0.03566599182631169 0.10658887542774637 0.07092288360143467
# remaining size for last Round 6: 102094
# 9
# ['step1_rr: 8', 'step2_rr: 8', 'step3_rr: 8', 'step4_rr: 8', 'step5_rr: 8', 'step6_rr: 8']
# empirical response rate 0.04777378318584071
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3727.99035410021
# orr termination 0.06454752489549298 0.07402193412579812 0.00947440923030514
# remaining size for Round 3: 141425
# Calculated size for Round 3: 5997.689376244115
# orr termination 0.011936171710145611 0.08294839169326405 0.07101221998311844
# remaining size for Round 4: 135428
# Calculated size for Round 4: 5407.136649798205
# orr termination 0.04138644224624845 0.09912902496563689 0.05774258271938844
# remaining size for Round 5: 130021
# Calculated size for Round 5: 15523.197747030215
# orr termination 0.08047547786226959 0.10138911856821516 0.020913640705945563
# remaining size for last Round 6: 114498
# 10
# ['step1_rr: 9', 'step2_rr: 9', 'step3_rr: 9', 'step4_rr: 9', 'step5_rr: 9', 'step6_rr: 9']
# empirical response rate 0.043037887168141595
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3404.8893784747597
# orr termination 0.04430992781756655 0.06244847075334501 0.018138542935778462
# remaining size for Round 3: 141748
# Calculated size for Round 3: 4352.006963614991
# orr termination 0.007907299055960163 0.09501180462153891 0.08710450556557875
# remaining size for Round 4: 137396
# Calculated size for Round 4: 4966.111368114512
# orr termination 0.027051173450352697 0.0949184907872026 0.0678673173368499
# remaining size for Round 5: 132430
# Calculated size for Round 5: 24256.524902666228
# orr termination 0.0499960960554763 0.10162622154214167 0.05163012548666537
# remaining size for last Round 6: 108174
# 11
# ['step1_rr: 10', 'step2_rr: 10', 'step3_rr: 10', 'step4_rr: 10', 'step5_rr: 10', 'step6_rr: 10']
# empirical response rate 0.03297842920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2728.965581830211
# orr termination 0.009123030111774606 0.08796790166204818 0.07884487155027357
# remaining size for Round 3: 142424
# Calculated size for Round 3: 14216.560072955277
# orr termination 0.06640884163750808 0.09871434461778622 0.032305502980278136
# remaining size for Round 4: 128208
# Calculated size for Round 4: 9405.926348695884
# orr termination 0.05155669959447874 0.10263752096700579 0.05108082137252705
# remaining size for Round 5: 118803
# 12
# ['step1_rr: 11', 'step2_rr: 11', 'step3_rr: 11', 'step4_rr: 11', 'step5_rr: 11', 'step6_rr: 11']
# empirical response rate 0.034603152654867256
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2837.1791262040406
# orr termination 0.014793701437681973 0.07061106319114341 0.055817361753461435
# remaining size for Round 3: 142315
# Calculated size for Round 3: 27917.76250760394
# orr termination 0.0299774930016307 0.0909214960093195 0.06094400300768879
# remaining size for Round 4: 114398
# 13
# ['step1_rr: 12', 'step2_rr: 12', 'step3_rr: 12', 'step4_rr: 12', 'step5_rr: 12', 'step6_rr: 12']
# empirical response rate 0.04124032079646018
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3283.0700374646344
# orr termination 0.02689648313145854 0.07253304594479215 0.045636562813333614
# remaining size for Round 3: 141869
# Calculated size for Round 3: 3651.755975353159
# orr termination 0.03537841949936116 0.07399240334415404 0.03861398384479288
# remaining size for Round 4: 138218
# Calculated size for Round 4: 6446.43447120579
# orr termination 0.004817709559929027 0.10467042622508047 0.09985271666515144
# remaining size for Round 5: 131772
# 14
# ['step1_rr: 13', 'step2_rr: 13', 'step3_rr: 13', 'step4_rr: 13', 'step5_rr: 13', 'step6_rr: 13']
# empirical response rate 0.07079646017699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5342.870662026109
# orr termination 0.05716232302386139 0.1196974781267267 0.06253515510286531
# remaining size for Round 3: 139810
# Calculated size for Round 3: 8340.647654878527
# orr termination 0.02909083283273986 0.12902467447650226 0.0999338416437624
# remaining size for Round 4: 131470
# Calculated size for Round 4: 9949.165947909438
# orr termination 0.037016962707536356 0.11330528118852201 0.07628831848098566
# remaining size for Round 5: 121521
# Calculated size for Round 5: 10322.627590962755
# orr termination 0.0646523125048027 0.10681775081128453 0.042165438306481826
# remaining size for last Round 6: 111199
# 15
# ['step1_rr: 14', 'step2_rr: 14', 'step3_rr: 14', 'step4_rr: 14', 'step5_rr: 14', 'step6_rr: 14']
# empirical response rate 0.03135370575221239
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2621.120723895575
# orr termination 0.029207945689372957 0.08519667746041851 0.05598873177104555
# remaining size for Round 3: 142531
# Calculated size for Round 3: 22047.052842610043
# orr termination 0.052082306098553424 0.09908958416713406 0.04700727806858064
# remaining size for Round 4: 120484
# Calculated size for Round 4: 7835.389516323153
# orr termination 0.06653727349292834 0.10104668002111158 0.03450940652818324
# remaining size for Round 5: 112649
# Calculated size for Round 5: 8307.841420691564
# orr termination 0.050409000314872526 0.1009514713536696 0.05054247103879707
# remaining size for last Round 6: 104342
# 16
# ['step1_rr: 15', 'step2_rr: 15', 'step3_rr: 15', 'step4_rr: 15', 'step5_rr: 15', 'step6_rr: 15']
# empirical response rate 0.07231747787610619
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5452.116013979351
# orr termination 0.02593796286904415 0.10123629375973273 0.07529833089068858
# remaining size for Round 3: 139700
# Calculated size for Round 3: 29013
# orr termination 0.050052898812109614 0.10140582187318738 0.05135292306107776
# remaining size for Round 4: 110687
# 17
# ['step1_rr: 16', 'step2_rr: 16', 'step3_rr: 16', 'step4_rr: 16', 'step5_rr: 16', 'step6_rr: 16']
# empirical response rate 0.02900304203539823
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2465.7425695144257
# orr termination 0.02724840864686191 0.06997105465651023 0.04272264600964831
# remaining size for Round 3: 142687
# Calculated size for Round 3: 4270.564810203814
# orr termination 0.015590559646624334 0.07139500265799224 0.05580444301136791
# remaining size for Round 4: 138417
# Calculated size for Round 4: 6050.777573284257
# orr termination 0.02955637765083296 0.08549014862666242 0.05593377097582946
# remaining size for Round 5: 132367
# Calculated size for Round 5: 9691.023916032455
# orr termination 0.06542415752872141 0.09648240296476875 0.031058245436047335
# remaining size for last Round 6: 122676
# 18
# ['step1_rr: 17', 'step2_rr: 17', 'step3_rr: 17', 'step4_rr: 17', 'step5_rr: 17', 'step6_rr: 17']
# empirical response rate 0.038682245575221236
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3110.4883281384073
# orr termination 0.052631930638643055 0.06578199672317364 0.013150066084530586
# remaining size for Round 3: 142042
# Calculated size for Round 3: 3596.861570865979
# orr termination 0.020113327471793434 0.08646416444901005 0.06635083697721661
# remaining size for Round 4: 138446
# Calculated size for Round 4: 4745.838655076456
# orr termination 0.0712449833977517 0.08648040218054626 0.015235418782794552
# remaining size for Round 5: 133701
# Calculated size for Round 5: 11343.110001578725
# orr termination 0.01872513444414359 0.10378431642529772 0.08505918198115413
# remaining size for last Round 6: 122358
# 19
# ['step1_rr: 18', 'step2_rr: 18', 'step3_rr: 18', 'step4_rr: 18', 'step5_rr: 18', 'step6_rr: 18']
# empirical response rate 0.04860342920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3784.913012723484
# orr termination 0.031540841121247026 0.08256592566839246 0.05102508454714544
# remaining size for Round 3: 141368
# Calculated size for Round 3: 5640.062940918241
# orr termination 0.03218585788067521 0.07981971658305462 0.047633858702379406
# remaining size for Round 4: 135728
# Calculated size for Round 4: 7241.858083262465
# orr termination 0.0428253432910219 0.08564124599505127 0.042815902704029365
# remaining size for Round 5: 128487
# Calculated size for Round 5: 8348.065614004017
# orr termination 0.012768589707054228 0.10070925974597991 0.08794067003892568
# remaining size for last Round 6: 120139
# 20
# ['step1_rr: 19', 'step2_rr: 19', 'step3_rr: 19', 'step4_rr: 19', 'step5_rr: 19', 'step6_rr: 19']
# empirical response rate 0.09053512168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6784.692301555903
# orr termination 0.0112318979539606 0.17675095351545678 0.16551905556149618
# remaining size for Round 3: 138368
# Calculated size for Round 3: 11451.244684357996
# orr termination 0.07827116913240607 0.10991956341183025 0.031648394279424175
# remaining size for Round 4: 126917
# Calculated size for Round 4: 11934.443432218337
# orr termination 0.06011812421151892 0.10115048457628358 0.04103236036476465
# remaining size for Round 5: 114983
# Calculated size for Round 5: 8294.854691428844
# orr termination 0.06736864620358071 0.10037212202501929 0.033003475821438574
# remaining size for last Round 6: 106689
# 21
# ['step1_rr: 20', 'step2_rr: 20', 'step3_rr: 20', 'step4_rr: 20', 'step5_rr: 20', 'step6_rr: 20']
# empirical response rate 0.04127488938053098
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3285.4084707208544
# orr termination 0.02347305161248203 0.10636836076080532 0.08289530914832328
# remaining size for Round 3: 141867
# Calculated size for Round 3: 13578.214262480322
# orr termination 0.03312777699891749 0.10321305572813304 0.07008527872921555
# remaining size for Round 4: 128289
# Calculated size for Round 4: 8952.4393453643
# orr termination 0.07002500514405108 0.10496428513166464 0.034939279987613564
# remaining size for Round 5: 119337
# Calculated size for Round 5: 10398.72065789123
# orr termination 0.048969085607652584 0.09982056135038414 0.05085147574273156
# remaining size for last Round 6: 108939
# 22
# ['step1_rr: 21', 'step2_rr: 21', 'step3_rr: 21', 'step4_rr: 21', 'step5_rr: 21', 'step6_rr: 21']
# empirical response rate 0.09153761061946902
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6859.296443568507
# orr termination 0.02318913342553989 0.15977274867134938 0.1365836152458095
# remaining size for Round 3: 138293
# Calculated size for Round 3: 12601.131937303302
# orr termination 0.038457476448902406 0.11448827197899561 0.0760307955300932
# remaining size for Round 4: 125692
# Calculated size for Round 4: 10768.009176627033
# orr termination 0.05236696469903582 0.10467034274572479 0.05230337804668897
# remaining size for Round 5: 114924
# Calculated size for Round 5: 10136.251882737371
# orr termination 0.051399446584819534 0.10308303427821175 0.051683587693392215
# remaining size for last Round 6: 104788
# 23
# ['step1_rr: 22', 'step2_rr: 22', 'step3_rr: 22', 'step4_rr: 22', 'step5_rr: 22', 'step6_rr: 22']
# empirical response rate 0.11189850663716815
# remaining size for Round 2: 145152
# Calculated size for Round 2: 8402.348985484643
# orr termination 0.04322036415574808 0.18654258871138424 0.14332222455563615
# remaining size for Round 3: 136750
# Calculated size for Round 3: 8709.414946817356
# orr termination 0.08810983381489057 0.16313599829983474 0.07502616448494417
# remaining size for Round 4: 128041
# Calculated size for Round 4: 18366.541239683735
# orr termination 0.04028153343267116 0.11524522621180555 0.0749636927791344
# remaining size for Round 5: 109675
# Calculated size for Round 5: 8645.92562221499
# orr termination 0.015239886584799144 0.10538062199178372 0.09014073540698457
# remaining size for last Round 6: 101030
# 24
# ['step1_rr: 23', 'step2_rr: 23', 'step3_rr: 23', 'step4_rr: 23', 'step5_rr: 23', 'step6_rr: 23']
# empirical response rate 0.06201603982300885
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4718.387240976126
# orr termination 0.043773719618310586 0.13533939863752947 0.09156567901921889
# remaining size for Round 3: 140434
# Calculated size for Round 3: 10975.815411335478
# orr termination 0.037927689154241134 0.1010453545356074 0.06311766538136626
# remaining size for Round 4: 129459
# Calculated size for Round 4: 8904.18465366133
# orr termination 0.05413181069910981 0.09752167132565709 0.04338986062654728
# remaining size for Round 5: 120555
# Calculated size for Round 5: 9017.472594982664
# orr termination 0.03801700201854828 0.09534513728635131 0.05732813526780303
# remaining size for last Round 6: 111538
# 25
# ['step1_rr: 24', 'step2_rr: 24', 'step3_rr: 24', 'step4_rr: 24', 'step5_rr: 24', 'step6_rr: 24']
# empirical response rate 0.05008987831858407
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3887.138480086987
# orr termination 0.016409505737378833 0.08504807044500531 0.06863856470762648
# remaining size for Round 3: 141265
# Calculated size for Round 3: 6379.771482491923
# orr termination 0.03646733266326797 0.08351450163590406 0.04704716897263608
# remaining size for Round 4: 134886
# Calculated size for Round 4: 9512.44039341753
# orr termination 0.043882207243405885 0.10209924825705027 0.05821704101364439
# remaining size for Round 5: 125374
# Calculated size for Round 5: 9425.186929085983
# orr termination 0.0646131934468317 0.0972540474584235 0.03264085401159181
# remaining size for last Round 6: 115949
# 26
# ['step1_rr: 25', 'step2_rr: 25', 'step3_rr: 25', 'step4_rr: 25', 'step5_rr: 25', 'step6_rr: 25']
# empirical response rate 0.03297842920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2728.965581830211
# orr termination 0.03626150519986958 0.06388587651510101 0.027624371315231433
# remaining size for Round 3: 142424
# Calculated size for Round 3: 4601.786218542244
# orr termination 0.014514277466847615 0.07123890210861758 0.056724624641769965
# remaining size for Round 4: 137823
# Calculated size for Round 4: 5267.940275787705
# orr termination 0.010039861388967852 0.0706781843510551 0.06063832296208725
# remaining size for Round 5: 132556
# Calculated size for Round 5: 6522.682739271518
# orr termination 0.048298679376669644 0.09367220498739377 0.04537352561072413
# remaining size for last Round 6: 126034
# 27
# ['step1_rr: 26', 'step2_rr: 26', 'step3_rr: 26', 'step4_rr: 26', 'step5_rr: 26', 'step6_rr: 26']
# empirical response rate 0.033842643805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2786.4800847064803
# orr termination 0.010642631341628812 0.05651543914161401 0.045872807799985205
# remaining size for Round 3: 142366
# Calculated size for Round 3: 3383.2568853564976
# orr termination 0.036426572139267865 0.06252910905605658 0.02610253691678871
# remaining size for Round 4: 138983
# Calculated size for Round 4: 7029.0985779402345
# orr termination 0.06471775903118203 0.06926932188149659 0.004551562850314564
# remaining size for Round 5: 131954
# Calculated size for Round 5: 6587.784488172228
# orr termination 0.03237781691313851 0.07747743410466304 0.04509961719152453
# remaining size for last Round 6: 125367
# 28
# ['step1_rr: 27', 'step2_rr: 27', 'step3_rr: 27', 'step4_rr: 27', 'step5_rr: 27', 'step6_rr: 27']
# empirical response rate 0.06077157079646018
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4630.73167611316
# orr termination 0.00860234358827687 0.0989020883040597 0.09029974471578282
# remaining size for Round 3: 140522
# Calculated size for Round 3: 6103.3268153378385
# orr termination 0.03069904189745945 0.09036045541015116 0.059661413512691705
# remaining size for Round 4: 134419
# Calculated size for Round 4: 11556.697956134685
# orr termination 0.025278742895315794 0.09488932722073234 0.06961058432541656
# remaining size for Round 5: 122863
# 29
# ['step1_rr: 28', 'step2_rr: 28', 'step3_rr: 28', 'step4_rr: 28', 'step5_rr: 28', 'step6_rr: 28']
# empirical response rate 0.06277654867256637
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4772.059228563532
# orr termination 0.04902783169279408 0.12355245050902443 0.07452461881623035
# remaining size for Round 3: 140380
# Calculated size for Round 3: 7492.682427598152
# orr termination 0.027115537312979242 0.11709837040250808 0.08998283308952884
# remaining size for Round 4: 132888
# Calculated size for Round 4: 9486.136936829675
# orr termination 0.07688626183816363 0.09706976215533245 0.020183500317168812
# remaining size for Round 5: 123402
# Calculated size for Round 5: 9471.720718405028
# orr termination 0.033529844662878006 0.09063402115307563 0.057104176490197625
# remaining size for last Round 6: 113931
# 30
# ['step1_rr: 29', 'step2_rr: 29', 'step3_rr: 29', 'step4_rr: 29', 'step5_rr: 29', 'step6_rr: 29']
# empirical response rate 0.07840154867256637
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5892.22320205354
# orr termination 0.05515319879753757 0.104924508408508 0.049771309610970434
# remaining size for Round 3: 139260
# Calculated size for Round 3: 5635.55307229724
# orr termination 0.06861612393040414 0.11700174067390842 0.04838561674350428
# remaining size for Round 4: 133625
# Calculated size for Round 4: 8861.549850847163
# orr termination 0.010354314407582466 0.13447238279137838 0.12411806838379591
# remaining size for Round 5: 124764
# Calculated size for Round 5: 8692.455614270197
# orr termination 0.05275001136075566 0.10622745874396973 0.05347744738321407
# remaining size for last Round 6: 116072
# 31
# ['step1_rr: 30', 'step2_rr: 30', 'step3_rr: 30', 'step4_rr: 30', 'step5_rr: 30', 'step6_rr: 30']
# empirical response rate 0.07701880530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5791.761187324277
# orr termination 0.0682055560131621 0.1494844949239903 0.0812789389108282
# remaining size for Round 3: 139361
# Calculated size for Round 3: 9100.947867074401
# orr termination 0.01820744664630671 0.14741862312988183 0.1292111764835751
# remaining size for Round 4: 130261
# Calculated size for Round 4: 11410.167070785126
# orr termination 0.03173212429024132 0.11229464750667276 0.08056252321643144
# remaining size for Round 5: 118851
# Calculated size for Round 5: 10834.643607579683
# orr termination 0.04816639508470346 0.09781769917496712 0.04965130409026366
# remaining size for last Round 6: 108017
# 32
# ['step1_rr: 31', 'step2_rr: 31', 'step3_rr: 31', 'step4_rr: 31', 'step5_rr: 31', 'step6_rr: 31']
# empirical response rate 0.08019911504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6023.206915866293
# orr termination 0.008175820120293761 0.13349023454225636 0.12531441442196262
# remaining size for Round 3: 139129
# Calculated size for Round 3: 14800.905945976247
# orr termination 0.03318311318742785 0.10014279970988495 0.0669596865224571
# remaining size for Round 4: 124329
# 33
# ['step1_rr: 32', 'step2_rr: 32', 'step3_rr: 32', 'step4_rr: 32', 'step5_rr: 32', 'step6_rr: 32']
# empirical response rate 0.07892007743362832
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5929.962574211673
# orr termination 0.01637693838154363 0.11344756223058713 0.0970706238490435
# remaining size for Round 3: 139223
# Calculated size for Round 3: 16974.698836719537
# orr termination 0.03447490409880532 0.10315863385182722 0.0686837297530219
# remaining size for Round 4: 122249
# 34
# ['step1_rr: 33', 'step2_rr: 33', 'step3_rr: 33', 'step4_rr: 33', 'step5_rr: 33', 'step6_rr: 33']
# empirical response rate 0.07159153761061947
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5399.937054375382
# orr termination 0.08204851033419391 0.11395195236778047 0.031903442033586554
# remaining size for Round 3: 139753
# Calculated size for Round 3: 9444.825013542095
# orr termination 0.024608477771803743 0.11735918058650258 0.09275070281469883
# remaining size for Round 4: 130309
# Calculated size for Round 4: 8311.6152004343
# orr termination 0.041501417889755414 0.12214789940953946 0.08064648151978404
# remaining size for Round 5: 121998
# Calculated size for Round 5: 13302.438547145275
# orr termination 0.07944458301574236 0.1074095643451761 0.02796498132943373
# remaining size for last Round 6: 108696
# 35
# ['step1_rr: 34', 'step2_rr: 34', 'step3_rr: 34', 'step4_rr: 34', 'step5_rr: 34', 'step6_rr: 34']
# empirical response rate 0.08182383849557522
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6141.967523856308
# orr termination 0.011872932765791183 0.13067631410624997 0.11880338134045879
# remaining size for Round 3: 139011
# Calculated size for Round 3: 9971.943564783267
# orr termination 0.06310410616533269 0.08959168075284613 0.02648757458751344
# remaining size for Round 4: 129040
# Calculated size for Round 4: 9739.88467545216
# orr termination 0.035820345912130354 0.09021137994040382 0.054391034028273465
# remaining size for Round 5: 119301
# Calculated size for Round 5: 7618.715268560554
# orr termination 0.04308630180122496 0.08683993785539397 0.04375363605416901
# remaining size for last Round 6: 111683
# 36
# ['step1_rr: 35', 'step2_rr: 35', 'step3_rr: 35', 'step4_rr: 35', 'step5_rr: 35', 'step6_rr: 35']
# empirical response rate 0.04206996681415929
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3339.2384022405945
# orr termination 0.0193033165844927 0.10010877838591772 0.08080546180142502
# remaining size for Round 3: 141813
# Calculated size for Round 3: 8007.711931754329
# orr termination 0.01977680789281841 0.09632076088694405 0.07654395299412564
# remaining size for Round 4: 133806
# Calculated size for Round 4: 11476.952751969198
# orr termination 0.04926356600963858 0.09795179628746252 0.048688230277823936
# remaining size for Round 5: 122330
# 37
# ['step1_rr: 36', 'step2_rr: 36', 'step3_rr: 36', 'step4_rr: 36', 'step5_rr: 36', 'step6_rr: 36']
# empirical response rate 0.04580337389380531
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3593.182438999496
# orr termination 0.02845815283811918 0.09004893891710189 0.06159078607898271
# remaining size for Round 3: 141559
# Calculated size for Round 3: 25084.564423330474
# orr termination 0.033727253115017036 0.09946191099312118 0.06573465787810415
# remaining size for Round 4: 116475
# Calculated size for Round 4: 7290.043309263126
# orr termination 0.051690918416889504 0.10090134315079874 0.049210424733909235
# remaining size for Round 5: 109185
# 38
# ['step1_rr: 37', 'step2_rr: 37', 'step3_rr: 37', 'step4_rr: 37', 'step5_rr: 37', 'step6_rr: 37']
# empirical response rate 0.047912057522123894
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3737.4708232996927
# orr termination 0.008223153156179785 0.11394096898779348 0.10571781583161369
# remaining size for Round 3: 141415
# Calculated size for Round 3: 6338.722839190534
# orr termination 0.016714569144836666 0.10800412812024596 0.09128955897540929
# remaining size for Round 4: 135077
# 39
# ['step1_rr: 38', 'step2_rr: 38', 'step3_rr: 38', 'step4_rr: 38', 'step5_rr: 38', 'step6_rr: 38']
# empirical response rate 0.07466814159292036
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5621.565807308865
# orr termination 0.029432299654978584 0.1099509201525228 0.08051862049754421
# remaining size for Round 3: 139531
# Calculated size for Round 3: 13179.68937718661
# orr termination 0.009759451938200258 0.09935108163959804 0.08959162970139778
# remaining size for Round 4: 126352
# 40
# ['step1_rr: 39', 'step2_rr: 39', 'step3_rr: 39', 'step4_rr: 39', 'step5_rr: 39', 'step6_rr: 39']
# empirical response rate 0.06301852876106195
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4789.153321772453
# orr termination 0.07616799957037766 0.10757149267973638 0.03140349310935872
# remaining size for Round 3: 140363
# Calculated size for Round 3: 9378.201054084097
# orr termination 0.05354352707839238 0.12429357780285089 0.0707500507244585
# remaining size for Round 4: 130985
# Calculated size for Round 4: 9303.193482159924
# orr termination 0.05232514977448895 0.11902041294916382 0.06669526317467488
# remaining size for Round 5: 121682
# Calculated size for Round 5: 10399.708839281408
# orr termination 0.06646256655374877 0.11000530537621186 0.043542738822463095
# remaining size for last Round 6: 111283
# 41
# ['step1_rr: 40', 'step2_rr: 40', 'step3_rr: 40', 'step4_rr: 40', 'step5_rr: 40', 'step6_rr: 40']
# empirical response rate 0.0742878871681416
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5594.104185697372
# orr termination 0.012644119772214123 0.15622060784880631 0.14357648807659218
# remaining size for Round 3: 139558
# Calculated size for Round 3: 12602.801622025578
# orr termination 0.06508309668981678 0.0967984414426506 0.031715344752833816
# remaining size for Round 4: 126956
# Calculated size for Round 4: 9629.426880403613
# orr termination 0.07251956598797663 0.09625827829107039 0.023738712303093767
# remaining size for Round 5: 117327
# Calculated size for Round 5: 7935.889834030147
# orr termination 0.06351627065773886 0.09455663613085905 0.031040365473120182
# remaining size for last Round 6: 109392
# 42
# ['step1_rr: 41', 'step2_rr: 41', 'step3_rr: 41', 'step4_rr: 41', 'step5_rr: 41', 'step6_rr: 41']
# empirical response rate 0.05403069690265487
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4159.637779672868
# orr termination 0.009186420168651944 0.08273848262405892 0.07355206245540698
# remaining size for Round 3: 140993
# Calculated size for Round 3: 4682.02739419119
# orr termination 0.009575643987259432 0.07782013778563057 0.06824449379837114
# remaining size for Round 4: 136311
# Calculated size for Round 4: 9536.379621404576
# orr termination 0.049225004868577636 0.09512278273513174 0.0458977778665541
# remaining size for Round 5: 126775
# 43
# ['step1_rr: 42', 'step2_rr: 42', 'step3_rr: 42', 'step4_rr: 42', 'step5_rr: 42', 'step6_rr: 42']
# empirical response rate 0.05517146017699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# orr termination 0.0162306072335077 0.12127232065944077 0.10504171342593308
# remaining size for Round 3: 140914
# Calculated size for Round 3: 5527.272861819297
# orr termination 0.008282395130266348 0.11992881296453044 0.11164641783426409
# remaining size for Round 4: 135387
# 44
# ['step1_rr: 43', 'step2_rr: 43', 'step3_rr: 43', 'step4_rr: 43', 'step5_rr: 43', 'step6_rr: 43']
# empirical response rate 0.04348727876106195
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3435.414549437817
# orr termination 0.013532879257644799 0.09661738856009731 0.08308450930245251
# remaining size for Round 3: 141717
# Calculated size for Round 3: 29013
# orr termination 0.046488502713673586 0.09481220767095368 0.04832370495728009
# remaining size for Round 4: 112704
# 45
# ['step1_rr: 44', 'step2_rr: 44', 'step3_rr: 44', 'step4_rr: 44', 'step5_rr: 44', 'step6_rr: 44']
# empirical response rate 0.052751659292035395
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4070.959200908221
# orr termination 0.05426140745256899 0.09822241621229708 0.04396100875972809
# remaining size for Round 3: 141082
# Calculated size for Round 3: 4505.533128676746
# orr termination 0.010812647914395209 0.11073512117394438 0.09992247325954917
# remaining size for Round 4: 136577
# Calculated size for Round 4: 8334.600945279759
# orr termination 0.04173484944807578 0.09936398199426114 0.057629132546185353
# remaining size for Round 5: 128243
# Calculated size for Round 5: 12784.059742959937
# orr termination 0.06360676318228276 0.09570799133001963 0.032101228147736874
# remaining size for last Round 6: 115459
# 46
# ['step1_rr: 45', 'step2_rr: 45', 'step3_rr: 45', 'step4_rr: 45', 'step5_rr: 45', 'step6_rr: 45']
# empirical response rate 0.08092505530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6076.226646023446
# orr termination 0.06458289288821484 0.10951811026677329 0.04493521737855845
# remaining size for Round 3: 139076
# Calculated size for Round 3: 29013
# orr termination 0.015742733948353932 0.09654150094155488 0.08079876699320095
# remaining size for Round 4: 110063
# 47
# ['step1_rr: 46', 'step2_rr: 46', 'step3_rr: 46', 'step4_rr: 46', 'step5_rr: 46', 'step6_rr: 46']
# empirical response rate 0.047428097345132744
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3704.3008047850903
# orr termination 0.03366704411259509 0.10581870689605286 0.07215166278345776
# remaining size for Round 3: 141448
# Calculated size for Round 3: 7206.910541565973
# orr termination 0.05820217672429132 0.0852449640589073 0.02704278733461598
# remaining size for Round 4: 134242
# Calculated size for Round 4: 8028.3957366164295
# orr termination 0.03781554975867425 0.08612719993225912 0.048311650173584866
# remaining size for Round 5: 126214
# Calculated size for Round 5: 7053.460866018304
# orr termination 0.061500812713665615 0.08711660574163782 0.025615793027972206
# remaining size for last Round 6: 119161
# 48
# ['step1_rr: 47', 'step2_rr: 47', 'step3_rr: 47', 'step4_rr: 47', 'step5_rr: 47', 'step6_rr: 47']
# empirical response rate 0.0380945796460177
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3070.9700987965853
# orr termination 0.060537048817705004 0.06634624337669612 0.005809194558991114
# remaining size for Round 3: 142082
# Calculated size for Round 3: 4780.398772805692
# orr termination 0.018934246501370808 0.10403467843850325 0.08510043193713245
# remaining size for Round 4: 137302
# Calculated size for Round 4: 5267.584519027135
# orr termination 0.0794565359809479 0.1056337689898745 0.026177233008926604
# remaining size for Round 5: 132035
# Calculated size for Round 5: 15178.887956439123
# orr termination 0.05346306546839598 0.10809620908810562 0.05463314361970964
# remaining size for last Round 6: 116857
# 49
# ['step1_rr: 48', 'step2_rr: 48', 'step3_rr: 48', 'step4_rr: 48', 'step5_rr: 48', 'step6_rr: 48']
# empirical response rate 0.04846515486725664
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3775.4192631143214
# orr termination 0.04843474427586096 0.055431588870650625 0.006996844594789664
# remaining size for Round 3: 141377
# Calculated size for Round 3: 3520.398211346426
# orr termination 0.01503577499039874 0.06587944895832953 0.0508436739679308
# remaining size for Round 4: 137857
# Calculated size for Round 4: 3371.2033253004533
# orr termination 0.02836736221257096 0.08207154059948242 0.05370417838691146
# remaining size for Round 5: 134486
# Calculated size for Round 5: 8186.731228719253
# orr termination 0.07988429212193515 0.08852929995021183 0.00864500782827668
# remaining size for last Round 6: 126300
# 50
# ['step1_rr: 49', 'step2_rr: 49', 'step3_rr: 49', 'step4_rr: 49', 'step5_rr: 49', 'step6_rr: 49']
# empirical response rate 0.03373893805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2779.5728369589106
# orr termination 0.03632531318164217 0.07748028958947605 0.041154976407833874
# remaining size for Round 3: 142373
# Calculated size for Round 3: 5085.997694431962
# orr termination 0.0015406744399721062 0.09651295206671866 0.09497227762674655
# remaining size for Round 4: 137288
# 51
# ['step1_rr: 50', 'step2_rr: 50', 'step3_rr: 50', 'step4_rr: 50', 'step5_rr: 50', 'step6_rr: 50']
# empirical response rate 0.04535398230088496
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3562.51238662459
# orr termination 0.0794273741473111 0.11086493696936547 0.03143756282205437
# remaining size for Round 3: 141590
# Calculated size for Round 3: 7195.516225696209
# orr termination 0.02256250555180299 0.13079714278216767 0.10823463723036468
# remaining size for Round 4: 134395
# Calculated size for Round 4: 9854.954935076134
# orr termination 0.019149841402559573 0.10702260079244445 0.08787275938988488
# remaining size for Round 5: 124541
# Calculated size for Round 5: 10323.497597753503
# orr termination 0.048905863910174305 0.09853032693763522 0.049624463027460916
# remaining size for last Round 6: 114218
# 52
# ['step1_rr: 51', 'step2_rr: 51', 'step3_rr: 51', 'step4_rr: 51', 'step5_rr: 51', 'step6_rr: 51']
# empirical response rate 0.040860066371681415
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3257.3582653305953
# orr termination 0.08291865897173994 0.09515325417965742 0.012234595207917476
# remaining size for Round 3: 141895
# Calculated size for Round 3: -23912.4968617621lt 0, break
# 53
# ['step1_rr: 52', 'step2_rr: 52', 'step3_rr: 52', 'step4_rr: 52', 'step5_rr: 52', 'step6_rr: 52']
# empirical response rate 0.07584347345132743
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5706.570481819797
# orr termination 0.04243100951424808 0.16773787316608368 0.1253068636518356
# remaining size for Round 3: 139446
# Calculated size for Round 3: 23511.827332248256
# orr termination 0.05230872744653721 0.09773010758579105 0.04542138013925384
# remaining size for Round 4: 115935
# Calculated size for Round 4: 7119.376754570878
# orr termination 0.054660872892177734 0.09482954815371225 0.04016867526153452
# remaining size for Round 5: 108816
# Calculated size for Round 5: 7656.766365287316
# orr termination 0.024003768608663476 0.09490924662233863 0.07090547801367515
# remaining size for last Round 6: 101160
# 54
# ['step1_rr: 53', 'step2_rr: 53', 'step3_rr: 53', 'step4_rr: 53', 'step5_rr: 53', 'step6_rr: 53']
# empirical response rate 0.06319137168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4801.3683051580465
# orr termination 0.06578718988871667 0.07319728427957062 0.007410094390853952
# remaining size for Round 3: 140351
# Calculated size for Round 3: 18437.274948659913
# orr termination 0.06814783006295566 0.08597775242020746 0.017829922357251796
# remaining size for Round 4: 121914
# Calculated size for Round 4: 6553.045804740103
# orr termination 0.05151879425045772 0.08740948310385943 0.035890688853401714
# remaining size for Round 5: 115361
# Calculated size for Round 5: 6474.161355844584
# orr termination 0.023161930378816028 0.08728031956962941 0.06411838919081338
# remaining size for last Round 6: 108887
# 55
# ['step1_rr: 54', 'step2_rr: 54', 'step3_rr: 54', 'step4_rr: 54', 'step5_rr: 54', 'step6_rr: 54']
# empirical response rate 0.0351908185840708
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2876.4109738220563
# orr termination 0.017209206991999425 0.10053576013855003 0.0833265531465506
# remaining size for Round 3: 142276
# Calculated size for Round 3: 5888.4319708494495
# orr termination 0.08226986134344177 0.09898097133677297 0.016711109993331197
# remaining size for Round 4: 136388
# Calculated size for Round 4: 18415.96732466091
# orr termination 0.0871663675430644 0.0967729656300664 0.00960659808700201
# remaining size for Round 5: 117973
# Calculated size for Round 5: 7452.448680853175
# orr termination 0.08652583826775881 0.0992870103703467 0.012761172102587898
# remaining size for last Round 6: 110521
# 56
# ['step1_rr: 55', 'step2_rr: 55', 'step3_rr: 55', 'step4_rr: 55', 'step5_rr: 55', 'step6_rr: 55']
# empirical response rate 0.04421321902654867
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3484.783847425881
# orr termination 0.02725538514766502 0.08653930147727863 0.05928391632961361
# remaining size for Round 3: 141668
# Calculated size for Round 3: 6164.87423602045
# orr termination 0.021669199156391115 0.11050529498236056 0.08883609582596944
# remaining size for Round 4: 135504
# Calculated size for Round 4: 10031.75967541209
# orr termination 0.05688495629603177 0.11124519606571058 0.05436023976967881
# remaining size for Round 5: 125473
# Calculated size for Round 5: 12453.9097048257
# orr termination 0.03528849907866847 0.10875426503622417 0.07346576595755569
# remaining size for last Round 6: 113020
# 57
# ['step1_rr: 56', 'step2_rr: 56', 'step3_rr: 56', 'step4_rr: 56', 'step5_rr: 56', 'step6_rr: 56']
# empirical response rate 0.06319137168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4801.3683051580465
# orr termination 0.023895085274617395 0.11959098176040436 0.09569589648578697
# remaining size for Round 3: 140351
# Calculated size for Round 3: 21456.99962606006
# orr termination 0.016804393048612535 0.10557504680057628 0.08877065375196375
# remaining size for Round 4: 118895
# 58
# ['step1_rr: 57', 'step2_rr: 57', 'step3_rr: 57', 'step4_rr: 57', 'step5_rr: 57', 'step6_rr: 57']
# empirical response rate 0.058351769911504425
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4460.900082113275
# orr termination 0.02564134798368549 0.10003406279328629 0.0743927148096008
# remaining size for Round 3: 140692
# Calculated size for Round 3: 25130.237897392042
# orr termination 0.01872626517188108 0.09461584915220865 0.07588958398032757
# remaining size for Round 4: 115562
# 59
# ['step1_rr: 58', 'step2_rr: 58', 'step3_rr: 58', 'step4_rr: 58', 'step5_rr: 58', 'step6_rr: 58']
# empirical response rate 0.03484513274336283
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2853.327576480575
# orr termination 0.015773744094442224 0.07377812128272368 0.058004377188281456
# remaining size for Round 3: 142299
# Calculated size for Round 3: 5648.082707916633
# orr termination 0.04428314577456609 0.08183699007844082 0.037553844303874734
# remaining size for Round 4: 136651
# Calculated size for Round 4: 10577.713507616583
# orr termination 0.05526692711215969 0.09210788565358163 0.03684095854142194
# remaining size for Round 5: 126074
# Calculated size for Round 5: 8166.411887537948
# orr termination 0.06923357019463938 0.09203963673281901 0.022806066538179626
# remaining size for last Round 6: 117908
# 60
# ['step1_rr: 59', 'step2_rr: 59', 'step3_rr: 59', 'step4_rr: 59', 'step5_rr: 59', 'step6_rr: 59']
# empirical response rate 0.04473174778761062
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3520.0925493885147
# orr termination 0.026997737941821403 0.09038671722451795 0.06338897928269654
# remaining size for Round 3: 141632
# Calculated size for Round 3: 11952.821377466751
# orr termination 0.06100753623087536 0.0961137038580036 0.03510616762712823
# remaining size for Round 4: 129680
# Calculated size for Round 4: 8405.876955561838
# orr termination 0.07889363323137799 0.09744997658726867 0.01855634335589068
# remaining size for Round 5: 121275
# Calculated size for Round 5: 8366.103164211363
# orr termination 0.07455227086370664 0.09941087957189246 0.02485860870818582
# remaining size for last Round 6: 112909
# 61
# ['step1_rr: 60', 'step2_rr: 60', 'step3_rr: 60', 'step4_rr: 60', 'step5_rr: 60', 'step6_rr: 60']
# empirical response rate 0.0829991703539823
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6228.098665219812
# orr termination 0.07230222766524347 0.130553116448074 0.05825088878283052
# remaining size for Round 3: 138924
# Calculated size for Round 3: 8702.280919237108
# orr termination 0.03203279890308326 0.1426546085424989 0.11062180963941563
# remaining size for Round 4: 130222
# Calculated size for Round 4: 10674.019780443925
# orr termination 0.008749315433572656 0.11059511370635156 0.1018457982727789
# remaining size for Round 5: 119548
# 62
# ['step1_rr: 61', 'step2_rr: 61', 'step3_rr: 61', 'step4_rr: 61', 'step5_rr: 61', 'step6_rr: 61']
# empirical response rate 0.06495436946902655
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4926.194977591092
# orr termination 0.05237554212955521 0.0983676951321531 0.04599215300259789
# remaining size for Round 3: 140226
# Calculated size for Round 3: 7105.818485541002
# orr termination 0.01312109230762545 0.10370499143148906 0.09058389912386361
# remaining size for Round 4: 133121
# Calculated size for Round 4: 7788.494821671672
# orr termination 0.07784075078964091 0.08889981488666436 0.011059064097023452
# remaining size for Round 5: 125333
# Calculated size for Round 5: 10774.948045648709
# orr termination 0.032783947231402696 0.10361315066391114 0.07082920343250844
# remaining size for last Round 6: 114559
# 63
# ['step1_rr: 62', 'step2_rr: 62', 'step3_rr: 62', 'step4_rr: 62', 'step5_rr: 62', 'step6_rr: 62']
# empirical response rate 0.08472759955752213
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6355.095390744717
# orr termination 0.06307340318706564 0.12123052435798663 0.05815712117092099
# remaining size for Round 3: 138797
# Calculated size for Round 3: 7917.247480473944
# orr termination 0.010196780458329172 0.14737312105541642 0.13717634059708725
# remaining size for Round 4: 130880
# Calculated size for Round 4: 10334.320118604599
# orr termination 0.08919522570492378 0.11160530906574483 0.02241008336082105
# remaining size for Round 5: 120546
# Calculated size for Round 5: 12676.581276571067
# orr termination 0.056574289324453866 0.110161850908266 0.05358756158381213
# remaining size for last Round 6: 107870
# 64
# ['step1_rr: 63', 'step2_rr: 63', 'step3_rr: 63', 'step4_rr: 63', 'step5_rr: 63', 'step6_rr: 63']
# empirical response rate 0.06993224557522124
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5280.93931401423
# orr termination 0.005110001255810785 0.1137084795582683 0.1085984783024575
# remaining size for Round 3: 139872
# 65
# ['step1_rr: 64', 'step2_rr: 64', 'step3_rr: 64', 'step4_rr: 64', 'step5_rr: 64', 'step6_rr: 64']
# empirical response rate 0.08856471238938053
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6638.439402074498
# orr termination 0.04788873284755572 0.1233697700901316 0.07548103724257588
# remaining size for Round 3: 138514
# Calculated size for Round 3: 7917.059815877277
# orr termination 0.012546261670909482 0.13188192714826236 0.11933566547735287
# remaining size for Round 4: 130597
# Calculated size for Round 4: 9914.002745861788
# orr termination 0.06571083495201002 0.09712570380160354 0.03141486884959352
# remaining size for Round 5: 120683
# Calculated size for Round 5: 9818.496300158064
# orr termination 0.06612418913722636 0.09040005800191708 0.024275868864690728
# remaining size for last Round 6: 110865
# 66
# ['step1_rr: 65', 'step2_rr: 65', 'step3_rr: 65', 'step4_rr: 65', 'step5_rr: 65', 'step6_rr: 65']
# empirical response rate 0.03691924778761062
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2992.078205242061
# orr termination 0.025102594940845706 0.08452878868714324 0.05942619374629753
# remaining size for Round 3: 142160
# Calculated size for Round 3: 11579.37706734198
# orr termination 0.05418054771511376 0.09684213122177485 0.042661583506661084
# remaining size for Round 4: 130581
# Calculated size for Round 4: 9210.177834290245
# orr termination 0.060619040237611325 0.10020684997652247 0.03958780973891115
# remaining size for Round 5: 121371
# Calculated size for Round 5: 8750.255255292583
# orr termination 0.06813978383905456 0.10187311907067914 0.033733335231624584
# remaining size for last Round 6: 112621
# 67
# ['step1_rr: 66', 'step2_rr: 66', 'step3_rr: 66', 'step4_rr: 66', 'step5_rr: 66', 'step6_rr: 66']
# empirical response rate 0.016178097345132744
# remaining size for Round 2: 145152
# Calculated size for Round 2: 1631.609389514148
# orr termination 0.006211524879743779 0.048262565313609146 0.042051040433865365
# remaining size for Round 3: 143521
# Calculated size for Round 3: 3482.1616796078533
# orr termination 0.013655018484158602 0.09019682268039193 0.07654180419623333
# remaining size for Round 4: 140039
# 68
# ['step1_rr: 67', 'step2_rr: 67', 'step3_rr: 67', 'step4_rr: 67', 'step5_rr: 67', 'step6_rr: 67']
# empirical response rate 0.08849557522123894
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6633.316959611526
# orr termination 0.05310695004551366 0.14302702683677376 0.0899200767912601
# remaining size for Round 3: 138519
# Calculated size for Round 3: 12347.852459635702
# orr termination 0.03663834470072751 0.1260334320528807 0.0893950873521532
# ...
# empirical response rate 0.04535398230088496
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3562.51238662459
# orr termination 0.030636768556759925 0.08211135407449241 0.051474585517732485
# remaining size for Round 3: 141590
# Calculated size for Round 3: 4494.823901181264
# orr termination 0.005949250422243837 0.10173043499860357 0.09578118457635973
# remaining size for Round 4: 137096
# Calculated size for Round 4: 9444.807545580194
# orr termination 0.043245679992728124 0.08795678883416601 0.044711108841437884
# remaining size for Round 5: 127652
# 79
# ['step1_rr: 78', 'step2_rr: 78', 'step3_rr: 78', 'step4_rr: 78', 'step5_rr: 78', 'step6_rr: 78']
# empirical response rate 0.07304341814159292
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5504.366351150113
# orr termination 0.053449515445863696 0.11343019171768827 0.05998067627182457
# remaining size for Round 3: 139648
# Calculated size for Round 3: 7994.418133895923
# orr termination 0.008691862851029295 0.12995540801032154 0.12126354515929225
# remaining size for Round 4: 131654
# Calculated size for Round 4: 10534.312703221338
# orr termination 0.03406300985011118 0.10042795673440888 0.0663649468842977
# remaining size for Round 5: 121120
# 80
# ['step1_rr: 79', 'step2_rr: 79', 'step3_rr: 79', 'step4_rr: 79', 'step5_rr: 79', 'step6_rr: 79']
# empirical response rate 0.03277101769911504
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2715.177622674948
# orr termination 0.00908642764901607 0.06532849241213702 0.05624206476312095
# remaining size for Round 3: 142437
# Calculated size for Round 3: 4701.317987497048
# orr termination 0.08048589162275058 0.09092532989331559 0.01043943827056501
# remaining size for Round 4: 137736
# Calculated size for Round 4: 29013
# orr termination 0.08960804639278769 0.10388148440927315 0.014273438016485465
# remaining size for Round 5: 108723
# Calculated size for Round 5: 7441.368917756829
# orr termination 0.018217548092685356 0.10908840295686024 0.09087085486417489
# remaining size for last Round 6: 101282
# 81
# ['step1_rr: 80', 'step2_rr: 80', 'step3_rr: 80', 'step4_rr: 80', 'step5_rr: 80', 'step6_rr: 80']
# empirical response rate 0.03723036504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3012.9425926886643
# orr termination 0.011752215463931619 0.10724704995085074 0.09549483448691912
# remaining size for Round 3: 142140
# Calculated size for Round 3: 24382.51255262325
# orr termination 0.06299250660969834 0.09690500022044911 0.03391249361075077
# remaining size for Round 4: 117758
# Calculated size for Round 4: 7420.154079105403
# orr termination 0.04821710802990996 0.09695013118617059 0.04873302315626063
# remaining size for Round 5: 110338
# 82
# ['step1_rr: 81', 'step2_rr: 81', 'step3_rr: 81', 'step4_rr: 81', 'step5_rr: 81', 'step6_rr: 81']
# empirical response rate 0.0478083517699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3730.3602223395455
# orr termination 0.0031912834859406996 0.09795221478461044 0.09476093129866975
# remaining size for Round 3: 141422
# Calculated size for Round 3: 8512.435311258554
# orr termination 0.04779358894499252 0.09488304538638541 0.04708945644139289
# remaining size for Round 4: 132910
# 83
# ['step1_rr: 82', 'step2_rr: 82', 'step3_rr: 82', 'step4_rr: 82', 'step5_rr: 82', 'step6_rr: 82']
# empirical response rate 0.08877212389380532
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6653.810492694055
# orr termination 0.10639477899665872 0.12464294840048766 0.018248169403828937
# remaining size for Round 3: 138499
# Calculated size for Round 3: 9235.630958729445
# orr termination 0.08882211972759196 0.13896541673180132 0.05014329700420936
# remaining size for Round 4: 129264
# Calculated size for Round 4: 9273.080832736932
# orr termination 0.006727936443112727 0.14797418019143116 0.14124624374831843
# remaining size for Round 5: 119991
# Calculated size for Round 5: 10043.667613567532
# orr termination 0.037861420230809524 0.11320219761102714 0.0753407773802176
# remaining size for last Round 6: 109948
# 84
# ['step1_rr: 83', 'step2_rr: 83', 'step3_rr: 83', 'step4_rr: 83', 'step5_rr: 83', 'step6_rr: 83']
# empirical response rate 0.03854397123893805
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3101.1855865909392
# orr termination 0.027999235483937054 0.11329842384737948 0.08529918836344243
# remaining size for Round 3: 142051
# Calculated size for Round 3: 12368.84181680881
# orr termination 0.009560719180561861 0.11376592324644347 0.1042052040658816
# remaining size for Round 4: 129683
# 85
# ['step1_rr: 84', 'step2_rr: 84', 'step3_rr: 84', 'step4_rr: 84', 'step5_rr: 84', 'step6_rr: 84']
# empirical response rate 0.036297013274336286
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2950.3899597530917
# orr termination 0.060285888322899994 0.07135856763553612 0.011072679312636127
# remaining size for Round 3: 142202
# Calculated size for Round 3: 6602.1319607041305
# orr termination 0.01652814930363806 0.0883363569432186 0.07180820763958054
# remaining size for Round 4: 135600
# Calculated size for Round 4: 5898.867138639943
# orr termination 0.04203216504985292 0.09551398567690672 0.053481820627053804
# remaining size for Round 5: 129702
# Calculated size for Round 5: 12655.255317053274
# orr termination 0.044366989230715304 0.09197840500833077 0.04761141577761546
# remaining size for last Round 6: 117047
# 86
# ['step1_rr: 85', 'step2_rr: 85', 'step3_rr: 85', 'step4_rr: 85', 'step5_rr: 85', 'step6_rr: 85']
# empirical response rate 0.05935425884955752
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4531.161082702762
# orr termination 0.0490643503328623 0.07773476305073013 0.028670412717867827
# remaining size for Round 3: 140621
# Calculated size for Round 3: 5377.094232988093
# orr termination 0.031627200616216766 0.09395384014719568 0.06232663953097892
# remaining size for Round 4: 135244
# Calculated size for Round 4: 6324.282368537854
# orr termination 0.08125874958963465 0.09905774166328261 0.017798992073647962
# remaining size for Round 5: 128920
# Calculated size for Round 5: 10934.895948858257
# orr termination 0.011884928763288343 0.10938814049729809 0.09750321173400975
# remaining size for last Round 6: 117986
# 87
# ['step1_rr: 86', 'step2_rr: 86', 'step3_rr: 86', 'step4_rr: 86', 'step5_rr: 86', 'step6_rr: 86']
# empirical response rate 0.03125
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2614.249528775035
# orr termination 0.011716816969715618 0.07796440171387758 0.06624758474416197
# remaining size for Round 3: 142538
# Calculated size for Round 3: 7496.681326554373
# orr termination 0.058530453283750755 0.08810998923216304 0.029579535948412283
# remaining size for Round 4: 135042
# Calculated size for Round 4: 12672.954815201167
# orr termination 0.07254060572640937 0.09704613374626439 0.02450552801985502
# remaining size for Round 5: 122370
# Calculated size for Round 5: 8341.843083573087
# orr termination 0.03342954951332459 0.09857258790668756 0.06514303839336297
# remaining size for last Round 6: 114029
# 88
# ['step1_rr: 87', 'step2_rr: 87', 'step3_rr: 87', 'step4_rr: 87', 'step5_rr: 87', 'step6_rr: 87']
# empirical response rate 0.059596238938053096
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4548.141371331619
# orr termination 0.0433021257404147 0.14845375729571464 0.10515163155529994
# remaining size for Round 3: 140604
# Calculated size for Round 3: 6127.867007597069
# orr termination 0.07481470842126768 0.13739783236410436 0.06258312394283667
# remaining size for Round 4: 134477
# Calculated size for Round 4: 19181.224772573194
# orr termination 0.018224632335516383 0.11550743518907915 0.09728280285356276
# remaining size for Round 5: 115296
# Calculated size for Round 5: 8273.429910927593
# orr termination 0.03622448272639912 0.10722760067141617 0.07100311794501704
# remaining size for last Round 6: 107023
# 89
# ['step1_rr: 88', 'step2_rr: 88', 'step3_rr: 88', 'step4_rr: 88', 'step5_rr: 88', 'step6_rr: 88']
# empirical response rate 0.055689988938053096
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4275.017492939368
# orr termination 0.02097221812992906 0.07378439582965723 0.05281217769972817
# remaining size for Round 3: 140877
# Calculated size for Round 3: 4604.31653262969
# orr termination 0.0213394671649611 0.07710736172526228 0.05576789456030118
# remaining size for Round 4: 136273
# Calculated size for Round 4: 7057.561087312363
# orr termination 0.021420440543363603 0.08517821544933346 0.06375777490596986
# remaining size for Round 5: 129216
# Calculated size for Round 5: 7891.062750527949
# orr termination 0.05744747454664679 0.08888569832821253 0.03143822378156574
# remaining size for last Round 6: 121325
# 90
# ['step1_rr: 89', 'step2_rr: 89', 'step3_rr: 89', 'step4_rr: 89', 'step5_rr: 89', 'step6_rr: 89']
# empirical response rate 0.06063329646017699
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4621.005307393422
# orr termination 0.01653474508223613 0.10709985758255036 0.09056511250031424
# remaining size for Round 3: 140531
# Calculated size for Round 3: 6191.753992828056
# orr termination 0.059118272819162196 0.09266683470164064 0.03354856188247844
# remaining size for Round 4: 134340
# Calculated size for Round 4: 10727.258844780035
# orr termination 0.025220484761513735 0.08670875535157316 0.06148827059005942
# remaining size for Round 5: 123613
# Calculated size for Round 5: 6817.588586036015
# orr termination 0.034487389372806015 0.0868522858707511 0.05236489649794508
# remaining size for last Round 6: 116796
# 91
# ['step1_rr: 90', 'step2_rr: 90', 'step3_rr: 90', 'step4_rr: 90', 'step5_rr: 90', 'step6_rr: 90']
# empirical response rate 0.06457411504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4899.235573728013
# orr termination 0.009737039191177773 0.12425348874357384 0.11451644955239607
# remaining size for Round 3: 140253
# Calculated size for Round 3: 11076.527988760154
# orr termination 0.06692041855667127 0.09121963466091906 0.02429921610424779
# remaining size for Round 4: 129177
# Calculated size for Round 4: 9528.081473328246
# orr termination 0.028916821899938355 0.09116013047674243 0.062243308576804074
# remaining size for Round 5: 119649
# 92
# ['step1_rr: 91', 'step2_rr: 91', 'step3_rr: 91', 'step4_rr: 91', 'step5_rr: 91', 'step6_rr: 91']
# empirical response rate 0.049571349557522126
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3851.4435988971077
# orr termination 0.041271555648441816 0.08386491671520613 0.04259336106676431
# remaining size for Round 3: 141301
# Calculated size for Round 3: 5689.398922922077
# orr termination 0.010510391038472974 0.10606062197192165 0.09555023093344868
# remaining size for Round 4: 135612
# Calculated size for Round 4: 7457.37052960313
# orr termination 0.02060139902593662 0.0884916517262492 0.06789025270031258
# remaining size for Round 5: 128155
# 93
# ['step1_rr: 92', 'step2_rr: 92', 'step3_rr: 92', 'step4_rr: 92', 'step5_rr: 92', 'step6_rr: 92']
# empirical response rate 0.05441095132743363
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4186.045338423161
# orr termination 0.05978933656220517 0.09827422152984955 0.03848488496764438
# remaining size for Round 3: 140966
# Calculated size for Round 3: 9869.048053449133
# orr termination 0.03289652038706573 0.10205731122597532 0.06916079083890958
# remaining size for Round 4: 131097
# Calculated size for Round 4: 8397.869907921011
# orr termination 0.02128985241851345 0.09931848590854808 0.07802863349003464
# remaining size for Round 5: 122700
# Calculated size for Round 5: 9744.382973816793
# orr termination 0.04874289316820126 0.09676320377859211 0.04802031061039085
# remaining size for last Round 6: 112956
# 94
# ['step1_rr: 93', 'step2_rr: 93', 'step3_rr: 93', 'step4_rr: 93', 'step5_rr: 93', 'step6_rr: 93']
# empirical response rate 0.05416897123893805
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4169.2382140388045
# orr termination 0.028845511262198913 0.11152983652133953 0.08268432525914063
# remaining size for Round 3: 140983
# Calculated size for Round 3: 8959.206716205223
# orr termination 0.012893657851443144 0.1031177450323075 0.09022408718086436
# remaining size for Round 4: 132024
# Calculated size for Round 4: 9493.933824207734
# orr termination 0.04582571668670359 0.09164588110974058 0.045820164423036984
# remaining size for Round 5: 122531
# 95
# ['step1_rr: 94', 'step2_rr: 94', 'step3_rr: 94', 'step4_rr: 94', 'step5_rr: 94', 'step6_rr: 94']
# empirical response rate 0.02623755530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2283.933061815767
# orr termination 0.007558922614974106 0.0545763533213232 0.04701743070634909
# remaining size for Round 3: 142869
# Calculated size for Round 3: 3892.74003797627
# orr termination 0.013688429281436647 0.07440937773361658 0.060720948452179936
# remaining size for Round 4: 138977
# Calculated size for Round 4: 13125.581999272104
# orr termination 0.047950447290413076 0.08759791556940638 0.039647468278993306
# remaining size for Round 5: 125852
# 96
# ['step1_rr: 95', 'step2_rr: 95', 'step3_rr: 95', 'step4_rr: 95', 'step5_rr: 95', 'step6_rr: 95']
# empirical response rate 0.05323561946902655
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4104.486625389775
# orr termination 0.02747491297388745 0.12174821787306381 0.09427330489917636
# remaining size for Round 3: 141048
# Calculated size for Round 3: 10901.368748511828
# orr termination 0.008136513061223484 0.11920357156127208 0.1110670585000486
# remaining size for Round 4: 130147
# 97
# ['step1_rr: 96', 'step2_rr: 96', 'step3_rr: 96', 'step4_rr: 96', 'step5_rr: 96', 'step6_rr: 96']
# empirical response rate 0.06419386061946902
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4872.29596410143
# orr termination 0.02181693595765509 0.0804313749053857 0.05861443894773061
# remaining size for Round 3: 140280
# Calculated size for Round 3: 6387.435807533768
# orr termination 0.006213966299554213 0.12017059310919789 0.11395662680964368
# remaining size for Round 4: 133893
# 98
# ['step1_rr: 97', 'step2_rr: 97', 'step3_rr: 97', 'step4_rr: 97', 'step5_rr: 97', 'step6_rr: 97']
# empirical response rate 0.04079092920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3252.685563220233
# orr termination 0.011962464495265912 0.06952172947109407 0.05755926497582816
# remaining size for Round 3: 141900
# Calculated size for Round 3: 7023.6181846554
# orr termination 0.045410967252508594 0.0922662492250146 0.046855281972506005
# remaining size for Round 4: 134877
# Calculated size for Round 4: 13900.386256830427
# orr termination 0.03140959381294661 0.09241205419566054 0.061002460382713924
# remaining size for Round 5: 120977
# 99
# ['step1_rr: 98', 'step2_rr: 98', 'step3_rr: 98', 'step4_rr: 98', 'step5_rr: 98', 'step6_rr: 98']
# empirical response rate 0.06236172566371682
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4742.773758541168
# orr termination 0.07066445298730217 0.08122455984808015 0.010560106860777976
# remaining size for Round 3: 140410
# Calculated size for Round 3: 5458.273966755301
# orr termination 0.03781470658987071 0.0989029994383634 0.061088292848492695
# remaining size for Round 4: 134952
# Calculated size for Round 4: 6043.450722386183
# orr termination 0.005660273255570454 0.11301930821948479 0.10735903496391433
# remaining size for Round 5: 128909
# Calculated size for Round 5: 8266.553908055512
# orr termination 0.06511494005744843 0.09681365824351887 0.03169871818607044
# remaining size for last Round 6: 120643
# 100
# ['step1_rr: 99', 'step2_rr: 99', 'step3_rr: 99', 'step4_rr: 99', 'step5_rr: 99', 'step6_rr: 99']
# empirical response rate 0.06498893805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4928.646813703883
# orr termination 0.023200955271213256 0.09460265135950949 0.07140169608829623
# remaining size for Round 3: 140224
# Calculated size for Round 3: 5039.243315474302
# orr termination 0.00784408164760839 0.10654951753353037 0.09870543588592198
# remaining size for Round 4: 135185
# Calculated size for Round 4: 10789.390589387749
# orr termination 0.03436629775334844 0.10229529743333055 0.0679289996799821
# remaining size for Round 5: 124396

# %% [markdown]
# ### Results summary

# %%
rr_df = pd.DataFrame(rr_dict)
rr_df
# Out:
#     step1_rr  step2_rr  step3_rr  step4_rr  step5_rr  step6_rr
# 0   0.054396  0.078530  0.081309  0.084359       NaN       NaN
# 1   0.052528  0.083724  0.088165  0.090658       NaN       NaN
# 2   0.053361  0.087416  0.094633  0.096771  0.098468  0.099401
# 3   0.054444  0.083992  0.089497  0.089427  0.094438       NaN
# 4   0.054870  0.073558  0.078578  0.086570  0.091481  0.095348
# ..       ...       ...       ...       ...       ...       ...
# 95  0.053512  0.086689  0.094272  0.098525       NaN       NaN
# 96  0.051957  0.070475  0.078233  0.099108       NaN       NaN
# 97  0.053364  0.084810  0.089790  0.091878  0.096693       NaN
# 98  0.053413  0.065950  0.069182  0.083328  0.093658  0.095393
# 99  0.058045  0.071302  0.090385  0.095800  0.096208       NaN
#
# [100 rows x 6 columns]

# %%
# Calculate average rounds:
row_non_nan_counts = rr_df.count(axis=1)

print(f"{np.mean(row_non_nan_counts):.1f} ({np.std(row_non_nan_counts):.1f})")
# Out:
# 5.3 (0.9)

# %%
# ORR for each round:
result_dict = {}
for key, values in rr_df.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"

for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_rr: 0.055 (0.002)
# step2_rr: 0.081 (0.007)
# step3_rr: 0.089 (0.007)
# step4_rr: 0.093 (0.005)
# step5_rr: 0.096 (0.004)
# step6_rr: 0.097 (0.002)

# %%
# Overall ORR:
result_dict = np.array(orr_total) / total_n
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f} ({std_result:.3f})")
# Out:
# Mean: 0.089 (0.002)

# %%
# Adaptive learning ORR:
result_dict = np.array(orr_total_adaptive) / (145152)
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f} ({std_result:.3f})")
# Out:
# Mean: 0.096 (0.003)

# %%
# highest true rr:
mean_result = (np.mean(highest_true_rr))
std_result = (np.std(highest_true_rr))
print(f"Mean: {mean_result:.3f} ({std_result:.3f})")
# Out:
# Mean: 0.098 (0.003)

# %%
# average plan number for each round:
result_dict = {}
for key, values in plan_number_dict.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.1f} ({std_value:.1f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_plan_number: nan (nan)
# step2_plan_number: 99.6 (61.7)
# step3_plan_number: 38.1 (43.2)
# step4_plan_number: 10.9 (16.5)
# step5_plan_number: 4.6 (4.6)
# step6_plan_number: 2.6 (2.3)

# %%
# early stopping probabilities:
means = {key: np.mean(values) for key, values in stopping_dict.items()}
means
# Out:
# {'early_stopping': 0.43,
#  'early_stopping_plan': 0.42,
#  'early_stopping_orr': 0.0,
#  'early_stopping_size': 0.01}

# %%
# sample size for last round:
print(np.mean(last_round_sample_size), np.std(last_round_sample_size))
# Out:
# 118781.68 9656.811945854595

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in sample_size_dict.items():
    mean_value = np.nanmean(values)
    std_value = np.nanstd(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_sample_size: 28928.000 (0.000)
# step2_sample_size: 4284.361 (1344.789)
# step3_sample_size: 12323.922 (19428.657)
# step4_sample_size: 34386.306 (48234.406)
# step5_sample_size: 38671.921 (49525.597)
# step6_sample_size: 114156.719 (7699.609)

# %%
# probability of better performance compared to the benchmark:
np.mean(better_chance)
# Out:
# 1.0

# %% [markdown]
# ## XGBoost

# %%
def ensemble_model_fit(data, data_pred):
    X_train, X_test, y_train, y_test = train_test_split(
        data.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1),
        data['response'],
        test_size=0.2,
        random_state=0
    )

    # Define the VotingClassifier with the individual classifiers
    voting_classifier = ensemble.VotingClassifier(
        estimators=[
            # ('LR', linear_model.LogisticRegression(max_iter=200, random_state=0))
#             ('Ridge', linear_model.LogisticRegression(penalty='l2', solver='lbfgs', max_iter=200, random_state=0))
                    # ('SVM', svm.SVC(kernel='linear', C=1.0, random_state=0, probability=True, class_weight='balanced'))
#                     ('RF', ensemble.RandomForestClassifier(n_estimators=200, criterion='gini', random_state=0))
                    ('XGB', XGBClassifier(n_estimators=50, learning_rate=0.1, random_state=0))
                   ],
        voting='soft'
    )

    # Define the hyperparameter grid to search
    # Best Hyperparameters: {'LR__C': 0.01, 'RF__n_estimators': 50, 'XGB__n_estimators': 50}
    param_grid = {
        # 'NB__alpha': [0.01, 0.05, 0.1],  # '__' is used to specify hyperparameters for individual classifiers
        # 'LR__C': [0.01] # [0.01, 0.05, 0.1]
        # 'Ridge__C': [0.01]
        # 'SVM__C': [0.01, 0.05, 0.1]
#         'RF__n_estimators': [50] # [10, 30, 50]
        'XGB__n_estimators': [50]
    }

    # Create a GridSearchCV object
    # custom_scorer_auc = make_scorer(roc_auc_score, needs_proba=True)
    grid_search = GridSearchCV(voting_classifier, param_grid, cv=10, scoring='roc_auc')

    # Perform the grid search on the training data
    grid_search.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = grid_search.best_params_

    # Train the final VotingClassifier with the best hyperparameters on the full training set
    final_voting_classifier = grid_search.best_estimator_
    final_voting_classifier.fit(X_train, y_train)

    # Predict probabilities instead of binary outcomes on the test set
    y_pred_proba_test = final_voting_classifier.predict_proba(X_test)
    y_pred_test = final_voting_classifier.predict(X_test)
    X_dt = data_pred.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1)
    y_pred = final_voting_classifier.predict_proba(X_dt)

    return y_pred

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import train_test_split

# def ensemble_model_fit(data, data_pred):
#     # Split the data into training and testing sets
#     X_train, X_test, y_train, y_test = train_test_split(
#         data.drop(['recruitment_plan', 'plan_response_rate', 'group_size','response'], axis=1),
#         data['response'],
#         test_size=0.2,
#         random_state=0
#     )

#     # Define the Logistic Regression model
#     logistic_regression = LogisticRegression(C=0.01, max_iter=200,random_state=0)

#     # Fit the Logistic Regression model on the training data
#     logistic_regression.fit(X_train, y_train)

#     # Print out the coefficients of the logistic regression model
#     print("Coefficients:", logistic_regression.coef_)
#     print("Intercept:", logistic_regression.intercept_)
#     print("Coefficients shape:", logistic_regression.coef_.shape)

#     # Predict probabilities instead of binary outcomes on the test set
#     y_pred_proba_test = logistic_regression.predict_proba(X_test)
#     y_pred_test = logistic_regression.predict(X_test)

#     # You can also predict probabilities for the prediction data (data_pred)
#     X_dt = data_pred.drop(['recruitment_plan', 'plan_response_rate', 'group_size','response'], axis=1)
#     y_pred = logistic_regression.predict_proba(X_dt)

#     return y_pred

# # Call the function
# # ensemble_model_fit(data, data_pred)

# %% [markdown]
# ### Simulation starts

# %%
n_sim = 100
# create a list of random seeds
random.seed(42)
random_seeds = [random.randint(1, 100000) for _ in range(n_sim)]

design_list = [5,8,10]
patient_n_list = [5468,680,170] # n_patient_per_plan

n_design = 8
n_patient_per_plan = 680
n_rounds = 6
total_n = n_patient_per_plan * (2**n_design)

## sample size determination
beta = 0.2
power = 1 - beta
alpha = 0.05
delta = 0.01 # effect size

## early stopping
epsilon = 0.001

# %%
rr_dict = {"step{}_rr".format(r): [] for r in range(1, n_rounds + 1)}
plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
sample_size_dict = {"step{}_sample_size".format(r): [] for r in range(1, n_rounds + 1)}
last_round_sample_size = []
random_rr_dict = {"step{}_random_max_rr".format(r): [] for r in range(1, n_rounds + 1)}
random_rr_dict.update({
    "step{}_random_mean_rr".format(r): [] for r in range(1, n_rounds + 1)
})

stopping_dict = {"early_stopping": [],
                 "early_stopping_plan":[],
                 "early_stopping_orr":[],
                 "early_stopping_size":[]}
final_plan_number = []
highest_rr_overall = []

better_chance = []

orr_total = []
orr_total_adaptive = []



i = 0

for seed in random_seeds:
    i += 1
    print(i)

    print([f"{key}: {len(value)}" for key, value in rr_dict.items()])



    event_list = 0
    event_list_adaptive = 0
    max_rr = []

    # step 1:
    ## Generate dataset
    dt_design_5 = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed)
    print("empirical response rate", dt_design_5['response'].mean())
    ## save for benchmark results
    maxidx = np.argmax(dt_design_5['plan_response_rate'])
    random_rr_dict['step1_random_max_rr'].append(dt_design_5.iloc[maxidx,6])
    random_rr_dict['step1_random_mean_rr'].append(dt_design_5['plan_response_rate'].mean())

    ## Ensemble modelling:
    y_pred = ensemble_model_fit(data=dt_design_5, data_pred = dt_design_5)

    ## select recruitment plan
    pred_df = pd.DataFrame(np.hstack((dt_design_5,  y_pred[:, 1].reshape(-1, 1))),
                             columns=list(dt_design_5.columns) + ['predicted_response_rate'])
    pred_df_rr = pred_df.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

    x = pred_df_rr['predicted_response_rate'].values
    if len(x) <= 10:
        best_k = 2
    else:
        best_k = kmeans_fit(data = x)['best_k']
    kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

    merged_df = pd.merge(pred_df_rr, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
    cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
    highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
    highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)


    p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))
    highest_cluster['p_vec'] = p_vec_next
    highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

    # highest_cluster = pred_df_rr

    # highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')
    # highest_cluster['cluster_number'] = highest_cluster['recruitment_plan']

    ## prepare to chance of better performance:
    temp = dt_design_5[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
    event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print("step1", np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print(temp)
    p0 = (temp['plan_response_rate'].mean())

    rr_dict["step1_rr"].append(dt_design_5['plan_response_rate'].mean())
    sample_size_dict["step1_sample_size"].append(len(dt_design_5))

    for round in range(2, n_rounds+1):

        rr_dict["step"+str(round)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))
        plan_number_dict["step"+str(round)+"_plan_number"].append(len(p_vec_next))

        ## when it comes to the last round:
        if round == n_rounds:

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            if round == 2: # if the last round is round 2
                remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
            else:
                remaining_size -= len(dt_design_5_step2up)

            print("remaining size for last Round " + str(round) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            ## data generation, combine previous data:
            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, 
                                                          design_number = n_design, n_rounds = n_rounds,
                                                          n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(0)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(len(temp), temp['plan_response_rate'].mean())
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break



        ## If haven't reached the last round:
        ## check remaining sample size:
        if round == 2:
            remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
        else:
            remaining_size -= len(dt_design_5_step2up)

        print("remaining size for Round " + str(round) + ": " + str(remaining_size))

        ## determine whether move on to step 2:
        if len(highest_cluster) == 1: # if there is only one plan left

            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size) # record the last round sample size
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(1)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        ## sample size determination:
        if round == 2:
            dt_design_5_step2up_overall = dt_design_5
        orr_1 = dt_design_5_step2up_overall['response'].mean() # observed overall response rates for previous rounds
        orr_2 = orr_1 + delta
        n_1 = len(dt_design_5_step2up_overall)

        size_step2up = sample_size_calc(orr_1, n_1, delta=delta, alpha=alpha, power=power) # total size for dataset
        if size_step2up > 0 and size_step2up < 1000:
            size_step2up = 1000 # if size in [0,1000], then it is 1000 for this round.
        elif size_step2up >= 1000:
            size_step2up = min(size_step2up, int(total_n/n_rounds)) # dataset size capped by the n_patient_per_plan
        else:
        # if size_step2up <= 0:
            # the process stops at this step
            print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up) + 'lt 0, break')
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(1)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up))

        sample_size_dict["step"+str(round)+"_sample_size"].append(size_step2up)

        ## save benchmark results for last round:
        dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                            n_patient_per_plan = n_patient_per_plan, seed=seed+round)
        maxidx = np.argmax(dt_benchmark['plan_response_rate'])
        random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
        random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

        ## data generation, combine previous data:
        dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                  design_number = n_design, n_rounds = n_rounds,
                                                  n_patient_per_plan = n_patient_per_plan, size = int(size_step2up), seed=seed)

        plan_list = dt_design_5_step2up['recruitment_plan'].unique()
        if round == 2:
            supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)]
        else:
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
        dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
        dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

        ## Ensemble model fitting:
        dt_design_5_step2up.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)
        y_pred2up = ensemble_model_fit(data = dt_design_5_step2up_overall, data_pred = dt_design_5_step2up)
        pred_df_step2up = pd.DataFrame(np.hstack((dt_design_5_step2up,  y_pred2up[:, 1].reshape(-1, 1))),
                                    columns=list(dt_design_5_step2up.columns) + ['predicted_response_rate'])
        pred_df_rr_step2up = pred_df_step2up.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

        ## select recruitment plans:
        x = pred_df_rr_step2up['predicted_response_rate'].values

        if len(x) <= 10:
            best_k = 2
        else:
            best_k = kmeans_fit(data = x)['best_k']
        kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

        ## match the cluster results back to the original data
        highest_cluster_previous = highest_cluster # save previous cluster results

        merged_df = pd.merge(pred_df_rr_step2up, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
        cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
        highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
        highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)

        # p_vec_previous = p_vec_next # save p_vec of previous round
        p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))

        highest_cluster['p_vec'] = p_vec_next

        highest_cluster = pd.merge(highest_cluster, dt_design_5_step2up[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

        ## prepare to chance of better performance:
        temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
        event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print(temp)

        ## check early stopping predicted ORR:
        orr_df = pd.merge(highest_cluster_previous, highest_cluster[['recruitment_plan','predicted_response_rate','p_vec']], on='recruitment_plan', how='left')
        orr_df.fillna(0, inplace=True)
        p_orr_1 = np.dot(np.array(orr_df['p_vec_x']), np.array(orr_df['predicted_response_rate_y']))
        p_orr_2 = np.dot(np.array(orr_df['p_vec_y']), np.array(orr_df['predicted_response_rate_y']))
        print("orr termination", p_orr_1, p_orr_2, p_orr_2 - p_orr_1)

        if (p_orr_2 - p_orr_1 < epsilon):
            # step 3 use the same strategy of step2
            print(i, p_orr_1, p_orr_2, "early stop at Round " + str(round))
            rr_dict["step"+str(round+1)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                                n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round+1)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round+1)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            ### update remaining size:
            remaining_size -= len(dt_design_5_step2up)
            print("early stop, remaining size for Round" + str(round + 1) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            for r in range(round+2, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, 
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(1)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            for r in range(round+2, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round+1), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break
# Out:
# 1
# ['step1_rr: 0', 'step2_rr: 0', 'step3_rr: 0', 'step4_rr: 0', 'step5_rr: 0', 'step6_rr: 0']
# empirical response rate 0.08033738938053098
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6033.300486728156
# orr termination 0.028243380593150458 0.1306070948183643 0.10236371422521384
# remaining size for Round 3: 139119
# Calculated size for Round 3: 9086.587828951835
# orr termination 0.012377602448893672 0.12776151972081992 0.11538391727192625
# remaining size for Round 4: 130033
# Calculated size for Round 4: 11322.570709866406
# orr termination 0.07073780401929976 0.10606157784215142 0.035323773822851665
# remaining size for Round 5: 118711
# Calculated size for Round 5: 11559.200541595686
# orr termination 0.05562178848425228 0.10909078270196915 0.053468994217716864
# remaining size for last Round 6: 107152
# 2
# ['step1_rr: 1', 'step2_rr: 1', 'step3_rr: 1', 'step4_rr: 1', 'step5_rr: 1', 'step6_rr: 1']
# empirical response rate 0.07836698008849557
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5889.708525120337
# orr termination 0.019561494444555377 0.10930190497286621 0.08974041052831083
# remaining size for Round 3: 139263
# Calculated size for Round 3: 7511.148850751564
# orr termination 0.011205038189064258 0.12312131454771041 0.11191627635864615
# remaining size for Round 4: 131752
# Calculated size for Round 4: 12707.680807367484
# orr termination 0.05245975621845277 0.1001322939991951 0.047672537780742326
# remaining size for Round 5: 119045
# 3
# ['step1_rr: 2', 'step2_rr: 2', 'step3_rr: 2', 'step4_rr: 2', 'step5_rr: 2', 'step6_rr: 2']
# empirical response rate 0.030593196902654867
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2570.7668488803606
# orr termination 0.036508613154356544 0.08159995311526662 0.045091339960910075
# remaining size for Round 3: 142582
# Calculated size for Round 3: 8333.679949744239
# orr termination 0.038337556254270655 0.0911367254564701 0.052799169202199445
# remaining size for Round 4: 134249
# Calculated size for Round 4: 8558.081785866532
# orr termination 0.04600368181144371 0.09208119313355662 0.04607751132211291
# remaining size for Round 5: 125691
# Calculated size for Round 5: 8649.478510881398
# orr termination 0.023798949027398788 0.09458663314580917 0.07078768411841038
# remaining size for last Round 6: 117042
# 4
# ['step1_rr: 3', 'step2_rr: 3', 'step3_rr: 3', 'step4_rr: 3', 'step5_rr: 3', 'step6_rr: 3']
# empirical response rate 0.06011476769911504
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4584.554843390879
# orr termination 0.04484816354296089 0.10346628966546385 0.058618126122502966
# remaining size for Round 3: 140568
# Calculated size for Round 3: 10886.835753283738
# orr termination 0.010606605033735977 0.1019363105583242 0.09132970552458822
# remaining size for Round 4: 129682
# Calculated size for Round 4: 8297.308220645129
# orr termination 0.049506116672715435 0.0970282331109047 0.04752211643818926
# remaining size for Round 5: 121385
# 5
# ['step1_rr: 4', 'step2_rr: 4', 'step3_rr: 4', 'step4_rr: 4', 'step5_rr: 4', 'step6_rr: 4']
# empirical response rate 0.09029314159292036
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6766.704057464664
# orr termination 0.039896347989448126 0.1293033579684027 0.08940700997895457
# remaining size for Round 3: 138386
# Calculated size for Round 3: 8605.397609932052
# orr termination 0.02161578290340726 0.13273544189263328 0.11111965898922602
# remaining size for Round 4: 129781
# Calculated size for Round 4: 11300.61225227053
# orr termination 0.05790730961207262 0.09186662131681866 0.033959311704746045
# remaining size for Round 5: 118481
# Calculated size for Round 5: 8218.903501233173
# orr termination 0.04171868486420201 0.09692892513428868 0.05521024027008667
# remaining size for last Round 6: 110263
# 6
# ['step1_rr: 5', 'step2_rr: 5', 'step3_rr: 5', 'step4_rr: 5', 'step5_rr: 5', 'step6_rr: 5']
# empirical response rate 0.04362555309734513
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3444.8125679843447
# orr termination 0.07809460936508715 0.08934040794053696 0.011245798575449814
# remaining size for Round 3: 141708
# Calculated size for Round 3: -68633.50621585705lt 0, break
# 7
# ['step1_rr: 6', 'step2_rr: 6', 'step3_rr: 6', 'step4_rr: 6', 'step5_rr: 6', 'step6_rr: 6']
# empirical response rate 0.04355641592920354
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3440.1132258982107
# orr termination 0.06469163979726562 0.07649310414735457 0.011801464350088942
# remaining size for Round 3: 141712
# Calculated size for Round 3: 5120.165547795912
# orr termination 0.047720637935320095 0.10155052626117467 0.05382988832585457
# remaining size for Round 4: 136592
# Calculated size for Round 4: 6454.60723458271
# orr termination 0.027025084827109677 0.10504417705060812 0.07801909222349844
# remaining size for Round 5: 130138
# Calculated size for Round 5: 7946.965605840074
# orr termination 0.0067900608161174806 0.09416041523218155 0.08737035441606407
# remaining size for last Round 6: 122192
# 8
# ['step1_rr: 7', 'step2_rr: 7', 'step3_rr: 7', 'step4_rr: 7', 'step5_rr: 7', 'step6_rr: 7']
# empirical response rate 0.08030282079646017
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6030.776854562427
# orr termination 0.02810330710725721 0.15936112772896974 0.13125782062171254
# remaining size for Round 3: 139122
# Calculated size for Round 3: 16953.77314714402
# orr termination 0.08431844934969746 0.1080957225785611 0.023777273228863638
# remaining size for Round 4: 122169
# Calculated size for Round 4: 9080.50367894296
# orr termination 0.06639389858087041 0.11239803518003837 0.04600413659916795
# remaining size for Round 5: 113089
# Calculated size for Round 5: 8511.054583450526
# orr termination 0.05511547586966897 0.11057870135757583 0.05546322548790686
# remaining size for last Round 6: 104578
# 9
# ['step1_rr: 8', 'step2_rr: 8', 'step3_rr: 8', 'step4_rr: 8', 'step5_rr: 8', 'step6_rr: 8']
# empirical response rate 0.04777378318584071
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3727.99035410021
# orr termination 0.04408441127235293 0.07793901047386914 0.03385459920151621
# remaining size for Round 3: 141425
# Calculated size for Round 3: 5857.332140858882
# orr termination 0.04705090745325141 0.09077480586788084 0.043723898414629425
# remaining size for Round 4: 135568
# Calculated size for Round 4: 7340.645430674691
# orr termination 0.003522753682795603 0.09589888155460358 0.09237612787180798
# remaining size for Round 5: 128228
# 10
# ['step1_rr: 9', 'step2_rr: 9', 'step3_rr: 9', 'step4_rr: 9', 'step5_rr: 9', 'step6_rr: 9']
# empirical response rate 0.043037887168141595
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3404.8893784747597
# orr termination 0.015566691563381307 0.07758794743724975 0.06202125587386845
# remaining size for Round 3: 141748
# Calculated size for Round 3: 4601.457462925366
# orr termination 0.00762797707440321 0.08225613444765323 0.07462815737325001
# remaining size for Round 4: 137147
# Calculated size for Round 4: 9777.294904195325
# orr termination 0.04451099423380877 0.08925844728946686 0.04474745305565809
# remaining size for Round 5: 127370
# 11
# ['step1_rr: 10', 'step2_rr: 10', 'step3_rr: 10', 'step4_rr: 10', 'step5_rr: 10', 'step6_rr: 10']
# empirical response rate 0.03297842920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2728.965581830211
# orr termination 0.04647261799013326 0.07550334966632694 0.029030731676193675
# remaining size for Round 3: 142424
# Calculated size for Round 3: 24826.481283994417
# orr termination 0.014939646204150309 0.09065713470407268 0.07571748849992237
# remaining size for Round 4: 117598
# Calculated size for Round 4: 6499.134947027208
# orr termination 0.0450526876904919 0.0902922973036766 0.045239609613184704
# remaining size for Round 5: 111099
# 12
# ['step1_rr: 11', 'step2_rr: 11', 'step3_rr: 11', 'step4_rr: 11', 'step5_rr: 11', 'step6_rr: 11']
# empirical response rate 0.034603152654867256
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2837.1791262040406
# orr termination 0.03492035150389556 0.06883114137641488 0.033910789872519324
# remaining size for Round 3: 142315
# Calculated size for Round 3: 11394.702307178424
# orr termination 0.007037973832999617 0.08973277360200882 0.0826947997690092
# remaining size for Round 4: 130921
# 13
# ['step1_rr: 12', 'step2_rr: 12', 'step3_rr: 12', 'step4_rr: 12', 'step5_rr: 12', 'step6_rr: 12']
# empirical response rate 0.04124032079646018
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3283.0700374646344
# orr termination 0.021122060046809804 0.07702865993303591 0.05590659988622611
# remaining size for Round 3: 141869
# Calculated size for Round 3: 4664.646352115455
# orr termination 0.032563972324759 0.08807172415771403 0.055507751832955025
# remaining size for Round 4: 137205
# Calculated size for Round 4: 10151.002682505397
# orr termination 0.01942198907593694 0.10354986955052856 0.08412788047459162
# remaining size for Round 5: 127054
# Calculated size for Round 5: 10323.236961107912
# orr termination 0.04660386213970062 0.09190411865711212 0.0453002565174115
# remaining size for last Round 6: 116731
# 14
# ['step1_rr: 13', 'step2_rr: 13', 'step3_rr: 13', 'step4_rr: 13', 'step5_rr: 13', 'step6_rr: 13']
# empirical response rate 0.07079646017699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5342.870662026109
# orr termination 0.06586101660065365 0.11863130729642632 0.05277029069577267
# remaining size for Round 3: 139810
# Calculated size for Round 3: 9002.322622240448
# orr termination 0.012632155427903403 0.13374084908562772 0.12110869365772432
# remaining size for Round 4: 130808
# Calculated size for Round 4: 9950.79324292859
# orr termination 0.03211354324427691 0.09766636625371067 0.06555282300943376
# remaining size for Round 5: 120858
# Calculated size for Round 5: 9415.351330285037
# orr termination 0.05203517195739281 0.09787196666002274 0.04583679470262993
# remaining size for last Round 6: 111443
# 15
# ['step1_rr: 14', 'step2_rr: 14', 'step3_rr: 14', 'step4_rr: 14', 'step5_rr: 14', 'step6_rr: 14']
# empirical response rate 0.03135370575221239
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2621.120723895575
# orr termination 0.019251331997666273 0.06082669425145752 0.04157536225379125
# remaining size for Round 3: 142531
# Calculated size for Round 3: 3492.221452707345
# orr termination 0.010901691625944291 0.07814724744594206 0.06724555581999778
# remaining size for Round 4: 139039
# Calculated size for Round 4: 5076.5992155322765
# orr termination 0.06895080060967895 0.09542450006544546 0.02647369945576651
# remaining size for Round 5: 133963
# Calculated size for Round 5: 29013
# orr termination 0.05972543446489838 0.09999402482818572 0.04026859036328734
# remaining size for last Round 6: 104950
# 16
# ['step1_rr: 15', 'step2_rr: 15', 'step3_rr: 15', 'step4_rr: 15', 'step5_rr: 15', 'step6_rr: 15']
# empirical response rate 0.07231747787610619
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5452.116013979351
# orr termination 0.007971773124676935 0.11891825372052421 0.11094648059584727
# remaining size for Round 3: 139700
# Calculated size for Round 3: 8267.117843218935
# orr termination 0.05738104777533562 0.09736552672519691 0.03998447894986129
# remaining size for Round 4: 131433
# Calculated size for Round 4: 13057.71553356278
# orr termination 0.06198539238658149 0.09319948307873627 0.031214090692154778
# remaining size for Round 5: 118376
# Calculated size for Round 5: 7746.224448770638
# orr termination 0.046902584614325414 0.09384144842624664 0.04693886381192123
# remaining size for last Round 6: 110630
# 17
# ['step1_rr: 16', 'step2_rr: 16', 'step3_rr: 16', 'step4_rr: 16', 'step5_rr: 16', 'step6_rr: 16']
# empirical response rate 0.02900304203539823
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2465.7425695144257
# orr termination 0.01742327569276982 0.06850038680178819 0.05107711110901837
# remaining size for Round 3: 142687
# Calculated size for Round 3: 4118.867915622046
# orr termination 0.04052417194954849 0.07064494899597759 0.030120777046429098
# remaining size for Round 4: 138569
# Calculated size for Round 4: 7786.535321090952
# orr termination 0.03141087839860348 0.07776837919860669 0.046357500800003205
# remaining size for Round 5: 130783
# Calculated size for Round 5: 6919.074736224539
# orr termination 0.05526486217277837 0.08278881237354518 0.02752395020076681
# remaining size for last Round 6: 123864
# 18
# ['step1_rr: 17', 'step2_rr: 17', 'step3_rr: 17', 'step4_rr: 17', 'step5_rr: 17', 'step6_rr: 17']
# empirical response rate 0.038682245575221236
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3110.4883281384073
# orr termination 0.024266403522384884 0.0706285164699386 0.04636211294755372
# remaining size for Round 3: 142042
# Calculated size for Round 3: 3490.2524812434294
# orr termination 0.02380714844124171 0.09522001162241152 0.07141286318116981
# remaining size for Round 4: 138552
# Calculated size for Round 4: 7770.143371255386
# orr termination 0.03439287788968899 0.10305168557950237 0.06865880768981338
# remaining size for Round 5: 130782
# Calculated size for Round 5: 11659.224251632813
# orr termination 0.07602039810734837 0.1005159176832783 0.024495519575929936
# remaining size for last Round 6: 119123
# 19
# ['step1_rr: 18', 'step2_rr: 18', 'step3_rr: 18', 'step4_rr: 18', 'step5_rr: 18', 'step6_rr: 18']
# empirical response rate 0.04860342920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3784.913012723484
# orr termination 0.02423742296971726 0.08287325666077025 0.05863583369105299
# remaining size for Round 3: 141368
# Calculated size for Round 3: 5597.302041473389
# orr termination 0.009496453435756426 0.09306436434156369 0.08356791090580726
# remaining size for Round 4: 135771
# Calculated size for Round 4: 9391.989237981905
# orr termination 0.03023500889402847 0.09071460366249084 0.060479594768462375
# remaining size for Round 5: 126380
# 20
# ['step1_rr: 19', 'step2_rr: 19', 'step3_rr: 19', 'step4_rr: 19', 'step5_rr: 19', 'step6_rr: 19']
# empirical response rate 0.09053512168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6784.692301555903
# orr termination 0.08554199091860064 0.14443543497322225 0.058893444054621616
# remaining size for Round 3: 138368
# Calculated size for Round 3: 10147.633950075635
# orr termination 0.00998080117978169 0.1773525319141248 0.1673717307343431
# remaining size for Round 4: 128221
# Calculated size for Round 4: 11363.898025363678
# orr termination 0.05318198962718697 0.10664411984935324 0.05346213022216627
# remaining size for Round 5: 116858
# Calculated size for Round 5: 11724.6056785801
# orr termination 0.05218709686291195 0.10489842295646667 0.05271132609355472
# remaining size for last Round 6: 105134
# 21
# ['step1_rr: 20', 'step2_rr: 20', 'step3_rr: 20', 'step4_rr: 20', 'step5_rr: 20', 'step6_rr: 20']
# empirical response rate 0.04127488938053098
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3285.4084707208544
# orr termination 0.027490330984086514 0.10270395829682123 0.07521362731273472
# remaining size for Round 3: 141867
# Calculated size for Round 3: 9590.11247852977
# orr termination 0.021682991529864647 0.10659599394864523 0.08491300241878058
# remaining size for Round 4: 132277
# Calculated size for Round 4: 10551.83180806321
# orr termination 0.06674511610300685 0.10254783820202022 0.035802722099013376
# remaining size for Round 5: 121726
# Calculated size for Round 5: 10320.02820559255
# orr termination 0.0521471403536843 0.10265351831912994 0.050506377965445645
# remaining size for last Round 6: 111406
# 22
# ['step1_rr: 21', 'step2_rr: 21', 'step3_rr: 21', 'step4_rr: 21', 'step5_rr: 21', 'step6_rr: 21']
# empirical response rate 0.09153761061946902
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6859.296443568507
# orr termination 0.038917283969869064 0.13856579509249364 0.09964851112262457
# remaining size for Round 3: 138293
# Calculated size for Round 3: 8616.216288879146
# orr termination 0.019985642393800223 0.14058018013492474 0.12059453774112451
# remaining size for Round 4: 129677
# Calculated size for Round 4: 12989.44206748189
# orr termination 0.022824131575748884 0.11159926652908325 0.08877513495333436
# remaining size for Round 5: 116688
# 23
# ['step1_rr: 22', 'step2_rr: 22', 'step3_rr: 22', 'step4_rr: 22', 'step5_rr: 22', 'step6_rr: 22']
# empirical response rate 0.11189850663716815
# remaining size for Round 2: 145152
# Calculated size for Round 2: 8402.348985484643
# orr termination 0.11223097079248169 0.1346567421275327 0.022425771335051012
# remaining size for Round 3: 136750
# Calculated size for Round 3: 8632.44103379548
# orr termination 0.049229482934237026 0.18361667391420972 0.1343871909799727
# remaining size for Round 4: 128118
# Calculated size for Round 4: 9785.19159854193
# orr termination 0.047073714592646185 0.16604531966427893 0.11897160507163275
# remaining size for Round 5: 118333
# Calculated size for Round 5: 15243.859683298033
# orr termination 0.02104861018163849 0.11642033720561469 0.0953717270239762
# remaining size for last Round 6: 103090
# 24
# ['step1_rr: 23', 'step2_rr: 23', 'step3_rr: 23', 'step4_rr: 23', 'step5_rr: 23', 'step6_rr: 23']
# empirical response rate 0.06201603982300885
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4718.387240976126
# orr termination 0.08049705340477867 0.10888850355949045 0.028391450154711784
# remaining size for Round 3: 140434
# Calculated size for Round 3: 7740.759664255125
# orr termination 0.02093074637295579 0.13300224245868583 0.11207149608573004
# remaining size for Round 4: 132694
# Calculated size for Round 4: 9272.130020157696
# orr termination 0.04302538744369495 0.10465536495640133 0.06162997751270639
# remaining size for Round 5: 123422
# Calculated size for Round 5: 10740.546410710795
# orr termination 0.03979839668418933 0.10043609562419993 0.0606376989400106
# remaining size for last Round 6: 112682
# 25
# ['step1_rr: 24', 'step2_rr: 24', 'step3_rr: 24', 'step4_rr: 24', 'step5_rr: 24', 'step6_rr: 24']
# empirical response rate 0.05008987831858407
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3887.138480086987
# orr termination 0.00499521567680687 0.09019807538580352 0.08520285970899664
# remaining size for Round 3: 141265
# Calculated size for Round 3: 6923.494792543116
# orr termination 0.0336491610205166 0.09336108714342117 0.059711926122904574
# remaining size for Round 4: 134342
# 26
# ['step1_rr: 25', 'step2_rr: 25', 'step3_rr: 25', 'step4_rr: 25', 'step5_rr: 25', 'step6_rr: 25']
# empirical response rate 0.03297842920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2728.965581830211
# orr termination 0.03575409690585384 0.05828819565098023 0.022534098745126387
# remaining size for Round 3: 142424
# Calculated size for Round 3: 5653.418424448843
# orr termination 0.03907858676243031 0.05310184847812492 0.01402326171569461
# remaining size for Round 4: 136771
# Calculated size for Round 4: 4742.074131867806
# orr termination 0.014590394636998752 0.05821745886636209 0.04362706422936334
# remaining size for Round 5: 132029
# Calculated size for Round 5: 4745.080017022759
# orr termination 0.029375183624756416 0.07373431752097234 0.04435913389621593
# remaining size for last Round 6: 127284
# 27
# ['step1_rr: 26', 'step2_rr: 26', 'step3_rr: 26', 'step4_rr: 26', 'step5_rr: 26', 'step6_rr: 26']
# empirical response rate 0.033842643805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2786.4800847064803
# orr termination 0.027705988454515454 0.0422225635406932 0.01451657508617775
# remaining size for Round 3: 142366
# Calculated size for Round 3: 3481.363518056131
# orr termination 0.008194304331654339 0.05087487448747295 0.04268057015581861
# remaining size for Round 4: 138885
# Calculated size for Round 4: 3670.086821109463
# orr termination 0.036197000423697834 0.07145383432228707 0.03525683389858923
# remaining size for Round 5: 135215
# Calculated size for Round 5: 17808.989805107234
# orr termination 0.06308766601033143 0.09354645516567434 0.030458789155342905
# remaining size for last Round 6: 117407
# 28
# ['step1_rr: 27', 'step2_rr: 27', 'step3_rr: 27', 'step4_rr: 27', 'step5_rr: 27', 'step6_rr: 27']
# empirical response rate 0.06077157079646018
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4630.73167611316
# orr termination 0.04283996517415053 0.08478805255739241 0.041948087383241885
# remaining size for Round 3: 140522
# Calculated size for Round 3: 5821.431991047379
# orr termination 0.04014458076861049 0.08838785326322263 0.04824327249461214
# remaining size for Round 4: 134701
# Calculated size for Round 4: 6692.7843991169475
# orr termination 0.03280792237127786 0.08819234532256168 0.05538442295128382
# remaining size for Round 5: 128009
# Calculated size for Round 5: 7232.7958033010245
# orr termination 0.01614086061934227 0.09151081704864034 0.07536995642929807
# remaining size for last Round 6: 120777
# 29
# ['step1_rr: 28', 'step2_rr: 28', 'step3_rr: 28', 'step4_rr: 28', 'step5_rr: 28', 'step6_rr: 28']
# empirical response rate 0.06277654867256637
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4772.059228563532
# orr termination 0.015836615344637806 0.1255597576999838 0.10972314235534598
# remaining size for Round 3: 140380
# Calculated size for Round 3: 8885.153825565592
# orr termination 0.08368942476995501 0.09665883400086037 0.012969409230905352
# remaining size for Round 4: 131495
# Calculated size for Round 4: 10624.590433502883
# orr termination 0.04850109662872089 0.08809356757802059 0.0395924709492997
# remaining size for Round 5: 120871
# Calculated size for Round 5: 7065.340139359128
# orr termination 0.013125325623463822 0.08873500674962997 0.07560968112616615
# remaining size for last Round 6: 113806
# 30
# ['step1_rr: 29', 'step2_rr: 29', 'step3_rr: 29', 'step4_rr: 29', 'step5_rr: 29', 'step6_rr: 29']
# empirical response rate 0.07840154867256637
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5892.22320205354
# orr termination 0.07679615976724308 0.09699235888569288 0.020196199118449804
# remaining size for Round 3: 139260
# Calculated size for Round 3: 6440.891690702097
# orr termination 0.03668195183901455 0.11556925856440908 0.07888730672539454
# remaining size for Round 4: 132820
# Calculated size for Round 4: 6954.929925500608
# orr termination 0.022406770537351673 0.1209949913120671 0.09858822077471543
# remaining size for Round 5: 125866
# Calculated size for Round 5: 10011.582941870296
# orr termination 0.029828322489080742 0.10354621312227545 0.07371789063319471
# remaining size for last Round 6: 115855
# 31
# ['step1_rr: 30', 'step2_rr: 30', 'step3_rr: 30', 'step4_rr: 30', 'step5_rr: 30', 'step6_rr: 30']
# empirical response rate 0.07701880530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5791.761187324277
# orr termination 0.06496880493586485 0.14110391303950626 0.07613510810364141
# remaining size for Round 3: 139361
# Calculated size for Round 3: 9562.22011659967
# orr termination 0.015752760484338622 0.15000354273339997 0.13425078224906134
# remaining size for Round 4: 129799
# Calculated size for Round 4: 10832.453855657966
# orr termination 0.03451488373868828 0.10942371621684106 0.07490883247815278
# remaining size for Round 5: 118967
# Calculated size for Round 5: 11100.910684269658
# orr termination 0.05009286241990589 0.10059918463230133 0.05050632221239544
# remaining size for last Round 6: 107867
# 32
# ['step1_rr: 31', 'step2_rr: 31', 'step3_rr: 31', 'step4_rr: 31', 'step5_rr: 31', 'step6_rr: 31']
# empirical response rate 0.08019911504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6023.206915866293
# orr termination 0.03382126559575985 0.1370496040921655 0.10322833849640564
# remaining size for Round 3: 139129
# Calculated size for Round 3: 8390.276009926387
# orr termination 0.015302155016773244 0.12442791956707895 0.1091257645503057
# remaining size for Round 4: 130739
# Calculated size for Round 4: 11239.043003050605
# orr termination 0.07895330093732711 0.09818764252367196 0.01923434158634485
# remaining size for Round 5: 119500
# Calculated size for Round 5: 9969.809939476714
# orr termination 0.026629281243916104 0.10371903330087662 0.07708975205696052
# remaining size for last Round 6: 109531
# 33
# ['step1_rr: 32', 'step2_rr: 32', 'step3_rr: 32', 'step4_rr: 32', 'step5_rr: 32', 'step6_rr: 32']
# empirical response rate 0.07892007743362832
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5929.962574211673
# orr termination 0.016182010502159283 0.13083792239574527 0.11465591189358598
# remaining size for Round 3: 139223
# Calculated size for Round 3: 7407.62900464
# orr termination 0.0063719574635026114 0.10976036638021469 0.10338840891671208
# remaining size for Round 4: 131816
# 34
# ['step1_rr: 33', 'step2_rr: 33', 'step3_rr: 33', 'step4_rr: 33', 'step5_rr: 33', 'step6_rr: 33']
# empirical response rate 0.07159153761061947
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5399.937054375382
# orr termination 0.05413653214264403 0.12045903718399666 0.06632250504135262
# remaining size for Round 3: 139753
# Calculated size for Round 3: 10144.120792219537
# orr termination 0.005071722169276124 0.1433410793542862 0.13826935718501007
# remaining size for Round 4: 129609
# 35
# ['step1_rr: 34', 'step2_rr: 34', 'step3_rr: 34', 'step4_rr: 34', 'step5_rr: 34', 'step6_rr: 34']
# empirical response rate 0.08182383849557522
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6141.967523856308
# orr termination 0.08866756538054829 0.09625041063200239 0.007582845251454098
# remaining size for Round 3: 139011
# Calculated size for Round 3: 8251.122206198967
# orr termination 0.03953484102426759 0.11667080355928974 0.07713596253502215
# remaining size for Round 4: 130760
# Calculated size for Round 4: 7760.73316043267
# orr termination 0.06994202395895148 0.11488274842133747 0.04494072446238599
# remaining size for Round 5: 123000
# Calculated size for Round 5: 10569.048408743934
# orr termination 0.006257078421595806 0.10717760026454926 0.10092052184295344
# remaining size for last Round 6: 112431
# 36
# ['step1_rr: 35', 'step2_rr: 35', 'step3_rr: 35', 'step4_rr: 35', 'step5_rr: 35', 'step6_rr: 35']
# empirical response rate 0.04206996681415929
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3339.2384022405945
# orr termination 0.045861845609135005 0.06909059215936521 0.023228746550230203
# remaining size for Round 3: 141813
# Calculated size for Round 3: 4289.623320243135
# orr termination 0.039122374771363974 0.08309817094741975 0.04397579617605578
# remaining size for Round 4: 137524
# Calculated size for Round 4: 5462.44373909616
# orr termination 0.008079347178831305 0.11211837945944086 0.10403903228060957
# remaining size for Round 5: 132062
# Calculated size for Round 5: 7481.136428069864
# orr termination 0.06534285521881612 0.09825246388955342 0.03290960867073729
# remaining size for last Round 6: 124581
# 37
# ['step1_rr: 36', 'step2_rr: 36', 'step3_rr: 36', 'step4_rr: 36', 'step5_rr: 36', 'step6_rr: 36']
# empirical response rate 0.04580337389380531
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3593.182438999496
# orr termination 0.06001960656770235 0.08619239646693432 0.02617278989923197
# remaining size for Round 3: 141559
# Calculated size for Round 3: 10348.246899848271
# orr termination 0.06320414183377114 0.10362416544485716 0.040420023611086014
# remaining size for Round 4: 131211
# Calculated size for Round 4: 7806.034313377802
# orr termination 0.03580260525485018 0.09437568175624902 0.05857307650139885
# remaining size for Round 5: 123405
# Calculated size for Round 5: 7573.89138830543
# orr termination 0.07935050044978967 0.09631557594025088 0.01696507549046121
# remaining size for last Round 6: 115832
# 38
# ['step1_rr: 37', 'step2_rr: 37', 'step3_rr: 37', 'step4_rr: 37', 'step5_rr: 37', 'step6_rr: 37']
# empirical response rate 0.047912057522123894
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3737.4708232996927
# orr termination 0.03729370349796553 0.0987215449448543 0.06142784144688877
# remaining size for Round 3: 141415
# Calculated size for Round 3: 7491.895841669475
# orr termination 0.04829444089794133 0.09999733825880694 0.051702897360865606
# remaining size for Round 4: 133924
# Calculated size for Round 4: 9917.812756666362
# orr termination 0.04277923074015258 0.10757532307761428 0.0647960923374617
# remaining size for Round 5: 124007
# Calculated size for Round 5: 9399.06124889963
# orr termination 0.06928977138250456 0.10336295219015049 0.03407318080764593
# remaining size for last Round 6: 114608
# 39
# ['step1_rr: 38', 'step2_rr: 38', 'step3_rr: 38', 'step4_rr: 38', 'step5_rr: 38', 'step6_rr: 38']
# empirical response rate 0.07466814159292036
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5621.565807308865
# orr termination 0.025860005495468123 0.11459797510313063 0.0887379696076625
# remaining size for Round 3: 139531
# Calculated size for Round 3: 13170.951899248497
# orr termination 0.02395925108804578 0.10213625406530055 0.07817700297725477
# remaining size for Round 4: 126361
# Calculated size for Round 4: 8252.071094742878
# orr termination 0.049783529470287156 0.1013856902718544 0.051602160801567244
# remaining size for Round 5: 118109
# 40
# ['step1_rr: 39', 'step2_rr: 39', 'step3_rr: 39', 'step4_rr: 39', 'step5_rr: 39', 'step6_rr: 39']
# empirical response rate 0.06301852876106195
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4789.153321772453
# orr termination 0.03229437113099954 0.13373828211186395 0.10144391098086442
# remaining size for Round 3: 140363
# Calculated size for Round 3: 20644.770656322726
# orr termination 0.035241878962940204 0.1062086447716028 0.0709667658086626
# remaining size for Round 4: 119719
# Calculated size for Round 4: 8145.6853524381
# orr termination 0.0341833014232335 0.1032545194029808 0.0690712179797473
# remaining size for Round 5: 111574
# 41
# ['step1_rr: 40', 'step2_rr: 40', 'step3_rr: 40', 'step4_rr: 40', 'step5_rr: 40', 'step6_rr: 40']
# empirical response rate 0.0742878871681416
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5594.104185697372
# orr termination 0.08282459928957873 0.13662604840328477 0.05380144911370603
# remaining size for Round 3: 139558
# Calculated size for Round 3: 13557.455292474307
# orr termination 0.016452579979486875 0.13473603168480908 0.1182834517053222
# remaining size for Round 4: 126001
# Calculated size for Round 4: 9914.03442486392
# orr termination 0.0787945913069175 0.09805536948902183 0.019260778182104324
# remaining size for Round 5: 116087
# Calculated size for Round 5: 10410.302395531848
# orr termination 0.07199577088216938 0.09640705776083508 0.0244112868786657
# remaining size for last Round 6: 105677
# 42
# ['step1_rr: 41', 'step2_rr: 41', 'step3_rr: 41', 'step4_rr: 41', 'step5_rr: 41', 'step6_rr: 41']
# empirical response rate 0.05403069690265487
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4159.637779672868
# orr termination 0.04554350230178333 0.08621684662836943 0.0406733443265861
# remaining size for Round 3: 140993
# Calculated size for Round 3: 12464.584627267544
# orr termination 0.027296382995132495 0.12525877608760497 0.09796239309247247
# remaining size for Round 4: 128529
# Calculated size for Round 4: 7696.6641253185635
# orr termination 0.03258761898214407 0.09845589846372604 0.06586827948158197
# remaining size for Round 5: 120833
# 43
# ['step1_rr: 42', 'step2_rr: 42', 'step3_rr: 42', 'step4_rr: 42', 'step5_rr: 42', 'step6_rr: 42']
# empirical response rate 0.05517146017699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# orr termination 0.01610244914340075 0.11608091379012296 0.0999784646467222
# remaining size for Round 3: 140914
# Calculated size for Round 3: 19106.89405330373
# orr termination 0.07352721847496912 0.09796969633171257 0.024442477856743444
# remaining size for Round 4: 121808
# Calculated size for Round 4: 8036.787313600268
# orr termination 0.06638638910171449 0.09927853041005932 0.032892141308344836
# remaining size for Round 5: 113772
# Calculated size for Round 5: 7843.635926707375
# orr termination 0.05103422778920137 0.10085014998912811 0.04981592219992674
# remaining size for last Round 6: 105929
# 44
# ['step1_rr: 43', 'step2_rr: 43', 'step3_rr: 43', 'step4_rr: 43', 'step5_rr: 43', 'step6_rr: 43']
# empirical response rate 0.04348727876106195
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3435.414549437817
# orr termination 0.027226472732650397 0.1026424763993188 0.0754160036666684
# remaining size for Round 3: 141717
# Calculated size for Round 3: 8771.116229037798
# orr termination 0.03902404646270917 0.10094170236812293 0.06191765590541376
# remaining size for Round 4: 132946
# Calculated size for Round 4: 10730.531557560693
# orr termination 0.04027549055390893 0.10234165542464997 0.06206616487074104
# remaining size for Round 5: 122216
# Calculated size for Round 5: 9280.661533225486
# orr termination 0.050430351396688736 0.09982690215110779 0.04939655075441905
# remaining size for last Round 6: 112936
# 45
# ['step1_rr: 44', 'step2_rr: 44', 'step3_rr: 44', 'step4_rr: 44', 'step5_rr: 44', 'step6_rr: 44']
# empirical response rate 0.052751659292035395
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4070.959200908221
# orr termination 0.04487040319612811 0.09860945765343496 0.05373905445730685
# remaining size for Round 3: 141082
# Calculated size for Round 3: 4972.48481487342
# orr termination 0.056542631783994234 0.10515050272259421 0.04860787093859998
# remaining size for Round 4: 136110
# Calculated size for Round 4: 8930.935556414104
# orr termination 0.022563483203340413 0.10777990131859197 0.08521641811525156
# remaining size for Round 5: 127180
# Calculated size for Round 5: 8819.649762679284
# orr termination 0.06977719321489032 0.1042220294335629 0.034444836218672586
# remaining size for last Round 6: 118361
# 46
# ['step1_rr: 45', 'step2_rr: 45', 'step3_rr: 45', 'step4_rr: 45', 'step5_rr: 45', 'step6_rr: 45']
# empirical response rate 0.08092505530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6076.226646023446
# orr termination 0.04603041183053222 0.13835878984350675 0.09232837801297453
# remaining size for Round 3: 139076
# Calculated size for Round 3: 20864.485762115793
# orr termination 0.03235500053129435 0.09535254648283484 0.06299754595154049
# remaining size for Round 4: 118212
# Calculated size for Round 4: 7091.579049657324
# orr termination 0.04746721260061753 0.0951299652191833 0.047662752618565764
# remaining size for Round 5: 111121
# Calculated size for Round 5: 8688.733120552226
# orr termination 0.04646963381221139 0.09390465170145035 0.047435017889238956
# remaining size for last Round 6: 102433
# 47
# ['step1_rr: 46', 'step2_rr: 46', 'step3_rr: 46', 'step4_rr: 46', 'step5_rr: 46', 'step6_rr: 46']
# empirical response rate 0.047428097345132744
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3704.3008047850903
# orr termination 0.06500723326677335 0.09092432339151502 0.025917090124741665
# remaining size for Round 3: 141448
# Calculated size for Round 3: 6236.817617579807
# orr termination 0.004492003376759093 0.10051122405004749 0.0960192206732884
# remaining size for Round 4: 135212
# Calculated size for Round 4: 6660.122730479306
# orr termination 0.02591440622329489 0.10008008778095245 0.07416568155765757
# remaining size for Round 5: 128552
# 48
# ['step1_rr: 47', 'step2_rr: 47', 'step3_rr: 47', 'step4_rr: 47', 'step5_rr: 47', 'step6_rr: 47']
# empirical response rate 0.0380945796460177
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3070.9700987965853
# orr termination 0.04151396581894492 0.09908598891724185 0.05757202309829693
# remaining size for Round 3: 142082
# Calculated size for Round 3: 8560.733270746448
# orr termination 0.03413485110171431 0.11283072954132264 0.07869587843960833
# remaining size for Round 4: 133522
# Calculated size for Round 4: 10370.68041392808
# orr termination 0.09202167577660934 0.10707102841889492 0.015049352642285574
# remaining size for Round 5: 123152
# Calculated size for Round 5: 10699.348648336701
# orr termination 0.0904049697586392 0.10791013739075109 0.017505167632111893
# remaining size for last Round 6: 112453
# 49
# ['step1_rr: 48', 'step2_rr: 48', 'step3_rr: 48', 'step4_rr: 48', 'step5_rr: 48', 'step6_rr: 48']
# empirical response rate 0.04846515486725664
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3775.4192631143214
# orr termination 0.01915635809963389 0.06931467068166329 0.0501583125820294
# remaining size for Round 3: 141377
# Calculated size for Round 3: 3681.796000729355
# orr termination 0.02890614559524359 0.08803484879090151 0.05912870319565792
# remaining size for Round 4: 137696
# Calculated size for Round 4: 7558.025702089737
# orr termination 0.03987580543711773 0.0977431684694663 0.05786736303234857
# remaining size for Round 5: 130138
# Calculated size for Round 5: 10733.596926242535
# orr termination 0.04281433729718416 0.10480171714905095 0.061987379851866795
# remaining size for last Round 6: 119405
# 50
# ['step1_rr: 49', 'step2_rr: 49', 'step3_rr: 49', 'step4_rr: 49', 'step5_rr: 49', 'step6_rr: 49']
# empirical response rate 0.03373893805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2779.5728369589106
# orr termination 0.027295511477220855 0.06670007280108849 0.03940456132386763
# remaining size for Round 3: 142373
# Calculated size for Round 3: 26653.776419066653
# orr termination 0.046806146026329716 0.09011665688046883 0.04331051085413911
# remaining size for Round 4: 115720
# Calculated size for Round 4: 6455.273679073263
# orr termination 0.04472707525695295 0.08876456320285797 0.04403748794590502
# remaining size for Round 5: 109265
# 51
# ['step1_rr: 50', 'step2_rr: 50', 'step3_rr: 50', 'step4_rr: 50', 'step5_rr: 50', 'step6_rr: 50']
# empirical response rate 0.04535398230088496
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3562.51238662459
# orr termination 0.03528807919124913 0.12443932077970186 0.08915124158845274
# remaining size for Round 3: 141590
# Calculated size for Round 3: 21322.085735473094
# orr termination 0.07362574883772474 0.09782408022690181 0.02419833138917707
# remaining size for Round 4: 120268
# Calculated size for Round 4: 7490.717708637155
# orr termination 0.04494416067033925 0.09810030930455826 0.05315614863421901
# remaining size for Round 5: 112778
# Calculated size for Round 5: 7363.515019252922
# orr termination 0.04990071101609829 0.10032496536845137 0.05042425435235308
# remaining size for last Round 6: 105415
# 52
# ['step1_rr: 51', 'step2_rr: 51', 'step3_rr: 51', 'step4_rr: 51', 'step5_rr: 51', 'step6_rr: 51']
# empirical response rate 0.040860066371681415
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3257.3582653305953
# orr termination 0.025892593057442077 0.09165586821571775 0.06576327515827568
# remaining size for Round 3: 141895
# Calculated size for Round 3: 29013
# orr termination 0.06168599121856404 0.1015786974010324 0.03989270618246836
# remaining size for Round 4: 112882
# Calculated size for Round 4: 7303.265928849807
# orr termination 0.033441015042865396 0.10020288825035095 0.06676187320748556
# remaining size for Round 5: 105579
# 53
# ['step1_rr: 52', 'step2_rr: 52', 'step3_rr: 52', 'step4_rr: 52', 'step5_rr: 52', 'step6_rr: 52']
# empirical response rate 0.07584347345132743
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5706.570481819797
# orr termination 0.013558965560061404 0.1274246380192826 0.1138656724592212
# remaining size for Round 3: 139446
# Calculated size for Round 3: 26490.313438528094
# orr termination 0.04991838422741129 0.09968738257884979 0.049768998351438505
# remaining size for Round 4: 112956
# 54
# ['step1_rr: 53', 'step2_rr: 53', 'step3_rr: 53', 'step4_rr: 53', 'step5_rr: 53', 'step6_rr: 53']
# empirical response rate 0.06319137168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4801.3683051580465
# orr termination 0.06970911164594173 0.09293991778589819 0.023230806139956456
# remaining size for Round 3: 140351
# Calculated size for Round 3: 10363.853976953133
# orr termination 0.037521428332800394 0.08645177307108191 0.04893034473828152
# remaining size for Round 4: 129988
# Calculated size for Round 4: 6818.017520400451
# orr termination 0.03279221909396027 0.08665911480186142 0.05386689570790115
# remaining size for Round 5: 123170
# Calculated size for Round 5: 7401.373666589409
# orr termination 0.016026715666437277 0.09249375760555267 0.0764670419391154
# remaining size for last Round 6: 115769
# 55
# ['step1_rr: 54', 'step2_rr: 54', 'step3_rr: 54', 'step4_rr: 54', 'step5_rr: 54', 'step6_rr: 54']
# empirical response rate 0.0351908185840708
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2876.4109738220563
# orr termination 0.021583090432587895 0.09530261128006895 0.07371952084748105
# remaining size for Round 3: 142276
# Calculated size for Round 3: 13103.538355046236
# orr termination 0.060782558524585195 0.09749843044393712 0.036715871919351925
# remaining size for Round 4: 129173
# Calculated size for Round 4: 9090.397520157883
# orr termination 0.05786170909364569 0.09738334532229614 0.03952163622865045
# remaining size for Round 5: 120083
# Calculated size for Round 5: 8318.158190658398
# orr termination 0.06595326038729549 0.09919292812383128 0.03323966773653579
# remaining size for last Round 6: 111765
# 56
# ['step1_rr: 55', 'step2_rr: 55', 'step3_rr: 55', 'step4_rr: 55', 'step5_rr: 55', 'step6_rr: 55']
# empirical response rate 0.04421321902654867
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3484.783847425881
# orr termination 0.043747418786135236 0.07814774255012844 0.0344003237639932
# remaining size for Round 3: 141668
# Calculated size for Round 3: 6138.2747325691635
# orr termination 0.0220365129825678 0.09252187798967215 0.07048536500710435
# remaining size for Round 4: 135530
# Calculated size for Round 4: 6866.897481153428
# orr termination 0.03677304014867054 0.10700453916219912 0.07023149901352858
# remaining size for Round 5: 128664
# Calculated size for Round 5: 14278.689528572539
# orr termination 0.08071386594648874 0.10743133314010178 0.026717467193613037
# remaining size for last Round 6: 114386
# 57
# ['step1_rr: 56', 'step2_rr: 56', 'step3_rr: 56', 'step4_rr: 56', 'step5_rr: 56', 'step6_rr: 56']
# empirical response rate 0.06319137168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4801.3683051580465
# orr termination 0.09604261280567244 0.10616506791343984 0.010122455107767395
# remaining size for Round 3: 140351
# Calculated size for Round 3: 29013
# orr termination 0.07860740085355358 0.09913851178711652 0.02053111093356294
# remaining size for Round 4: 111338
# Calculated size for Round 4: 6938.231315948025
# orr termination 0.030300812784248565 0.10361286403993555 0.07331205125568699
# remaining size for Round 5: 104400
# Calculated size for Round 5: 7178.174274282052
# orr termination 0.052117582883077156 0.1025337427854538 0.05041615990237664
# remaining size for last Round 6: 97222
# 58
# ['step1_rr: 57', 'step2_rr: 57', 'step3_rr: 57', 'step4_rr: 57', 'step5_rr: 57', 'step6_rr: 57']
# empirical response rate 0.058351769911504425
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4460.900082113275
# orr termination 0.06198725593308049 0.12025970913325833 0.058272453200177834
# remaining size for Round 3: 140692
# Calculated size for Round 3: 9725.28591933105
# orr termination 0.02266713916254922 0.113632677037277 0.09096553787472778
# remaining size for Round 4: 130967
# Calculated size for Round 4: 8708.399763440806
# orr termination 0.05414533281827083 0.07798609184075622 0.02384075902248539
# remaining size for Round 5: 122259
# Calculated size for Round 5: 7383.971493664296
# orr termination 0.05520630029271252 0.07641880694475109 0.021212506652038568
# remaining size for last Round 6: 114876
# 59
# ['step1_rr: 58', 'step2_rr: 58', 'step3_rr: 58', 'step4_rr: 58', 'step5_rr: 58', 'step6_rr: 58']
# empirical response rate 0.03484513274336283
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2853.327576480575
# orr termination 0.013958385062118743 0.07353310574568489 0.059574720683566146
# remaining size for Round 3: 142299
# Calculated size for Round 3: 11156.89133584386
# orr termination 0.06347569373935315 0.08816432143668718 0.02468862769733403
# remaining size for Round 4: 131143
# Calculated size for Round 4: 8853.582629043929
# orr termination 0.030716777137555808 0.08949743211269379 0.05878065497513798
# remaining size for Round 5: 122290
# 60
# ['step1_rr: 59', 'step2_rr: 59', 'step3_rr: 59', 'step4_rr: 59', 'step5_rr: 59', 'step6_rr: 59']
# empirical response rate 0.04473174778761062
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3520.0925493885147
# orr termination 0.06415461698518171 0.07822385440171661 0.014069237416534902
# remaining size for Round 3: 141632
# Calculated size for Round 3: 10601.598620674364
# orr termination 0.022020010313409083 0.1001866158798251 0.07816660556641601
# remaining size for Round 4: 131031
# Calculated size for Round 4: 7013.1771064094655
# orr termination 0.042417697178939784 0.10067929672001477 0.05826159954107499
# remaining size for Round 5: 124018
# Calculated size for Round 5: 11691.580709381884
# orr termination 0.050953122241617244 0.10177072137594223 0.05081759913432499
# remaining size for last Round 6: 112327
# 61
# ['step1_rr: 60', 'step2_rr: 60', 'step3_rr: 60', 'step4_rr: 60', 'step5_rr: 60', 'step6_rr: 60']
# empirical response rate 0.0829991703539823
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6228.098665219812
# orr termination 0.04037199543369331 0.15986940291918583 0.11949740748549252
# remaining size for Round 3: 138924
# Calculated size for Round 3: 12634.17671678264
# orr termination 0.02517058944895038 0.11443340910797185 0.08926281965902147
# remaining size for Round 4: 126290
# Calculated size for Round 4: 9490.469916506283
# orr termination 0.05082580518871996 0.10158804037528621 0.05076223518656625
# remaining size for Round 5: 116800
# Calculated size for Round 5: 10547.13610478794
# orr termination 0.04911352175888177 0.09814311563968658 0.049029593880804814
# remaining size for last Round 6: 106253
# 62
# ['step1_rr: 61', 'step2_rr: 61', 'step3_rr: 61', 'step4_rr: 61', 'step5_rr: 61', 'step6_rr: 61']
# empirical response rate 0.06495436946902655
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4926.194977591092
# orr termination 0.07183075379609216 0.08518418173412436 0.013353427938032195
# remaining size for Round 3: 140226
# Calculated size for Round 3: 6134.941550195635
# orr termination 0.020416928898360102 0.09638651638042191 0.07596958748206181
# remaining size for Round 4: 134092
# Calculated size for Round 4: 6213.629415278419
# orr termination 0.02337494653725535 0.10699897432572932 0.08362402778847397
# remaining size for Round 5: 127879
# Calculated size for Round 5: 10342.922687921688
# orr termination 0.05278674420799821 0.10641697251430841 0.0536302283063102
# remaining size for last Round 6: 117537
# 63
# ['step1_rr: 62', 'step2_rr: 62', 'step3_rr: 62', 'step4_rr: 62', 'step5_rr: 62', 'step6_rr: 62']
# empirical response rate 0.08472759955752213
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6355.095390744717
# orr termination 0.06089081072887152 0.11994289939378855 0.05905208866491703
# remaining size for Round 3: 138797
# Calculated size for Round 3: 8108.233136530877
# orr termination 0.03291259409131189 0.14076041239112508 0.10784781829981319
# remaining size for Round 4: 130689
# Calculated size for Round 4: 10481.40792325095
# orr termination 0.026590781768429522 0.13354284168064767 0.10695205991221815
# remaining size for Round 5: 120208
# Calculated size for Round 5: 12037.497591024343
# orr termination 0.03754561473832088 0.11004044860601425 0.07249483386769337
# remaining size for last Round 6: 108171
# 64
# ['step1_rr: 63', 'step2_rr: 63', 'step3_rr: 63', 'step4_rr: 63', 'step5_rr: 63', 'step6_rr: 63']
# empirical response rate 0.06993224557522124
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5280.93931401423
# orr termination 0.06733302291350815 0.10438703393827617 0.03705401102476802
# remaining size for Round 3: 139872
# Calculated size for Round 3: 11313.502103904546
# orr termination 0.011758911405622156 0.09687258014281196 0.0851136687371898
# remaining size for Round 4: 128559
# Calculated size for Round 4: 7280.3691552312985
# orr termination 0.033683130538956975 0.10094277560710907 0.0672596450681521
# remaining size for Round 5: 121279
# 65
# ['step1_rr: 64', 'step2_rr: 64', 'step3_rr: 64', 'step4_rr: 64', 'step5_rr: 64', 'step6_rr: 64']
# empirical response rate 0.08856471238938053
# remaining size for Round 2: 145152
# ...
# 67
# ['step1_rr: 66', 'step2_rr: 66', 'step3_rr: 66', 'step4_rr: 66', 'step5_rr: 66', 'step6_rr: 66']
# empirical response rate 0.016178097345132744
# remaining size for Round 2: 145152
# Calculated size for Round 2: 1631.609389514148
# orr termination 0.024801965963157466 0.03321689644269876 0.008414930479541297
# remaining size for Round 3: 143521
# Calculated size for Round 3: 3499.012056704881
# orr termination 0.014078341442828372 0.043932647789393584 0.02985430634656521
# remaining size for Round 4: 140022
# Calculated size for Round 4: 3875.7874680210707
# orr termination 0.03932677252839313 0.07957159131409092 0.040244818785697786
# remaining size for Round 5: 136147
# Calculated size for Round 5: 14402.99646866485
# orr termination 0.04686420357275756 0.09127024282087658 0.04440603924811902
# remaining size for last Round 6: 121745
# 68
# ['step1_rr: 67', 'step2_rr: 67', 'step3_rr: 67', 'step4_rr: 67', 'step5_rr: 67', 'step6_rr: 67']
# empirical response rate 0.08849557522123894
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6633.316959611526
# orr termination 0.046366612253192566 0.14106194338770972 0.09469533113451716
# remaining size for Round 3: 138519
# Calculated size for Round 3: 10513.365494906846
# orr termination 0.02558003233616756 0.11899780074387206 0.0934177684077045
# remaining size for Round 4: 128006
# Calculated size for Round 4: 10459.729451323416
# orr termination 0.018588426397905054 0.11397765576839447 0.09538922937048941
# remaining size for Round 5: 117547
# 69
# ['step1_rr: 68', 'step2_rr: 68', 'step3_rr: 68', 'step4_rr: 68', 'step5_rr: 68', 'step6_rr: 68']
# empirical response rate 0.06073700221238938
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4628.299837474318
# orr termination 0.008422688457275335 0.12399665307053684 0.1155739646132615
# remaining size for Round 3: 140524
# Calculated size for Round 3: 14664.367709884607
# orr termination 0.031045715437674405 0.09221304208040237 0.06116732664272797
# remaining size for Round 4: 125860
# 70
# ['step1_rr: 69', 'step2_rr: 69', 'step3_rr: 69', 'step4_rr: 69', 'step5_rr: 69', 'step6_rr: 69']
# empirical response rate 0.053823285398230086
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4145.242088058297
# orr termination 0.01737239412700283 0.07975457147254059 0.062382177345537755
# remaining size for Round 3: 141007
# Calculated size for Round 3: 4551.609934966866
# orr termination 0.03396746934862187 0.10002815451440021 0.06606068516577834
# remaining size for Round 4: 136456
# Calculated size for Round 4: 12562.564016330633
# orr termination 0.08574782606436264 0.09735232491076735 0.011604498846404715
# remaining size for Round 5: 123894
# Calculated size for Round 5: 9156.775673800232
# orr termination 0.030694109296833992 0.10534413573588244 0.07465002643904844
# remaining size for last Round 6: 114738
# 71
# ['step1_rr: 70', 'step2_rr: 70', 'step3_rr: 70', 'step4_rr: 70', 'step5_rr: 70', 'step6_rr: 70']
# empirical response rate 0.037264933628318585
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3015.2616918343456
# orr termination 0.017217424522225314 0.0647941552929317 0.047576730770706385
# remaining size for Round 3: 142137
# Calculated size for Round 3: 4321.774170147295
# orr termination 0.03910894833807068 0.07283397901912445 0.033725030681053765
# remaining size for Round 4: 137816
# Calculated size for Round 4: 7616.948677841961
# orr termination 0.007998561347916103 0.08712530136108398 0.07912674001316788
# remaining size for Round 5: 130200
# 72
# ['step1_rr: 71', 'step2_rr: 71', 'step3_rr: 71', 'step4_rr: 71', 'step5_rr: 71', 'step6_rr: 71']
# empirical response rate 0.04089463495575221
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3259.694866267412
# orr termination 0.008803072473816304 0.07063613582884054 0.06183306335502424
# remaining size for Round 3: 141893
# Calculated size for Round 3: 4382.82231480457
# orr termination 0.02805513251662667 0.09813152263884595 0.07007639012221928
# remaining size for Round 4: 137511
# Calculated size for Round 4: 25714.24257662512
# orr termination 0.034141226891268646 0.1041569709777832 0.07001574408651456
# remaining size for Round 5: 111797
# 73
# ['step1_rr: 72', 'step2_rr: 72', 'step3_rr: 72', 'step4_rr: 72', 'step5_rr: 72', 'step6_rr: 72']
# empirical response rate 0.017042311946902654
# remaining size for Round 2: 145152
# Calculated size for Round 2: 1687.0964287990566
# orr termination 0.005760012390143298 0.03055149976902094 0.024791487378877642
# remaining size for Round 3: 143465
# Calculated size for Round 3: 2073.7351971721414
# orr termination 0.007812603313576479 0.04165682044536184 0.03384421713178536
# remaining size for Round 4: 141392
# Calculated size for Round 4: 4194.419728774228
# orr termination 0.029195672685086133 0.0883922278881073 0.05919655520302117
# remaining size for Round 5: 137198
# 74
# ['step1_rr: 73', 'step2_rr: 73', 'step3_rr: 73', 'step4_rr: 73', 'step5_rr: 73', 'step6_rr: 73']
# empirical response rate 0.061359236725663714
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4672.098065320721
# orr termination 0.008008660023162896 0.10899005468827792 0.10098139466511502
# remaining size for Round 3: 140480
# Calculated size for Round 3: 11960.017770106222
# orr termination 0.048209068095237326 0.09723944962024689 0.04903038152500956
# remaining size for Round 4: 128520
# 75
# ['step1_rr: 74', 'step2_rr: 74', 'step3_rr: 74', 'step4_rr: 74', 'step5_rr: 74', 'step6_rr: 74']
# empirical response rate 0.06775442477876106
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5125.322856327205
# orr termination 0.01818374472086156 0.11203441411655979 0.09385066939569822
# remaining size for Round 3: 140027
# Calculated size for Round 3: 8059.206072464578
# orr termination 0.03373254715645762 0.09880693511122318 0.06507438795476556
# remaining size for Round 4: 131968
# Calculated size for Round 4: 11610.781605421178
# orr termination 0.07000904623975776 0.09309649844501607 0.023087452205258305
# remaining size for Round 5: 120358
# Calculated size for Round 5: 8849.833957340643
# orr termination 0.0631656192785201 0.09375329689321156 0.030587677614691458
# remaining size for last Round 6: 111509
# 76
# ['step1_rr: 75', 'step2_rr: 75', 'step3_rr: 75', 'step4_rr: 75', 'step5_rr: 75', 'step6_rr: 75']
# empirical response rate 0.028933904867256638
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2461.184309921726
# orr termination 0.014116706397237666 0.08887209514366057 0.0747553887464229
# remaining size for Round 3: 142691
# Calculated size for Round 3: 9449.811144392304
# orr termination 0.0733535184605495 0.08899111126887087 0.015637592808321374
# remaining size for Round 4: 133242
# Calculated size for Round 4: 10639.905321677716
# orr termination 0.07645207845100942 0.09395471424431505 0.017502635793305632
# remaining size for Round 5: 122603
# Calculated size for Round 5: 7784.843068194979
# orr termination 0.02605141496563338 0.10199180245399475 0.07594038748836138
# remaining size for last Round 6: 114819
# 77
# ['step1_rr: 76', 'step2_rr: 76', 'step3_rr: 76', 'step4_rr: 76', 'step5_rr: 76', 'step6_rr: 76']
# empirical response rate 0.03373893805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2779.5728369589106
# orr termination 0.041233251755794786 0.05136609819028394 0.010132846434489154
# remaining size for Round 3: 142373
# Calculated size for Round 3: 3961.3845415924616
# orr termination 0.0044193884950667 0.07433095964683994 0.06991157115177324
# remaining size for Round 4: 138412
# Calculated size for Round 4: 4496.708877245007
# orr termination 0.01911218332806855 0.0948946475982666 0.07578246427019805
# remaining size for Round 5: 133916
# 78
# ['step1_rr: 77', 'step2_rr: 77', 'step3_rr: 77', 'step4_rr: 77', 'step5_rr: 77', 'step6_rr: 77']
# empirical response rate 0.04535398230088496
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3562.51238662459
# orr termination 0.052148420022306935 0.07529571893411095 0.023147298911804018
# remaining size for Round 3: 141590
# Calculated size for Round 3: 6084.674818616904
# orr termination 0.0356145041826541 0.08935665621591335 0.05374215203325925
# remaining size for Round 4: 135506
# Calculated size for Round 4: 6944.556888279002
# orr termination 0.03290597031162057 0.08231937796222884 0.04941340765060827
# remaining size for Round 5: 128562
# Calculated size for Round 5: 7532.777090617504
# orr termination 0.011633277401579064 0.09300898015499115 0.08137570275341209
# remaining size for last Round 6: 121030
# 79
# ['step1_rr: 78', 'step2_rr: 78', 'step3_rr: 78', 'step4_rr: 78', 'step5_rr: 78', 'step6_rr: 78']
# empirical response rate 0.07304341814159292
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5504.366351150113
# orr termination 0.02541654810858516 0.11645562290960684 0.09103907480102169
# remaining size for Round 3: 139648
# Calculated size for Round 3: 7674.597740194279
# orr termination 0.024723277081033602 0.12165255304676328 0.09692927596572969
# remaining size for Round 4: 131974
# Calculated size for Round 4: 13282.28735551291
# orr termination 0.05811348639748069 0.09864200947564625 0.040528523078165554
# remaining size for Round 5: 118692
# Calculated size for Round 5: 8838.464202558403
# orr termination 0.06747452307781604 0.1008455077728912 0.033370984695075157
# remaining size for last Round 6: 109854
# 80
# ['step1_rr: 79', 'step2_rr: 79', 'step3_rr: 79', 'step4_rr: 79', 'step5_rr: 79', 'step6_rr: 79']
# empirical response rate 0.03277101769911504
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2715.177622674948
# orr termination 0.05887454269893098 0.09992317999639468 0.0410486372974637
# remaining size for Round 3: 142437
# Calculated size for Round 3: -13841.469185410942lt 0, break
# 81
# ['step1_rr: 80', 'step2_rr: 80', 'step3_rr: 80', 'step4_rr: 80', 'step5_rr: 80', 'step6_rr: 80']
# empirical response rate 0.03723036504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3851.4435988971077
# orr termination 0.03166996731600645 0.08232966266099517 0.05065969534498872
# remaining size for Round 3: 141301
# Calculated size for Round 3: 4902.22034857871
# orr termination 0.007108463001606699 0.11230200016295601 0.10519353716134931
# remaining size for Round 4: 136399
# Calculated size for Round 4: 7553.881375201907
# orr termination 0.054243911070269234 0.08286027105217586 0.028616359981906626
# remaining size for Round 5: 128846
# Calculated size for Round 5: 12030.898414969235
# orr termination 0.04407717608968176 0.08908043056726456 0.0450032544775828
# remaining size for last Round 6: 116816
# 93
# ['step1_rr: 92', 'step2_rr: 92', 'step3_rr: 92', 'step4_rr: 92', 'step5_rr: 92', 'step6_rr: 92']
# empirical response rate 0.05441095132743363
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4186.045338423161
# orr termination 0.009893128007367653 0.10216247084268046 0.09226934283531281
# remaining size for Round 3: 140966
# Calculated size for Round 3: 4656.529380236925
# orr termination 0.03449091517752219 0.10564158783620561 0.07115067265868343
# remaining size for Round 4: 136310
# Calculated size for Round 4: 29013
# orr termination 0.04911424507608518 0.09823869652059951 0.04912445144451433
# remaining size for Round 5: 107297
# Calculated size for Round 5: 7050.636531755982
# orr termination 0.048446370688381146 0.09713445603847504 0.04868808535009389
# remaining size for last Round 6: 100247
# 94
# ['step1_rr: 93', 'step2_rr: 93', 'step3_rr: 93', 'step4_rr: 93', 'step5_rr: 93', 'step6_rr: 93']
# empirical response rate 0.05416897123893805
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4169.2382140388045
# orr termination 0.008287032092380952 0.10986223788025501 0.10157520578787406
# remaining size for Round 3: 140983
# Calculated size for Round 3: 7803.321011411978
# orr termination 0.07611390770772908 0.09497245643380503 0.018858548726075952
# remaining size for Round 4: 133180
# Calculated size for Round 4: 13638.62552274579
# orr termination 0.023521986348196904 0.09303223341703415 0.06951024706883724
# remaining size for Round 5: 119542
# 95
# ['step1_rr: 94', 'step2_rr: 94', 'step3_rr: 94', 'step4_rr: 94', 'step5_rr: 94', 'step6_rr: 94']
# empirical response rate 0.02623755530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2283.933061815767
# orr termination 0.004678175655693497 0.057179120525597406 0.05250094486990391
# remaining size for Round 3: 142869
# Calculated size for Round 3: 3720.575636375043
# orr termination 0.017442239780506463 0.07863809168338776 0.06119585190288129
# remaining size for Round 4: 139149
# 96
# ['step1_rr: 95', 'step2_rr: 95', 'step3_rr: 95', 'step4_rr: 95', 'step5_rr: 95', 'step6_rr: 95']
# empirical response rate 0.05323561946902655
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4104.486625389775
# orr termination 0.05847615437037353 0.07883613066252121 0.020359976292147676
# remaining size for Round 3: 141048
# Calculated size for Round 3: 4435.7593498288725
# orr termination 0.038321895398455375 0.10603921765242968 0.06771732225397431
# remaining size for Round 4: 136613
# Calculated size for Round 4: 6036.577243966009
# orr termination 0.018138558035713057 0.114761511037907 0.09662295300219394
# remaining size for Round 5: 130577
# Calculated size for Round 5: 11001.745272398563
# orr termination 0.017330736337740522 0.10499346256256104 0.08766272622482052
# remaining size for last Round 6: 119576
# 97
# ['step1_rr: 96', 'step2_rr: 96', 'step3_rr: 96', 'step4_rr: 96', 'step5_rr: 96', 'step6_rr: 96']
# empirical response rate 0.06419386061946902
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4872.29596410143
# orr termination 0.005907368323750566 0.08878686101624826 0.0828794926924977
# remaining size for Round 3: 140280
# Calculated size for Round 3: 6524.329587343094
# orr termination 0.021818115602327538 0.09285826981067657 0.07104015420834904
# remaining size for Round 4: 133756
# 98
# ['step1_rr: 97', 'step2_rr: 97', 'step3_rr: 97', 'step4_rr: 97', 'step5_rr: 97', 'step6_rr: 97']
# empirical response rate 0.04079092920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3252.685563220233
# orr termination 0.011488505340287693 0.07320073438711117 0.06171222904682347
# remaining size for Round 3: 141900
# Calculated size for Round 3: 6473.586258619355
# orr termination 0.06371424229729036 0.09673386614680171 0.03301962384951135
# remaining size for Round 4: 135427
# Calculated size for Round 4: 17701.41217302569
# orr termination 0.02307426068241456 0.0942559540271759 0.07118169334476135
# remaining size for Round 5: 117726
# 99
# ['step1_rr: 98', 'step2_rr: 98', 'step3_rr: 98', 'step4_rr: 98', 'step5_rr: 98', 'step6_rr: 98']
# empirical response rate 0.06236172566371682
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4742.773758541168
# orr termination 0.05586321364185359 0.0868532429234781 0.030990029281624504
# remaining size for Round 3: 140410
# Calculated size for Round 3: 5969.747093024291
# orr termination 0.04464188736385078 0.099000903429376 0.05435901606552521
# remaining size for Round 4: 134441
# Calculated size for Round 4: 7070.866355003311
# orr termination 0.006924090521261656 0.10628310330364325 0.0993590127823816
# remaining size for Round 5: 127371
# Calculated size for Round 5: 7933.757512111784
# orr termination 0.032876830278411484 0.09896916151046753 0.06609233123205605
# remaining size for last Round 6: 119438
# 100
# ['step1_rr: 99', 'step2_rr: 99', 'step3_rr: 99', 'step4_rr: 99', 'step5_rr: 99', 'step6_rr: 99']
# empirical response rate 0.06498893805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4928.646813703883
# orr termination 0.06725177005052418 0.07453759925931515 0.007285829208790964
# remaining size for Round 3: 140224
# Calculated size for Round 3: 5558.377631824825
# orr termination 0.055373011324903035 0.07903561009471102 0.023662598769807988
# remaining size for Round 4: 134666
# Calculated size for Round 4: 5280.207512986761
# orr termination 0.0661364735996787 0.07754686109855165 0.011410387498872951
# remaining size for Round 5: 129386
# Calculated size for Round 5: 5638.959953914194
# orr termination 0.012615847423159882 0.08992977713408065 0.07731392971092077
# remaining size for last Round 6: 123748

# %% [markdown]
# ### Results summary

# %%
rr_df = pd.DataFrame(rr_dict)
rr_df
# Out:
#     step1_rr  step2_rr  step3_rr  step4_rr  step5_rr  step6_rr
# 0   0.054396  0.070295  0.078934  0.089636  0.090734  0.093620
# 1   0.052528  0.074177  0.086270  0.092497  0.098554       NaN
# 2   0.053361  0.087269  0.092155  0.095123  0.097144  0.099401
# 3   0.054444  0.082225  0.086903  0.095683  0.098377       NaN
# 4   0.054870  0.070507  0.072940  0.075614  0.085809  0.097719
# ..       ...       ...       ...       ...       ...       ...
# 95  0.053512  0.067440  0.076367  0.091650  0.094239  0.093985
# 96  0.051957  0.070790  0.081487  0.095419       NaN       NaN
# 97  0.053364  0.078225  0.093246  0.093573  0.094931       NaN
# 98  0.053413  0.067511  0.075186  0.086497  0.089630  0.099327
# 99  0.058045  0.073097  0.076330  0.081440  0.083898  0.090148
#
# [100 rows x 6 columns]

# %%
# Calculate average rounds:
row_non_nan_counts = rr_df.count(axis=1)

print(f"{np.mean(row_non_nan_counts):.1f} ({np.std(row_non_nan_counts):.1f})")
# Out:
# 5.5 (0.7)

# %%
# ORR for each round:
result_dict = {}
for key, values in rr_df.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"

for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_rr: 0.055 (0.002)
# step2_rr: 0.079 (0.008)
# step3_rr: 0.088 (0.007)
# step4_rr: 0.093 (0.005)
# step5_rr: 0.096 (0.003)
# step6_rr: 0.097 (0.002)

# %%
# overall orr:
result_dict = np.array(orr_total) / total_n
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f}, StD: {std_result:.3f}")
# Out:
# Mean: 0.089, StD: 0.002

# %%
# highest true rr:
print(np.max(highest_true_rr))
print(np.std(highest_true_rr))
# Out:
# 0.09999923871657082
# 0.0025259100947249806

# %%
# adaptive learning orr:
result_dict = np.array(orr_total_adaptive) / (145152)
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f}, StD: {std_result:.3f}")
# Out:
# Mean: 0.096, StD: 0.003

# %%
# average plan number for each round:
result_dict = {}
for key, values in plan_number_dict.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.1f} ({std_value:.1f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_plan_number: nan (nan)
# step2_plan_number: 97.2 (60.1)
# step3_plan_number: 39.1 (39.5)
# step4_plan_number: 11.4 (15.3)
# step5_plan_number: 4.6 (9.1)
# step6_plan_number: 2.1 (1.7)

# %%
# early stopping probabilities:
means = {key: np.mean(values) for key, values in stopping_dict.items()}
means
# Out:
# {'early_stopping': 0.37,
#  'early_stopping_plan': 0.35,
#  'early_stopping_orr': 0.0,
#  'early_stopping_size': 0.02}

# %%
print(np.mean(last_round_sample_size), np.std(last_round_sample_size))
# Out:
# 116989.04 9351.301639793253

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in sample_size_dict.items():
    mean_value = np.nanmean(values)
    std_value = np.nanstd(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_sample_size: 28928.000 (0.000)
# step2_sample_size: 4284.361 (1344.789)
# step3_sample_size: 12121.751 (19535.674)
# step4_sample_size: 20434.512 (35042.463)
# step5_sample_size: 42108.729 (50388.031)
# step6_sample_size: 113087.286 (6569.725)

# %%
np.mean(better_chance)
# Out:
# 1.0

# %% [markdown]
# ## Ensemble learning - 3 methods

# %%
# def ensemble_model_fit(data, data_pred):
#     X_train, X_test, y_train, y_test = train_test_split(
#         data.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1),
#         data['response'],
#         test_size=0.2,
#         random_state=0
#     )

#     # Define the VotingClassifier with the individual classifiers
#     voting_classifier = ensemble.VotingClassifier(
#         estimators=[
#             ('LR', linear_model.LogisticRegression(max_iter=200, random_state=0)),
# #             ('Ridge', linear_model.LogisticRegression(penalty='l2', solver='lbfgs', max_iter=200, random_state=0))
#                     # ('SVM', svm.SVC(kernel='linear', C=1.0, random_state=0, probability=True, class_weight='balanced'))
#                     ('RF', ensemble.RandomForestClassifier(criterion='gini', random_state=0)),
#                     ('XGB', XGBClassifier(learning_rate=0.1, random_state=0))
#                    ],
#         voting='soft'
#     )

#     # Define the hyperparameter grid to search
#     # Best Hyperparameters: {'LR__C': 0.01, 'RF__n_estimators': 50, 'XGB__n_estimators': 50}
#     param_grid = {
#         # 'NB__alpha': [0.01, 0.05, 0.1],  # '__' is used to specify hyperparameters for individual classifiers
#         'LR__C': [0.01, 0.05, 0.1],
#         # 'Ridge__C': [0.01]
#         # 'SVM__C': [0.01, 0.05, 0.1]
#         'RF__n_estimators': [50, 100, 200],
#         'XGB__n_estimators': [50, 100, 200]
#     }

#     # Create a GridSearchCV object
#     # custom_scorer_auc = make_scorer(roc_auc_score, needs_proba=True)
#     grid_search = GridSearchCV(voting_classifier, param_grid, cv=10, scoring='roc_auc')

#     # Perform the grid search on the training data
#     grid_search.fit(X_train, y_train)

#     # Get the best hyperparameters
#     best_params = grid_search.best_params_
#     # Print the best fitted parameters
#     print("Best fitted parameters:")
#     print(best_params)

#     # Train the final VotingClassifier with the best hyperparameters on the full training set
#     final_voting_classifier = grid_search.best_estimator_
#     final_voting_classifier.fit(X_train, y_train)

#     # Predict probabilities instead of binary outcomes on the test set
#     y_pred_proba_test = final_voting_classifier.predict_proba(X_test)
#     y_pred_test = final_voting_classifier.predict(X_test)
#     X_dt = data_pred.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1)
#     y_pred = final_voting_classifier.predict_proba(X_dt)

#     return y_pred

# %%
# ensemble_model_fit(dt_design_5, dt_design_5)

# %%
def ensemble_model_fit(data, data_pred):
    X_train, X_test, y_train, y_test = train_test_split(
        data.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1),
        data['response'],
        test_size=0.2,
        random_state=0
    )

    # Define the VotingClassifier with the individual classifiers
    voting_classifier = ensemble.VotingClassifier(
        estimators=[
            ('LR', linear_model.LogisticRegression(max_iter=200, random_state=0)),
#             ('Ridge', linear_model.LogisticRegression(penalty='l2', solver='lbfgs', max_iter=200, random_state=0))
                    # ('SVM', svm.SVC(kernel='linear', C=1.0, random_state=0, probability=True, class_weight='balanced'))
                    ('RF', ensemble.RandomForestClassifier(criterion='gini', random_state=0)),
                    ('XGB', XGBClassifier(learning_rate=0.1, random_state=0))
                   ],
        voting='soft'
    )

    # Define the hyperparameter grid to search
    # Best Hyperparameters: {'LR__C': 0.01, 'RF__n_estimators': 50, 'XGB__n_estimators': 50}
    param_grid = {
        # 'NB__alpha': [0.01, 0.05, 0.1],  # '__' is used to specify hyperparameters for individual classifiers
        'LR__C': [0.05],
        # 'Ridge__C': [0.01]
        # 'SVM__C': [0.05]
        'RF__n_estimators': [100],
        'XGB__n_estimators': [50]
    }

    # Create a GridSearchCV object
    # custom_scorer_auc = make_scorer(roc_auc_score, needs_proba=True)
    grid_search = GridSearchCV(voting_classifier, param_grid, cv=10, scoring='roc_auc')

    # Perform the grid search on the training data
    grid_search.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = grid_search.best_params_

    # Train the final VotingClassifier with the best hyperparameters on the full training set
    final_voting_classifier = grid_search.best_estimator_
    final_voting_classifier.fit(X_train, y_train)

    # Predict probabilities instead of binary outcomes on the test set
    y_pred_proba_test = final_voting_classifier.predict_proba(X_test)
    y_pred_test = final_voting_classifier.predict(X_test)
    X_dt = data_pred.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1)
    y_pred = final_voting_classifier.predict_proba(X_dt)

    return y_pred

# %% [markdown]
# ### Simulation starts

# %%
n_sim = 100
# create a list of random seeds
random.seed(42)
random_seeds = [random.randint(1, 100000) for _ in range(n_sim)]

design_list = [5,8,10]
patient_n_list = [5468,680,170] # n_patient_per_plan

n_design = 8
n_patient_per_plan = 680
n_rounds = 6
total_n = n_patient_per_plan * (2**n_design)

## sample size determination
beta = 0.2
power = 1 - beta
alpha = 0.05
delta = 0.01 # effect size

## early stopping
epsilon = 0.001

# %%
rr_dict = {"step{}_rr".format(r): [] for r in range(1, n_rounds + 1)}
plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
sample_size_dict = {"step{}_sample_size".format(r): [] for r in range(1, n_rounds + 1)}
last_round_sample_size = []
random_rr_dict = {"step{}_random_max_rr".format(r): [] for r in range(1, n_rounds + 1)}
random_rr_dict.update({
    "step{}_random_mean_rr".format(r): [] for r in range(1, n_rounds + 1)
})

stopping_dict = {"early_stopping": [],
                 "early_stopping_plan":[],
                 "early_stopping_orr":[],
                 "early_stopping_size":[]}
final_plan_number = []
highest_rr_overall = []

better_chance = []

orr_total = []
orr_total_adaptive = []



i = 0

for seed in random_seeds:
    i += 1
    print(i)

    print([f"{key}: {len(value)}" for key, value in rr_dict.items()])



    event_list = 0
    event_list_adaptive = 0
    max_rr = []

    # step 1:
    ## Generate dataset
    dt_design_5 = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed)
    print("empirical response rate", dt_design_5['response'].mean())
    ## save for benchmark results
    maxidx = np.argmax(dt_design_5['plan_response_rate'])
    random_rr_dict['step1_random_max_rr'].append(dt_design_5.iloc[maxidx,6])
    random_rr_dict['step1_random_mean_rr'].append(dt_design_5['plan_response_rate'].mean())

    ## Ensemble modelling:
    y_pred = ensemble_model_fit(data=dt_design_5, data_pred = dt_design_5)

    ## select recruitment plan
    pred_df = pd.DataFrame(np.hstack((dt_design_5,  y_pred[:, 1].reshape(-1, 1))),
                             columns=list(dt_design_5.columns) + ['predicted_response_rate'])
    pred_df_rr = pred_df.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

    x = pred_df_rr['predicted_response_rate'].values
    if len(x) <= 10:
        best_k = 2
    else:
        best_k = kmeans_fit(data = x)['best_k']
    kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

    merged_df = pd.merge(pred_df_rr, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
    cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
    highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
    highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)


    p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))
    highest_cluster['p_vec'] = p_vec_next
    highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

    # highest_cluster = pred_df_rr

    # highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')
    # highest_cluster['cluster_number'] = highest_cluster['recruitment_plan']

    ## prepare to chance of better performance:
    temp = dt_design_5[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
    event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print("step1", np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print(temp)
    p0 = (temp['plan_response_rate'].mean())

    rr_dict["step1_rr"].append(dt_design_5['plan_response_rate'].mean())
    sample_size_dict["step1_sample_size"].append(len(dt_design_5))

    for round in range(2, n_rounds+1):

        rr_dict["step"+str(round)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))
        plan_number_dict["step"+str(round)+"_plan_number"].append(len(p_vec_next))

        ## when it comes to the last round:
        if round == n_rounds:

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            if round == 2: # if the last round is round 2
                remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
            else:
                remaining_size -= len(dt_design_5_step2up)

            print("remaining size for last Round " + str(round) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            ## data generation, combine previous data:
            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, 
                                                          design_number = n_design, n_rounds = n_rounds,
                                                          n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(0)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(len(temp), temp['plan_response_rate'].mean())
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break



        ## If haven't reached the last round:
        ## check remaining sample size:
        if round == 2:
            remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
        else:
            remaining_size -= len(dt_design_5_step2up)

        print("remaining size for Round " + str(round) + ": " + str(remaining_size))

        ## determine whether move on to step 2:
        if len(highest_cluster) == 1: # if there is only one plan left

            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size) # record the last round sample size
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(1)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        ## sample size determination:
        if round == 2:
            dt_design_5_step2up_overall = dt_design_5
        orr_1 = dt_design_5_step2up_overall['response'].mean() # observed overall response rates for previous rounds
        orr_2 = orr_1 + delta
        n_1 = len(dt_design_5_step2up_overall)

        size_step2up = sample_size_calc(orr_1, n_1, delta=delta, alpha=alpha, power=power) # total size for dataset
        if size_step2up > 0 and size_step2up < 1000:
            size_step2up = 1000 # if size in [0,1000], then it is 1000 for this round.
        elif size_step2up >= 1000:
            size_step2up = min(size_step2up, int(total_n/n_rounds)) # dataset size capped by the n_patient_per_plan
        else:
        # if size_step2up <= 0:
            # the process stops at this step
            print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up) + 'lt 0, break')
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(1)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up))

        sample_size_dict["step"+str(round)+"_sample_size"].append(size_step2up)

        ## save benchmark results for last round:
        dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                            n_patient_per_plan = n_patient_per_plan, seed=seed+round)
        maxidx = np.argmax(dt_benchmark['plan_response_rate'])
        random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
        random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

        ## data generation, combine previous data:
        dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                  design_number = n_design, n_rounds = n_rounds,
                                                  n_patient_per_plan = n_patient_per_plan, size = int(size_step2up), seed=seed)

        plan_list = dt_design_5_step2up['recruitment_plan'].unique()
        if round == 2:
            supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)]
        else:
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
        dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
        dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

        ## Ensemble model fitting:
        dt_design_5_step2up.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)
        y_pred2up = ensemble_model_fit(data = dt_design_5_step2up_overall, data_pred = dt_design_5_step2up)
        pred_df_step2up = pd.DataFrame(np.hstack((dt_design_5_step2up,  y_pred2up[:, 1].reshape(-1, 1))),
                                    columns=list(dt_design_5_step2up.columns) + ['predicted_response_rate'])
        pred_df_rr_step2up = pred_df_step2up.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

        ## select recruitment plans:
        x = pred_df_rr_step2up['predicted_response_rate'].values

        if len(x) <= 10:
            best_k = 2
        else:
            best_k = kmeans_fit(data = x)['best_k']
        kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

        ## match the cluster results back to the original data
        highest_cluster_previous = highest_cluster # save previous cluster results

        merged_df = pd.merge(pred_df_rr_step2up, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
        cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
        highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
        highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)

        # p_vec_previous = p_vec_next # save p_vec of previous round
        p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))

        highest_cluster['p_vec'] = p_vec_next

        highest_cluster = pd.merge(highest_cluster, dt_design_5_step2up[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

        ## prepare to chance of better performance:
        temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
        event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print(temp)

        ## check early stopping predicted ORR:
        orr_df = pd.merge(highest_cluster_previous, highest_cluster[['recruitment_plan','predicted_response_rate','p_vec']], on='recruitment_plan', how='left')
        orr_df.fillna(0, inplace=True)
        p_orr_1 = np.dot(np.array(orr_df['p_vec_x']), np.array(orr_df['predicted_response_rate_y']))
        p_orr_2 = np.dot(np.array(orr_df['p_vec_y']), np.array(orr_df['predicted_response_rate_y']))
        print("orr termination", p_orr_1, p_orr_2, p_orr_2 - p_orr_1)

        if (p_orr_2 - p_orr_1 < epsilon):
            # step 3 use the same strategy of step2
            print(i, p_orr_1, p_orr_2, "early stop at Round " + str(round))
            rr_dict["step"+str(round+1)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                                n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round+1)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round+1)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            ### update remaining size:
            remaining_size -= len(dt_design_5_step2up)
            print("early stop, remaining size for Round" + str(round + 1) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            for r in range(round+2, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, 
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(1)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            for r in range(round+2, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round+1), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break
# Out:
# 1
# ['step1_rr: 0', 'step2_rr: 0', 'step3_rr: 0', 'step4_rr: 0', 'step5_rr: 0', 'step6_rr: 0']
# empirical response rate 0.08033738938053098
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6033.300486728156
# orr termination 0.04685333817779393 0.1213889223459235 0.07453558416812957
# remaining size for Round 3: 139119
# Calculated size for Round 3: 8892.831445302378
# orr termination 0.05319367836315933 0.11427488691453713 0.0610812085513778
# remaining size for Round 4: 130227
# Calculated size for Round 4: 9533.165104789463
# orr termination 0.008716083764798124 0.12682551418558144 0.11810943042078331
# remaining size for Round 5: 120694
# Calculated size for Round 5: 9800.036524840632
# orr termination 0.055137297275802105 0.11014018795425386 0.05500289067845175
# remaining size for last Round 6: 110894
# 2
# ['step1_rr: 1', 'step2_rr: 1', 'step3_rr: 1', 'step4_rr: 1', 'step5_rr: 1', 'step6_rr: 1']
# empirical response rate 0.07836698008849557
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5889.708525120337
# orr termination 0.05052813282210508 0.12932842360965072 0.07880029078754563
# remaining size for Round 3: 139263
# Calculated size for Round 3: 15143.63593405173
# orr termination 0.039008584813554556 0.10204737062548735 0.0630387858119328
# remaining size for Round 4: 124120
# Calculated size for Round 4: 7836.064525392681
# orr termination 0.05153142475672821 0.10179196757663828 0.05026054281991007
# remaining size for Round 5: 116284
# Calculated size for Round 5: 8927.031620351316
# orr termination 0.05035102185460996 0.10000304767379353 0.04965202581918357
# remaining size for last Round 6: 107357
# 3
# ['step1_rr: 2', 'step2_rr: 2', 'step3_rr: 2', 'step4_rr: 2', 'step5_rr: 2', 'step6_rr: 2']
# empirical response rate 0.030593196902654867
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2570.7668488803606
# orr termination 0.02284239367211303 0.08274210730178906 0.05989971362967603
# remaining size for Round 3: 142582
# Calculated size for Round 3: 7251.888381050665
# orr termination 0.07203348675195244 0.08132819546509723 0.009294708713144792
# remaining size for Round 4: 135331
# Calculated size for Round 4: 10229.832868093772
# orr termination 0.019946753280063755 0.09899922378844382 0.07905247050838007
# remaining size for Round 5: 125102
# Calculated size for Round 5: 7681.397655196381
# orr termination 0.03194846712409772 0.09707414752520722 0.0651256804011095
# remaining size for last Round 6: 117421
# 4
# ['step1_rr: 3', 'step2_rr: 3', 'step3_rr: 3', 'step4_rr: 3', 'step5_rr: 3', 'step6_rr: 3']
# empirical response rate 0.06011476769911504
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4584.554843390879
# orr termination 0.02549357976744772 0.10306357811866698 0.07756999835121926
# remaining size for Round 3: 140568
# Calculated size for Round 3: 10604.067982345634
# orr termination 0.059630119521737045 0.10199156386725972 0.04236144434552267
# remaining size for Round 4: 129964
# Calculated size for Round 4: 10166.868633887894
# orr termination 0.08656835869757715 0.10095069125667894 0.01438233255910179
# remaining size for Round 5: 119798
# Calculated size for Round 5: 8668.876536285821
# orr termination 0.050850304653845685 0.10143149939392367 0.05058119474007798
# remaining size for last Round 6: 111130
# 5
# ['step1_rr: 4', 'step2_rr: 4', 'step3_rr: 4', 'step4_rr: 4', 'step5_rr: 4', 'step6_rr: 4']
# empirical response rate 0.09029314159292036
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6766.704057464664
# orr termination 0.10080890493918791 0.11515286936863975 0.014343964429451836
# remaining size for Round 3: 138386
# Calculated size for Round 3: 8666.649654374773
# orr termination 0.04928098036560377 0.12796617155400988 0.07868519118840611
# remaining size for Round 4: 129720
# Calculated size for Round 4: 8825.539258832714
# orr termination 0.055995707327040414 0.12616211788080478 0.07016641055376437
# remaining size for Round 5: 120895
# Calculated size for Round 5: 10266.49146541358
# orr termination 0.02015178578184518 0.12013919629051631 0.09998741050867113
# remaining size for last Round 6: 110629
# 6
# ['step1_rr: 5', 'step2_rr: 5', 'step3_rr: 5', 'step4_rr: 5', 'step5_rr: 5', 'step6_rr: 5']
# empirical response rate 0.04362555309734513
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3444.8125679843447
# orr termination 0.010234072108583275 0.07110968386860388 0.0608756117600206
# remaining size for Round 3: 141708
# Calculated size for Round 3: 5816.252283425663
# orr termination 0.022672463552154777 0.09447140291679769 0.0717989393646429
# remaining size for Round 4: 135892
# Calculated size for Round 4: 16135.692229256198
# orr termination 0.04648749508581855 0.09260413685331792 0.04611664176749937
# remaining size for Round 5: 119757
# 7
# ['step1_rr: 6', 'step2_rr: 6', 'step3_rr: 6', 'step4_rr: 6', 'step5_rr: 6', 'step6_rr: 6']
# empirical response rate 0.04355641592920354
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3440.1132258982107
# orr termination 0.05232145026982639 0.0852062826903065 0.03288483242048011
# remaining size for Round 3: 141712
# Calculated size for Round 3: 6206.623818586162
# orr termination 0.020604390923521135 0.0978930790830336 0.07728868815951247
# remaining size for Round 4: 135506
# Calculated size for Round 4: 7775.00414600195
# orr termination 0.03283304383248444 0.08646721671133342 0.05363417287884898
# remaining size for Round 5: 127731
# Calculated size for Round 5: 8234.177534897632
# orr termination 0.04622786238507452 0.09166280792513529 0.045434945540060764
# remaining size for last Round 6: 119497
# 8
# ['step1_rr: 7', 'step2_rr: 7', 'step3_rr: 7', 'step4_rr: 7', 'step5_rr: 7', 'step6_rr: 7']
# empirical response rate 0.08030282079646017
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6030.776854562427
# orr termination 0.03000828077006923 0.15217319129857515 0.12216491052850592
# remaining size for Round 3: 139122
# Calculated size for Round 3: 17900.342437225063
# orr termination 0.07129692269319418 0.1112058405025537 0.03990891780935951
# remaining size for Round 4: 121222
# Calculated size for Round 4: 9131.481373327184
# orr termination 0.034128023742208385 0.11688027281917507 0.08275224907696668
# remaining size for Round 5: 112091
# Calculated size for Round 5: 9039.644347823541
# orr termination 0.0545324511977735 0.10851757084776997 0.05398511964999647
# remaining size for last Round 6: 103052
# 9
# ['step1_rr: 8', 'step2_rr: 8', 'step3_rr: 8', 'step4_rr: 8', 'step5_rr: 8', 'step6_rr: 8']
# empirical response rate 0.04777378318584071
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3727.99035410021
# orr termination 0.021335517488499146 0.07993594145280405 0.05860042396430491
# remaining size for Round 3: 141425
# Calculated size for Round 3: 6166.276818003042
# orr termination 0.07551177915262787 0.07903122760073425 0.00351944844810638
# remaining size for Round 4: 135259
# Calculated size for Round 4: 8895.606935289712
# orr termination 0.021634235009908655 0.09686529550730807 0.07523106049739942
# remaining size for Round 5: 126364
# Calculated size for Round 5: 7068.29340956543
# orr termination 0.02195828783979445 0.10631405498317806 0.08435576714338361
# remaining size for last Round 6: 119296
# 10
# ['step1_rr: 9', 'step2_rr: 9', 'step3_rr: 9', 'step4_rr: 9', 'step5_rr: 9', 'step6_rr: 9']
# empirical response rate 0.043037887168141595
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3404.8893784747597
# orr termination 0.016349393016891985 0.06694180283903073 0.050592409822138744
# remaining size for Round 3: 141748
# Calculated size for Round 3: 4505.662713744397
# orr termination 0.01761114125189179 0.07723435824574054 0.05962321699384875
# remaining size for Round 4: 137243
# Calculated size for Round 4: 7876.693862887459
# orr termination 0.06451622250908323 0.08965260136387013 0.025136378854786895
# remaining size for Round 5: 129367
# Calculated size for Round 5: 10919.865373388506
# orr termination 0.019358590959837496 0.09465621425752388 0.07529762329768638
# remaining size for last Round 6: 118448
# 11
# ['step1_rr: 10', 'step2_rr: 10', 'step3_rr: 10', 'step4_rr: 10', 'step5_rr: 10', 'step6_rr: 10']
# empirical response rate 0.03297842920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2728.965581830211
# orr termination 0.03454216544156305 0.08713615066111477 0.05259398521955172
# remaining size for Round 3: 142424
# Calculated size for Round 3: -25160.51736826657lt 0, break
# 12
# ['step1_rr: 11', 'step2_rr: 11', 'step3_rr: 11', 'step4_rr: 11', 'step5_rr: 11', 'step6_rr: 11']
# empirical response rate 0.034603152654867256
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2837.1791262040406
# orr termination 0.008006730785256301 0.06920784632015438 0.06120111553489808
# remaining size for Round 3: 142315
# Calculated size for Round 3: 4649.057332656156
# orr termination 0.03366941636664743 0.07425226727058964 0.040582850903942216
# remaining size for Round 4: 137666
# Calculated size for Round 4: 11654.359444105829
# orr termination 0.04289525740436464 0.08430839831066869 0.041413140906304054
# remaining size for Round 5: 126012
# Calculated size for Round 5: 7032.569457771514
# orr termination 0.03131378762416997 0.08918097298582321 0.057867185361653244
# remaining size for last Round 6: 118980
# 13
# ['step1_rr: 12', 'step2_rr: 12', 'step3_rr: 12', 'step4_rr: 12', 'step5_rr: 12', 'step6_rr: 12']
# empirical response rate 0.04124032079646018
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3283.0700374646344
# orr termination 0.005540312471927598 0.07011125473783278 0.06457094226590518
# remaining size for Round 3: 141869
# Calculated size for Round 3: 3965.945534950182
# orr termination 0.027617413622083684 0.100148549022449 0.07253113540036532
# remaining size for Round 4: 137904
# Calculated size for Round 4: 29013
# orr termination 0.034598807830379136 0.10407820204716098 0.06947939421678184
# remaining size for Round 5: 108891
# 14
# ['step1_rr: 13', 'step2_rr: 13', 'step3_rr: 13', 'step4_rr: 13', 'step5_rr: 13', 'step6_rr: 13']
# empirical response rate 0.07079646017699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5342.870662026109
# orr termination 0.05599583102065178 0.11650770543557329 0.06051187441492151
# remaining size for Round 3: 139810
# Calculated size for Round 3: 8756.522165653505
# orr termination 0.07395482789519993 0.12269159245844749 0.04873676456324756
# remaining size for Round 4: 131054
# Calculated size for Round 4: 10299.35157329502
# orr termination 0.038392687978297715 0.11095541759432556 0.07256272961602785
# remaining size for Round 5: 120755
# Calculated size for Round 5: 8783.950523180183
# orr termination 0.07327050304252544 0.10554498286294317 0.03227447982041773
# remaining size for last Round 6: 111972
# 15
# ['step1_rr: 14', 'step2_rr: 14', 'step3_rr: 14', 'step4_rr: 14', 'step5_rr: 14', 'step6_rr: 14']
# empirical response rate 0.03135370575221239
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2621.120723895575
# orr termination 0.009358576454034562 0.06440767623126618 0.05504909977723162
# remaining size for Round 3: 142531
# Calculated size for Round 3: 5469.017220619117
# orr termination 0.05106236985333297 0.1010677748148707 0.05000540496153773
# remaining size for Round 4: 137062
# Calculated size for Round 4: 29013
# orr termination 0.031081073564386115 0.09603757311412955 0.06495649954974345
# remaining size for Round 5: 108049
# 16
# ['step1_rr: 15', 'step2_rr: 15', 'step3_rr: 15', 'step4_rr: 15', 'step5_rr: 15', 'step6_rr: 15']
# empirical response rate 0.07231747787610619
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5452.116013979351
# orr termination 0.09349038376700025 0.1055635650426555 0.012073181275655251
# remaining size for Round 3: 139700
# Calculated size for Round 3: 29013
# orr termination 0.05943414372125354 0.09476558147623393 0.03533143775498039
# remaining size for Round 4: 110687
# Calculated size for Round 4: 6636.037216870658
# orr termination 0.01903357472964909 0.094539234706903 0.0755056599772539
# remaining size for Round 5: 104051
# 17
# ['step1_rr: 16', 'step2_rr: 16', 'step3_rr: 16', 'step4_rr: 16', 'step5_rr: 16', 'step6_rr: 16']
# empirical response rate 0.02900304203539823
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2465.7425695144257
# orr termination 0.022004389688452308 0.06308335312749483 0.04107896343904252
# remaining size for Round 3: 142687
# Calculated size for Round 3: 4304.694979662596
# orr termination 0.010933067664738621 0.07118961254414935 0.06025654487941073
# remaining size for Round 4: 138383
# Calculated size for Round 4: 6374.864682540911
# orr termination 0.06674895487571508 0.08038561818056926 0.013636663304854177
# remaining size for Round 5: 132009
# Calculated size for Round 5: 11718.446315586687
# orr termination 0.03924436383236485 0.09509278074251198 0.055848416910147136
# remaining size for last Round 6: 120291
# 18
# ['step1_rr: 17', 'step2_rr: 17', 'step3_rr: 17', 'step4_rr: 17', 'step5_rr: 17', 'step6_rr: 17']
# empirical response rate 0.038682245575221236
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3110.4883281384073
# orr termination 0.022722395798910278 0.06513399784029726 0.042411602041386984
# remaining size for Round 3: 142042
# Calculated size for Round 3: 3505.486678637812
# orr termination 0.00727752048848739 0.09464283132128984 0.08736531083280245
# remaining size for Round 4: 138537
# Calculated size for Round 4: 7830.9503968468425
# orr termination 0.07307602248612502 0.09676737596861754 0.023691353482492516
# remaining size for Round 5: 130707
# Calculated size for Round 5: 14777.050245709497
# orr termination 0.0668147260929796 0.09955164904183374 0.032736922948854136
# remaining size for last Round 6: 115930
# 19
# ['step1_rr: 18', 'step2_rr: 18', 'step3_rr: 18', 'step4_rr: 18', 'step5_rr: 18', 'step6_rr: 18']
# empirical response rate 0.04860342920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3784.913012723484
# orr termination 0.004669108967582804 0.08612203869222303 0.08145292972464022
# remaining size for Round 3: 141368
# Calculated size for Round 3: 5894.26018685183
# orr termination 0.016590208447782313 0.10256382230004557 0.08597361385226326
# remaining size for Round 4: 135474
# 20
# ['step1_rr: 19', 'step2_rr: 19', 'step3_rr: 19', 'step4_rr: 19', 'step5_rr: 19', 'step6_rr: 19']
# empirical response rate 0.09053512168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6784.692301555903
# orr termination 0.03883343060341023 0.15255514710381468 0.11372171650040445
# remaining size for Round 3: 138368
# Calculated size for Round 3: 11153.583461680468
# orr termination 0.09406508587458305 0.13168544713173136 0.03762036125714831
# remaining size for Round 4: 127215
# Calculated size for Round 4: 12673.666889109089
# orr termination 0.017317456247797573 0.1254669081161206 0.10814945186832303
# remaining size for Round 5: 114542
# Calculated size for Round 5: 9375.233371848488
# orr termination 0.0713717084646743 0.10688007556109354 0.03550836709641923
# remaining size for last Round 6: 105167
# 21
# ['step1_rr: 20', 'step2_rr: 20', 'step3_rr: 20', 'step4_rr: 20', 'step5_rr: 20', 'step6_rr: 20']
# empirical response rate 0.04127488938053098
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3285.4084707208544
# orr termination 0.0156718655298635 0.10287798605709303 0.08720612052722954
# remaining size for Round 3: 141867
# Calculated size for Round 3: 12204.529427390074
# orr termination 0.041007068821234685 0.09553152564922529 0.054524456827990606
# remaining size for Round 4: 129663
# Calculated size for Round 4: 9179.753695825078
# orr termination 0.06814316392052111 0.10250004813606656 0.03435688421554545
# remaining size for Round 5: 120484
# Calculated size for Round 5: 9626.29021367227
# orr termination 0.05200196507789655 0.10177390022080618 0.04977193514290963
# remaining size for last Round 6: 110858
# 22
# ['step1_rr: 21', 'step2_rr: 21', 'step3_rr: 21', 'step4_rr: 21', 'step5_rr: 21', 'step6_rr: 21']
# empirical response rate 0.09153761061946902
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6859.296443568507
# orr termination 0.0891381459358033 0.12332988471180337 0.03419173877600007
# remaining size for Round 3: 138293
# Calculated size for Round 3: 9562.013429579509
# orr termination 0.04900757508268402 0.13783897460445532 0.0888313995217713
# remaining size for Round 4: 128731
# Calculated size for Round 4: 10117.234192318905
# orr termination 0.00942317624272164 0.1347103475148816 0.12528717127215994
# remaining size for Round 5: 118614
# Calculated size for Round 5: 10836.178101776142
# orr termination 0.05204579841577704 0.1057602275356626 0.053714429119885554
# remaining size for last Round 6: 107778
# 23
# ['step1_rr: 22', 'step2_rr: 22', 'step3_rr: 22', 'step4_rr: 22', 'step5_rr: 22', 'step6_rr: 22']
# empirical response rate 0.11189850663716815
# remaining size for Round 2: 145152
# Calculated size for Round 2: 8402.348985484643
# orr termination 0.07136347036320911 0.14556426878461767 0.07420079842140856
# remaining size for Round 3: 136750
# Calculated size for Round 3: 8780.81747457657
# orr termination 0.06965933598071551 0.17665982817551074 0.10700049219479522
# remaining size for Round 4: 127970
# Calculated size for Round 4: 13366.416886972933
# orr termination 0.02156364698846477 0.15018511039584664 0.12862146340738187
# remaining size for Round 5: 114604
# Calculated size for Round 5: 11801.599791463457
# orr termination 0.06539327984545568 0.10816888313045825 0.04277560328500257
# remaining size for last Round 6: 102803
# 24
# ['step1_rr: 23', 'step2_rr: 23', 'step3_rr: 23', 'step4_rr: 23', 'step5_rr: 23', 'step6_rr: 23']
# empirical response rate 0.06201603982300885
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4718.387240976126
# orr termination 0.0030273229167644784 0.1310746405474041 0.12804731763063962
# remaining size for Round 3: 140434
# Calculated size for Round 3: 9823.762586711275
# orr termination 0.05197506443271342 0.10139040218177454 0.04941533774906112
# remaining size for Round 4: 130611
# 25
# ['step1_rr: 24', 'step2_rr: 24', 'step3_rr: 24', 'step4_rr: 24', 'step5_rr: 24', 'step6_rr: 24']
# empirical response rate 0.05008987831858407
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3887.138480086987
# orr termination 0.021665287615278202 0.07720990580464271 0.05554461818936451
# remaining size for Round 3: 141265
# Calculated size for Round 3: 6664.769113206606
# orr termination 0.023712050003433984 0.0816575066373478 0.05794545663391382
# remaining size for Round 4: 134601
# Calculated size for Round 4: 8530.325986047646
# orr termination 0.07805882442845656 0.09470567312836037 0.016646848699903807
# remaining size for Round 5: 126071
# Calculated size for Round 5: 10225.497268505333
# orr termination 0.06522671168806493 0.10286265892612004 0.037635947238055106
# remaining size for last Round 6: 115846
# 26
# ['step1_rr: 25', 'step2_rr: 25', 'step3_rr: 25', 'step4_rr: 25', 'step5_rr: 25', 'step6_rr: 25']
# empirical response rate 0.03297842920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2728.965581830211
# orr termination 0.017636088024894463 0.06288105208124677 0.0452449640563523
# remaining size for Round 3: 142424
# Calculated size for Round 3: 5027.13189133477
# orr termination 0.012905538323034703 0.05944293469515882 0.04653739637212412
# remaining size for Round 4: 137397
# Calculated size for Round 4: 5923.7692076950525
# orr termination 0.016724796352382606 0.08017523959235118 0.06345044323996857
# remaining size for Round 5: 131474
# 27
# ['step1_rr: 26', 'step2_rr: 26', 'step3_rr: 26', 'step4_rr: 26', 'step5_rr: 26', 'step6_rr: 26']
# empirical response rate 0.033842643805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2786.4800847064803
# orr termination 0.004939466992247074 0.047121412336348735 0.04218194534410166
# remaining size for Round 3: 142366
# Calculated size for Round 3: 3954.174196364552
# orr termination 0.05387251426092362 0.07161524497517335 0.017742730714249734
# remaining size for Round 4: 138412
# Calculated size for Round 4: 25332.470337262534
# orr termination 0.06759857459783179 0.09705502103794635 0.029456446440114553
# remaining size for Round 5: 113080
# Calculated size for Round 5: 6918.402953658914
# orr termination 0.04786632828298327 0.09568054579329568 0.047814217510312416
# remaining size for last Round 6: 106162
# 28
# ['step1_rr: 27', 'step2_rr: 27', 'step3_rr: 27', 'step4_rr: 27', 'step5_rr: 27', 'step6_rr: 27']
# empirical response rate 0.06077157079646018
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4630.73167611316
# orr termination 0.030723816570139284 0.08422825124719371 0.05350443467705443
# remaining size for Round 3: 140522
# Calculated size for Round 3: 6061.784814423423
# orr termination 0.004067848006533998 0.1020429864938466 0.09797513848731261
# remaining size for Round 4: 134461
# Calculated size for Round 4: 7915.698392279893
# orr termination 0.04575299263461229 0.09258695169046413 0.04683395905585184
# remaining size for Round 5: 126546
# 29
# ['step1_rr: 28', 'step2_rr: 28', 'step3_rr: 28', 'step4_rr: 28', 'step5_rr: 28', 'step6_rr: 28']
# empirical response rate 0.06277654867256637
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4772.059228563532
# orr termination 0.02457384406188335 0.12053073263523863 0.09595688857335527
# remaining size for Round 3: 140380
# Calculated size for Round 3: 9384.04887171615
# orr termination 0.028043717500995238 0.0995382979665884 0.07149458046559316
# remaining size for Round 4: 130996
# Calculated size for Round 4: 9667.816771565022
# orr termination 0.0396865864380236 0.0937384401182374 0.0540518536802138
# remaining size for Round 5: 121329
# Calculated size for Round 5: 8963.54331174838
# orr termination 0.030922845680613435 0.09330660819771007 0.06238376251709664
# remaining size for last Round 6: 112366
# 30
# ['step1_rr: 29', 'step2_rr: 29', 'step3_rr: 29', 'step4_rr: 29', 'step5_rr: 29', 'step6_rr: 29']
# empirical response rate 0.07840154867256637
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5892.22320205354
# orr termination 0.08035966693302352 0.09248500907714022 0.012125342144116702
# remaining size for Round 3: 139260
# Calculated size for Round 3: 6442.104742487888
# orr termination 0.011165897024951363 0.11028066949270221 0.09911477246775084
# remaining size for Round 4: 132818
# Calculated size for Round 4: 6409.234943802827
# orr termination 0.08826955017258414 0.10281142275328795 0.014541872580703802
# remaining size for Round 5: 126409
# Calculated size for Round 5: 16265.63956006708
# orr termination 0.05360841139129162 0.10458388092853588 0.05097546953724426
# remaining size for last Round 6: 110144
# 31
# ['step1_rr: 30', 'step2_rr: 30', 'step3_rr: 30', 'step4_rr: 30', 'step5_rr: 30', 'step6_rr: 30']
# empirical response rate 0.07701880530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5791.761187324277
# orr termination 0.02793999496297484 0.1459989739082906 0.11805897894531578
# remaining size for Round 3: 139361
# Calculated size for Round 3: 9631.830455277963
# orr termination 0.04535251514928631 0.12730018161836648 0.08194766646908017
# remaining size for Round 4: 129730
# Calculated size for Round 4: 12831.708671803635
# orr termination 0.09281561450931215 0.10592928945245952 0.013113674943147371
# remaining size for Round 5: 116899
# Calculated size for Round 5: 9434.415018948586
# orr termination 0.014877780807488911 0.10554983945245226 0.09067205864496335
# remaining size for last Round 6: 107465
# 32
# ['step1_rr: 31', 'step2_rr: 31', 'step3_rr: 31', 'step4_rr: 31', 'step5_rr: 31', 'step6_rr: 31']
# empirical response rate 0.08019911504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6023.206915866293
# orr termination 0.03199474004303867 0.11809425076041082 0.08609951071737215
# remaining size for Round 3: 139129
# Calculated size for Round 3: 14984.847073256537
# orr termination 0.028033386621794314 0.09091460891107297 0.06288122228927866
# remaining size for Round 4: 124145
# Calculated size for Round 4: 7823.61715945502
# orr termination 0.06076330520594867 0.09092336674970507 0.030160061543756396
# remaining size for Round 5: 116322
# Calculated size for Round 5: 9325.078583144079
# orr termination 0.04578531523478909 0.09122943802196573 0.04544412278717664
# remaining size for last Round 6: 106997
# 33
# ['step1_rr: 32', 'step2_rr: 32', 'step3_rr: 32', 'step4_rr: 32', 'step5_rr: 32', 'step6_rr: 32']
# empirical response rate 0.07892007743362832
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5929.962574211673
# orr termination 0.04322966960113542 0.1127042438344566 0.06947457423332118
# remaining size for Round 3: 139223
# Calculated size for Round 3: 9433.099410970523
# orr termination 0.016115389135457823 0.11092860010353989 0.09481321096808207
# remaining size for Round 4: 129790
# Calculated size for Round 4: 8819.464133437248
# orr termination 0.07722503844502639 0.09654504838545297 0.019320009940426583
# remaining size for Round 5: 120971
# Calculated size for Round 5: 10917.583737828769
# orr termination 0.05108666972796425 0.10067670255339978 0.049590032825435525
# remaining size for last Round 6: 110054
# 34
# ['step1_rr: 33', 'step2_rr: 33', 'step3_rr: 33', 'step4_rr: 33', 'step5_rr: 33', 'step6_rr: 33']
# empirical response rate 0.07159153761061947
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5399.937054375382
# orr termination 0.02279489423998812 0.12688378715044824 0.10408889291046011
# remaining size for Round 3: 139753
# Calculated size for Round 3: 14447.355175367918
# orr termination 0.07492780140075087 0.111736821033007 0.036809019632256135
# remaining size for Round 4: 125306
# Calculated size for Round 4: 9950.709925241197
# orr termination 0.05386030184881982 0.10704630379903732 0.0531860019502175
# remaining size for Round 5: 115356
# Calculated size for Round 5: 8864.168826687755
# orr termination 0.03559064595246455 0.10659012527958146 0.07099947932711692
# remaining size for last Round 6: 106492
# 35
# ['step1_rr: 34', 'step2_rr: 34', 'step3_rr: 34', 'step4_rr: 34', 'step5_rr: 34', 'step6_rr: 34']
# empirical response rate 0.08182383849557522
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6141.967523856308
# orr termination 0.010534101717998356 0.1115122295259408 0.10097812780794244
# remaining size for Round 3: 139011
# Calculated size for Round 3: 8126.339958611442
# orr termination 0.010678778361230252 0.09262948451093281 0.08195070614970255
# remaining size for Round 4: 130885
# 36
# ['step1_rr: 35', 'step2_rr: 35', 'step3_rr: 35', 'step4_rr: 35', 'step5_rr: 35', 'step6_rr: 35']
# empirical response rate 0.04206996681415929
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3339.2384022405945
# orr termination 0.0289664456554054 0.07122484533465583 0.04225839967925042
# remaining size for Round 3: 141813
# Calculated size for Round 3: 4209.566826366591
# orr termination 0.014141498195293298 0.0978114516265694 0.0836699534312761
# remaining size for Round 4: 137604
# Calculated size for Round 4: 6996.613436508472
# orr termination 0.05792183597740295 0.09292635349274317 0.03500451751534022
# remaining size for Round 5: 130608
# Calculated size for Round 5: 13007.232160347328
# orr termination 0.07658324986899219 0.09482199155619493 0.018238741687202742
# remaining size for last Round 6: 117601
# 37
# ['step1_rr: 36', 'step2_rr: 36', 'step3_rr: 36', 'step4_rr: 36', 'step5_rr: 36', 'step6_rr: 36']
# empirical response rate 0.04580337389380531
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3593.182438999496
# orr termination 0.02339685020677493 0.09565199038008078 0.07225514017330585
# remaining size for Round 3: 141559
# Calculated size for Round 3: 17828.109573644804
# orr termination 0.05793423107815025 0.09990888689672846 0.041974655818578205
# remaining size for Round 4: 123731
# Calculated size for Round 4: 8154.4476011812585
# orr termination 0.052238592789524994 0.0995344520005682 0.0472958592110432
# remaining size for Round 5: 115577
# Calculated size for Round 5: 8174.009292738205
# orr termination 0.04824375911818012 0.09757518155752681 0.04933142243934669
# remaining size for last Round 6: 107403
# 38
# ['step1_rr: 37', 'step2_rr: 37', 'step3_rr: 37', 'step4_rr: 37', 'step5_rr: 37', 'step6_rr: 37']
# empirical response rate 0.047912057522123894
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3737.4708232996927
# orr termination 0.06665460779993389 0.08404802079834545 0.01739341299841156
# remaining size for Round 3: 141415
# Calculated size for Round 3: 6815.185437924916
# orr termination 0.03637835551932696 0.09638483432097152 0.06000647880164456
# remaining size for Round 4: 134600
# Calculated size for Round 4: 7387.329040515229
# orr termination 0.018914179377972254 0.10542536077240705 0.0865111813944348
# remaining size for Round 5: 127213
# Calculated size for Round 5: 9420.59493835795
# orr termination 0.020469439236028338 0.10425758380146281 0.08378814456543447
# remaining size for last Round 6: 117793
# 39
# ['step1_rr: 38', 'step2_rr: 38', 'step3_rr: 38', 'step4_rr: 38', 'step5_rr: 38', 'step6_rr: 38']
# empirical response rate 0.07466814159292036
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5621.565807308865
# orr termination 0.031205652367932407 0.1066829302676448 0.0754772778997124
# remaining size for Round 3: 139531
# Calculated size for Round 3: 13205.815238097202
# orr termination 0.03520061724368404 0.09453210132049644 0.0593314840768124
# remaining size for Round 4: 126326
# Calculated size for Round 4: 7738.761188081351
# orr termination 0.047930625745117444 0.096597381203655 0.04866675545853756
# remaining size for Round 5: 118588
# Calculated size for Round 5: 9420.599331702484
# orr termination 0.048673665263973466 0.09762574452359701 0.04895207925962355
# remaining size for last Round 6: 109168
# 40
# ['step1_rr: 39', 'step2_rr: 39', 'step3_rr: 39', 'step4_rr: 39', 'step5_rr: 39', 'step6_rr: 39']
# empirical response rate 0.06301852876106195
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4789.153321772453
# orr termination 0.059527556709058405 0.11255448617809055 0.05302692946903215
# remaining size for Round 3: 140363
# Calculated size for Round 3: 11349.772184930187
# orr termination 0.03349988444842871 0.11302967090304085 0.07952978645461214
# remaining size for Round 4: 129014
# Calculated size for Round 4: 9336.068366407453
# orr termination 0.04858537931659314 0.10850814163395078 0.059922762317357645
# remaining size for Round 5: 119678
# Calculated size for Round 5: 10315.881763388912
# orr termination 0.026455613139757746 0.10665709548019102 0.08020148234043327
# remaining size for last Round 6: 109363
# 41
# ['step1_rr: 40', 'step2_rr: 40', 'step3_rr: 40', 'step4_rr: 40', 'step5_rr: 40', 'step6_rr: 40']
# empirical response rate 0.0742878871681416
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5594.104185697372
# orr termination 0.07191764311250924 0.13672430589620205 0.0648066627836928
# remaining size for Round 3: 139558
# Calculated size for Round 3: 14419.02078613268
# orr termination 0.05044178709717015 0.1307806840089311 0.08033889691176094
# remaining size for Round 4: 125139
# Calculated size for Round 4: 10356.730889241855
# orr termination 0.06800987207822595 0.11890754306654276 0.05089767098831681
# remaining size for Round 5: 114783
# Calculated size for Round 5: 10397.152003728903
# orr termination 0.06912485173858568 0.11072187072664809 0.04159701898806241
# remaining size for last Round 6: 104386
# 42
# ['step1_rr: 41', 'step2_rr: 41', 'step3_rr: 41', 'step4_rr: 41', 'step5_rr: 41', 'step6_rr: 41']
# empirical response rate 0.05403069690265487
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4159.637779672868
# orr termination 0.009391790072900901 0.07672551303919653 0.06733372296629563
# remaining size for Round 3: 140993
# Calculated size for Round 3: 5410.639283409994
# orr termination 0.01564158194088893 0.08357849769761352 0.06793691575672459
# remaining size for Round 4: 135583
# Calculated size for Round 4: 12141.217753513365
# orr termination 0.048883404528344554 0.09467416232883902 0.045790757800494464
# remaining size for Round 5: 123442
# 43
# ['step1_rr: 42', 'step2_rr: 42', 'step3_rr: 42', 'step4_rr: 42', 'step5_rr: 42', 'step6_rr: 42']
# empirical response rate 0.05517146017699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# orr termination 0.0154204084406449 0.09989421828395885 0.08447380984331394
# remaining size for Round 3: 140914
# Calculated size for Round 3: 5568.463557781286
# orr termination 0.03603613360057562 0.11084824118432714 0.07481210758375151
# remaining size for Round 4: 135346
# Calculated size for Round 4: 16801.302309159935
# orr termination 0.04712282840290216 0.10767464595006307 0.06055181754716091
# remaining size for Round 5: 118545
# Calculated size for Round 5: 8701.34474591542
# orr termination 0.07237627632070773 0.10635117894910592 0.033974902628398196
# remaining size for last Round 6: 109844
# 44
# ['step1_rr: 43', 'step2_rr: 43', 'step3_rr: 43', 'step4_rr: 43', 'step5_rr: 43', 'step6_rr: 43']
# empirical response rate 0.04348727876106195
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3435.414549437817
# orr termination 0.011627379349370439 0.09068337214402897 0.07905599279465853
# remaining size for Round 3: 141717
# Calculated size for Round 3: 29013
# orr termination 0.04706658629778519 0.094273170981772 0.04720658468398681
# remaining size for Round 4: 112704
# 45
# ['step1_rr: 44', 'step2_rr: 44', 'step3_rr: 44', 'step4_rr: 44', 'step5_rr: 44', 'step6_rr: 44']
# empirical response rate 0.052751659292035395
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4070.959200908221
# orr termination 0.013199983485319833 0.09503700117445675 0.08183701768913691
# remaining size for Round 3: 141082
# Calculated size for Round 3: 4436.220319526588
# orr termination 0.046712004809068494 0.10826400145004059 0.06155199664097209
# remaining size for Round 4: 136646
# Calculated size for Round 4: 27171.287869311807
# orr termination 0.07326885652028658 0.09893250953140093 0.02566365301111434
# remaining size for Round 5: 109475
# Calculated size for Round 5: 7282.072163993446
# orr termination 0.05119122532855254 0.10195169091380893 0.05076046558525639
# remaining size for last Round 6: 102193
# 46
# ['step1_rr: 45', 'step2_rr: 45', 'step3_rr: 45', 'step4_rr: 45', 'step5_rr: 45', 'step6_rr: 45']
# empirical response rate 0.08092505530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6076.226646023446
# orr termination 0.023747430081744514 0.11916140565186559 0.09541397557012107
# remaining size for Round 3: 139076
# Calculated size for Round 3: 28763.60736639196
# orr termination 0.06584078488016756 0.0988763451120595 0.03303556023189194
# remaining size for Round 4: 110313
# Calculated size for Round 4: 7178.059093235865
# orr termination 0.050511527173089016 0.09930159126302723 0.04879006408993822
# remaining size for Round 5: 103135
# 47
# ['step1_rr: 46', 'step2_rr: 46', 'step3_rr: 46', 'step4_rr: 46', 'step5_rr: 46', 'step6_rr: 46']
# empirical response rate 0.047428097345132744
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3704.3008047850903
# orr termination 0.009405993017247524 0.10380583099653204 0.09439983797928451
# remaining size for Round 3: 141448
# Calculated size for Round 3: 7284.254007591773
# orr termination 0.028875079715935392 0.09640931453481755 0.06753423481888216
# remaining size for Round 4: 134164
# Calculated size for Round 4: 12823.713083015002
# orr termination 0.06906914905989942 0.10251204038879677 0.033442891328897356
# remaining size for Round 5: 121341
# Calculated size for Round 5: 9604.920179429117
# orr termination 0.05174373280992907 0.10398236946095057 0.052238636651021506
# remaining size for last Round 6: 111737
# 48
# ['step1_rr: 47', 'step2_rr: 47', 'step3_rr: 47', 'step4_rr: 47', 'step5_rr: 47', 'step6_rr: 47']
# empirical response rate 0.0380945796460177
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3070.9700987965853
# orr termination 0.005037712486328026 0.10935371987950475 0.10431600739317673
# remaining size for Round 3: 142082
# Calculated size for Round 3: 7707.020233600801
# orr termination 0.07024597817430606 0.10301168190043483 0.032765703726128775
# remaining size for Round 4: 134375
# Calculated size for Round 4: 19843.881760448203
# orr termination 0.04705589081400893 0.0975621712533498 0.05050628043934087
# remaining size for Round 5: 114532
# 49
# ['step1_rr: 48', 'step2_rr: 48', 'step3_rr: 48', 'step4_rr: 48', 'step5_rr: 48', 'step6_rr: 48']
# empirical response rate 0.04846515486725664
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3775.4192631143214
# orr termination 0.012314591883431647 0.06332010362360854 0.051005511740176895
# remaining size for Round 3: 141377
# Calculated size for Round 3: 3651.805153975215
# orr termination 0.007665417530630414 0.10214240696819529 0.09447698943756488
# remaining size for Round 4: 137726
# Calculated size for Round 4: 9975.234088779745
# orr termination 0.04792423397880835 0.09626277873924229 0.048338544760433935
# remaining size for Round 5: 127751
# 50
# ['step1_rr: 49', 'step2_rr: 49', 'step3_rr: 49', 'step4_rr: 49', 'step5_rr: 49', 'step6_rr: 49']
# empirical response rate 0.03373893805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2779.5728369589106
# orr termination 0.019241827412144308 0.07381720864999701 0.0545753812378527
# remaining size for Round 3: 142373
# Calculated size for Round 3: 5111.812324505038
# orr termination 0.045935994361880894 0.07159541873264016 0.02565942437075927
# remaining size for Round 4: 137262
# Calculated size for Round 4: 7137.840473322084
# orr termination 0.01597064379662539 0.07775263983241269 0.0617819960357873
# remaining size for Round 5: 130125
# Calculated size for Round 5: 6253.136078067379
# orr termination 0.04075204954608068 0.08224305079820335 0.04149100125212267
# remaining size for last Round 6: 123872
# 51
# ['step1_rr: 50', 'step2_rr: 50', 'step3_rr: 50', 'step4_rr: 50', 'step5_rr: 50', 'step6_rr: 50']
# empirical response rate 0.04535398230088496
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3562.51238662459
# orr termination 0.07121302957449305 0.10982368971133016 0.038610660136837116
# remaining size for Round 3: 141590
# Calculated size for Round 3: 8697.613568534594
# orr termination 0.04418647810965831 0.12097866243445854 0.07679218432480023
# remaining size for Round 4: 132893
# Calculated size for Round 4: 10131.390230952995
# orr termination 0.08836689605199892 0.10936800152371942 0.021001105471720502
# remaining size for Round 5: 122762
# Calculated size for Round 5: 10114.4639008787
# orr termination 0.07564732869310531 0.10713956860859317 0.03149223991548786
# remaining size for last Round 6: 112648
# 52
# ['step1_rr: 51', 'step2_rr: 51', 'step3_rr: 51', 'step4_rr: 51', 'step5_rr: 51', 'step6_rr: 51']
# empirical response rate 0.040860066371681415
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3257.3582653305953
# orr termination 0.012460496941161397 0.10336421229258433 0.09090371535142293
# remaining size for Round 3: 141895
# Calculated size for Round 3: 7648.800477848643
# orr termination 0.03228544191599377 0.08731003133339457 0.0550245894174008
# remaining size for Round 4: 134247
# Calculated size for Round 4: 10343.364719688403
# orr termination 0.06208277867392514 0.09178512457728913 0.029702345903363986
# remaining size for Round 5: 123904
# Calculated size for Round 5: 8670.304890598021
# orr termination 0.04537427382853542 0.09120985404792219 0.045835580219386766
# remaining size for last Round 6: 115234
# 53
# ['step1_rr: 52', 'step2_rr: 52', 'step3_rr: 52', 'step4_rr: 52', 'step5_rr: 52', 'step6_rr: 52']
# empirical response rate 0.07584347345132743
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5706.570481819797
# orr termination 0.004605170145234499 0.14707062734823115 0.14246545720299664
# remaining size for Round 3: 139446
# 54
# ['step1_rr: 53', 'step2_rr: 53', 'step3_rr: 53', 'step4_rr: 53', 'step5_rr: 53', 'step6_rr: 53']
# empirical response rate 0.06319137168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4801.3683051580465
# orr termination 0.042615962294497114 0.096262258551218 0.05364629625672089
# remaining size for Round 3: 140351
# Calculated size for Round 3: 11165.851882891388
# orr termination 0.013274537975656999 0.0840270978934595 0.0707525599178025
# remaining size for Round 4: 129186
# Calculated size for Round 4: 6976.793348623626
# orr termination 0.03048865391781392 0.08937955350629055 0.05889089958847663
# remaining size for Round 5: 122210
# 55
# ['step1_rr: 54', 'step2_rr: 54', 'step3_rr: 54', 'step4_rr: 54', 'step5_rr: 54', 'step6_rr: 54']
# empirical response rate 0.0351908185840708
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2876.4109738220563
# orr termination 0.036630822672917576 0.062066150899178205 0.02543532822626063
# remaining size for Round 3: 142276
# Calculated size for Round 3: 4132.0845638549545
# orr termination 0.0396116719033861 0.08679237635792034 0.047180704454534234
# remaining size for Round 4: 138144
# Calculated size for Round 4: 6735.204653872679
# orr termination 0.00707450306270666 0.10977755216558621 0.10270304910287956
# remaining size for Round 5: 131409
# Calculated size for Round 5: 9689.414072536585
# orr termination 0.04930295765506534 0.09756461332136646 0.04826165566630112
# remaining size for last Round 6: 121720
# 56
# ['step1_rr: 55', 'step2_rr: 55', 'step3_rr: 55', 'step4_rr: 55', 'step5_rr: 55', 'step6_rr: 55']
# empirical response rate 0.04421321902654867
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3484.783847425881
# orr termination 0.027389195861198198 0.07972420921788742 0.05233501335668922
# remaining size for Round 3: 141668
# Calculated size for Round 3: 5938.344221325124
# orr termination 0.020097381124415226 0.08975623513640876 0.06965885401199354
# remaining size for Round 4: 135730
# Calculated size for Round 4: 8102.618737194875
# orr termination 0.07870879647793215 0.10440117166684378 0.025692375188911626
# remaining size for Round 5: 127628
# Calculated size for Round 5: 13547.952774846299
# orr termination 0.0371666592414678 0.1078893292732617 0.07072267003179389
# remaining size for last Round 6: 114081
# 57
# ['step1_rr: 56', 'step2_rr: 56', 'step3_rr: 56', 'step4_rr: 56', 'step5_rr: 56', 'step6_rr: 56']
# empirical response rate 0.06319137168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4801.3683051580465
# orr termination 0.01779206032555334 0.11256102756875058 0.09476896724319725
# remaining size for Round 3: 140351
# Calculated size for Round 3: 10200.046471729154
# orr termination 0.07527093186333662 0.10514330251053766 0.029872370647201038
# remaining size for Round 4: 130151
# Calculated size for Round 4: 11766.941383813024
# orr termination 0.062110649058781484 0.10338516410130585 0.04127451504252437
# remaining size for Round 5: 118385
# Calculated size for Round 5: 8394.277239074503
# orr termination 0.06751720670377531 0.10120929038679825 0.03369208368302294
# remaining size for last Round 6: 109991
# 58
# ['step1_rr: 57', 'step2_rr: 57', 'step3_rr: 57', 'step4_rr: 57', 'step5_rr: 57', 'step6_rr: 57']
# empirical response rate 0.058351769911504425
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4460.900082113275
# orr termination 0.01733238465780644 0.12647069014259127 0.10913830548478483
# remaining size for Round 3: 140692
# Calculated size for Round 3: 9066.564302207558
# orr termination 0.032922129242556955 0.08294568183344149 0.050023552590884535
# remaining size for Round 4: 131626
# Calculated size for Round 4: 8181.896076492134
# orr termination 0.03992949374506549 0.08159962073696295 0.041670126991897455
# remaining size for Round 5: 123445
# Calculated size for Round 5: 7479.181670436572
# orr termination 0.03296881451704648 0.0885027181710219 0.05553390365397542
# remaining size for last Round 6: 115966
# 59
# ['step1_rr: 58', 'step2_rr: 58', 'step3_rr: 58', 'step4_rr: 58', 'step5_rr: 58', 'step6_rr: 58']
# empirical response rate 0.03484513274336283
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2853.327576480575
# orr termination 0.008233619486577779 0.06458421210803142 0.05635059262145364
# remaining size for Round 3: 142299
# Calculated size for Round 3: 4004.020310387821
# orr termination 0.03916770709491471 0.08757514114133381 0.048407434046419104
# remaining size for Round 4: 138295
# Calculated size for Round 4: 19979.714453758454
# orr termination 0.059206760426398886 0.08929431033509334 0.030087549908694458
# remaining size for Round 5: 118316
# Calculated size for Round 5: 7022.777336233557
# orr termination 0.04842138361215452 0.09597330543877079 0.04755192182661627
# remaining size for last Round 6: 111294
# 60
# ['step1_rr: 59', 'step2_rr: 59', 'step3_rr: 59', 'step4_rr: 59', 'step5_rr: 59', 'step6_rr: 59']
# empirical response rate 0.04473174778761062
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3520.0925493885147
# orr termination 0.01132418785857926 0.09539051218819469 0.08406632432961543
# remaining size for Round 3: 141632
# Calculated size for Round 3: 12054.670733364537
# orr termination 0.034892977865185096 0.1001295336455994 0.0652365557804143
# remaining size for Round 4: 129578
# 61
# ['step1_rr: 60', 'step2_rr: 60', 'step3_rr: 60', 'step4_rr: 60', 'step5_rr: 60', 'step6_rr: 60']
# empirical response rate 0.0829991703539823
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6228.098665219812
# orr termination 0.07000844073859469 0.1284136934816224 0.058405252743027714
# remaining size for Round 3: 138924
# Calculated size for Round 3: 9950.559355314384
# orr termination 0.0960276967133053 0.121374244130961 0.0253465474176557
# remaining size for Round 4: 128974
# Calculated size for Round 4: 10055.075290607276
# orr termination 0.10495926567965252 0.11282634193207988 0.007867076252427357
# remaining size for Round 5: 118919
# Calculated size for Round 5: 8681.172997879154
# orr termination 0.06860885669581268 0.11232992753342749 0.04372107083761481
# remaining size for last Round 6: 110238
# 62
# ['step1_rr: 61', 'step2_rr: 61', 'step3_rr: 61', 'step4_rr: 61', 'step5_rr: 61', 'step6_rr: 61']
# empirical response rate 0.06495436946902655
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4926.194977591092
# orr termination 0.06466839491169543 0.08702543771379406 0.02235704280209863
# remaining size for Round 3: 140226
# Calculated size for Round 3: 6191.310368184776
# orr termination 0.024306769921747257 0.09266535536690002 0.06835858544515276
# remaining size for Round 4: 134035
# Calculated size for Round 4: 6607.531819556923
# orr termination 0.05694133909007154 0.09872040113180602 0.04177906204173448
# remaining size for Round 5: 127428
# Calculated size for Round 5: 10234.414923803204
# orr termination 0.01722266515937147 0.10710629805891972 0.08988363289954825
# remaining size for last Round 6: 117194
# 63
# ['step1_rr: 62', 'step2_rr: 62', 'step3_rr: 62', 'step4_rr: 62', 'step5_rr: 62', 'step6_rr: 62']
# empirical response rate 0.08472759955752213
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6355.095390744717
# orr termination 0.04492251382171969 0.11504049626010013 0.07011798243838044
# remaining size for Round 3: 138797
# Calculated size for Round 3: 8021.813457515678
# orr termination 0.04137085904285327 0.12853943223455955 0.08716857319170628
# remaining size for Round 4: 130776
# Calculated size for Round 4: 11160.712369054389
# orr termination 0.022551837071455402 0.12570892979715562 0.10315709272570021
# remaining size for Round 5: 119616
# Calculated size for Round 5: 11320.033526496753
# orr termination 0.038127668966200894 0.1126120069362783 0.07448433797007742
# remaining size for last Round 6: 108296
# 64
# ['step1_rr: 63', 'step2_rr: 63', 'step3_rr: 63', 'step4_rr: 63', 'step5_rr: 63', 'step6_rr: 63']
# empirical response rate 0.06993224557522124
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5280.93931401423
# orr termination 0.007219560982463479 0.11367774282544356 0.10645818184298007
# remaining size for Round 3: 139872
# Calculated size for Round 3: 14923.749873985456
# orr termination 0.04983168068869827 0.09886986985394668 0.04903818916524841
# remaining size for Round 4: 124949
# 65
# ['step1_rr: 64', 'step2_rr: 64', 'step3_rr: 64', 'step4_rr: 64', 'step5_rr: 64', 'step6_rr: 64']
# empirical response rate 0.08856471238938053
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6638.439402074498
# orr termination 0.05921371308453537 0.11171412500858517 0.0525004119240498
# remaining size for Round 3: 138514
# Calculated size for Round 3: 7934.921978667156
# ...
# remaining size for Round 3: 141590
# Calculated size for Round 3: 4573.232384838109
# orr termination 0.018779171160543142 0.09489048208795195 0.0761113109274088
# remaining size for Round 4: 137017
# 79
# ['step1_rr: 78', 'step2_rr: 78', 'step3_rr: 78', 'step4_rr: 78', 'step5_rr: 78', 'step6_rr: 78']
# empirical response rate 0.07304341814159292
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5504.366351150113
# orr termination 0.009891197267853334 0.11878555453934939 0.10889435727149605
# remaining size for Round 3: 139648
# Calculated size for Round 3: 8073.888666035988
# orr termination 0.04610051567413227 0.0920001825214885 0.04589966684735623
# remaining size for Round 4: 131575
# Calculated size for Round 4: 10768.00386820621
# orr termination 0.06722311264796452 0.08915716063462026 0.02193404798665574
# remaining size for Round 5: 120807
# Calculated size for Round 5: 8349.449243192146
# orr termination 0.06288175793855845 0.09416976221320102 0.03128800427464257
# remaining size for last Round 6: 112458
# 80
# ['step1_rr: 79', 'step2_rr: 79', 'step3_rr: 79', 'step4_rr: 79', 'step5_rr: 79', 'step6_rr: 79']
# empirical response rate 0.03277101769911504
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2715.177622674948
# orr termination 0.00911004854801559 0.0576033031188079 0.048493254570792316
# remaining size for Round 3: 142437
# Calculated size for Round 3: 5096.415919867398
# orr termination 0.02165820941836841 0.09555648390303774 0.07389827448466933
# remaining size for Round 4: 137341
# 81
# ['step1_rr: 80', 'step2_rr: 80', 'step3_rr: 80', 'step4_rr: 80', 'step5_rr: 80', 'step6_rr: 80']
# empirical response rate 0.03723036504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3012.9425926886643
# orr termination 0.0027439243168882487 0.10597792110563621 0.10323399678874796
# remaining size for Round 3: 142140
# 82
# ['step1_rr: 81', 'step2_rr: 81', 'step3_rr: 81', 'step4_rr: 81', 'step5_rr: 81', 'step6_rr: 81']
# empirical response rate 0.0478083517699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3730.3602223395455
# orr termination 0.05611486179731469 0.06937614619705604 0.01326128439974135
# remaining size for Round 3: 141422
# Calculated size for Round 3: 4577.193755073528
# orr termination 0.011944818218099507 0.09213515701411668 0.08019033879601717
# remaining size for Round 4: 136845
# Calculated size for Round 4: 5917.217743825128
# orr termination 0.004897417645712476 0.10500557793494376 0.1001081602892313
# remaining size for Round 5: 130928
# 83
# ['step1_rr: 82', 'step2_rr: 82', 'step3_rr: 82', 'step4_rr: 82', 'step5_rr: 82', 'step6_rr: 82']
# empirical response rate 0.08877212389380532
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6653.810492694055
# orr termination 0.0666309486351257 0.1249881221566363 0.0583571735215106
# remaining size for Round 3: 138499
# Calculated size for Round 3: 8339.310266355295
# orr termination 0.040573073220158795 0.1421799612418797 0.10160688802172091
# remaining size for Round 4: 130160
# Calculated size for Round 4: 11338.203664052762
# orr termination 0.0270920594946878 0.11862029196640242 0.09152823247171463
# remaining size for Round 5: 118822
# Calculated size for Round 5: 9846.96508850051
# orr termination 0.022498352329454192 0.11058220751618858 0.0880838551867344
# remaining size for last Round 6: 108976
# 84
# ['step1_rr: 83', 'step2_rr: 83', 'step3_rr: 83', 'step4_rr: 83', 'step5_rr: 83', 'step6_rr: 83']
# empirical response rate 0.03854397123893805
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3101.1855865909392
# orr termination 0.048675643375188454 0.0787088043110385 0.03003316093585004
# remaining size for Round 3: 142051
# Calculated size for Round 3: 5524.810744398786
# orr termination 0.0056348870371934374 0.10746436397359041 0.10182947693639698
# remaining size for Round 4: 136527
# Calculated size for Round 4: 7971.972361852286
# orr termination 0.061815699067799344 0.09389865255650401 0.032082953488704664
# remaining size for Round 5: 128556
# Calculated size for Round 5: 14554.066561535448
# orr termination 0.048549549720135046 0.09621860881983443 0.04766905909969939
# remaining size for last Round 6: 114002
# 85
# ['step1_rr: 84', 'step2_rr: 84', 'step3_rr: 84', 'step4_rr: 84', 'step5_rr: 84', 'step6_rr: 84']
# empirical response rate 0.036297013274336286
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2950.3899597530917
# orr termination 0.04583732226711172 0.07153913678106688 0.02570181451395516
# remaining size for Round 3: 142202
# Calculated size for Round 3: 6099.929227804539
# orr termination 0.027927922392812055 0.08109341569755021 0.05316549330473816
# remaining size for Round 4: 136103
# Calculated size for Round 4: 6519.715882393288
# orr termination 0.03577623336680957 0.08577184064795834 0.04999560728114877
# remaining size for Round 5: 129584
# Calculated size for Round 5: 9028.165704265868
# orr termination 0.045674206001194664 0.09106974847760016 0.045395542476405495
# remaining size for last Round 6: 120556
# 86
# ['step1_rr: 85', 'step2_rr: 85', 'step3_rr: 85', 'step4_rr: 85', 'step5_rr: 85', 'step6_rr: 85']
# empirical response rate 0.05935425884955752
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4531.161082702762
# orr termination 0.027570372782357407 0.07447970415356371 0.0469093313712063
# remaining size for Round 3: 140621
# Calculated size for Round 3: 4486.354825915267
# orr termination 0.022150994716499367 0.09108723896731975 0.06893624425082039
# remaining size for Round 4: 136135
# Calculated size for Round 4: 7215.559963229717
# orr termination 0.015988487420694468 0.11107201545986418 0.09508352803916972
# remaining size for Round 5: 128920
# Calculated size for Round 5: 13299.03074236861
# orr termination 0.04960866443707565 0.09777177918920119 0.048163114752125535
# remaining size for last Round 6: 115621
# 87
# ['step1_rr: 86', 'step2_rr: 86', 'step3_rr: 86', 'step4_rr: 86', 'step5_rr: 86', 'step6_rr: 86']
# empirical response rate 0.03125
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2614.249528775035
# orr termination 0.017877470043719396 0.06881442574959742 0.05093695570587803
# remaining size for Round 3: 142538
# Calculated size for Round 3: 13349.184232250707
# orr termination 0.07550971060726813 0.09409174859223282 0.01858203798496469
# remaining size for Round 4: 129189
# Calculated size for Round 4: 8825.252024819501
# orr termination 0.04915692354185226 0.09636269157515731 0.04720576803330505
# remaining size for Round 5: 120364
# Calculated size for Round 5: 7626.16852051599
# orr termination 0.050733233376474264 0.09893887834529819 0.04820564496882392
# remaining size for last Round 6: 112738
# 88
# ['step1_rr: 87', 'step2_rr: 87', 'step3_rr: 87', 'step4_rr: 87', 'step5_rr: 87', 'step6_rr: 87']
# empirical response rate 0.059596238938053096
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4548.141371331619
# orr termination 0.02756864274619148 0.13265180951787472 0.10508316677168325
# remaining size for Round 3: 140604
# Calculated size for Round 3: 6335.022808465445
# orr termination 0.008752924850690189 0.14004509715345753 0.13129217230276735
# remaining size for Round 4: 134269
# Calculated size for Round 4: 21674.027918462376
# orr termination 0.05015955033194725 0.09921752347056856 0.04905797313862131
# remaining size for Round 5: 112595
# 89
# ['step1_rr: 88', 'step2_rr: 88', 'step3_rr: 88', 'step4_rr: 88', 'step5_rr: 88', 'step6_rr: 88']
# empirical response rate 0.055689988938053096
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4275.017492939368
# orr termination 0.034926613409815344 0.08259179608841055 0.04766518267859521
# remaining size for Round 3: 140877
# Calculated size for Round 3: 7647.47428671192
# orr termination 0.06418208559792832 0.08483619970419606 0.020654114106267746
# remaining size for Round 4: 133230
# Calculated size for Round 4: 7924.01320907002
# orr termination 0.011525684477525952 0.09316126651983576 0.0816355820423098
# remaining size for Round 5: 125306
# Calculated size for Round 5: 6978.715823734401
# orr termination 0.04525170402090644 0.09005051062327984 0.044798806602373405
# remaining size for last Round 6: 118328
# 90
# ['step1_rr: 89', 'step2_rr: 89', 'step3_rr: 89', 'step4_rr: 89', 'step5_rr: 89', 'step6_rr: 89']
# empirical response rate 0.06063329646017699
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4621.005307393422
# orr termination 0.004859046573254041 0.10153373069701145 0.0966746841237574
# remaining size for Round 3: 140531
# Calculated size for Round 3: 6295.093234970061
# orr termination 0.022217921627451585 0.08549294572513702 0.06327502409768543
# remaining size for Round 4: 134236
# Calculated size for Round 4: 13206.233989519736
# orr termination 0.0463077282569477 0.09310152549470796 0.04679379723776026
# remaining size for Round 5: 121030
# 91
# ['step1_rr: 90', 'step2_rr: 90', 'step3_rr: 90', 'step4_rr: 90', 'step5_rr: 90', 'step6_rr: 90']
# empirical response rate 0.06457411504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4899.235573728013
# orr termination 0.020039521526336437 0.09396592895120243 0.07392640742486599
# remaining size for Round 3: 140253
# Calculated size for Round 3: 7034.793171379295
# orr termination 0.045114794818993276 0.09997495532350989 0.054860160504516614
# remaining size for Round 4: 133219
# Calculated size for Round 4: 12081.313526031981
# orr termination 0.06759253392642378 0.0943821066016032 0.026789572675179424
# remaining size for Round 5: 121138
# Calculated size for Round 5: 8530.269888400057
# orr termination 0.04012924788658158 0.10093184272952967 0.06080259484294809
# remaining size for last Round 6: 112608
# 92
# ['step1_rr: 91', 'step2_rr: 91', 'step3_rr: 91', 'step4_rr: 91', 'step5_rr: 91', 'step6_rr: 91']
# empirical response rate 0.049571349557522126
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3851.4435988971077
# orr termination 0.04956762878422419 0.07094364445437662 0.021376015670152432
# remaining size for Round 3: 141301
# Calculated size for Round 3: 5138.232150194167
# orr termination 0.016041770665533923 0.0935318091631506 0.07749003849761668
# remaining size for Round 4: 136163
# Calculated size for Round 4: 5899.39450933057
# orr termination 0.07747023765850192 0.09092011463670989 0.013449876978207972
# remaining size for Round 5: 130264
# Calculated size for Round 5: 12794.47110627491
# orr termination 0.07034238033899518 0.08674044031076811 0.016398059971772933
# remaining size for last Round 6: 117470
# 93
# ['step1_rr: 92', 'step2_rr: 92', 'step3_rr: 92', 'step4_rr: 92', 'step5_rr: 92', 'step6_rr: 92']
# empirical response rate 0.05441095132743363
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4186.045338423161
# orr termination 0.012664417037370297 0.10047626405629022 0.08781184701891992
# remaining size for Round 3: 140966
# 94
# ['step1_rr: 93', 'step2_rr: 93', 'step3_rr: 93', 'step4_rr: 93', 'step5_rr: 93', 'step6_rr: 93']
# empirical response rate 0.05416897123893805
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4169.2382140388045
# orr termination 0.042729736719110074 0.09558830467980933 0.05285856796069926
# remaining size for Round 3: 140983
# Calculated size for Round 3: 8328.574205479406
# orr termination 0.064722374019615 0.0994637093790024 0.03474133535938739
# remaining size for Round 4: 132655
# Calculated size for Round 4: 9395.244723844018
# orr termination 0.08296082305355058 0.08729469783345115 0.004333874779900562
# remaining size for Round 5: 123260
# Calculated size for Round 5: 7615.480899404783
# orr termination 0.03820274337819074 0.09117346661122892 0.05297072323303818
# remaining size for last Round 6: 115645
# 95
# ['step1_rr: 94', 'step2_rr: 94', 'step3_rr: 94', 'step4_rr: 94', 'step5_rr: 94', 'step6_rr: 94']
# empirical response rate 0.02623755530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2283.933061815767
# orr termination 0.002263064789752252 0.05418293149019937 0.05191986670044712
# remaining size for Round 3: 142869
# Calculated size for Round 3: 3929.837001862187
# orr termination 0.054971534827709084 0.08129815284614048 0.02632661801843139
# remaining size for Round 4: 138940
# Calculated size for Round 4: -136646.2359988602lt 0, break
# 96
# ['step1_rr: 95', 'step2_rr: 95', 'step3_rr: 95', 'step4_rr: 95', 'step5_rr: 95', 'step6_rr: 95']
# empirical response rate 0.05323561946902655
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4104.486625389775
# orr termination 0.045881448257804935 0.08298516784739274 0.0371037195895878
# remaining size for Round 3: 141048
# Calculated size for Round 3: 4505.476578658636
# orr termination 0.07033402153675385 0.10321371228771184 0.03287969075095799
# remaining size for Round 4: 136543
# Calculated size for Round 4: 8267.933286613548
# orr termination 0.023895569765331474 0.11055753135084909 0.08666196158551762
# remaining size for Round 5: 128276
# Calculated size for Round 5: 8306.38497714027
# orr termination 0.009429593868841972 0.1144634211216215 0.10503382725277953
# remaining size for last Round 6: 119970
# 97
# ['step1_rr: 96', 'step2_rr: 96', 'step3_rr: 96', 'step4_rr: 96', 'step5_rr: 96', 'step6_rr: 96']
# empirical response rate 0.06419386061946902
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4872.29596410143
# orr termination 0.032776461377646345 0.07819701040261962 0.04542054902497327
# remaining size for Round 3: 140280
# Calculated size for Round 3: 7302.877418674763
# orr termination 0.055501614833690836 0.10216137677713033 0.046659761943439494
# remaining size for Round 4: 132978
# Calculated size for Round 4: 10664.770942738383
# orr termination 0.026680824249067692 0.10732526895214417 0.08064444470307648
# remaining size for Round 5: 122314
# Calculated size for Round 5: 9035.074942277677
# orr termination 0.03460863434940608 0.10284912403466728 0.0682404896852612
# remaining size for last Round 6: 113279
# 98
# ['step1_rr: 97', 'step2_rr: 97', 'step3_rr: 97', 'step4_rr: 97', 'step5_rr: 97', 'step6_rr: 97']
# empirical response rate 0.04079092920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3252.685563220233
# orr termination 0.009977537208215693 0.06908680135071063 0.05910926414249494
# remaining size for Round 3: 141900
# Calculated size for Round 3: 6656.950380337482
# orr termination 0.031448837028099225 0.09388890549164862 0.062440068463549395
# remaining size for Round 4: 135244
# Calculated size for Round 4: 15461.886578517713
# orr termination 0.0481031659437401 0.09596572932412811 0.04786256338038801
# remaining size for Round 5: 119783
# 99
# ['step1_rr: 98', 'step2_rr: 98', 'step3_rr: 98', 'step4_rr: 98', 'step5_rr: 98', 'step6_rr: 98']
# empirical response rate 0.06236172566371682
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4742.773758541168
# orr termination 0.029416267427580335 0.08873367074150074 0.0593174033139204
# remaining size for Round 3: 140410
# Calculated size for Round 3: 5764.989187021268
# orr termination 0.037607143289723734 0.10218563829320458 0.06457849500348084
# remaining size for Round 4: 134646
# Calculated size for Round 4: 8893.205404815812
# orr termination 0.010537054299806826 0.10853336265966702 0.0979963083598602
# remaining size for Round 5: 125753
# Calculated size for Round 5: 9509.074094271273
# orr termination 0.051128485918880626 0.10295266388861755 0.05182417796973693
# remaining size for last Round 6: 116244
# 100
# ['step1_rr: 99', 'step2_rr: 99', 'step3_rr: 99', 'step4_rr: 99', 'step5_rr: 99', 'step6_rr: 99']
# empirical response rate 0.06498893805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4928.646813703883
# orr termination 0.04979370365719393 0.07838411215597904 0.028590408498785108
# remaining size for Round 3: 140224
# Calculated size for Round 3: 5420.559075748289
# orr termination 0.0251210876486444 0.08271007019241455 0.05758898254377015
# remaining size for Round 4: 134804
# Calculated size for Round 4: 5920.695885546209
# orr termination 0.01906352534092558 0.09706741444066694 0.07800388909974136
# remaining size for Round 5: 128884
# Calculated size for Round 5: 9542.152723411427
# orr termination 0.06378606668774886 0.09653529289975722 0.03274922621200836
# remaining size for last Round 6: 119342

# %% [markdown]
# ### Results summary

# %%
rr_df = pd.DataFrame(rr_dict)
rr_df
# Out:
#     step1_rr  step2_rr  step3_rr  step4_rr  step5_rr  step6_rr
# 0   0.054396  0.069769  0.074098  0.082860  0.090087  0.098086
# 1   0.052528  0.081552  0.084982  0.092581  0.094741  0.096592
# 2   0.053361  0.087278  0.094884  0.096033  0.099115  0.099331
# 3   0.054444  0.083072  0.090408  0.092797  0.093733  0.094046
# 4   0.054870  0.070627  0.073284  0.075362  0.077342  0.088224
# ..       ...       ...       ...       ...       ...       ...
# 95  0.053512  0.067426  0.083837  0.089460  0.093341  0.093093
# 96  0.051957  0.072207  0.075413  0.084172  0.096681  0.099108
# 97  0.053364  0.082072  0.089235  0.092669  0.099892       NaN
# 98  0.053413  0.066432  0.083077  0.087931  0.096547  0.099559
# 99  0.058045  0.072431  0.080805  0.090572  0.094287  0.094614
#
# [100 rows x 6 columns]

# %%
# Calculate average rounds:
row_non_nan_counts = rr_df.count(axis=1)

print(f"{np.mean(row_non_nan_counts):.1f} ({np.std(row_non_nan_counts):.1f})")
# Out:
# 5.5 (0.8)

# %%
result_dict = {}
for key, values in rr_df.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"

for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_rr: 0.055 (0.002)
# step2_rr: 0.079 (0.008)
# step3_rr: 0.089 (0.006)
# step4_rr: 0.093 (0.005)
# step5_rr: 0.096 (0.004)
# step6_rr: 0.097 (0.003)

# %%
result_dict = np.array(orr_total) / total_n
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f} ({std_result:.3f})")
# Out:
# Mean: 0.089 (0.002)

# %%
result_dict = np.array(orr_total_adaptive) / (145152)
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f} ({std_result:.3f})")
# Out:
# Mean: 0.096 (0.003)

# %%
mean_result = (np.mean(highest_true_rr))
pristd_result = (np.std(highest_true_rr))

print(f"Mean: {mean_result:.3f} ({std_result:.3f})")
# Out:
# Mean: 0.098 (0.003)

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in plan_number_dict.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.1f} ({std_value:.1f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_plan_number: nan (nan)
# step2_plan_number: 102.6 (58.4)
# step3_plan_number: 34.0 (35.8)
# step4_plan_number: 11.1 (11.6)
# step5_plan_number: 4.6 (5.5)
# step6_plan_number: 2.5 (3.2)

# %%
means = {key: np.mean(values) for key, values in stopping_dict.items()}
means
# Out:
# {'early_stopping': 0.3,
#  'early_stopping_plan': 0.27,
#  'early_stopping_orr': 0.0,
#  'early_stopping_size': 0.03}

# %%
print(np.mean(last_round_sample_size), np.std(last_round_sample_size))
# Out:
# 117005.0 9722.315756032613

# %%
np.mean(better_chance)
# Out:
# 1.0

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in sample_size_dict.items():
    mean_value = np.nanmean(values)
    std_value = np.nanstd(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_sample_size: 28928.000 (0.000)
# step2_sample_size: 4284.361 (1344.789)
# step3_sample_size: 13655.023 (26494.286)
# step4_sample_size: 23063.283 (37500.560)
# step5_sample_size: 30100.966 (42538.116)
# step6_sample_size: 113123.814 (5210.607)

# %% [markdown]
# ## Ensemble learning - 7 methods

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import ensemble, linear_model
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier

def ensemble_model_fit(data, data_pred):
    X_train, X_test, y_train, y_test = train_test_split(
        data.drop(['recruitment_plan', 'plan_response_rate', 'group_size', 'response'], axis=1),
        data['response'],
        test_size=0.2,
        random_state=0
    )

    # Define the VotingClassifier with the individual classifiers
    voting_classifier = ensemble.VotingClassifier(
        estimators=[
            ('LR', linear_model.LogisticRegression(penalty = 'none', max_iter=200, random_state=0)),
            ('Lasso', linear_model.LogisticRegression(penalty = "l1", max_iter=200, random_state=0,
                                                     solver="liblinear")),
            ('Ridge', linear_model.LogisticRegression(penalty = "l2", max_iter=200, random_state=0)),
            ('GBM', ensemble.GradientBoostingClassifier(random_state=0)),
            ('RF', ensemble.RandomForestClassifier(random_state=0)),
            ('XGB', XGBClassifier(random_state=0)),
            ('NN', MLPClassifier(random_state=0))
        ],
        voting='soft'
    )

    # Define the hyperparameter grid to search
#     param_grid = {
# #         'LR__C': [0.01, 0.1, 1.0],  # Regularization parameter for logistic regression
#         'Lasso__C': [0.01, 0.1, 1.0],  # Regularization parameter for lasso regression
#         'Ridge__C': [0.01, 0.1, 1.0],  # Regularization parameter for ridge regression
#         'GBM__learning_rate': [0.01, 0.1, 0.5],  # Learning rate for gradient boosting machine
#         'GBM__n_estimators': [50, 100, 200],  # Number of trees for gradient boosting machine
#         'RF__n_estimators': [50, 100, 200],  # Number of trees for random forest
# #         'RF__max_depth': [10, 20],  # Maximum depth of trees for random forest
#         'XGB__learning_rate': [0.01, 0.1, 0.5],  # Learning rate for XGBoost
#         'XGB__n_estimators': [50, 100, 200],  # Number of trees for XGBoost
#         'NN__hidden_layer_sizes': [(50,), (100,), (50, 50)],  # Size of hidden layers for neural networks
#         'NN__alpha': [0.0001, 0.001, 0.01]  # Regularization parameter for neural networks
#     }
    param_grid = {
#         'LR__C': [0.01, 0.1, 1.0],  # Regularization parameter for logistic regression
        'Lasso__C': [0.1],  # Regularization parameter for lasso regression
        'Ridge__C': [0.01],  # Regularization parameter for ridge regression
        'GBM__learning_rate': [0.01],  # Learning rate for gradient boosting machine
        'GBM__n_estimators': [50],  # Number of trees for gradient boosting machine
        'RF__n_estimators': [50],  # Number of trees for random forest
#         'RF__max_depth': [10, 20],  # Maximum depth of trees for random forest
        'XGB__learning_rate': [0.01],  # Learning rate for XGBoost
        'XGB__n_estimators': [50],  # Number of trees for XGBoost
        'NN__hidden_layer_sizes': [(50,)],  # Size of hidden layers for neural networks
        'NN__alpha': [0.01]  # Regularization parameter for neural networks
    }

    # Create a GridSearchCV object
    grid_search = GridSearchCV(voting_classifier, param_grid, cv=10, scoring='roc_auc')

    # Perform the grid search on the training data
    grid_search.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = grid_search.best_params_
#     print("Best fit parameters:", best_params)

    # Train the final VotingClassifier with the best hyperparameters on the full training set
    final_voting_classifier = grid_search.best_estimator_
    final_voting_classifier.fit(X_train, y_train)

    # Predict probabilities instead of binary outcomes on the test set
    y_pred_proba_test = final_voting_classifier.predict_proba(X_test)
    y_pred_test = final_voting_classifier.predict(X_test)
    X_dt = data_pred.drop(['recruitment_plan', 'plan_response_rate', 'group_size', 'response'], axis=1)
    y_pred = final_voting_classifier.predict_proba(X_dt)

    return y_pred

# %%
# ensemble_model_fit(dt_design_5, dt_design_5)

# %% [markdown]
# ### Simulation starts

# %%
n_sim = 100
# create a list of random seeds
random.seed(42)
random_seeds = [random.randint(1, 100000) for _ in range(n_sim)]

design_list = [5,8,10]
patient_n_list = [5468,680,170] # n_patient_per_plan

n_design = 8
n_patient_per_plan = 680
n_rounds = 6
total_n = n_patient_per_plan * (2**n_design)

## sample size determination
beta = 0.2
power = 1 - beta
alpha = 0.05
delta = 0.01 # effect size

## early stopping
epsilon = 0.001

# %%
rr_dict = {"step{}_rr".format(r): [] for r in range(1, n_rounds + 1)}
plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
sample_size_dict = {"step{}_sample_size".format(r): [] for r in range(1, n_rounds + 1)}
last_round_sample_size = []
random_rr_dict = {"step{}_random_max_rr".format(r): [] for r in range(1, n_rounds + 1)}
random_rr_dict.update({
    "step{}_random_mean_rr".format(r): [] for r in range(1, n_rounds + 1)
})

stopping_dict = {"early_stopping": [],
                 "early_stopping_plan":[],
                 "early_stopping_orr":[],
                 "early_stopping_size":[]}
final_plan_number = []
highest_rr_overall = []
highest_true_rr = []

better_chance = []

orr_total = []
orr_total_adaptive = []



i = 0

for seed in random_seeds:
    i += 1
    print(i)

    print([f"{key}: {len(value)}" for key, value in rr_dict.items()])



    event_list = 0
    event_list_adaptive = 0
    max_rr = []

    # step 1:
    ## Generate dataset
    dt_design_5 = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed)
    highest_true_rr.append(np.max(dt_design_5['plan_response_rate']))
    print("empirical response rate", dt_design_5['response'].mean())
    ## save for benchmark results
    maxidx = np.argmax(dt_design_5['plan_response_rate'])
    random_rr_dict['step1_random_max_rr'].append(dt_design_5.iloc[maxidx,6])
    random_rr_dict['step1_random_mean_rr'].append(dt_design_5['plan_response_rate'].mean())

    ## Ensemble modelling:
    y_pred = ensemble_model_fit(data=dt_design_5, data_pred = dt_design_5)

    ## select recruitment plan
    pred_df = pd.DataFrame(np.hstack((dt_design_5,  y_pred[:, 1].reshape(-1, 1))),
                             columns=list(dt_design_5.columns) + ['predicted_response_rate'])
    pred_df_rr = pred_df.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

    x = pred_df_rr['predicted_response_rate'].values
    if len(x) <= 10:
        best_k = 2
    else:
        best_k = kmeans_fit(data = x)['best_k']
    kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

    merged_df = pd.merge(pred_df_rr, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
    cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
    highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
    highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)


    p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))
    highest_cluster['p_vec'] = p_vec_next
    highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

    # highest_cluster = pred_df_rr

    # highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')
    # highest_cluster['cluster_number'] = highest_cluster['recruitment_plan']

    ## prepare to chance of better performance:
    temp = dt_design_5[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
    event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print("step1", np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print(temp)
    p0 = (temp['plan_response_rate'].mean())

    rr_dict["step1_rr"].append(dt_design_5['plan_response_rate'].mean())
    sample_size_dict["step1_sample_size"].append(len(dt_design_5))

    for round in range(2, n_rounds+1):

        rr_dict["step"+str(round)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))
        plan_number_dict["step"+str(round)+"_plan_number"].append(len(p_vec_next))

        ## when it comes to the last round:
        if round == n_rounds:

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            if round == 2: # if the last round is round 2
                remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
            else:
                remaining_size -= len(dt_design_5_step2up)

            print("remaining size for last Round " + str(round) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            ## data generation, combine previous data:
            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, 
                                                          design_number = n_design, n_rounds = n_rounds,
                                                          n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(0)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(len(temp), temp['plan_response_rate'].mean())
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break



        ## If haven't reached the last round:
        ## check remaining sample size:
        if round == 2:
            remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
        else:
            remaining_size -= len(dt_design_5_step2up)

        print("remaining size for Round " + str(round) + ": " + str(remaining_size))

        ## determine whether move on to step 2:
        if len(highest_cluster) == 1: # if there is only one plan left

            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size) # record the last round sample size
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(1)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        ## sample size determination:
        if round == 2:
            dt_design_5_step2up_overall = dt_design_5
        orr_1 = dt_design_5_step2up_overall['response'].mean() # observed overall response rates for previous rounds
        orr_2 = orr_1 + delta
        n_1 = len(dt_design_5_step2up_overall)

        size_step2up = sample_size_calc(orr_1, n_1, delta=delta, alpha=alpha, power=power) # total size for dataset
        if size_step2up > 0 and size_step2up < 1000:
            size_step2up = 1000 # if size in [0,1000], then it is 1000 for this round.
        elif size_step2up >= 1000:
            size_step2up = min(size_step2up, int(total_n/n_rounds)) # dataset size capped by the n_patient_per_plan
        else:
        # if size_step2up <= 0:
            # the process stops at this step
            print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up) + 'lt 0, break')
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(1)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up))

        sample_size_dict["step"+str(round)+"_sample_size"].append(size_step2up)

        ## save benchmark results for last round:
        dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                            n_patient_per_plan = n_patient_per_plan, seed=seed+round)
        maxidx = np.argmax(dt_benchmark['plan_response_rate'])
        random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
        random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

        ## data generation, combine previous data:
        dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,
                                                  design_number = n_design, n_rounds = n_rounds,
                                                  n_patient_per_plan = n_patient_per_plan, size = int(size_step2up), seed=seed)

        plan_list = dt_design_5_step2up['recruitment_plan'].unique()
        if round == 2:
            supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)]
        else:
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
        dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
        dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

        ## Ensemble model fitting:
        dt_design_5_step2up.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)
        y_pred2up = ensemble_model_fit(data = dt_design_5_step2up_overall, data_pred = dt_design_5_step2up)
        pred_df_step2up = pd.DataFrame(np.hstack((dt_design_5_step2up,  y_pred2up[:, 1].reshape(-1, 1))),
                                    columns=list(dt_design_5_step2up.columns) + ['predicted_response_rate'])
        pred_df_rr_step2up = pred_df_step2up.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

        ## select recruitment plans:
        x = pred_df_rr_step2up['predicted_response_rate'].values

        if len(x) <= 10:
            best_k = 2
        else:
            best_k = kmeans_fit(data = x)['best_k']
        kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

        ## match the cluster results back to the original data
        highest_cluster_previous = highest_cluster # save previous cluster results

        merged_df = pd.merge(pred_df_rr_step2up, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
        cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
        highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
        highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)

        # p_vec_previous = p_vec_next # save p_vec of previous round
        p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))

        highest_cluster['p_vec'] = p_vec_next

        highest_cluster = pd.merge(highest_cluster, dt_design_5_step2up[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

        ## prepare to chance of better performance:
        temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
        event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print(temp)

        ## check early stopping predicted ORR:
        orr_df = pd.merge(highest_cluster_previous, highest_cluster[['recruitment_plan','predicted_response_rate','p_vec']], on='recruitment_plan', how='left')
        orr_df.fillna(0, inplace=True)
        p_orr_1 = np.dot(np.array(orr_df['p_vec_x']), np.array(orr_df['predicted_response_rate_y']))
        p_orr_2 = np.dot(np.array(orr_df['p_vec_y']), np.array(orr_df['predicted_response_rate_y']))
        print("orr termination", p_orr_1, p_orr_2, p_orr_2 - p_orr_1)

        if (p_orr_2 - p_orr_1 < epsilon):
            # step 3 use the same strategy of step2
            print(i, p_orr_1, p_orr_2, "early stop at Round " + str(round))
            rr_dict["step"+str(round+1)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                                n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round+1)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round+1)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            ### update remaining size:
            remaining_size -= len(dt_design_5_step2up)
            print("early stop, remaining size for Round" + str(round + 1) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            for r in range(round+2, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, 
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(1)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            for r in range(round+2, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round+1), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break
# Out:
# 1
# ['step1_rr: 0', 'step2_rr: 0', 'step3_rr: 0', 'step4_rr: 0', 'step5_rr: 0', 'step6_rr: 0']
# empirical response rate 0.08033738938053098
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6033.300486728156
# orr termination 0.0043194783914648986 0.1260951876926159 0.121775709301151
# remaining size for Round 3: 139119
# Calculated size for Round 3: 8648.409637537236
# orr termination 0.06303668199515125 0.10457878202838691 0.04154210003323566
# remaining size for Round 4: 130471
# Calculated size for Round 4: 13680.720780766038
# orr termination 0.07215593921987264 0.10796515142709878 0.035809212207226146
# remaining size for Round 5: 116791
# Calculated size for Round 5: 8511.420539758952
# orr termination 0.056460552833455566 0.11145372471178164 0.05499317187832607
# remaining size for last Round 6: 108280
# 2
# ['step1_rr: 1', 'step2_rr: 1', 'step3_rr: 1', 'step4_rr: 1', 'step5_rr: 1', 'step6_rr: 1']
# empirical response rate 0.07836698008849557
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5889.708525120337
# orr termination 0.00833444074499875 0.10852954036170104 0.10019509961670228
# remaining size for Round 3: 139263
# Calculated size for Round 3: 8625.116051689038
# orr termination 0.057759253543213616 0.10095203884988734 0.04319278530667372
# remaining size for Round 4: 130638
# Calculated size for Round 4: 11868.104102247835
# orr termination 0.07974807928382191 0.10620655858353789 0.02645847929971598
# remaining size for Round 5: 118770
# Calculated size for Round 5: 8473.801964385137
# orr termination 0.03683838398954486 0.10943291722924303 0.07259453323969817
# remaining size for last Round 6: 110297
# 3
# ['step1_rr: 2', 'step2_rr: 2', 'step3_rr: 2', 'step4_rr: 2', 'step5_rr: 2', 'step6_rr: 2']
# empirical response rate 0.030593196902654867
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2570.7668488803606
# orr termination 0.04092956942191139 0.07863768195411976 0.03770811253220837
# remaining size for Round 3: 142582
# Calculated size for Round 3: 6097.211543196938
# orr termination 0.002141099837202613 0.08814327726290638 0.08600217742570378
# remaining size for Round 4: 136485
# 4
# ['step1_rr: 3', 'step2_rr: 3', 'step3_rr: 3', 'step4_rr: 3', 'step5_rr: 3', 'step6_rr: 3']
# empirical response rate 0.06011476769911504
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4584.554843390879
# orr termination 0.009580810809865947 0.11413429843704075 0.1045534876271748
# remaining size for Round 3: 140568
# Calculated size for Round 3: 15555.338827578862
# orr termination 0.03552521519031075 0.10334995863024941 0.06782474343993866
# remaining size for Round 4: 125013
# 5
# ['step1_rr: 4', 'step2_rr: 4', 'step3_rr: 4', 'step4_rr: 4', 'step5_rr: 4', 'step6_rr: 4']
# empirical response rate 0.09029314159292036
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6766.704057464664
# orr termination 0.049219456312469864 0.12069138120319564 0.07147192489072578
# remaining size for Round 3: 138386
# Calculated size for Round 3: 8286.217348973552
# orr termination 0.07561079037280602 0.1259218160105744 0.050311025637768375
# remaining size for Round 4: 130100
# Calculated size for Round 4: 10591.849402006323
# orr termination 0.11537411313638092 0.12395420988709574 0.008580096750714819
# remaining size for Round 5: 119509
# Calculated size for Round 5: 9653.036094993537
# orr termination 0.022918073452648006 0.12960783737152776 0.10668976391887974
# remaining size for last Round 6: 109856
# 6
# ['step1_rr: 5', 'step2_rr: 5', 'step3_rr: 5', 'step4_rr: 5', 'step5_rr: 5', 'step6_rr: 5']
# empirical response rate 0.04362555309734513
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3444.8125679843447
# orr termination 0.005363287205482332 0.07327011989695609 0.06790683269147375
# remaining size for Round 3: 141708
# Calculated size for Round 3: 5775.141621078705
# orr termination 0.07593554281879616 0.10083598695598145 0.024900444137185285
# remaining size for Round 4: 135933
# Calculated size for Round 4: 29013
# orr termination 0.034349047679006345 0.10425037849924447 0.06990133082023813
# remaining size for Round 5: 106920
# 7
# ['step1_rr: 6', 'step2_rr: 6', 'step3_rr: 6', 'step4_rr: 6', 'step5_rr: 6', 'step6_rr: 6']
# empirical response rate 0.04355641592920354
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3440.1132258982107
# orr termination 0.0031643124437447526 0.09811173716354483 0.09494742471980008
# remaining size for Round 3: 141712
# Calculated size for Round 3: 6633.0122952061
# orr termination 0.06154582954028896 0.08228622458472966 0.020740395044440696
# remaining size for Round 4: 135079
# Calculated size for Round 4: 12355.716739050034
# orr termination 0.060135761808907305 0.08897513109170084 0.028839369282793535
# remaining size for Round 5: 122724
# Calculated size for Round 5: 6858.828939290592
# orr termination 0.045475395717256714 0.0908385462516548 0.045363150534398086
# remaining size for last Round 6: 115866
# 8
# ['step1_rr: 7', 'step2_rr: 7', 'step3_rr: 7', 'step4_rr: 7', 'step5_rr: 7', 'step6_rr: 7']
# empirical response rate 0.08030282079646017
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6030.776854562427
# orr termination 0.0700890463496839 0.13872927119467848 0.06864022484499459
# remaining size for Round 3: 139122
# Calculated size for Round 3: 19248.836455186796
# orr termination 0.059466123192548466 0.12265259337828538 0.06318647018573692
# remaining size for Round 4: 119874
# Calculated size for Round 4: 8963.635727121518
# orr termination 0.011442636026662267 0.12256892376119426 0.111126287734532
# remaining size for Round 5: 110911
# 9
# ['step1_rr: 8', 'step2_rr: 8', 'step3_rr: 8', 'step4_rr: 8', 'step5_rr: 8', 'step6_rr: 8']
# empirical response rate 0.04777378318584071
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3727.99035410021
# orr termination 0.010884038136542692 0.08137010489941109 0.0704860667628684
# remaining size for Round 3: 141425
# Calculated size for Round 3: 6554.840577569971
# orr termination 0.00942845527710538 0.10442467819989039 0.094996222922785
# remaining size for Round 4: 134871
# 10
# ['step1_rr: 9', 'step2_rr: 9', 'step3_rr: 9', 'step4_rr: 9', 'step5_rr: 9', 'step6_rr: 9']
# empirical response rate 0.043037887168141595
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3404.8893784747597
# orr termination 0.040674306010606766 0.08007263971119087 0.039398333700584105
# remaining size for Round 3: 141748
# Calculated size for Round 3: 26365.35318448894
# orr termination 0.04453869794100725 0.10689796514921202 0.06235926720820476
# remaining size for Round 4: 115383
# Calculated size for Round 4: 7133.660986841784
# orr termination 0.06998263203579508 0.10432525771608425 0.034342625680289174
# remaining size for Round 5: 108250
# Calculated size for Round 5: 8296.74442344957
# orr termination 0.05350302998156703 0.10636751296801905 0.05286448298645202
# remaining size for last Round 6: 99954
# 11
# ['step1_rr: 10', 'step2_rr: 10', 'step3_rr: 10', 'step4_rr: 10', 'step5_rr: 10', 'step6_rr: 10']
# empirical response rate 0.03297842920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2728.965581830211
# orr termination 0.025496454948332848 0.08067803258532467 0.05518157763699183
# remaining size for Round 3: 142424
# Calculated size for Round 3: 29013
# orr termination 0.04120192326836976 0.10349346436264271 0.062291541094272956
# remaining size for Round 4: 113411
# Calculated size for Round 4: 7023.375533660853
# orr termination 0.05314663960529846 0.10623210887439404 0.053085469269095575
# remaining size for Round 5: 106388
# 12
# ['step1_rr: 11', 'step2_rr: 11', 'step3_rr: 11', 'step4_rr: 11', 'step5_rr: 11', 'step6_rr: 11']
# empirical response rate 0.034603152654867256
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2837.1791262040406
# orr termination 0.005495756400434447 0.06895765225837129 0.06346189585793685
# remaining size for Round 3: 142315
# Calculated size for Round 3: 5227.204766237536
# orr termination 0.045049783692074505 0.0901065091399872 0.0450567254479127
# remaining size for Round 4: 137088
# Calculated size for Round 4: 18450.75791574265
# orr termination 0.03241264317629596 0.09262770425653123 0.06021506108023527
# remaining size for Round 5: 118638
# 13
# ['step1_rr: 12', 'step2_rr: 12', 'step3_rr: 12', 'step4_rr: 12', 'step5_rr: 12', 'step6_rr: 12']
# empirical response rate 0.04124032079646018
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3283.0700374646344
# orr termination 0.039186471992447874 0.05915074493822571 0.019964272945777836
# remaining size for Round 3: 141869
# Calculated size for Round 3: 3822.3726117990445
# orr termination 0.027736525562994024 0.06709749130625349 0.039360965743259466
# remaining size for Round 4: 138047
# Calculated size for Round 4: 4588.189178582393
# orr termination 0.014923843950919856 0.07821710210023633 0.06329325814931647
# remaining size for Round 5: 133459
# Calculated size for Round 5: 6425.090414068619
# orr termination 0.04619843195359953 0.10183848408582141 0.05564005213222188
# remaining size for last Round 6: 127034
# 14
# ['step1_rr: 13', 'step2_rr: 13', 'step3_rr: 13', 'step4_rr: 13', 'step5_rr: 13', 'step6_rr: 13']
# empirical response rate 0.07079646017699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5342.870662026109
# orr termination 0.023026021408834488 0.11872711927400877 0.09570109786517428
# remaining size for Round 3: 139810
# Calculated size for Round 3: 9327.607469378045
# orr termination 0.04456245077080344 0.11918601798611937 0.07462356721531593
# remaining size for Round 4: 130483
# Calculated size for Round 4: 12010.578976678727
# orr termination 0.04686054368360044 0.10788494054116425 0.06102439685756381
# remaining size for Round 5: 118473
# Calculated size for Round 5: 8882.630495508645
# orr termination 0.07492686254120164 0.1127617842281668 0.03783492168696516
# remaining size for last Round 6: 109591
# 15
# ['step1_rr: 14', 'step2_rr: 14', 'step3_rr: 14', 'step4_rr: 14', 'step5_rr: 14', 'step6_rr: 14']
# empirical response rate 0.03135370575221239
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2621.120723895575
# orr termination 0.002306760304389924 0.07041456252106125 0.06810780221667133
# remaining size for Round 3: 142531
# 16
# ['step1_rr: 15', 'step2_rr: 15', 'step3_rr: 15', 'step4_rr: 15', 'step5_rr: 15', 'step6_rr: 15']
# empirical response rate 0.07231747787610619
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5452.116013979351
# orr termination 0.02343723710098406 0.12970624814063134 0.10626901103964728
# remaining size for Round 3: 139700
# Calculated size for Round 3: 16758.6027503181
# orr termination 0.056075006130397224 0.09934825798146045 0.043273251851063226
# remaining size for Round 4: 122942
# Calculated size for Round 4: 7930.612071903205
# orr termination 0.025082226841659002 0.10052795701782666 0.07544573017616765
# remaining size for Round 5: 115012
# 17
# ['step1_rr: 16', 'step2_rr: 16', 'step3_rr: 16', 'step4_rr: 16', 'step5_rr: 16', 'step6_rr: 16']
# empirical response rate 0.02900304203539823
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2465.7425695144257
# orr termination 0.005284914824723912 0.0645939079079222 0.059308993083198286
# remaining size for Round 3: 142687
# Calculated size for Round 3: 4381.271046338324
# orr termination 0.040884278970204566 0.07359188074644665 0.03270760177624209
# remaining size for Round 4: 138306
# Calculated size for Round 4: 12574.706829930195
# orr termination 0.06334140226513821 0.10449844326838119 0.04115704100324298
# remaining size for Round 5: 125732
# Calculated size for Round 5: 8967.747570327207
# orr termination 0.0368710234726432 0.10742204956358548 0.07055102609094227
# remaining size for last Round 6: 116765
# 18
# ['step1_rr: 17', 'step2_rr: 17', 'step3_rr: 17', 'step4_rr: 17', 'step5_rr: 17', 'step6_rr: 17']
# empirical response rate 0.038682245575221236
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3110.4883281384073
# orr termination 0.016695124779250222 0.06458010816152991 0.047884983382279686
# remaining size for Round 3: 142042
# Calculated size for Round 3: 3977.0479623393
# orr termination 0.023576175441679035 0.08498897888395746 0.061412803442278424
# remaining size for Round 4: 138065
# Calculated size for Round 4: 8119.570375660307
# orr termination 0.05846827320544394 0.09973862723131843 0.04127035402587449
# remaining size for Round 5: 129946
# Calculated size for Round 5: 10759.104069437484
# orr termination 0.044089964220686464 0.10160365497586701 0.05751369075518055
# remaining size for last Round 6: 119187
# 19
# ['step1_rr: 18', 'step2_rr: 18', 'step3_rr: 18', 'step4_rr: 18', 'step5_rr: 18', 'step6_rr: 18']
# empirical response rate 0.04860342920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3784.913012723484
# orr termination 0.0037598258934721266 0.08146983128360202 0.0777100053901299
# remaining size for Round 3: 141368
# Calculated size for Round 3: 5631.978847232979
# orr termination 0.022035607159019085 0.11256408311414041 0.09052847595512133
# remaining size for Round 4: 135737
# 20
# ['step1_rr: 19', 'step2_rr: 19', 'step3_rr: 19', 'step4_rr: 19', 'step5_rr: 19', 'step6_rr: 19']
# empirical response rate 0.09053512168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6784.692301555903
# orr termination 0.03668457615345902 0.1450453369457464 0.10836076079228738
# remaining size for Round 3: 138368
# Calculated size for Round 3: 11616.908438268474
# orr termination 0.06371140691520535 0.1314475826742364 0.06773617575903104
# remaining size for Round 4: 126752
# Calculated size for Round 4: 11803.345454409702
# orr termination 0.11793156442392783 0.12710441532751932 0.00917285090359149
# remaining size for Round 5: 114949
# Calculated size for Round 5: 10345.620401548202
# orr termination 0.10416213706998344 0.1221950746314414 0.018032937561457962
# remaining size for last Round 6: 104604
# 21
# ['step1_rr: 20', 'step2_rr: 20', 'step3_rr: 20', 'step4_rr: 20', 'step5_rr: 20', 'step6_rr: 20']
# empirical response rate 0.04127488938053098
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3285.4084707208544
# orr termination 0.01587323495970335 0.0991065406064769 0.08323330564677356
# remaining size for Round 3: 141867
# Calculated size for Round 3: 11136.298522287101
# orr termination 0.0517591051574658 0.1022915623745799 0.0505324572171141
# remaining size for Round 4: 130731
# Calculated size for Round 4: 9851.922033940085
# orr termination 0.0510913651047504 0.10267931133317336 0.05158794622842296
# remaining size for Round 5: 120880
# Calculated size for Round 5: 8835.909488450758
# orr termination 0.05237445758244462 0.10342056152467119 0.05104610394222657
# remaining size for last Round 6: 112045
# 22
# ['step1_rr: 21', 'step2_rr: 21', 'step3_rr: 21', 'step4_rr: 21', 'step5_rr: 21', 'step6_rr: 21']
# empirical response rate 0.09153761061946902
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6859.296443568507
# orr termination 0.016863835400042528 0.12207231809697186 0.10520848269692934
# remaining size for Round 3: 138293
# Calculated size for Round 3: 8025.935323881298
# orr termination 0.00627781143109222 0.12872958797539097 0.12245177654429874
# remaining size for Round 4: 130268
# 23
# ['step1_rr: 22', 'step2_rr: 22', 'step3_rr: 22', 'step4_rr: 22', 'step5_rr: 22', 'step6_rr: 22']
# empirical response rate 0.11189850663716815
# remaining size for Round 2: 145152
# Calculated size for Round 2: 8402.348985484643
# orr termination 0.015932081392240158 0.14428154488458855 0.12834946349234838
# remaining size for Round 3: 136750
# Calculated size for Round 3: 8587.397500884972
# orr termination 0.08341867260806754 0.13955150367040536 0.056132831062337823
# remaining size for Round 4: 128163
# Calculated size for Round 4: 17446.32580917855
# orr termination 0.009278555259969203 0.11496714875291567 0.10568859349294646
# remaining size for Round 5: 110717
# 24
# ['step1_rr: 23', 'step2_rr: 23', 'step3_rr: 23', 'step4_rr: 23', 'step5_rr: 23', 'step6_rr: 23']
# empirical response rate 0.06201603982300885
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4718.387240976126
# orr termination 0.09289746945298155 0.11539945240042446 0.022501982947442906
# remaining size for Round 3: 140434
# Calculated size for Round 3: 10813.738980433307
# orr termination 0.012889518876070217 0.12233572919779329 0.10944621032172307
# remaining size for Round 4: 129621
# Calculated size for Round 4: 8655.160403041968
# orr termination 0.030659738009406058 0.10730565938930008 0.07664592137989401
# remaining size for Round 5: 120966
# Calculated size for Round 5: 11818.74885965598
# orr termination 0.05519170396504114 0.11040310370966627 0.055211399744625134
# remaining size for last Round 6: 109148
# 25
# ['step1_rr: 24', 'step2_rr: 24', 'step3_rr: 24', 'step4_rr: 24', 'step5_rr: 24', 'step6_rr: 24']
# empirical response rate 0.05008987831858407
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3887.138480086987
# orr termination 0.00846796298937294 0.08529210612733712 0.07682414313796418
# remaining size for Round 3: 141265
# Calculated size for Round 3: 9322.685933366802
# orr termination 0.06937352515478001 0.0923638564502804 0.02299033129550039
# remaining size for Round 4: 131943
# Calculated size for Round 4: 10321.799013059594
# orr termination 0.062425632647368126 0.09336481624366055 0.030939183596292427
# remaining size for Round 5: 121622
# Calculated size for Round 5: 7350.448525389341
# orr termination 0.04800964085490987 0.09581826122232802 0.04780862036741815
# remaining size for last Round 6: 114272
# 26
# ['step1_rr: 25', 'step2_rr: 25', 'step3_rr: 25', 'step4_rr: 25', 'step5_rr: 25', 'step6_rr: 25']
# empirical response rate 0.03297842920353982
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2728.965581830211
# orr termination 0.0057096104995721505 0.07096142723218546 0.06525181673261331
# remaining size for Round 3: 142424
# Calculated size for Round 3: 4679.226536516427
# orr termination 0.008184277133911372 0.0750236013929573 0.06683932425904593
# remaining size for Round 4: 137745
# 27
# ['step1_rr: 26', 'step2_rr: 26', 'step3_rr: 26', 'step4_rr: 26', 'step5_rr: 26', 'step6_rr: 26']
# empirical response rate 0.033842643805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2786.4800847064803
# orr termination 0.0069968500686246 0.0490777520460061 0.0420809019773815
# remaining size for Round 3: 142366
# Calculated size for Round 3: 3457.701348370808
# orr termination 0.014833337550488563 0.08125361530605471 0.06642027775556615
# remaining size for Round 4: 138909
# Calculated size for Round 4: 15194.015331149374
# orr termination 0.04887519102033313 0.09815697314844171 0.04928178212810858
# remaining size for Round 5: 123715
# 28
# ['step1_rr: 27', 'step2_rr: 27', 'step3_rr: 27', 'step4_rr: 27', 'step5_rr: 27', 'step6_rr: 27']
# empirical response rate 0.06077157079646018
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4630.73167611316
# orr termination 0.02162095306590562 0.08314803977381105 0.06152708670790543
# remaining size for Round 3: 140522
# Calculated size for Round 3: 6110.759887249727
# orr termination 0.0027977906229323495 0.08982540819566519 0.08702761757273283
# remaining size for Round 4: 134412
# 29
# ['step1_rr: 28', 'step2_rr: 28', 'step3_rr: 28', 'step4_rr: 28', 'step5_rr: 28', 'step6_rr: 28']
# empirical response rate 0.06277654867256637
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4772.059228563532
# orr termination 0.05421918367757999 0.11365052931276583 0.05943134563518584
# remaining size for Round 3: 140380
# Calculated size for Round 3: 8766.765648071867
# orr termination 0.023412628219196513 0.10930180804557366 0.08588917982637714
# remaining size for Round 4: 131614
# Calculated size for Round 4: 8688.871197170502
# orr termination 0.05467006857428204 0.10105358647489575 0.04638351790061371
# remaining size for Round 5: 122926
# Calculated size for Round 5: 9831.099748895911
# orr termination 0.014263860688538783 0.10129418659056694 0.08703032590202815
# remaining size for last Round 6: 113095
# 30
# ['step1_rr: 29', 'step2_rr: 29', 'step3_rr: 29', 'step4_rr: 29', 'step5_rr: 29', 'step6_rr: 29']
# empirical response rate 0.07840154867256637
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5892.22320205354
# orr termination 0.047225978346860174 0.10423016242591303 0.057004184079052854
# remaining size for Round 3: 139260
# Calculated size for Round 3: 7119.675966044646
# orr termination 0.0377409011515913 0.11983860353325976 0.08209770238166846
# remaining size for Round 4: 132141
# Calculated size for Round 4: 9716.258467355088
# orr termination 0.011454398955200375 0.11815568605202698 0.10670128709682661
# remaining size for Round 5: 122425
# Calculated size for Round 5: 10146.147930407182
# orr termination 0.0521538234746 0.10541891326675704 0.053265089792157036
# remaining size for last Round 6: 112279
# 31
# ['step1_rr: 30', 'step2_rr: 30', 'step3_rr: 30', 'step4_rr: 30', 'step5_rr: 30', 'step6_rr: 30']
# empirical response rate 0.07701880530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5791.761187324277
# orr termination 0.07396516598187158 0.12417027086584549 0.05020510488397391
# remaining size for Round 3: 139361
# Calculated size for Round 3: 8800.190220097753
# orr termination 0.009150884458030346 0.13931124660831554 0.1301603621502852
# remaining size for Round 4: 130561
# Calculated size for Round 4: 10241.43364341993
# orr termination 0.08405409706147035 0.10074204084799536 0.01668794378652501
# remaining size for Round 5: 120320
# Calculated size for Round 5: 10223.813362919029
# orr termination 0.03957938347939792 0.09742492027343924 0.05784553679404132
# remaining size for last Round 6: 110097
# 32
# ['step1_rr: 31', 'step2_rr: 31', 'step3_rr: 31', 'step4_rr: 31', 'step5_rr: 31', 'step6_rr: 31']
# empirical response rate 0.08019911504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6023.206915866293
# orr termination 0.04690640308889257 0.09453922717391897 0.04763282408502639
# remaining size for Round 3: 139129
# Calculated size for Round 3: 16005.713758577414
# orr termination 0.059031445405498 0.09770958843918323 0.03867814303368523
# remaining size for Round 4: 123124
# Calculated size for Round 4: 7547.530971720034
# orr termination 0.03229267020466161 0.09763022423522352 0.0653375540305619
# remaining size for Round 5: 115577
# 33
# ['step1_rr: 32', 'step2_rr: 32', 'step3_rr: 32', 'step4_rr: 32', 'step5_rr: 32', 'step6_rr: 32']
# empirical response rate 0.07892007743362832
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5929.962574211673
# orr termination 0.08254044440968968 0.11327869903668976 0.030738254627000083
# remaining size for Round 3: 139223
# Calculated size for Round 3: 9333.183240579112
# orr termination 0.024720447616022087 0.11037946347795753 0.08565901586193544
# remaining size for Round 4: 129890
# Calculated size for Round 4: 8081.017232327425
# orr termination 0.08261838537096618 0.10492453949113734 0.02230615412017116
# remaining size for Round 5: 121809
# Calculated size for Round 5: 10116.297596096114
# orr termination 0.01964381637136267 0.10729982552629538 0.08765600915493271
# remaining size for last Round 6: 111693
# 34
# ['step1_rr: 33', 'step2_rr: 33', 'step3_rr: 33', 'step4_rr: 33', 'step5_rr: 33', 'step6_rr: 33']
# empirical response rate 0.07159153761061947
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5399.937054375382
# orr termination 0.06493656656391296 0.11154097155118395 0.04660440498727099
# remaining size for Round 3: 139753
# Calculated size for Round 3: 10044.384295782122
# orr termination 0.0049200826157236215 0.10684195195201784 0.10192186933629423
# remaining size for Round 4: 129709
# Calculated size for Round 4: 8113.749765953109
# orr termination 0.05273455210973691 0.10528442104822514 0.052549868938488224
# remaining size for Round 5: 121596
# 35
# ['step1_rr: 34', 'step2_rr: 34', 'step3_rr: 34', 'step4_rr: 34', 'step5_rr: 34', 'step6_rr: 34']
# empirical response rate 0.08182383849557522
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6141.967523856308
# orr termination 0.051662343796010424 0.09881641664980054 0.04715407285379011
# remaining size for Round 3: 139011
# Calculated size for Round 3: 7625.189640474576
# orr termination 0.07429682396747445 0.1084877346100173 0.03419091064254286
# remaining size for Round 4: 131386
# Calculated size for Round 4: 8930.13261505363
# orr termination 0.009798641832239541 0.11445942200391003 0.10466078017167049
# remaining size for Round 5: 122456
# Calculated size for Round 5: 8514.727435307148
# orr termination 0.06415362827742951 0.09658467022416467 0.032431041946735156
# remaining size for last Round 6: 113942
# 36
# ['step1_rr: 35', 'step2_rr: 35', 'step3_rr: 35', 'step4_rr: 35', 'step5_rr: 35', 'step6_rr: 35']
# empirical response rate 0.04206996681415929
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3339.2384022405945
# orr termination 0.011961738046135808 0.07052584241919385 0.05856410437305804
# remaining size for Round 3: 141813
# Calculated size for Round 3: 4268.115497917627
# orr termination 0.017791759832878232 0.10033617237897088 0.08254441254609265
# remaining size for Round 4: 137545
# Calculated size for Round 4: 12275.46524983616
# orr termination 0.04573107146798449 0.10574732099620754 0.06001624952822305
# remaining size for Round 5: 125270
# Calculated size for Round 5: 9128.5059098571
# orr termination 0.0529695045684939 0.10449123728859692 0.051521732720103026
# remaining size for last Round 6: 116142
# 37
# ['step1_rr: 36', 'step2_rr: 36', 'step3_rr: 36', 'step4_rr: 36', 'step5_rr: 36', 'step6_rr: 36']
# empirical response rate 0.04580337389380531
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3593.182438999496
# orr termination 0.0024530055032155633 0.10207907371755437 0.09962606821433881
# remaining size for Round 3: 141559
# 38
# ['step1_rr: 37', 'step2_rr: 37', 'step3_rr: 37', 'step4_rr: 37', 'step5_rr: 37', 'step6_rr: 37']
# empirical response rate 0.047912057522123894
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3737.4708232996927
# orr termination 0.004453377565447587 0.09543462240579238 0.0909812448403448
# remaining size for Round 3: 141415
# Calculated size for Round 3: 7438.494180794369
# orr termination 0.07250129727060207 0.0965249186682445 0.024023621397642428
# remaining size for Round 4: 133977
# Calculated size for Round 4: 15742.108452064793
# orr termination 0.03340688306612307 0.1001913006306294 0.06678441756450634
# remaining size for Round 5: 118235
# 39
# ['step1_rr: 38', 'step2_rr: 38', 'step3_rr: 38', 'step4_rr: 38', 'step5_rr: 38', 'step6_rr: 38']
# empirical response rate 0.07466814159292036
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5621.565807308865
# orr termination 0.07120328930666142 0.09187993548721989 0.020676646180558464
# remaining size for Round 3: 139531
# Calculated size for Round 3: 17437.606285440273
# orr termination 0.057129358958416795 0.09874139865471163 0.04161203969629483
# remaining size for Round 4: 122094
# Calculated size for Round 4: 7078.244963416879
# orr termination 0.07589702546388816 0.10107879925217156 0.0251817737882834
# remaining size for Round 5: 115016
# Calculated size for Round 5: 7784.258224074996
# orr termination 0.06697451569073405 0.10013850138289887 0.03316398569216482
# remaining size for last Round 6: 107232
# 40
# ['step1_rr: 39', 'step2_rr: 39', 'step3_rr: 39', 'step4_rr: 39', 'step5_rr: 39', 'step6_rr: 39']
# empirical response rate 0.06301852876106195
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4789.153321772453
# orr termination 0.006312095550976784 0.11979269280853769 0.1134805972575609
# remaining size for Round 3: 140363
# Calculated size for Round 3: 12025.267613520373
# orr termination 0.07175203352977227 0.1070685174778925 0.03531648394812023
# remaining size for Round 4: 128338
# Calculated size for Round 4: 10544.868696159949
# orr termination 0.053809651571641935 0.10744327054276606 0.053633618971124127
# remaining size for Round 5: 117794
# 41
# ['step1_rr: 40', 'step2_rr: 40', 'step3_rr: 40', 'step4_rr: 40', 'step5_rr: 40', 'step6_rr: 40']
# empirical response rate 0.0742878871681416
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5594.104185697372
# orr termination 0.009259341056189935 0.13631734159814363 0.12705800054195368
# remaining size for Round 3: 139558
# Calculated size for Round 3: 12672.155191778207
# orr termination 0.0410132272131872 0.1028476442390788 0.0618344170258916
# remaining size for Round 4: 126886
# Calculated size for Round 4: 9421.631706829148
# orr termination 0.05206647133429555 0.10366199824761697 0.05159552691332142
# remaining size for Round 5: 117465
# 42
# ['step1_rr: 41', 'step2_rr: 41', 'step3_rr: 41', 'step4_rr: 41', 'step5_rr: 41', 'step6_rr: 41']
# empirical response rate 0.05403069690265487
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4159.637779672868
# orr termination 0.014097322132796367 0.08200821760988533 0.06791089547708896
# remaining size for Round 3: 140993
# Calculated size for Round 3: 6291.299489433688
# orr termination 0.007508998785682099 0.0907397688378134 0.08323077005213131
# remaining size for Round 4: 134702
# 43
# ['step1_rr: 42', 'step2_rr: 42', 'step3_rr: 42', 'step4_rr: 42', 'step5_rr: 42', 'step6_rr: 42']
# empirical response rate 0.05517146017699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# orr termination 0.06158877401659958 0.08701089496937263 0.025422120952773047
# remaining size for Round 3: 140914
# Calculated size for Round 3: 6086.0674536777
# orr termination 0.05641041740389605 0.09586714030822133 0.039456722904325274
# remaining size for Round 4: 134828
# Calculated size for Round 4: 6974.909223964932
# orr termination 0.03294706931907142 0.10882012545815542 0.075873056139084
# remaining size for Round 5: 127854
# Calculated size for Round 5: 8098.577359576102
# orr termination 0.05302762278745792 0.11809697381030237 0.06506935102284445
# remaining size for last Round 6: 119756
# 44
# ['step1_rr: 43', 'step2_rr: 43', 'step3_rr: 43', 'step4_rr: 43', 'step5_rr: 43', 'step6_rr: 43']
# empirical response rate 0.04348727876106195
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3435.414549437817
# orr termination 0.05484106306193737 0.07606158265380138 0.02122051959186401
# remaining size for Round 3: 141717
# Calculated size for Round 3: 5645.31499055232
# orr termination 0.043089370343544424 0.08355783374201635 0.040468463398471925
# remaining size for Round 4: 136072
# Calculated size for Round 4: 6162.745202521891
# orr termination 0.011151515986282199 0.09502548808509884 0.08387397209881664
# remaining size for Round 5: 129910
# Calculated size for Round 5: 7049.68089310608
# orr termination 0.050562435985317296 0.10040280746709457 0.04984037148177727
# remaining size for last Round 6: 122861
# 45
# ['step1_rr: 44', 'step2_rr: 44', 'step3_rr: 44', 'step4_rr: 44', 'step5_rr: 44', 'step6_rr: 44']
# empirical response rate 0.052751659292035395
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4070.959200908221
# orr termination 0.023828172605899367 0.07780338920497944 0.05397521659908007
# remaining size for Round 3: 141082
# Calculated size for Round 3: 4484.15625559737
# orr termination 0.005585237598615743 0.1035675092170387 0.09798227161842295
# remaining size for Round 4: 136598
# Calculated size for Round 4: 9060.182213694126
# orr termination 0.03558441788637576 0.1058572727781669 0.07027285489179114
# remaining size for Round 5: 127538
# 46
# ['step1_rr: 45', 'step2_rr: 45', 'step3_rr: 45', 'step4_rr: 45', 'step5_rr: 45', 'step6_rr: 45']
# empirical response rate 0.08092505530973451
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6076.226646023446
# orr termination 0.06442731869044344 0.1181887187983511 0.05376140010790767
# remaining size for Round 3: 139076
# Calculated size for Round 3: 29013
# orr termination 0.05886407121546104 0.10116513946484469 0.04230106824938365
# remaining size for Round 4: 110063
# Calculated size for Round 4: 6843.3388327502935
# orr termination 0.05227429744403311 0.1039641336679431 0.05168983622390999
# remaining size for Round 5: 103220
# Calculated size for Round 5: 7424.345595340574
# orr termination 0.05110960640905737 0.1029823589403998 0.05187275253134242
# remaining size for last Round 6: 95796
# 47
# ['step1_rr: 46', 'step2_rr: 46', 'step3_rr: 46', 'step4_rr: 46', 'step5_rr: 46', 'step6_rr: 46']
# empirical response rate 0.047428097345132744
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3704.3008047850903
# orr termination 0.005503632479857294 0.10068894447989898 0.09518531200004168
# remaining size for Round 3: 141448
# Calculated size for Round 3: 7403.233998322974
# orr termination 0.053107699028929284 0.10605292731041333 0.05294522828148404
# remaining size for Round 4: 134045
# Calculated size for Round 4: 16422.153814885423
# orr termination 0.0729128398985674 0.11045822755619858 0.037545387657631185
# remaining size for Round 5: 117623
# Calculated size for Round 5: 8497.919298246756
# orr termination 0.05739119775303586 0.11248461544566589 0.05509341769263003
# remaining size for last Round 6: 109126
# 48
# ['step1_rr: 47', 'step2_rr: 47', 'step3_rr: 47', 'step4_rr: 47', 'step5_rr: 47', 'step6_rr: 47']
# empirical response rate 0.0380945796460177
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3070.9700987965853
# orr termination 0.03830276665113748 0.11617332944304451 0.07787056279190703
# remaining size for Round 3: 142082
# Calculated size for Round 3: -11882.284320347082lt 0, break
# 49
# ['step1_rr: 48', 'step2_rr: 48', 'step3_rr: 48', 'step4_rr: 48', 'step5_rr: 48', 'step6_rr: 48']
# empirical response rate 0.04846515486725664
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3775.4192631143214
# orr termination 0.03238612172376724 0.05509733094367448 0.02271120921990724
# remaining size for Round 3: 141377
# Calculated size for Round 3: 3601.344354079941
# orr termination 0.03048215529622494 0.05717700781497992 0.026694852518754978
# remaining size for Round 4: 137776
# Calculated size for Round 4: 3822.839949560038
# orr termination 0.006345748190672813 0.06266846166286791 0.0563227134721951
# remaining size for Round 5: 133954
# Calculated size for Round 5: 4215.377807674775
# orr termination 0.07814216796262027 0.09305343348616346 0.014911265523543188
# remaining size for last Round 6: 129739
# 50
# ['step1_rr: 49', 'step2_rr: 49', 'step3_rr: 49', 'step4_rr: 49', 'step5_rr: 49', 'step6_rr: 49']
# empirical response rate 0.03373893805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2779.5728369589106
# orr termination 0.005608293379326485 0.07771525598911459 0.0721069626097881
# remaining size for Round 3: 142373
# Calculated size for Round 3: 5416.007877817088
# orr termination 0.0692477427958599 0.07945397795866135 0.010206235162801447
# remaining size for Round 4: 136957
# Calculated size for Round 4: 12251.170116465164
# orr termination 0.05057297540506817 0.08510212592549364 0.03452915052042547
# remaining size for Round 5: 124706
# Calculated size for Round 5: 6278.275077965791
# orr termination 0.06487916930414324 0.0860969545835846 0.021217785279441362
# remaining size for last Round 6: 118428
# 51
# ['step1_rr: 50', 'step2_rr: 50', 'step3_rr: 50', 'step4_rr: 50', 'step5_rr: 50', 'step6_rr: 50']
# empirical response rate 0.04535398230088496
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3562.51238662459
# orr termination 0.020500593539049875 0.12160264852603148 0.1011020549869816
# remaining size for Round 3: 141590
# Calculated size for Round 3: 12595.322787023388
# orr termination 0.01697525344831556 0.11002943331810028 0.09305417986978472
# remaining size for Round 4: 128995
# Calculated size for Round 4: 8878.024111864686
# orr termination 0.05020712029266377 0.09967871550190825 0.04947159520924448
# remaining size for Round 5: 120117
# 52
# ['step1_rr: 51', 'step2_rr: 51', 'step3_rr: 51', 'step4_rr: 51', 'step5_rr: 51', 'step6_rr: 51']
# empirical response rate 0.040860066371681415
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3257.3582653305953
# orr termination 0.02179685419131893 0.09698226172124608 0.07518540752992714
# remaining size for Round 3: 141895
# Calculated size for Round 3: 9644.064980843477
# orr termination 0.007949855045599842 0.09666041104156879 0.08871055599596894
# remaining size for Round 4: 132251
# 53
# ['step1_rr: 52', 'step2_rr: 52', 'step3_rr: 52', 'step4_rr: 52', 'step5_rr: 52', 'step6_rr: 52']
# empirical response rate 0.07584347345132743
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5706.570481819797
# orr termination 0.03819354346040796 0.11362331730747977 0.07542977384707181
# remaining size for Round 3: 139446
# Calculated size for Round 3: 28506.90992481453
# orr termination 0.05021852148446557 0.1009149329112597 0.05069641142679414
# remaining size for Round 4: 110940
# Calculated size for Round 4: 6999.381866077384
# orr termination 0.05054946325208738 0.10124654388522841 0.05069708063314103
# remaining size for Round 5: 103941
# 54
# ['step1_rr: 53', 'step2_rr: 53', 'step3_rr: 53', 'step4_rr: 53', 'step5_rr: 53', 'step6_rr: 53']
# empirical response rate 0.06319137168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4801.3683051580465
# orr termination 0.010453579505601602 0.10475931055091627 0.09430573104531466
# remaining size for Round 3: 140351
# Calculated size for Round 3: 10466.069074608291
# orr termination 0.038349377614822426 0.09856774625599075 0.06021836864116833
# remaining size for Round 4: 129885
# Calculated size for Round 4: 9136.26326987825
# orr termination 0.05123415953269978 0.10046131751805329 0.04922715798535351
# remaining size for Round 5: 120749
# 55
# ['step1_rr: 54', 'step2_rr: 54', 'step3_rr: 54', 'step4_rr: 54', 'step5_rr: 54', 'step6_rr: 54']
# empirical response rate 0.0351908185840708
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2876.4109738220563
# orr termination 0.007878076337311506 0.06547933641309746 0.05760126007578595
# remaining size for Round 3: 142276
# Calculated size for Round 3: 3962.2789107317235
# orr termination 0.022460017871015408 0.10658782656834792 0.08412780869733251
# remaining size for Round 4: 138314
# Calculated size for Round 4: 29013
# orr termination 0.07369319975854677 0.09857018637975819 0.02487698662121142
# remaining size for Round 5: 109301
# Calculated size for Round 5: 6900.099442024211
# orr termination 0.035089599705082485 0.10439139548532277 0.06930179578024029
# remaining size for last Round 6: 102401
# 56
# ['step1_rr: 55', 'step2_rr: 55', 'step3_rr: 55', 'step4_rr: 55', 'step5_rr: 55', 'step6_rr: 55']
# empirical response rate 0.04421321902654867
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3484.783847425881
# orr termination 0.0036055953263838016 0.08531377123397288 0.08170817590758908
# remaining size for Round 3: 141668
# Calculated size for Round 3: 6102.0817837895775
# orr termination 0.0868934767479955 0.11498989183663796 0.028096415088642468
# remaining size for Round 4: 135566
# Calculated size for Round 4: 29013
# orr termination 0.0709303151502322 0.10645415557735197 0.03552384042711977
# remaining size for Round 5: 106553
# Calculated size for Round 5: 7226.053518740839
# orr termination 0.05559088199989999 0.1104405206455825 0.054849638645682514
# remaining size for last Round 6: 99327
# 57
# ['step1_rr: 56', 'step2_rr: 56', 'step3_rr: 56', 'step4_rr: 56', 'step5_rr: 56', 'step6_rr: 56']
# empirical response rate 0.06319137168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4801.3683051580465
# orr termination 0.024543718438125747 0.1160561055963443 0.09151238715821855
# remaining size for Round 3: 140351
# Calculated size for Round 3: 24594.841603018107
# orr termination 0.08428194373738722 0.10548847228025036 0.021206528542863146
# remaining size for Round 4: 115757
# Calculated size for Round 4: 7694.398503891901
# orr termination 0.02727559177804642 0.10960562539009533 0.08233003361204891
# remaining size for Round 5: 108063
# 58
# ['step1_rr: 57', 'step2_rr: 57', 'step3_rr: 57', 'step4_rr: 57', 'step5_rr: 57', 'step6_rr: 57']
# empirical response rate 0.058351769911504425
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4460.900082113275
# orr termination 0.014541577251588417 0.12216974382467717 0.10762816657308875
# remaining size for Round 3: 140692
# Calculated size for Round 3: 8481.02351832409
# orr termination 0.029371060480012492 0.08844259645362813 0.05907153597361564
# remaining size for Round 4: 132211
# Calculated size for Round 4: 8825.29693293948
# orr termination 0.019082779023201026 0.09563789151502587 0.07655511249182484
# remaining size for Round 5: 123386
# 59
# ['step1_rr: 58', 'step2_rr: 58', 'step3_rr: 58', 'step4_rr: 58', 'step5_rr: 58', 'step6_rr: 58']
# empirical response rate 0.03484513274336283
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2853.327576480575
# orr termination 0.016577516567278724 0.062329023237940595 0.04575150667066187
# remaining size for Round 3: 142299
# Calculated size for Round 3: 4186.761759788382
# orr termination 0.010949671339995614 0.07711359250229252 0.06616392116229691
# remaining size for Round 4: 138113
# Calculated size for Round 4: 7930.415675119621
# orr termination 0.048995546597330034 0.09725119270002264 0.048255646102692604
# remaining size for Round 5: 130183
# Calculated size for Round 5: 11283.856925986374
# orr termination 0.04966294848336125 0.09840296649305016 0.04874001800968891
# remaining size for last Round 6: 118900
# 60
# ['step1_rr: 59', 'step2_rr: 59', 'step3_rr: 59', 'step4_rr: 59', 'step5_rr: 59', 'step6_rr: 59']
# empirical response rate 0.04473174778761062
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3520.0925493885147
# orr termination 0.044511735289003894 0.08489231914076764 0.04038058385176375
# remaining size for Round 3: 141632
# Calculated size for Round 3: 14901.003499515284
# orr termination 0.0307483510590391 0.10154909390198599 0.07080074284294689
# remaining size for Round 4: 126731
# Calculated size for Round 4: 7201.312794378588
# orr termination 0.03567757296821595 0.10605588969707513 0.07037831672885919
# remaining size for Round 5: 119530
# 61
# ['step1_rr: 60', 'step2_rr: 60', 'step3_rr: 60', 'step4_rr: 60', 'step5_rr: 60', 'step6_rr: 60']
# empirical response rate 0.0829991703539823
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6228.098665219812
# orr termination 0.05320547517544742 0.1174112280491615 0.06420575287371408
# remaining size for Round 3: 138924
# Calculated size for Round 3: 8779.251186443094
# orr termination 0.05207787895217583 0.1267081616028955 0.07463028265071966
# remaining size for Round 4: 130145
# Calculated size for Round 4: 10431.54648594743
# orr termination 0.02985137012032714 0.11837123491126014 0.088519864790933
# remaining size for Round 5: 119714
# Calculated size for Round 5: 9644.896961796203
# orr termination 0.04528934899499059 0.11246439219038926 0.06717504319539866
# remaining size for last Round 6: 110070
# 62
# ['step1_rr: 61', 'step2_rr: 61', 'step3_rr: 61', 'step4_rr: 61', 'step5_rr: 61', 'step6_rr: 61']
# empirical response rate 0.06495436946902655
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4926.194977591092
# orr termination 0.008213968082686676 0.0964620316204532 0.08824806353776653
# remaining size for Round 3: 140226
# Calculated size for Round 3: 6532.663656593493
# orr termination 0.07203342454236045 0.09591561755444324 0.02388219301208279
# remaining size for Round 4: 133694
# Calculated size for Round 4: 14134.900726697992
# orr termination 0.03526352047600568 0.10523077399036906 0.06996725351436339
# remaining size for Round 5: 119560
# Calculated size for Round 5: 7775.3806611423
# orr termination 0.07710495805283109 0.11378901434191696 0.03668405628908587
# remaining size for last Round 6: 111785
# 63
# ['step1_rr: 62', 'step2_rr: 62', 'step3_rr: 62', 'step4_rr: 62', 'step5_rr: 62', 'step6_rr: 62']
# empirical response rate 0.08472759955752213
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6355.095390744717
# orr termination 0.044525818755397725 0.11461510628593789 0.07008928753054017
# remaining size for Round 3: 138797
# Calculated size for Round 3: 8356.757676142865
# orr termination 0.11774708159154729 0.12763753903129565 0.009890457439748368
# remaining size for Round 4: 130441
# Calculated size for Round 4: 11563.52749919818
# orr termination 0.011518693757573362 0.13563734054023183 0.12411864678265846
# remaining size for Round 5: 118878
# Calculated size for Round 5: 9369.920251020916
# orr termination 0.09212658610604171 0.12237157491657283 0.030244988810531115
# remaining size for last Round 6: 109509
# 64
# ['step1_rr: 63', 'step2_rr: 63', 'step3_rr: 63', 'step4_rr: 63', 'step5_rr: 63', 'step6_rr: 63']
# empirical response rate 0.06993224557522124
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5280.93931401423
# orr termination 0.012386132733432146 0.11015066539403161 0.09776453266059947
# remaining size for Round 3: 139872
# Calculated size for Round 3: 10728.519239935376
# orr termination 0.06676062344452946 0.09922257049494959 0.03246194705042013
# remaining size for Round 4: 129144
# Calculated size for Round 4: 9750.213307867696
# orr termination 0.07535661988741538 0.10001520600966998 0.024658586122254605
# remaining size for Round 5: 119394
# Calculated size for Round 5: 7863.047156536525
# orr termination 0.03460762728383762 0.09976640543552832 0.0651587781516907
# remaining size for last Round 6: 111531
# 65
# ['step1_rr: 64', 'step2_rr: 64', 'step3_rr: 64', 'step4_rr: 64', 'step5_rr: 64', 'step6_rr: 64']
# empirical response rate 0.08856471238938053
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6638.439402074498
# orr termination 0.06537721342066265 0.11034400411293993 0.044966790692277284
# remaining size for Round 3: 138514
# Calculated size for Round 3: 7782.859001818638
# orr termination 0.06690554299867532 0.11428846781258516 0.047382924813909835
# remaining size for Round 4: 130732
# Calculated size for Round 4: 8359.876673850811
# orr termination 0.03487088315820572 0.11528758348877016 0.08041670033056444
# remaining size for Round 5: 122373
# Calculated size for Round 5: 8489.781370879082
# orr termination 0.08826010113133939 0.11341735459242389 0.025157253461084494
# remaining size for last Round 6: 113884
# 66
# ['step1_rr: 65', 'step2_rr: 65', 'step3_rr: 65', 'step4_rr: 65', 'step5_rr: 65', 'step6_rr: 65']
# empirical response rate 0.03691924778761062
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2992.078205242061
# orr termination 0.011250542431597812 0.07322815606211258 0.061977613630514766
# remaining size for Round 3: 142160
# Calculated size for Round 3: 6527.111613170828
# orr termination 0.08657518826709551 0.10089991136273972 0.014324723095644212
# remaining size for Round 4: 135633
# Calculated size for Round 4: 15944.83726386377
# orr termination 0.053476604897288046 0.1028386424106787 0.04936203751339065
# remaining size for Round 5: 119689
# Calculated size for Round 5: 7607.26213468691
# orr termination 0.07338792452056248 0.10928804672366457 0.0359001222031021
# remaining size for last Round 6: 112082
# 67
# ['step1_rr: 66', 'step2_rr: 66', 'step3_rr: 66', 'step4_rr: 66', 'step5_rr: 66', 'step6_rr: 66']
# empirical response rate 0.016178097345132744
# remaining size for Round 2: 145152
# Calculated size for Round 2: 1631.609389514148
# orr termination 0.020842156988902284 0.0428832934672783 0.02204113647837602
# remaining size for Round 3: 143521
# Calculated size for Round 3: 4000.2428875684436
# orr termination 0.03389561853422231 0.06623622329409294 0.032340604759870634
# remaining size for Round 4: 139521
# Calculated size for Round 4: 7137.888494501996
# orr termination 0.03438835751149636 0.09001591213699006 0.0556275546254937
# remaining size for Round 5: 132384
# Calculated size for Round 5: 9400.117103046501
# orr termination 0.03312933933186681 0.10058790409798703 0.06745856476612022
# remaining size for last Round 6: 122984
# 68
# ['step1_rr: 67', 'step2_rr: 67', 'step3_rr: 67', 'step4_rr: 67', 'step5_rr: 67', 'step6_rr: 67']
# empirical response rate 0.08849557522123894
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6633.316959611526
# orr termination 0.04045782380180471 0.1344296319800054 0.0939718081782007
# remaining size for Round 3: 138519
# Calculated size for Round 3: 13387.18092196639
# orr termination 0.02942924579122575 0.1332279854872141 0.10379873969598835
# remaining size for Round 4: 125132
# Calculated size for Round 4: 11663.58221647877
# orr termination 0.0879667801501862 0.1173735400113154 0.0294067598611292
# remaining size for Round 5: 113469
# Calculated size for Round 5: 10800.018605201907
# orr termination 0.03779149148044366 0.11376588797294938 0.07597439649250573
# remaining size for last Round 6: 102669
# 69
# ['step1_rr: 68', 'step2_rr: 68', 'step3_rr: 68', 'step4_rr: 68', 'step5_rr: 68', 'step6_rr: 68']
# empirical response rate 0.06073700221238938
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4628.299837474318
# orr termination 0.019037309293557816 0.11196983535657531 0.0929325260630175
# remaining size for Round 3: 140524
# Calculated size for Round 3: 10296.8468834217
# orr termination 0.03260678359501187 0.10623664145922132 0.07362985786420945
# remaining size for Round 4: 130228
# Calculated size for Round 4: 10498.916922908906
# orr termination 0.025121163896884145 0.10310103573592504 0.0779798718390409
# remaining size for Round 5: 119730
# 70
# ['step1_rr: 69', 'step2_rr: 69', 'step3_rr: 69', 'step4_rr: 69', 'step5_rr: 69', 'step6_rr: 69']
# empirical response rate 0.053823285398230086
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4145.242088058297
# orr termination 0.0063162418724259945 0.07318409625418554 0.06686785438175954
# remaining size for Round 3: 141007
# Calculated size for Round 3: 4980.524657669485
# orr termination 0.011179415784599273 0.10234153798262988 0.0911621221980306
# remaining size for Round 4: 136027
# 71
# ['step1_rr: 70', 'step2_rr: 70', 'step3_rr: 70', 'step4_rr: 70', 'step5_rr: 70', 'step6_rr: 70']
# empirical response rate 0.037264933628318585
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3015.2616918343456
# orr termination 0.025077669418677475 0.06006067538198086 0.03498300596330338
# remaining size for Round 3: 142137
# Calculated size for Round 3: 4411.054010736229
# orr termination 0.023272942265173208 0.07336037154271381 0.050087429277540604
# remaining size for Round 4: 137726
# Calculated size for Round 4: 5921.980191971662
# orr termination 0.058752202510638764 0.08613348642961399 0.02738128391897523
# remaining size for Round 5: 131805
# Calculated size for Round 5: 9381.570640258962
# orr termination 0.015781124960548794 0.0951591189997787 0.0793779940392299
# remaining size for last Round 6: 122424
# 72
# ['step1_rr: 71', 'step2_rr: 71', 'step3_rr: 71', 'step4_rr: 71', 'step5_rr: 71', 'step6_rr: 71']
# empirical response rate 0.04089463495575221
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3259.694866267412
# orr termination 0.019833665866669577 0.06227262041771078 0.04243895455104121
# remaining size for Round 3: 141893
# Calculated size for Round 3: 4363.13379171961
# orr termination 0.004580791966231597 0.06813068629433962 0.06354989432810802
# remaining size for Round 4: 137530
# Calculated size for Round 4: 5948.348843720834
# orr termination 0.0565461721396321 0.11283774407663517 0.05629157193700307
# remaining size for Round 5: 131582
# 73
# ['step1_rr: 72', 'step2_rr: 72', 'step3_rr: 72', 'step4_rr: 72', 'step5_rr: 72', 'step6_rr: 72']
# empirical response rate 0.017042311946902654
# remaining size for Round 2: 145152
# Calculated size for Round 2: 1687.0964287990566
# orr termination 0.009232421120209111 0.03026786012690641 0.0210354390066973
# remaining size for Round 3: 143465
# Calculated size for Round 3: 1864.6994682911825
# orr termination 0.007295547360596421 0.0395872210214918 0.03229167366089538
# remaining size for Round 4: 141601
# Calculated size for Round 4: 2738.467088009712
# orr termination 0.04105851469924596 0.08161846331344748 0.04055994861420152
# remaining size for Round 5: 138863
# Calculated size for Round 5: 29013
# orr termination 0.07594915366356136 0.10118892185501395 0.025239768191452586
# remaining size for last Round 6: 109850
# 74
# ['step1_rr: 73', 'step2_rr: 73', 'step3_rr: 73', 'step4_rr: 73', 'step5_rr: 73', 'step6_rr: 73']
# empirical response rate 0.061359236725663714
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4672.098065320721
# orr termination 0.01144022959592686 0.06889260963655108 0.057452380040624224
# remaining size for Round 3: 140480
# Calculated size for Round 3: 4402.038203801951
# orr termination 0.016927811116620707 0.08640538744597721 0.0694775763293565
# remaining size for Round 4: 136078
# Calculated size for Round 4: 9688.996924328138
# orr termination 0.07359850366647386 0.09668668816318443 0.023088184496710573
# remaining size for Round 5: 126390
# Calculated size for Round 5: 9673.969703947927
# orr termination 0.03315317838105104 0.09888207908143733 0.06572890070038628
# remaining size for last Round 6: 116717
# 75
# ['step1_rr: 74', 'step2_rr: 74', 'step3_rr: 74', 'step4_rr: 74', 'step5_rr: 74', 'step6_rr: 74']
# empirical response rate 0.06775442477876106
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5125.322856327205
# orr termination 0.021522902866256296 0.10114576315968196 0.07962286029342566
# remaining size for Round 3: 140027
# Calculated size for Round 3: 7908.968368601732
# orr termination 0.07338016670533938 0.09916408719850145 0.02578392049316207
# remaining size for Round 4: 132119
# Calculated size for Round 4: 10049.07944179643
# orr termination 0.021199106873644326 0.10208173400518165 0.08088262713153732
# remaining size for Round 5: 122070
# Calculated size for Round 5: 7863.551575185585
# orr termination 0.06861649751768623 0.10270980502065463 0.034093307502968406
# remaining size for last Round 6: 114207
# 76
# ['step1_rr: 75', 'step2_rr: 75', 'step3_rr: 75', 'step4_rr: 75', 'step5_rr: 75', 'step6_rr: 75']
# empirical response rate 0.028933904867256638
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2461.184309921726
# orr termination 0.0020536165662872383 0.08220058333135238 0.08014696676506515
# remaining size for Round 3: 142691
# 77
# ['step1_rr: 76', 'step2_rr: 76', 'step3_rr: 76', 'step4_rr: 76', 'step5_rr: 76', 'step6_rr: 76']
# empirical response rate 0.03373893805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2779.5728369589106
# orr termination 0.003860132679155618 0.06676084740783123 0.0629007147286756
# remaining size for Round 3: 142373
# Calculated size for Round 3: 4350.378281005687
# orr termination 0.03938544095795979 0.09928533123154125 0.05989989027358146
# remaining size for Round 4: 138023
# Calculated size for Round 4: 29013
# orr termination 0.05532209225813823 0.10590577402718195 0.050583681769043716
# remaining size for Round 5: 109010
# 78
# ['step1_rr: 77', 'step2_rr: 77', 'step3_rr: 77', 'step4_rr: 77', 'step5_rr: 77', 'step6_rr: 77']
# empirical response rate 0.04535398230088496
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3562.51238662459
# orr termination 0.013707213396465088 0.059730736654432924 0.04602352325796784
# remaining size for Round 3: 141590
# Calculated size for Round 3: 3611.7615641516104
# orr termination 0.010886420410228501 0.0862200376678726 0.0753336172576441
# remaining size for Round 4: 137979
# Calculated size for Round 4: 8730.950034043088
# orr termination 0.020481672988280023 0.10301443058116685 0.08253275759288684
# remaining size for Round 5: 129249
# 79
# ['step1_rr: 78', 'step2_rr: 78', 'step3_rr: 78', 'step4_rr: 78', 'step5_rr: 78', 'step6_rr: 78']
# empirical response rate 0.07304341814159292
# remaining size for Round 2: 145152
# Calculated size for Round 2: 5504.366351150113
# orr termination 0.026283330214589708 0.10826249589731278 0.08197916568272307
# remaining size for Round 3: 139648
# Calculated size for Round 3: 7880.329065630651
# orr termination 0.01871027477046422 0.12389066431243857 0.10518038954197435
# remaining size for Round 4: 131768
# Calculated size for Round 4: 12809.032115128275
# orr termination 0.07252555544370183 0.09630931970328324 0.02378376425958141
# remaining size for Round 5: 118959
# Calculated size for Round 5: 8544.811437985285
# orr termination 0.06441440966476089 0.09605312275907461 0.03163871309431372
# remaining size for last Round 6: 110415
# 80
# ['step1_rr: 79', 'step2_rr: 79', 'step3_rr: 79', 'step4_rr: 79', 'step5_rr: 79', 'step6_rr: 79']
# empirical response rate 0.03277101769911504
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2715.177622674948
# orr termination 0.015021139969759564 0.10566749325594586 0.0906463532861863
# remaining size for Round 3: 142437
# 81
# ['step1_rr: 80', 'step2_rr: 80', 'step3_rr: 80', 'step4_rr: 80', 'step5_rr: 80', 'step6_rr: 80']
# empirical response rate 0.03723036504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3012.9425926886643
# orr termination 0.006330933897641975 0.10285115172391351 0.09652021782627154
# remaining size for Round 3: 142140
# Calculated size for Round 3: 18642.176977043044
# orr termination 0.052720556008972595 0.10400491929522253 0.05128436328624993
# remaining size for Round 4: 123498
# 82
# ['step1_rr: 81', 'step2_rr: 81', 'step3_rr: 81', 'step4_rr: 81', 'step5_rr: 81', 'step6_rr: 81']
# empirical response rate 0.0478083517699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3730.3602223395455
# orr termination 0.04379837853891989 0.08151368737625622 0.037715308837336335
# remaining size for Round 3: 141422
# Calculated size for Round 3: 6673.912918898215
# orr termination 0.050597617755312546 0.07805051118456477 0.027452893429252223
# remaining size for Round 4: 134749
# Calculated size for Round 4: 6514.153293111907
# orr termination 0.013041039111870427 0.09158224875541784 0.07854120964354741
# remaining size for Round 5: 128235
# Calculated size for Round 5: 7032.735328260225
# orr termination 0.08123441370670823 0.10809814231063264 0.026863728603924414
# remaining size for last Round 6: 121203
# 83
# ['step1_rr: 82', 'step2_rr: 82', 'step3_rr: 82', 'step4_rr: 82', 'step5_rr: 82', 'step6_rr: 82']
# empirical response rate 0.08877212389380532
# remaining size for Round 2: 145152
# Calculated size for Round 2: 6653.810492694055
# orr termination 0.008465297165985673 0.120426707199098 0.11196141003311233
# remaining size for Round 3: 138499
# Calculated size for Round 3: 7610.9074072505855
# orr termination 0.02773974322920565 0.11118368992734026 0.08344394669813461
# remaining size for Round 4: 130889
# Calculated size for Round 4: 13414.723426645329
# orr termination 0.07727340315579363 0.11584637207880359 0.03857296892300996
# remaining size for Round 5: 117475
# Calculated size for Round 5: 10065.55383450625
# orr termination 0.05698747117636051 0.11335378801470894 0.05636631683834843
# remaining size for last Round 6: 107410
# 84
# ['step1_rr: 83', 'step2_rr: 83', 'step3_rr: 83', 'step4_rr: 83', 'step5_rr: 83', 'step6_rr: 83']
# empirical response rate 0.03854397123893805
# remaining size for Round 2: 145152
# Calculated size for Round 2: 3101.1855865909392
# orr termination 0.051896420387996474 0.10065901047214812 0.048762590084151645
# remaining size for Round 3: 142051
# Calculated size for Round 3: 29013
# orr termination 0.045548258666664176 0.11328625752008767 0.06773799885342349
# remaining size for Round 4: 113038
# Calculated size for Round 4: 7663.121987340048
# orr termination 0.01862697481046732 0.11245749523129996 0.09383052042083263
# remaining size for Round 5: 105375
# 85
# ['step1_rr: 84', 'step2_rr: 84', 'step3_rr: 84', 'step4_rr: 84', 'step5_rr: 84', 'step6_rr: 84']
# empirical response rate 0.036297013274336286
# remaining size for Round 2: 145152
# Calculated size for Round 2: 2950.3899597530917
# orr termination 0.013566728509254625 0.08124812005738458 0.06768139154812995
# remaining size for Round 3: 142202
# Calculated size for Round 3: 8245.120502169359
# orr termination 0.025008192525864385 0.09899125768363079 0.0739830651577664
# remaining size for Round 4: 133957
# Calculated size for Round 4: 11783.507704472942
# orr termination 0.047106544106734524 0.09446670913302946 0.047360165026294934
# remaining size for Round 5: 122174
# 86
# ['step1_rr: 85', 'step2_rr: 85', 'step3_rr: 85', 'step4_rr: 85', 'step5_rr: 85', 'step6_rr: 85']
# empirical response rate 0.05935425884955752
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4531.161082702762
# orr termination 0.016789580729487802 0.10818933196071484 0.09139975123122704
# remaining size for Round 3: 140621
# Calculated size for Round 3: 23435.08057150121
# orr termination 0.03392695566262608 0.10229647126584485 0.06836951560321877
# remaining size for Round 4: 117186
# 87
# ['step1_rr: 86', 'step2_rr: 86', 'step3_rr: 86', 'step4_rr: 86', 'step5_rr: 86', 'step6_rr: 86']
# empirical response rate 0.03125

# %% [markdown]
# ### Results summary

# %%
rr_df = pd.DataFrame(rr_dict)
rr_df

# %%
# Calculate average rounds:
row_non_nan_counts = rr_df.count(axis=1)

print(f"{np.mean(row_non_nan_counts):.1f} ({np.std(row_non_nan_counts):.1f})")

# %%
result_dict = {}
for key, values in rr_df.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"

for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")

# %%
result_dict = np.array(orr_total) / total_n
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f}, StD: {std_result:.3f}")

# %%
print(np.mean(highest_true_rr))
print(np.std(highest_true_rr))
# highest_true_rr.append(np.max(dt_design_5['plan_response_rate']))

# %%
result_dict = np.array(orr_total_adaptive) / (total_n-34976)
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f}, StD: {std_result:.3f}")

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in plan_number_dict.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.1f} ({std_value:.1f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")

# %%
means = {key: np.mean(values) for key, values in stopping_dict.items()}
means

# %%
print(np.mean(last_round_sample_size), np.std(last_round_sample_size))

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in sample_size_dict.items():
    mean_value = np.nanmean(values)
    std_value = np.nanstd(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")

# %%
np.mean(better_chance)
