# %%
import numpy as np
import pandas as pd
import random
import time
from itertools import product
from scipy.stats import norm, binomtest
import matplotlib.pyplot as plt
from sklearn.preprocessing import OneHotEncoder
from sklearn.linear_model import LogisticRegression, Lasso, Ridge

from sklearn import linear_model, svm, naive_bayes, ensemble
from sklearn.model_selection import cross_validate, train_test_split, RepeatedStratifiedKFold
from sklearn.utils import class_weight
from sklearn.model_selection import cross_val_score
from sklearn.metrics import make_scorer, f1_score, roc_auc_score
from xgboost import XGBClassifier
# from lightgbm import LGBMClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import f1_score, accuracy_score, classification_report, confusion_matrix, roc_auc_score, matthews_corrcoef

from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score

# %% [markdown]
# ## Read functions

# %%
# %run functions_scenario2.ipynb

# %% [markdown]
# ## Scenario 2, Case 2 with interaction

# %%
def invlogit(p_list):
    invlogit_values = []
    for p in p_list:
        invlogit_values.append(np.exp(p) / (1 + np.exp(p)))

    return invlogit_values

# %%
design_list = [5,8,10]
patient_n_list = [5400,680,170] # n_patient_per_plan

# def plan_true_rate(row, impact_rates):
#     tmp = row * impact_rates
#     tmp = tmp[tmp != 0]
#     return np.prod(tmp) * 0.05

def generate_data_step1(design_number = 5, n_rounds = 4, n_patient_per_plan = 5400, seed=42):

  # design_list = [5,8,10]

  # Record the start time
#   start_time = time.time()

  # scenario 2:
  random.seed(seed)

  # n_design = design_number
  n_patient_per_plan_round = n_patient_per_plan/n_rounds # each round is capped by this patient number

  # Create all possible combinations of design features
  design_combinations = list(product([1, 0], repeat=n_design))

  design_feature_df = pd.DataFrame(design_combinations, columns=[f'Design_Feature_{i+1}' for i in range(n_design)])
  # add interaction term:
  interaction = [1 if row['Design_Feature_1'] + row['Design_Feature_2'] == 2 else 0 for _, row in design_feature_df.iterrows()]
  design_feature_df['interaction'] = interaction

  design_feature_df['recruitment_plan'] = [x + 1 for x in range(2 ** n_design)]

  # design_feature_df
  random.seed(seed)
  # impact_rates = np.array([random.uniform(0.6, 1.5) for _ in range(n_design)])
  impact_rates = np.array([-0.5, 0, 0, 0, 0, 0, 0, 0, 1]) # design 2 has the highest rr
  response_rate_list = np.dot(np.array(design_feature_df.iloc[:,:(n_design+1)]), impact_rates)
  # normalize to [0,1]
  # normalized_values = normalize_to_0_1(response_rate_list) * 0.115
  # inverse logit
  normalized_values = np.array(invlogit(response_rate_list)) * 0.11
  design_feature_df['plan_response_rate'] = normalized_values

  design_feature_df.drop(columns=['interaction'], axis = 1, inplace=True)

  # Apply plan_true_rate to each row
  # result_column = design_feature_df.iloc[:, :n_design].apply(lambda row: plan_true_rate(row, impact_rates), axis=1)

  # Add the result_column to the design_feature_df
  # design_feature_df['plan_response_rate'] = result_column

  # each combination repeat for n_patient_per_plan_round
  design_feature_df = pd.DataFrame(np.repeat(design_feature_df.values, n_patient_per_plan_round, axis=0), columns=design_feature_df.columns)

  # add response outcome column:
  grouped_df = design_feature_df.groupby(list(design_feature_df.columns)).size().reset_index(name='group_size')

  random.seed(seed)
  random_seeds_for_resp = [random.randint(1, 100000) for _ in range(len(grouped_df))]

  def generate_responses(row):
      rate = row['plan_response_rate']
      num = row['group_size']
      # random.seed(42)
      seed1 = random_seeds_for_resp[row.name]
      np.random.seed(seed1)
      return np.random.binomial(n=1, p=rate, size=int(num))

  grouped_df['response'] = grouped_df.apply(generate_responses, axis=1)

  # Explode the 'response' arrays to expand the DataFrame
  expanded_df = grouped_df.explode('response').reset_index(drop=True)
  expanded_df['response'] = expanded_df['response'].astype(float)

#   end_time = time.time()

#   elapsed_time = end_time - start_time

#   print(f"Elapsed time: {elapsed_time} seconds")

  return expanded_df

# %% [markdown]
# ## Logistic regression

# %%
def ensemble_model_fit(data, data_pred):
    X_train, X_test, y_train, y_test = train_test_split(
        data.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1),
        data['response'],
        test_size=0.2,
        random_state=0
    )

    # Define the VotingClassifier with the individual classifiers
    voting_classifier = ensemble.VotingClassifier(
        estimators=[
            ('LR', linear_model.LogisticRegression(max_iter=200, random_state=0))
#             ('Ridge', linear_model.LogisticRegression(penalty='l2', solver='lbfgs', max_iter=200, random_state=0))
                    # ('SVM', svm.SVC(kernel='linear', C=1.0, random_state=0, probability=True, class_weight='balanced'))
#                     ('RF', ensemble.RandomForestClassifier(n_estimators=200, criterion='gini', random_state=0))
                    # ('XGB', XGBClassifier(n_estimators=50, learning_rate=0.1, random_state=0))
                   ],
        voting='soft'
    )

    # Define the hyperparameter grid to search
    # Best Hyperparameters: {'LR__C': 0.01, 'RF__n_estimators': 50, 'XGB__n_estimators': 50}
    param_grid = {
        # 'NB__alpha': [0.01, 0.05, 0.1],  # '__' is used to specify hyperparameters for individual classifiers
        'LR__C': [0.01, 0.1, 1.0] # [0.01, 0.05, 0.1]
        # 'Ridge__C': [0.01]
        # 'SVM__C': [0.01, 0.05, 0.1]
#         'RF__n_estimators': [50] # [10, 30, 50]
        # 'XGB__n_estimators': [50]
    }

    # Create a GridSearchCV object
    # custom_scorer_auc = make_scorer(roc_auc_score, needs_proba=True)
    grid_search = GridSearchCV(voting_classifier, param_grid, cv=10, scoring='roc_auc')

    # Perform the grid search on the training data
    grid_search.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = grid_search.best_params_
    print(best_params)

    # Train the final VotingClassifier with the best hyperparameters on the full training set
    final_voting_classifier = grid_search.best_estimator_
    final_voting_classifier.fit(X_train, y_train)

    # Predict probabilities instead of binary outcomes on the test set
    y_pred_proba_test = final_voting_classifier.predict_proba(X_test)
    y_pred_test = final_voting_classifier.predict(X_test)
    X_dt = data_pred.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1)
    y_pred = final_voting_classifier.predict_proba(X_dt)

    return y_pred

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import train_test_split

# def ensemble_model_fit(data, data_pred):
#     # Split the data into training and testing sets
#     X_train, X_test, y_train, y_test = train_test_split(
#         data.drop(['recruitment_plan', 'plan_response_rate', 'group_size','response'], axis=1),
#         data['response'],
#         test_size=0.2,
#         random_state=0
#     )

#     # Define the Logistic Regression model
#     logistic_regression = LogisticRegression(C=0.01, max_iter=200,random_state=0)

#     # Fit the Logistic Regression model on the training data
#     logistic_regression.fit(X_train, y_train)

#     # Print out the coefficients of the logistic regression model
#     print("Coefficients:", logistic_regression.coef_)
#     print("Intercept:", logistic_regression.intercept_)
#     print("Coefficients shape:", logistic_regression.coef_.shape)

#     # Predict probabilities instead of binary outcomes on the test set
#     y_pred_proba_test = logistic_regression.predict_proba(X_test)
#     y_pred_test = logistic_regression.predict(X_test)

#     # You can also predict probabilities for the prediction data (data_pred)
#     X_dt = data_pred.drop(['recruitment_plan', 'plan_response_rate', 'group_size','response'], axis=1)
#     y_pred = logistic_regression.predict_proba(X_dt)

#     return y_pred

# # Call the function
# # ensemble_model_fit(data, data_pred)

# %% [markdown]
# ### Simulation starts

# %%
n_sim = 100
# create a list of random seeds
random.seed(42)
random_seeds = [random.randint(1, 100000) for _ in range(n_sim)]

design_list = [5,8,10]
patient_n_list = [5468,680,170] # n_patient_per_plan

n_design = 8
n_patient_per_plan = 680
n_rounds = 6
total_n = n_patient_per_plan * (2**n_design)

## sample size determination
beta = 0.2
power = 1 - beta
alpha = 0.05
delta = 0.01 # effect size

## early stopping
epsilon = 0.001

# %%
rr_dict = {"step{}_rr".format(r): [] for r in range(1, n_rounds + 1)}
plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
sample_size_dict = {"step{}_sample_size".format(r): [] for r in range(1, n_rounds + 1)}
last_round_sample_size = []
random_rr_dict = {"step{}_random_max_rr".format(r): [] for r in range(1, n_rounds + 1)}
random_rr_dict.update({
    "step{}_random_mean_rr".format(r): [] for r in range(1, n_rounds + 1)
})

stopping_dict = {"early_stopping": [],
                 "early_stopping_plan":[],
                 "early_stopping_orr":[],
                 "early_stopping_size":[]}
final_plan_number = []
highest_rr_overall = []
highest_true_rr = []

better_chance = []

orr_total = []
orr_total_adaptive = []



i = 0

for seed in random_seeds:
    i += 1
    print(i)

    print([f"{key}: {len(value)}" for key, value in rr_dict.items()])



    event_list = 0
    event_list_adaptive = 0
    max_rr = []

    # step 1:
    ## Generate dataset
    dt_design_5 = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed)
    highest_true_rr.append(np.max(dt_design_5['plan_response_rate']))
    print("empirical response rate", dt_design_5['response'].mean())
    ## save for benchmark results
    maxidx = np.argmax(dt_design_5['plan_response_rate'])
    random_rr_dict['step1_random_max_rr'].append(dt_design_5.iloc[maxidx,6])
    random_rr_dict['step1_random_mean_rr'].append(dt_design_5['plan_response_rate'].mean())

    ## Ensemble modelling:
    y_pred = ensemble_model_fit(data=dt_design_5, data_pred = dt_design_5)

    ## select recruitment plan
    pred_df = pd.DataFrame(np.hstack((dt_design_5,  y_pred[:, 1].reshape(-1, 1))),
                             columns=list(dt_design_5.columns) + ['predicted_response_rate'])
    pred_df_rr = pred_df.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

    x = pred_df_rr['predicted_response_rate'].values
    if len(x) <= 10:
        best_k = 2
    else:
        best_k = kmeans_fit(data = x)['best_k']
    kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

    merged_df = pd.merge(pred_df_rr, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
    cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
    highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
    highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)


    p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))
    highest_cluster['p_vec'] = p_vec_next
    highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

    # highest_cluster = pred_df_rr

    # highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')
    # highest_cluster['cluster_number'] = highest_cluster['recruitment_plan']

    ## prepare to chance of better performance:
    temp = dt_design_5[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
    event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print("step1", np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print(temp)
    p0 = (temp['plan_response_rate'].mean())

    rr_dict["step1_rr"].append(dt_design_5['plan_response_rate'].mean())
    sample_size_dict["step1_sample_size"].append(len(dt_design_5))

    for round in range(2, n_rounds+1):

        rr_dict["step"+str(round)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))
        plan_number_dict["step"+str(round)+"_plan_number"].append(len(p_vec_next))

        ## when it comes to the last round:
        if round == n_rounds:

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            if round == 2: # if the last round is round 2
                remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
            else:
                remaining_size -= len(dt_design_5_step2up)

            print("remaining size for last Round " + str(round) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            ## data generation, combine previous data:
            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, round=round,
                                                          design_number = n_design, n_rounds = n_rounds,
                                                          n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(0)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(len(temp), temp['plan_response_rate'].mean())
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break



        ## If haven't reached the last round:
        ## check remaining sample size:
        if round == 2:
            remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
        else:
            remaining_size -= len(dt_design_5_step2up)

        print("remaining size for Round " + str(round) + ": " + str(remaining_size))

        ## determine whether move on to step 2:
        if len(highest_cluster) == 1: # if there is only one plan left

            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size) # record the last round sample size
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(1)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        ## sample size determination:
        if round == 2:
            dt_design_5_step2up_overall = dt_design_5
        orr_1 = dt_design_5_step2up_overall['response'].mean() # observed overall response rates for previous rounds
        orr_2 = orr_1 + delta
        n_1 = len(dt_design_5_step2up_overall)

        size_step2up = sample_size_calc(orr_1, n_1, delta=delta, alpha=alpha, power=power) # total size for dataset
        if size_step2up > 0 and size_step2up < 1000:
            size_step2up = 1000 # if size in [0,1000], then it is 1000 for this round.
        elif size_step2up >= 1000:
            size_step2up = min(size_step2up, int(total_n/n_rounds)) # dataset size capped by the n_patient_per_plan
        else:
        # if size_step2up <= 0:
            # the process stops at this step
            print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up) + 'lt 0, break')
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(1)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up))

        sample_size_dict["step"+str(round)+"_sample_size"].append(size_step2up)

        ## save benchmark results for last round:
        dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                            n_patient_per_plan = n_patient_per_plan, seed=seed+round)
        maxidx = np.argmax(dt_benchmark['plan_response_rate'])
        random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
        random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

        ## data generation, combine previous data:
        dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                  design_number = n_design, n_rounds = n_rounds,
                                                  n_patient_per_plan = n_patient_per_plan, size = int(size_step2up), seed=seed)

        plan_list = dt_design_5_step2up['recruitment_plan'].unique()
        if round == 2:
            supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)]
        else:
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
        dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
        dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

        ## Ensemble model fitting:
        dt_design_5_step2up.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)
        y_pred2up = ensemble_model_fit(data = dt_design_5_step2up_overall, data_pred = dt_design_5_step2up)
        pred_df_step2up = pd.DataFrame(np.hstack((dt_design_5_step2up,  y_pred2up[:, 1].reshape(-1, 1))),
                                    columns=list(dt_design_5_step2up.columns) + ['predicted_response_rate'])
        pred_df_rr_step2up = pred_df_step2up.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

        ## select recruitment plans:
        x = pred_df_rr_step2up['predicted_response_rate'].values

        if len(x) <= 10:
            best_k = 2
        else:
            best_k = kmeans_fit(data = x)['best_k']
        kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

        ## match the cluster results back to the original data
        highest_cluster_previous = highest_cluster # save previous cluster results

        merged_df = pd.merge(pred_df_rr_step2up, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
        cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
        highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
        highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)

        # p_vec_previous = p_vec_next # save p_vec of previous round
        p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))

        highest_cluster['p_vec'] = p_vec_next

        highest_cluster = pd.merge(highest_cluster, dt_design_5_step2up[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

        ## prepare to chance of better performance:
        temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
        event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print(temp)

        ## check early stopping predicted ORR:
        orr_df = pd.merge(highest_cluster_previous, highest_cluster[['recruitment_plan','predicted_response_rate','p_vec']], on='recruitment_plan', how='left')
        orr_df.fillna(0, inplace=True)
        p_orr_1 = np.dot(np.array(orr_df['p_vec_x']), np.array(orr_df['predicted_response_rate_y']))
        p_orr_2 = np.dot(np.array(orr_df['p_vec_y']), np.array(orr_df['predicted_response_rate_y']))
        print("orr termination", p_orr_1, p_orr_2, p_orr_2 - p_orr_1)

        if (p_orr_2 - p_orr_1 < epsilon):
            # step 3 use the same strategy of step2
            print(i, p_orr_1, p_orr_2, "early stop at Round " + str(round))
            rr_dict["step"+str(round+1)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                                n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round+1)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round+1)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            ### update remaining size:
            remaining_size -= len(dt_design_5_step2up)
            print("early stop, remaining size for Round" + str(round + 1) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            for r in range(round+2, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(1)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            for r in range(round+2, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round+1), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break
# Out:
# 1
# ['step1_rr: 0', 'step2_rr: 0', 'step3_rr: 0', 'step4_rr: 0', 'step5_rr: 0', 'step6_rr: 0']
# empirical response rate 0.05295907079646018
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4085.324125976102
# {'LR__C': 0.1}
# orr termination 0.016484381840233098 0.08190069999881822 0.06541631815858512
# remaining size for Round 3: 141067
# Calculated size for Round 3: 11720.937161727807
# {'LR__C': 0.1}
# orr termination 0.017755218243390578 0.07305221580509873 0.05529699756170815
# remaining size for Round 4: 129347
# 2
# ['step1_rr: 1', 'step2_rr: 1', 'step3_rr: 1', 'step4_rr: 1', 'step5_rr: 1', 'step6_rr: 1']
# empirical response rate 0.056312223451327435
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4318.382983229351
# {'LR__C': 0.01}
# orr termination 0.05126019033147661 0.06560612306027376 0.014345932728797153
# remaining size for Round 3: 140834
# Calculated size for Round 3: 5093.458360806866
# {'LR__C': 1.0}
# orr termination 0.03260075976847697 0.07161276381072598 0.03901200404224901
# remaining size for Round 4: 135741
# Calculated size for Round 4: 5293.732640885153
# {'LR__C': 0.1}
# orr termination 0.05252622514834779 0.07027416626343745 0.017747941115089663
# remaining size for Round 5: 130448
# Calculated size for Round 5: 6294.649573957182
# {'LR__C': 0.01}
# orr termination 0.006947956174618129 0.0768408105505028 0.06989285437588467
# remaining size for last Round 6: 124154
# 3
# ['step1_rr: 2', 'step2_rr: 2', 'step3_rr: 2', 'step4_rr: 2', 'step5_rr: 2', 'step6_rr: 2']
# empirical response rate 0.053650442477876106
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4133.2502256140915
# {'LR__C': 1.0}
# orr termination 0.031215421703240306 0.0687325083167965 0.0375170866135562
# remaining size for Round 3: 141019
# Calculated size for Round 3: 5099.356038308353
# {'LR__C': 0.01}
# orr termination 0.0642259586521412 0.07002830672241409 0.005802348070272884
# remaining size for Round 4: 135920
# Calculated size for Round 4: 6522.136238108765
# {'LR__C': 0.01}
# orr termination 0.027455316910364104 0.07440850723196094 0.04695319032159683
# remaining size for Round 5: 129398
# Calculated size for Round 5: 5687.610093285968
# {'LR__C': 0.01}
# orr termination 0.012649409070477822 0.0752853045887447 0.06263589551826688
# remaining size for last Round 6: 123711
# 4
# ['step1_rr: 3', 'step2_rr: 3', 'step3_rr: 3', 'step4_rr: 3', 'step5_rr: 3', 'step6_rr: 3']
# empirical response rate 0.05437638274336283
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4183.643824785205
# {'LR__C': 0.01}
# orr termination 0.04224586276608082 0.06743038662833331 0.025184523862252492
# remaining size for Round 3: 140969
# Calculated size for Round 3: 5911.285597813006
# {'LR__C': 1.0}
# orr termination 0.0068779054003106094 0.08470694943916597 0.07782904403885536
# remaining size for Round 4: 135058
# Calculated size for Round 4: 6263.177070790434
# {'LR__C': 0.1}
# orr termination 0.035665685399698666 0.07081331680186699 0.035147631402168325
# remaining size for Round 5: 128795
# Calculated size for Round 5: 9339.95399999228
# {'LR__C': 0.01}
# orr termination 0.03971146752034057 0.07516618440514887 0.0354547168848083
# remaining size for last Round 6: 119456
# 5
# ['step1_rr: 4', 'step2_rr: 4', 'step3_rr: 4', 'step4_rr: 4', 'step5_rr: 4', 'step6_rr: 4']
# empirical response rate 0.05530973451327434
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4248.542691505998
# {'LR__C': 0.1}
# orr termination 0.012022752700353441 0.07146786650021243 0.05944511379985899
# remaining size for Round 3: 140904
# Calculated size for Round 3: 5244.132694938928
# {'LR__C': 1.0}
# orr termination 0.010366069779717376 0.07673658311904344 0.06637051333932606
# remaining size for Round 4: 135660
# Calculated size for Round 4: 8309.648682434734
# {'LR__C': 0.01}
# orr termination 0.04771325739429725 0.07164122935148019 0.023927971957182943
# remaining size for Round 5: 127351
# Calculated size for Round 5: 8291.966696403511
# {'LR__C': 0.01}
# orr termination 0.03590825975631435 0.07299585810991549 0.03708759835360114
# remaining size for last Round 6: 119060
# 6
# ['step1_rr: 5', 'step2_rr: 5', 'step3_rr: 5', 'step4_rr: 5', 'step5_rr: 5', 'step6_rr: 5']
# empirical response rate 0.05361587389380531
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4130.852349241689
# {'LR__C': 1.0}
# orr termination 0.009836557607130496 0.0722358490396211 0.06239929143249061
# remaining size for Round 3: 141022
# Calculated size for Round 3: 5865.618047435739
# {'LR__C': 0.1}
# orr termination 0.02455937113829571 0.07492702407129585 0.05036765293300014
# remaining size for Round 4: 135157
# Calculated size for Round 4: 8646.784610411474
# {'LR__C': 0.1}
# orr termination 0.044158961593600166 0.06697471553774278 0.02281575394414262
# remaining size for Round 5: 126511
# Calculated size for Round 5: 6364.496922877303
# {'LR__C': 0.01}
# orr termination 0.03401927143320229 0.06767814099655693 0.03365886956335464
# remaining size for last Round 6: 120147
# 7
# ['step1_rr: 6', 'step2_rr: 6', 'step3_rr: 6', 'step4_rr: 6', 'step5_rr: 6', 'step6_rr: 6']
# empirical response rate 0.05330475663716814
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4109.278904649849
# {'LR__C': 0.01}
# orr termination 0.03401108175661849 0.06451230344456675 0.030501221687948263
# remaining size for Round 3: 141043
# Calculated size for Round 3: 5584.758338508455
# {'LR__C': 0.01}
# orr termination 0.007921661075008976 0.07494207754385507 0.06702041646884609
# remaining size for Round 4: 135459
# Calculated size for Round 4: 6763.133879767843
# {'LR__C': 1.0}
# orr termination 0.04042540733411441 0.08033099710160735 0.039905589767492936
# remaining size for Round 5: 128696
# Calculated size for Round 5: 9581.36894098188
# {'LR__C': 0.01}
# orr termination 0.037032635647315675 0.07309678788467065 0.03606415223735498
# remaining size for last Round 6: 119115
# 8
# ['step1_rr: 7', 'step2_rr: 7', 'step3_rr: 7', 'step4_rr: 7', 'step5_rr: 7', 'step6_rr: 7']
# empirical response rate 0.055724557522123894
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4277.425283765311
# {'LR__C': 1.0}
# orr termination 0.04394614391913064 0.07079316516915966 0.026847021250029024
# remaining size for Round 3: 140875
# Calculated size for Round 3: 5211.217517777837
# {'LR__C': 1.0}
# orr termination 0.04264220832902814 0.07050345455898008 0.02786124622995194
# remaining size for Round 4: 135664
# Calculated size for Round 4: 5686.72277612557
# {'LR__C': 0.1}
# orr termination 0.023547038229854305 0.07566545569906369 0.05211841746920938
# remaining size for Round 5: 129978
# Calculated size for Round 5: 6311.003382227907
# {'LR__C': 1.0}
# orr termination 0.0054534887422095345 0.07597033198118656 0.07051684323897703
# remaining size for last Round 6: 123667
# 9
# ['step1_rr: 8', 'step2_rr: 8', 'step3_rr: 8', 'step4_rr: 8', 'step5_rr: 8', 'step6_rr: 8']
# empirical response rate 0.05676161504424779
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4349.735755102456
# {'LR__C': 0.1}
# orr termination 0.007150236429713583 0.07373699976644454 0.06658676333673096
# remaining size for Round 3: 140803
# Calculated size for Round 3: 5867.501481336253
# {'LR__C': 0.01}
# orr termination 0.03345703681221246 0.06725389547579089 0.03379685866357843
# remaining size for Round 4: 134936
# Calculated size for Round 4: 9820.864647643497
# {'LR__C': 1.0}
# orr termination 0.019274926156456554 0.07610416489709639 0.05682923874063983
# remaining size for Round 5: 125116
# 10
# ['step1_rr: 9', 'step2_rr: 9', 'step3_rr: 9', 'step4_rr: 9', 'step5_rr: 9', 'step6_rr: 9']
# empirical response rate 0.053650442477876106
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4133.2502256140915
# {'LR__C': 0.01}
# orr termination 0.006520097128823243 0.07295636159564783 0.06643626446682459
# remaining size for Round 3: 141019
# Calculated size for Round 3: 6412.374837904525
# {'LR__C': 0.01}
# orr termination 0.014664429792514465 0.07426231344036123 0.05959788364784677
# remaining size for Round 4: 134607
# 11
# ['step1_rr: 10', 'step2_rr: 10', 'step3_rr: 10', 'step4_rr: 10', 'step5_rr: 10', 'step6_rr: 10']
# empirical response rate 0.05188744469026549
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4011.169485577855
# {'LR__C': 1.0}
# orr termination 0.04810611496462633 0.061414858074267886 0.013308743109641558
# remaining size for Round 3: 141141
# Calculated size for Round 3: 4957.199518706059
# {'LR__C': 1.0}
# orr termination 0.025726808181121878 0.06860292482843672 0.04287611664731484
# remaining size for Round 4: 136184
# Calculated size for Round 4: 5277.667608764581
# {'LR__C': 0.1}
# orr termination 0.041189308906581415 0.07442753853591877 0.033238229629337354
# remaining size for Round 5: 130907
# Calculated size for Round 5: 6586.034760985998
# {'LR__C': 1.0}
# orr termination 0.009015740494243694 0.07536311210954025 0.06634737161529655
# remaining size for last Round 6: 124321
# 12
# ['step1_rr: 11', 'step2_rr: 11', 'step3_rr: 11', 'step4_rr: 11', 'step5_rr: 11', 'step6_rr: 11']
# empirical response rate 0.05420353982300885
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4171.638735916014
# {'LR__C': 0.01}
# orr termination 0.025754904093206778 0.06999499995521889 0.044240095862012115
# remaining size for Round 3: 140981
# Calculated size for Round 3: 6793.145972046842
# {'LR__C': 0.1}
# orr termination 0.04422723247778141 0.07287271512780003 0.028645482650018615
# remaining size for Round 4: 134188
# Calculated size for Round 4: 7052.415358361722
# {'LR__C': 0.1}
# orr termination 0.00717801551956953 0.08342908473714993 0.07625106921758039
# remaining size for Round 5: 127136
# 13
# ['step1_rr: 12', 'step2_rr: 12', 'step3_rr: 12', 'step4_rr: 12', 'step5_rr: 12', 'step6_rr: 12']
# empirical response rate 0.05489491150442478
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4219.683881321882
# {'LR__C': 0.1}
# orr termination 0.010730622243945432 0.07601860774584648 0.06528798550190106
# remaining size for Round 3: 140933
# Calculated size for Round 3: 5618.245879103238
# {'LR__C': 0.1}
# orr termination 0.005789341024408993 0.07776674259178677 0.07197740156737778
# remaining size for Round 4: 135315
# 14
# ['step1_rr: 13', 'step2_rr: 13', 'step3_rr: 13', 'step4_rr: 13', 'step5_rr: 13', 'step6_rr: 13']
# empirical response rate 0.05496404867256637
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4224.492031131622
# {'LR__C': 0.01}
# orr termination 0.005780318492854972 0.07091429560779952 0.06513397711494455
# remaining size for Round 3: 140928
# Calculated size for Round 3: 6087.566753225717
# {'LR__C': 1.0}
# orr termination 0.030734043982749648 0.07737980813340792 0.04664576415065827
# remaining size for Round 4: 134841
# Calculated size for Round 4: 12450.671753627703
# {'LR__C': 0.01}
# orr termination 0.03366985046187492 0.06701727432658822 0.033347423864713295
# remaining size for Round 5: 122391
# 15
# ['step1_rr: 14', 'step2_rr: 14', 'step3_rr: 14', 'step4_rr: 14', 'step5_rr: 14', 'step6_rr: 14']
# empirical response rate 0.05620851769911504
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4311.151688005828
# {'LR__C': 1.0}
# orr termination 0.050241681487765866 0.06939814902661144 0.019156467538845576
# remaining size for Round 3: 140841
# Calculated size for Round 3: 5335.38962026583
# {'LR__C': 1.0}
# orr termination 0.031991617477529 0.07736004758091918 0.04536843010339017
# remaining size for Round 4: 135506
# Calculated size for Round 4: 5447.363086618181
# {'LR__C': 0.01}
# orr termination 0.017792807145785725 0.07436024492702703 0.056567437781241306
# remaining size for Round 5: 130059
# Calculated size for Round 5: 6695.465407354757
# {'LR__C': 0.01}
# orr termination 0.018134526724157433 0.07277159226748059 0.054637065543323156
# remaining size for last Round 6: 123364
# 16
# ['step1_rr: 15', 'step2_rr: 15', 'step3_rr: 15', 'step4_rr: 15', 'step5_rr: 15', 'step6_rr: 15']
# empirical response rate 0.05399612831858407
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4157.238084390138
# {'LR__C': 0.01}
# orr termination 0.008693527229002044 0.076375416126093 0.06768188889709095
# remaining size for Round 3: 140995
# Calculated size for Round 3: 5082.968110893499
# {'LR__C': 0.01}
# orr termination 0.022328653513892464 0.07947093073842136 0.0571422772245289
# remaining size for Round 4: 135913
# Calculated size for Round 4: 12207.546197166796
# {'LR__C': 0.01}
# orr termination 0.055190021958306384 0.07284400603410283 0.01765398407579645
# remaining size for Round 5: 123706
# Calculated size for Round 5: 6552.886975295068
# {'LR__C': 0.1}
# orr termination 0.050171386693405505 0.07477102856625302 0.024599641872847515
# remaining size for last Round 6: 117154
# 17
# ['step1_rr: 16', 'step2_rr: 16', 'step3_rr: 16', 'step4_rr: 16', 'step5_rr: 16', 'step6_rr: 16']
# empirical response rate 0.05517146017699115
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# {'LR__C': 0.1}
# orr termination 0.045753147407724834 0.06886439508638986 0.02311124767866503
# remaining size for Round 3: 140914
# Calculated size for Round 3: 4986.730224683194
# {'LR__C': 1.0}
# orr termination 0.012741288132869042 0.07714999007279935 0.06440870193993031
# remaining size for Round 4: 135928
# Calculated size for Round 4: 5738.267438389287
# {'LR__C': 0.01}
# orr termination 0.00570471008830035 0.07669206462503554 0.07098735453673519
# remaining size for Round 5: 130190
# 18
# ['step1_rr: 17', 'step2_rr: 17', 'step3_rr: 17', 'step4_rr: 17', 'step5_rr: 17', 'step6_rr: 17']
# empirical response rate 0.055240597345132744
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4243.731238049317
# {'LR__C': 1.0}
# orr termination 0.03325965555708107 0.06868610610330589 0.03542645054622482
# remaining size for Round 3: 140909
# Calculated size for Round 3: 5055.827744360612
# {'LR__C': 0.01}
# orr termination 0.02875419729575216 0.06980253666127559 0.04104833936552343
# remaining size for Round 4: 135854
# Calculated size for Round 4: 5999.246940460195
# {'LR__C': 0.01}
# orr termination 0.005733809334189079 0.07733739377836624 0.07160358444417717
# remaining size for Round 5: 129855
# Calculated size for Round 5: 6846.807441469031
# {'LR__C': 0.01}
# orr termination 0.03585859020602667 0.0719402355253822 0.03608164531935553
# remaining size for last Round 6: 123009
# 19
# ['step1_rr: 18', 'step2_rr: 18', 'step3_rr: 18', 'step4_rr: 18', 'step5_rr: 18', 'step6_rr: 18']
# empirical response rate 0.05610481194690266
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4303.921878005255
# {'LR__C': 0.01}
# orr termination 0.008194111623656982 0.06565790288892359 0.05746379126526661
# remaining size for Round 3: 140849
# Calculated size for Round 3: 9338.984277706828
# {'LR__C': 0.01}
# orr termination 0.03351691235077587 0.06804088669006714 0.03452397433929127
# remaining size for Round 4: 131511
# 20
# ['step1_rr: 19', 'step2_rr: 19', 'step3_rr: 19', 'step4_rr: 19', 'step5_rr: 19', 'step6_rr: 19']
# empirical response rate 0.05669247787610619
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4344.910437079735
# {'LR__C': 0.01}
# orr termination 0.009665744807564092 0.07073229758960653 0.06106655278204244
# remaining size for Round 3: 140808
# Calculated size for Round 3: 5342.0765403444775
# {'LR__C': 1.0}
# orr termination 0.024158711708599998 0.08136178635643854 0.05720307464783854
# remaining size for Round 4: 135466
# Calculated size for Round 4: 9697.114063533772
# {'LR__C': 0.01}
# orr termination 0.018586440715933874 0.0745026339903247 0.05591619327439082
# remaining size for Round 5: 125769
# 21
# ['step1_rr: 20', 'step2_rr: 20', 'step3_rr: 20', 'step4_rr: 20', 'step5_rr: 20', 'step6_rr: 20']
# empirical response rate 0.0547220685840708
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4207.666398075275
# {'LR__C': 0.01}
# orr termination 0.03092700076000153 0.06243677500870107 0.03150977424869954
# remaining size for Round 3: 140945
# Calculated size for Round 3: 5046.975007548205
# {'LR__C': 1.0}
# orr termination 0.062259761211009186 0.06854912731595106 0.006289366104941872
# remaining size for Round 4: 135899
# Calculated size for Round 4: 6101.218864058591
# {'LR__C': 0.1}
# orr termination 0.009045141997352586 0.07341077442485122 0.06436563242749864
# remaining size for Round 5: 129798
# Calculated size for Round 5: 5562.245361014943
# {'LR__C': 0.01}
# orr termination 0.03525839973320652 0.07047417190475677 0.03521577217155025
# remaining size for last Round 6: 124236
# 22
# ['step1_rr: 21', 'step2_rr: 21', 'step3_rr: 21', 'step4_rr: 21', 'step5_rr: 21', 'step6_rr: 21']
# empirical response rate 0.05807522123893805
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4441.542106735752
# {'LR__C': 1.0}
# orr termination 0.056874015633933586 0.06793552729094496 0.011061511657011372
# remaining size for Round 3: 140711
# Calculated size for Round 3: 5477.986679248514
# {'LR__C': 1.0}
# orr termination 0.019874791942871152 0.07801555567765472 0.05814076373478357
# remaining size for Round 4: 135234
# Calculated size for Round 4: 5305.704210247072
# {'LR__C': 1.0}
# orr termination 0.01106442426765085 0.08322502335846188 0.07216059909081103
# remaining size for Round 5: 129929
# Calculated size for Round 5: 7676.6361298511
# {'LR__C': 0.01}
# orr termination 0.04811582436169834 0.07175860209970274 0.023642777738004397
# remaining size for last Round 6: 122253
# 23
# ['step1_rr: 22', 'step2_rr: 22', 'step3_rr: 22', 'step4_rr: 22', 'step5_rr: 22', 'step6_rr: 22']
# empirical response rate 0.054756637168141595
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4210.069564273832
# {'LR__C': 1.0}
# orr termination 0.006885295731486039 0.06521985531678712 0.05833455958530108
# remaining size for Round 3: 140942
# Calculated size for Round 3: 4992.544197081404
# {'LR__C': 0.1}
# orr termination 0.012548372614419148 0.07636295144788897 0.06381457883346983
# remaining size for Round 4: 135950
# Calculated size for Round 4: 9644.807426074807
# {'LR__C': 0.01}
# orr termination 0.03355933350908657 0.06838929555203747 0.034829962042950906
# remaining size for Round 5: 126306
# 24
# ['step1_rr: 23', 'step2_rr: 23', 'step3_rr: 23', 'step4_rr: 23', 'step5_rr: 23', 'step6_rr: 23']
# empirical response rate 0.054756637168141595
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4210.069564273832
# {'LR__C': 0.1}
# orr termination 0.04970525033750789 0.06547312971450991 0.015767879377002025
# remaining size for Round 3: 140942
# Calculated size for Round 3: 5045.174345042331
# {'LR__C': 1.0}
# orr termination 0.023908370289883053 0.07313624773678121 0.049227877446898154
# remaining size for Round 4: 135897
# Calculated size for Round 4: 5158.1181128432045
# {'LR__C': 0.01}
# orr termination 0.0201494545543886 0.07136583841852591 0.05121638386413731
# remaining size for Round 5: 130739
# Calculated size for Round 5: 7142.516137236389
# {'LR__C': 0.01}
# orr termination 0.02827189980533039 0.07484935588093881 0.046577456075608425
# remaining size for last Round 6: 123597
# 25
# ['step1_rr: 24', 'step2_rr: 24', 'step3_rr: 24', 'step4_rr: 24', 'step5_rr: 24', 'step6_rr: 24']
# empirical response rate 0.05406526548672566
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4162.037640283698
# {'LR__C': 0.01}
# orr termination 0.04412999092849211 0.05783480975810547 0.013704818829613358
# remaining size for Round 3: 140990
# Calculated size for Round 3: 6497.432880460468
# {'LR__C': 0.01}
# orr termination 0.017111632124198844 0.060979262096596744 0.043867629972397904
# remaining size for Round 4: 134493
# Calculated size for Round 4: 5176.372496274571
# {'LR__C': 1.0}
# orr termination 0.040608295734344796 0.0647715197702252 0.024163224035880407
# remaining size for Round 5: 129317
# Calculated size for Round 5: 6685.618866251845
# {'LR__C': 1.0}
# orr termination 0.026102287481953715 0.06648559132682968 0.04038330384487597
# remaining size for last Round 6: 122632
# 26
# ['step1_rr: 25', 'step2_rr: 25', 'step3_rr: 25', 'step4_rr: 25', 'step5_rr: 25', 'step6_rr: 25']
# empirical response rate 0.05254424778761062
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4056.600233593618
# {'LR__C': 0.01}
# orr termination 0.04241344078371724 0.06293353547916311 0.02052009469544587
# remaining size for Round 3: 141096
# Calculated size for Round 3: 7232.664858575887
# {'LR__C': 1.0}
# orr termination 0.0519353302361254 0.06878788194127865 0.01685255170515325
# remaining size for Round 4: 133864
# Calculated size for Round 4: 6009.321275742473
# {'LR__C': 0.01}
# orr termination 0.06233777582300236 0.06545236863760476 0.003114592814602399
# remaining size for Round 5: 127855
# Calculated size for Round 5: 5814.8580065097785
# {'LR__C': 1.0}
# orr termination 0.01028239529239883 0.073847507993757 0.06356511270135817
# remaining size for last Round 6: 122041
# 27
# ['step1_rr: 26', 'step2_rr: 26', 'step3_rr: 26', 'step4_rr: 26', 'step5_rr: 26', 'step6_rr: 26']
# empirical response rate 0.053201050884955754
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4102.090733905276
# {'LR__C': 0.01}
# orr termination 0.02925090379216882 0.06462212048404092 0.035371216691872105
# remaining size for Round 3: 141050
# Calculated size for Round 3: 5407.814927278187
# {'LR__C': 0.01}
# orr termination 0.004902633759729264 0.07269633160726395 0.06779369784753468
# remaining size for Round 4: 135643
# Calculated size for Round 4: 6532.964994498977
# {'LR__C': 0.1}
# orr termination 0.04819744817912995 0.07254059893806106 0.024343150758931106
# remaining size for Round 5: 129111
# Calculated size for Round 5: 10517.949663734182
# {'LR__C': 0.01}
# orr termination 0.03355693481706327 0.06588461145400555 0.03232767663694228
# remaining size for last Round 6: 118594
# 28
# ['step1_rr: 27', 'step2_rr: 27', 'step3_rr: 27', 'step4_rr: 27', 'step5_rr: 27', 'step6_rr: 27']
# empirical response rate 0.05849004424778761
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4470.5830227383985
# {'LR__C': 0.01}
# orr termination 0.0028700841692511523 0.07740459249852388 0.07453450832927273
# remaining size for Round 3: 140682
# Calculated size for Round 3: 7120.456907788459
# {'LR__C': 0.01}
# orr termination 0.03241855905013975 0.06517816362867118 0.03275960457853143
# remaining size for Round 4: 133562
# 29
# ['step1_rr: 28', 'step2_rr: 28', 'step3_rr: 28', 'step4_rr: 28', 'step5_rr: 28', 'step6_rr: 28']
# empirical response rate 0.05537887168141593
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4253.354805576213
# {'LR__C': 1.0}
# orr termination 0.03894105627346192 0.07006148391668676 0.03112042764322484
# remaining size for Round 3: 140899
# Calculated size for Round 3: 5039.4530091795295
# {'LR__C': 0.1}
# orr termination 0.014312003893320092 0.0743753325840922 0.060063328690772105
# remaining size for Round 4: 135860
# Calculated size for Round 4: 5835.004069480124
# {'LR__C': 0.01}
# orr termination 0.03129539093430328 0.07327276427261814 0.04197737333831486
# remaining size for Round 5: 130025
# Calculated size for Round 5: 7985.724939118024
# {'LR__C': 1.0}
# orr termination 0.025476644531205645 0.07672866070820623 0.05125201617700059
# remaining size for last Round 6: 122040
# 30
# ['step1_rr: 29', 'step2_rr: 29', 'step3_rr: 29', 'step4_rr: 29', 'step5_rr: 29', 'step6_rr: 29']
# empirical response rate 0.056173949115044246
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4308.741586307481
# {'LR__C': 1.0}
# orr termination 0.008505133130507974 0.07119135818855374 0.06268622505804576
# remaining size for Round 3: 140844
# Calculated size for Round 3: 5059.393200827525
# {'LR__C': 0.1}
# orr termination 0.013988035300125632 0.07569008619790857 0.06170205089778294
# remaining size for Round 4: 135785
# Calculated size for Round 4: 9824.124612796946
# {'LR__C': 0.01}
# orr termination 0.024571237168013738 0.07528113093701441 0.050709893769000675
# remaining size for Round 5: 125961
# 31
# ['step1_rr: 30', 'step2_rr: 30', 'step3_rr: 30', 'step4_rr: 30', 'step5_rr: 30', 'step6_rr: 30']
# empirical response rate 0.05517146017699115
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# {'LR__C': 1.0}
# orr termination 0.05050004546114935 0.07015021906345754 0.019650173602308196
# remaining size for Round 3: 140914
# Calculated size for Round 3: 5677.7451835907605
# {'LR__C': 1.0}
# orr termination 0.01040654291528235 0.07723550777873402 0.06682896486345166
# remaining size for Round 4: 135237
# Calculated size for Round 4: 5808.822698811558
# {'LR__C': 0.1}
# orr termination 0.032568385138158185 0.07691976860250163 0.04435138346434345
# remaining size for Round 5: 129429
# Calculated size for Round 5: 9901.653676847875
# {'LR__C': 0.01}
# orr termination 0.049356936022927345 0.07127303071481911 0.021916094691891763
# remaining size for last Round 6: 119528
# 32
# ['step1_rr: 31', 'step2_rr: 31', 'step3_rr: 31', 'step4_rr: 31', 'step5_rr: 31', 'step6_rr: 31']
# empirical response rate 0.05544800884955752
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4258.167580221075
# {'LR__C': 1.0}
# orr termination 0.012801949549913042 0.07392033068863361 0.061118381138720576
# remaining size for Round 3: 140894
# Calculated size for Round 3: 5848.627269045002
# {'LR__C': 0.01}
# orr termination 0.06450509025479445 0.07105412659412852 0.006549036339334069
# remaining size for Round 4: 135046
# Calculated size for Round 4: 9223.086804696703
# {'LR__C': 0.01}
# orr termination 0.023467017214569813 0.073062006809368 0.04959498959479819
# remaining size for Round 5: 125823
# Calculated size for Round 5: 5750.73323892457
# {'LR__C': 1.0}
# orr termination 0.049121245792998466 0.0759483009505503 0.026827055157551835
# remaining size for last Round 6: 120073
# 33
# ['step1_rr: 32', 'step2_rr: 32', 'step3_rr: 32', 'step4_rr: 32', 'step5_rr: 32', 'step6_rr: 32']
# empirical response rate 0.05482577433628318
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4214.876392356589
# {'LR__C': 1.0}
# orr termination 0.04486252781363041 0.07108202762317349 0.02621949980954308
# remaining size for Round 3: 140938
# Calculated size for Round 3: 5689.74706764736
# {'LR__C': 0.1}
# orr termination 0.012498318554309195 0.07976472448485875 0.06726640593054956
# remaining size for Round 4: 135249
# Calculated size for Round 4: 6537.70931452858
# {'LR__C': 1.0}
# orr termination 0.02054558322243075 0.08046958396700261 0.05992400074457187
# remaining size for Round 5: 128712
# Calculated size for Round 5: 8070.973266248172
# {'LR__C': 0.01}
# orr termination 0.0365915821229621 0.07010504123727826 0.033513459114316156
# remaining size for last Round 6: 120642
# 34
# ['step1_rr: 33', 'step2_rr: 33', 'step3_rr: 33', 'step4_rr: 33', 'step5_rr: 33', 'step6_rr: 33']
# empirical response rate 0.054756637168141595
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4210.069564273832
# {'LR__C': 0.01}
# orr termination 0.0283387085934622 0.06591625024525971 0.03757754165179751
# remaining size for Round 3: 140942
# Calculated size for Round 3: 4820.581078050764
# {'LR__C': 0.01}
# orr termination 0.021723793476619006 0.07140182641300304 0.04967803293638403
# remaining size for Round 4: 136122
# Calculated size for Round 4: 6400.872123851262
# {'LR__C': 1.0}
# orr termination 0.016079530790150422 0.07715683618383831 0.061077305393687886
# remaining size for Round 5: 129722
# Calculated size for Round 5: 7252.235535982925
# {'LR__C': 0.1}
# orr termination 0.03585794718247047 0.07284701386031774 0.036989066677847265
# remaining size for last Round 6: 122470
# 35
# ['step1_rr: 34', 'step2_rr: 34', 'step3_rr: 34', 'step4_rr: 34', 'step5_rr: 34', 'step6_rr: 34']
# empirical response rate 0.05548257743362832
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4260.5742152468165
# {'LR__C': 1.0}
# orr termination 0.035497528936872275 0.06837619422627382 0.032878665289401546
# remaining size for Round 3: 140892
# Calculated size for Round 3: 4653.648056170633
# {'LR__C': 0.1}
# orr termination 0.04420762084249336 0.07241009256211078 0.02820247171961742
# remaining size for Round 4: 136239
# Calculated size for Round 4: 5887.597192397069
# {'LR__C': 1.0}
# orr termination 0.037586572874685434 0.07622234377560419 0.038635770900918756
# remaining size for Round 5: 130352
# Calculated size for Round 5: 6242.450577766757
# {'LR__C': 0.01}
# orr termination 0.03470662766833552 0.07664208905700848 0.041935461388672955
# remaining size for last Round 6: 124110
# 36
# ['step1_rr: 35', 'step2_rr: 35', 'step3_rr: 35', 'step4_rr: 35', 'step5_rr: 35', 'step6_rr: 35']
# empirical response rate 0.05479120575221239
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4212.472895702519
# {'LR__C': 1.0}
# orr termination 0.016324561419074304 0.07101025549985512 0.05468569408078082
# remaining size for Round 3: 140940
# Calculated size for Round 3: 5851.886445740313
# {'LR__C': 0.01}
# orr termination 0.008305859692921786 0.06298527539315005 0.05467941570022826
# remaining size for Round 4: 135089
# Calculated size for Round 4: 7140.737377388203
# {'LR__C': 0.01}
# orr termination 0.030334172917677295 0.06102160873407823 0.030687435816400932
# remaining size for Round 5: 127949
# 37
# ['step1_rr: 36', 'step2_rr: 36', 'step3_rr: 36', 'step4_rr: 36', 'step5_rr: 36', 'step6_rr: 36']
# empirical response rate 0.054272676991150445
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4176.440275580975
# {'LR__C': 0.01}
# orr termination 0.014674497214885718 0.05950689046859628 0.044832393253710565
# remaining size for Round 3: 140976
# Calculated size for Round 3: 9097.873163133487
# {'LR__C': 0.01}
# orr termination 0.014602753654296505 0.05828837423913698 0.043685620584840476
# remaining size for Round 4: 131879
# 38
# ['step1_rr: 37', 'step2_rr: 37', 'step3_rr: 37', 'step4_rr: 37', 'step5_rr: 37', 'step6_rr: 37']
# empirical response rate 0.05333932522123894
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4111.675292416549
# {'LR__C': 0.1}
# orr termination 0.04456206725704137 0.06552169449390052 0.020959627236859152
# remaining size for Round 3: 141041
# Calculated size for Round 3: 5029.19605015052
# {'LR__C': 1.0}
# orr termination 0.035461036593178605 0.0703871342581488 0.03492609766497019
# remaining size for Round 4: 136012
# Calculated size for Round 4: 5304.491763332011
# {'LR__C': 1.0}
# orr termination 0.013294886519721176 0.07373057952595224 0.06043569300623107
# remaining size for Round 5: 130708
# Calculated size for Round 5: 6285.974314022975
# {'LR__C': 0.01}
# orr termination 0.010351464639684475 0.07341753209787642 0.06306606745819195
# remaining size for last Round 6: 124423
# 39
# ['step1_rr: 38', 'step2_rr: 38', 'step3_rr: 38', 'step4_rr: 38', 'step5_rr: 38', 'step6_rr: 38']
# empirical response rate 0.05278622787610619
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4073.3529413786146
# {'LR__C': 0.1}
# orr termination 0.011665054860178974 0.07628410678922415 0.06461905192904517
# remaining size for Round 3: 141079
# Calculated size for Round 3: 5478.749659193455
# {'LR__C': 1.0}
# orr termination 0.06173967410562962 0.07702216247095908 0.015282488365329465
# remaining size for Round 4: 135601
# Calculated size for Round 4: 9177.621989980038
# {'LR__C': 0.01}
# orr termination 0.034717463976960614 0.07156778161590913 0.03685031763894851
# remaining size for Round 5: 126424
# Calculated size for Round 5: 6043.94581792517
# {'LR__C': 0.01}
# orr termination 0.033979902803605924 0.06858736560926826 0.034607462805662334
# remaining size for last Round 6: 120381
# 40
# ['step1_rr: 39', 'step2_rr: 39', 'step3_rr: 39', 'step4_rr: 39', 'step5_rr: 39', 'step6_rr: 39']
# empirical response rate 0.05420353982300885
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4171.638735916014
# {'LR__C': 1.0}
# orr termination 0.047914672225227245 0.06590956730249659 0.01799489507726934
# remaining size for Round 3: 140981
# Calculated size for Round 3: 4973.222426539794
# {'LR__C': 1.0}
# orr termination 0.05190250821507303 0.07153630591722142 0.01963379770214839
# remaining size for Round 4: 136008
# Calculated size for Round 4: 5360.477224277127
# {'LR__C': 1.0}
# orr termination 0.001338388300565182 0.08141130207540907 0.08007291377484389
# remaining size for Round 5: 130648
# 41
# ['step1_rr: 40', 'step2_rr: 40', 'step3_rr: 40', 'step4_rr: 40', 'step5_rr: 40', 'step6_rr: 40']
# empirical response rate 0.058213495575221236
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4451.219776662242
# {'LR__C': 1.0}
# orr termination 0.04965270098559019 0.06826587009375548 0.018613169108165295
# remaining size for Round 3: 140701
# Calculated size for Round 3: 5204.613383259877
# {'LR__C': 1.0}
# orr termination 0.05866777419764478 0.07091014655272099 0.012242372355076206
# remaining size for Round 4: 135497
# Calculated size for Round 4: 5648.986065119816
# {'LR__C': 0.01}
# orr termination 0.026812178989801573 0.07343443344034056 0.04662225445053899
# remaining size for Round 5: 129849
# Calculated size for Round 5: 5627.105465220871
# {'LR__C': 1.0}
# orr termination 0.006471175300349166 0.08267652408463247 0.0762053487842833
# remaining size for last Round 6: 124222
# 42
# ['step1_rr: 41', 'step2_rr: 41', 'step3_rr: 41', 'step4_rr: 41', 'step5_rr: 41', 'step6_rr: 41']
# empirical response rate 0.05389242256637168
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4150.039990556384
# {'LR__C': 0.01}
# orr termination 0.022533503217720425 0.06744047718986079 0.04490697397214037
# remaining size for Round 3: 141002
# Calculated size for Round 3: 6027.3255150919385
# {'LR__C': 0.01}
# orr termination 0.04260442322011091 0.06962535746298906 0.02702093424287815
# remaining size for Round 4: 134975
# Calculated size for Round 4: 7677.659490034105
# {'LR__C': 0.1}
# orr termination 0.03343380969922989 0.07748446278956946 0.044050653090339564
# remaining size for Round 5: 127298
# Calculated size for Round 5: 6584.571428033026
# {'LR__C': 0.01}
# orr termination 0.01253002918836206 0.07366769914952415 0.061137669961162086
# remaining size for last Round 6: 120714
# 43
# ['step1_rr: 42', 'step2_rr: 42', 'step3_rr: 42', 'step4_rr: 42', 'step5_rr: 42', 'step6_rr: 42']
# empirical response rate 0.053477599557522126
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4121.262497623935
# {'LR__C': 0.01}
# orr termination 0.01220059421371016 0.0686473145677026 0.05644672035399244
# remaining size for Round 3: 141031
# Calculated size for Round 3: 5243.690741743736
# {'LR__C': 1.0}
# orr termination 0.010249357816966537 0.08302593150068516 0.07277657368371862
# remaining size for Round 4: 135788
# Calculated size for Round 4: 9003.232845358016
# {'LR__C': 0.01}
# orr termination 0.0357505004462757 0.07426334788099358 0.038512847434717876
# remaining size for Round 5: 126785
# 44
# ['step1_rr: 43', 'step2_rr: 43', 'step3_rr: 43', 'step4_rr: 43', 'step5_rr: 43', 'step6_rr: 43']
# empirical response rate 0.055413440265486724
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4255.761110329247
# {'LR__C': 1.0}
# orr termination 0.05136782060157394 0.06478084485462947 0.01341302425305553
# remaining size for Round 3: 140897
# Calculated size for Round 3: 5188.308152298461
# {'LR__C': 1.0}
# orr termination 0.012355152201061467 0.07579991839089424 0.06344476618983277
# remaining size for Round 4: 135709
# Calculated size for Round 4: 5349.617906834026
# {'LR__C': 0.1}
# orr termination 0.016410915474396572 0.07781757685959918 0.06140666138520261
# remaining size for Round 5: 130360
# Calculated size for Round 5: 8810.839729600491
# {'LR__C': 0.01}
# orr termination 0.023588170276770234 0.07442606357697193 0.05083789330020169
# remaining size for last Round 6: 121550
# 45
# ['step1_rr: 44', 'step2_rr: 44', 'step3_rr: 44', 'step4_rr: 44', 'step5_rr: 44', 'step6_rr: 44']
# empirical response rate 0.05579369469026549
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4282.241360696144
# {'LR__C': 1.0}
# orr termination 0.031178432105980765 0.06963517774074734 0.03845674563476658
# remaining size for Round 3: 140870
# Calculated size for Round 3: 4858.356310871639
# {'LR__C': 0.01}
# orr termination 0.004796285645190888 0.07609266006208024 0.07129637441688935
# remaining size for Round 4: 136012
# Calculated size for Round 4: 6281.72496882263
# {'LR__C': 0.01}
# orr termination 0.0537896011938399 0.07178735042639403 0.01799774923255413
# remaining size for Round 5: 129731
# Calculated size for Round 5: 10532.308802032392
# {'LR__C': 0.1}
# orr termination 0.024749794748210107 0.07286600331576494 0.04811620856755483
# remaining size for last Round 6: 119199
# 46
# ['step1_rr: 45', 'step2_rr: 45', 'step3_rr: 45', 'step4_rr: 45', 'step5_rr: 45', 'step6_rr: 45']
# empirical response rate 0.05486034292035398
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4217.280054231296
# {'LR__C': 0.01}
# orr termination 0.052843405289252306 0.06877557605779253 0.01593217076854022
# remaining size for Round 3: 140935
# Calculated size for Round 3: 5354.197107643707
# {'LR__C': 1.0}
# orr termination 0.019083343757909668 0.07834208008042479 0.05925873632251512
# remaining size for Round 4: 135581
# Calculated size for Round 4: 5562.492800211617
# {'LR__C': 0.1}
# orr termination 0.015834850725999793 0.08560460617828006 0.06976975545228026
# remaining size for Round 5: 130019
# Calculated size for Round 5: 7897.361715062993
# {'LR__C': 0.01}
# orr termination 0.01919840696893489 0.07611792040308935 0.05691951343415445
# remaining size for last Round 6: 122122
# 47
# ['step1_rr: 46', 'step2_rr: 46', 'step3_rr: 46', 'step4_rr: 46', 'step5_rr: 46', 'step6_rr: 46']
# empirical response rate 0.054307245575221236
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4178.841293359456
# {'LR__C': 1.0}
# orr termination 0.04523576493918876 0.07037245488850619 0.025136689949317427
# remaining size for Round 3: 140974
# Calculated size for Round 3: 5005.3180156426715
# {'LR__C': 1.0}
# orr termination 0.048498620450116964 0.07301346663281788 0.024514846182700917
# remaining size for Round 4: 135969
# Calculated size for Round 4: 5626.016737242751
# {'LR__C': 1.0}
# orr termination 0.03658816463568067 0.07597752534102188 0.039389360705341214
# remaining size for Round 5: 130343
# Calculated size for Round 5: 6324.666048249588
# {'LR__C': 0.01}
# orr termination 0.010668608234861978 0.07740984243426212 0.06674123419940015
# remaining size for last Round 6: 124019
# 48
# ['step1_rr: 47', 'step2_rr: 47', 'step3_rr: 47', 'step4_rr: 47', 'step5_rr: 47', 'step6_rr: 47']
# empirical response rate 0.055862831858407076
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4287.058097965914
# {'LR__C': 1.0}
# orr termination 0.012874266737424776 0.06951710695346726 0.05664284021604248
# remaining size for Round 3: 140865
# Calculated size for Round 3: 5912.769522311551
# {'LR__C': 0.01}
# orr termination 0.03244812824377691 0.07171140088778333 0.03926327264400642
# remaining size for Round 4: 134953
# Calculated size for Round 4: 8951.525443663479
# {'LR__C': 1.0}
# orr termination 0.042789033475074144 0.07184929879357953 0.029060265318505384
# remaining size for Round 5: 126002
# Calculated size for Round 5: 6804.195497025236
# {'LR__C': 0.01}
# orr termination 0.04869926485437197 0.07312900299875938 0.02442973814438741
# remaining size for last Round 6: 119198
# 49
# ['step1_rr: 48', 'step2_rr: 48', 'step3_rr: 48', 'step4_rr: 48', 'step5_rr: 48', 'step6_rr: 48']
# empirical response rate 0.05658877212389381
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4337.673697209837
# {'LR__C': 1.0}
# orr termination 0.01956617557364406 0.0749046003177596 0.05533842474411554
# remaining size for Round 3: 140815
# Calculated size for Round 3: 4826.784720688492
# {'LR__C': 0.01}
# orr termination 0.022523237186241253 0.07255432469189335 0.0500310875056521
# remaining size for Round 4: 135989
# Calculated size for Round 4: 7405.738639205242
# {'LR__C': 1.0}
# orr termination 0.01788470315491982 0.07573087072603604 0.05784616757111623
# remaining size for Round 5: 128584
# Calculated size for Round 5: 7251.144256643935
# {'LR__C': 0.1}
# orr termination 0.02411299934973614 0.07340683609387078 0.049293836744134636
# remaining size for last Round 6: 121333
# 50
# ['step1_rr: 49', 'step2_rr: 49', 'step3_rr: 49', 'step4_rr: 49', 'step5_rr: 49', 'step6_rr: 49']
# empirical response rate 0.05793694690265487
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4431.867072682371
# {'LR__C': 1.0}
# orr termination 0.01873118934824373 0.07644967705919178 0.05771848771094805
# remaining size for Round 3: 140721
# Calculated size for Round 3: 5500.286434043792
# {'LR__C': 1.0}
# orr termination 0.024367730582825108 0.08276052661318524 0.05839279603036013
# remaining size for Round 4: 135221
# Calculated size for Round 4: 7969.366426415232
# {'LR__C': 1.0}
# orr termination 0.010800782191852668 0.08038296304381634 0.06958218085196367
# remaining size for Round 5: 127252
# 51
# ['step1_rr: 50', 'step2_rr: 50', 'step3_rr: 50', 'step4_rr: 50', 'step5_rr: 50', 'step6_rr: 50']
# empirical response rate 0.05548257743362832
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4260.5742152468165
# {'LR__C': 0.01}
# orr termination 0.011920631133037676 0.06738533382429854 0.05546470269126086
# remaining size for Round 3: 140892
# Calculated size for Round 3: 7063.261852570205
# {'LR__C': 1.0}
# orr termination 0.06315605975694927 0.075562252249288 0.012406192492338736
# remaining size for Round 4: 133829
# Calculated size for Round 4: 9488.172171534217
# {'LR__C': 0.01}
# orr termination 0.04109326189665012 0.06857882061924708 0.02748555872259696
# remaining size for Round 5: 124341
# Calculated size for Round 5: 5856.197158919789
# {'LR__C': 0.01}
# orr termination 0.04681245822058418 0.069976278475829 0.023163820255244827
# remaining size for last Round 6: 118485
# 52
# ['step1_rr: 51', 'step2_rr: 51', 'step3_rr: 51', 'step4_rr: 51', 'step5_rr: 51', 'step6_rr: 51']
# empirical response rate 0.05420353982300885
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4171.638735916014
# {'LR__C': 1.0}
# orr termination 0.022195837833995133 0.07380488886043124 0.051609051026436106
# remaining size for Round 3: 140981
# Calculated size for Round 3: 5025.833562384705
# {'LR__C': 0.01}
# orr termination 0.015822996305826897 0.07811373577911347 0.062290739473286574
# remaining size for Round 4: 135956
# Calculated size for Round 4: 7499.248010676254
# {'LR__C': 0.01}
# orr termination 0.0317458497174892 0.07437078277188101 0.042624933054391814
# remaining size for Round 5: 128457
# Calculated size for Round 5: 8075.2142552471705
# {'LR__C': 0.1}
# orr termination 0.026963095247476313 0.0805389104428317 0.053575815195355384
# remaining size for last Round 6: 120382
# 53
# ['step1_rr: 52', 'step2_rr: 52', 'step3_rr: 52', 'step4_rr: 52', 'step5_rr: 52', 'step6_rr: 52']
# empirical response rate 0.055240597345132744
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4243.731238049317
# {'LR__C': 0.1}
# orr termination 0.010527176961748992 0.09017632600468595 0.07964914904293696
# remaining size for Round 3: 140909
# Calculated size for Round 3: 7903.256305657422
# {'LR__C': 1.0}
# orr termination 0.035045503931924515 0.06916013356175643 0.034114629629831916
# remaining size for Round 4: 133006
# Calculated size for Round 4: 8296.030350297626
# {'LR__C': 0.01}
# orr termination 0.03677280728416381 0.07397758055376837 0.03720477326960456
# remaining size for Round 5: 124710
# 54
# ['step1_rr: 53', 'step2_rr: 53', 'step3_rr: 53', 'step4_rr: 53', 'step5_rr: 53', 'step6_rr: 53']
# empirical response rate 0.05392699115044248
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4152.439189827319
# {'LR__C': 0.1}
# orr termination 0.03555176419199471 0.06630435747935233 0.03075259328735762
# remaining size for Round 3: 141000
# Calculated size for Round 3: 5250.260819901437
# {'LR__C': 0.01}
# orr termination 0.03683907604512192 0.07163692836252689 0.03479785231740497
# remaining size for Round 4: 135750
# Calculated size for Round 4: 6316.815896239848
# {'LR__C': 0.01}
# orr termination 0.015531643794062938 0.0772869236870832 0.061755279893020265
# remaining size for Round 5: 129434
# Calculated size for Round 5: 6591.394085347152
# {'LR__C': 1.0}
# orr termination 0.02557079785920927 0.07585103521871756 0.05028023735950829
# remaining size for last Round 6: 122843
# 55
# ['step1_rr: 54', 'step2_rr: 54', 'step3_rr: 54', 'step4_rr: 54', 'step5_rr: 54', 'step6_rr: 54']
# empirical response rate 0.055240597345132744
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4243.731238049317
# {'LR__C': 0.1}
# orr termination 0.0425617928289276 0.06811887178025816 0.02555707895133056
# remaining size for Round 3: 140909
# Calculated size for Round 3: 5163.943690778757
# {'LR__C': 1.0}
# orr termination 0.014031977932147428 0.07492272974341581 0.06089075181126838
# remaining size for Round 4: 135746
# Calculated size for Round 4: 5854.345853401881
# {'LR__C': 0.01}
# orr termination 0.01453274504255113 0.07368931108769339 0.05915656604514226
# remaining size for Round 5: 129892
# Calculated size for Round 5: 7725.484403516738
# {'LR__C': 0.01}
# orr termination 0.02441388364440065 0.07284187118931777 0.04842798754491712
# remaining size for last Round 6: 122167
# 56
# ['step1_rr: 55', 'step2_rr: 55', 'step3_rr: 55', 'step4_rr: 55', 'step5_rr: 55', 'step6_rr: 55']
# empirical response rate 0.05496404867256637
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4224.492031131622
# {'LR__C': 1.0}
# orr termination 0.037504105491132124 0.07133913693827713 0.03383503144714501
# remaining size for Round 3: 140928
# Calculated size for Round 3: 5320.166190207833
# {'LR__C': 1.0}
# orr termination 0.05808218017606828 0.06857602898736226 0.010493848811293977
# remaining size for Round 4: 135608
# Calculated size for Round 4: 6096.6259340153065
# {'LR__C': 0.01}
# orr termination 0.0026035909551541353 0.07373612471081846 0.07113253375566432
# remaining size for Round 5: 129512
# Calculated size for Round 5: 5735.887361334597
# {'LR__C': 0.01}
# orr termination 0.03364997603502802 0.06709065976727456 0.03344068373224654
# remaining size for last Round 6: 123777
# 57
# ['step1_rr: 56', 'step2_rr: 56', 'step3_rr: 56', 'step4_rr: 56', 'step5_rr: 56', 'step6_rr: 56']
# empirical response rate 0.05544800884955752
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4258.167580221075
# {'LR__C': 0.01}
# orr termination 0.014799772758485449 0.06704162278597468 0.05224185002748923
# remaining size for Round 3: 140894
# Calculated size for Round 3: 5153.419999526667
# {'LR__C': 0.01}
# orr termination 0.03753269494008056 0.07154262849716866 0.034009933557088104
# remaining size for Round 4: 135741
# Calculated size for Round 4: 8363.304609731435
# {'LR__C': 0.01}
# orr termination 0.03131519063850231 0.06880468509472978 0.03748949445622747
# remaining size for Round 5: 127378
# Calculated size for Round 5: 6797.587455212508
# {'LR__C': 0.01}
# orr termination 0.016014065196478265 0.0794708064497913 0.06345674125331305
# remaining size for last Round 6: 120581
# 58
# ['step1_rr: 57', 'step2_rr: 57', 'step3_rr: 57', 'step4_rr: 57', 'step5_rr: 57', 'step6_rr: 57']
# empirical response rate 0.05479120575221239
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4212.472895702519
# {'LR__C': 0.01}
# orr termination 0.0347308991208898 0.06760043643932334 0.03286953731843354
# remaining size for Round 3: 140940
# Calculated size for Round 3: 5919.637343186312
# {'LR__C': 0.1}
# orr termination 0.009285388043746571 0.08136773702908345 0.07208234898533689
# remaining size for Round 4: 135021
# Calculated size for Round 4: 6201.4895881210105
# {'LR__C': 0.01}
# orr termination 0.018703358226057176 0.07555175316446146 0.05684839493840428
# remaining size for Round 5: 128820
# 59
# ['step1_rr: 58', 'step2_rr: 58', 'step3_rr: 58', 'step4_rr: 58', 'step5_rr: 58', 'step6_rr: 58']
# empirical response rate 0.0537195796460177
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4138.04647448891
# {'LR__C': 0.1}
# orr termination 0.019302017587008523 0.06015229459975716 0.04085027701274864
# remaining size for Round 3: 141014
# Calculated size for Round 3: 6419.232526286228
# {'LR__C': 1.0}
# ...
# Calculated size for Round 5: 5913.797745223398
# {'LR__C': 0.01}
# orr termination 0.04956397091685669 0.07341503942189445 0.023851068505037765
# remaining size for last Round 6: 119424
# 81
# ['step1_rr: 80', 'step2_rr: 80', 'step3_rr: 80', 'step4_rr: 80', 'step5_rr: 80', 'step6_rr: 80']
# empirical response rate 0.05489491150442478
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4219.683881321882
# {'LR__C': 0.01}
# orr termination 0.016942117628791574 0.06602794986968158 0.049085832240890005
# remaining size for Round 3: 140933
# Calculated size for Round 3: 5176.551741753612
# {'LR__C': 1.0}
# orr termination 0.05416056082562447 0.06918623500872692 0.015025674183102453
# remaining size for Round 4: 135757
# Calculated size for Round 4: 7239.825481808656
# {'LR__C': 1.0}
# orr termination 0.038024021658452256 0.07157942140465073 0.03355539974619848
# remaining size for Round 5: 128518
# Calculated size for Round 5: 5961.537799533767
# {'LR__C': 0.01}
# orr termination 0.035759854424844556 0.07659493594069464 0.04083508151585008
# remaining size for last Round 6: 122557
# 82
# ['step1_rr: 81', 'step2_rr: 81', 'step3_rr: 81', 'step4_rr: 81', 'step5_rr: 81', 'step6_rr: 81']
# empirical response rate 0.0546529314159292
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4202.860561387483
# {'LR__C': 0.01}
# orr termination 0.025256635322340716 0.06578625888918588 0.04052962356684516
# remaining size for Round 3: 140950
# Calculated size for Round 3: 4935.302487717345
# {'LR__C': 1.0}
# orr termination 0.027597809148413477 0.074176193473841 0.04657838432542752
# remaining size for Round 4: 136015
# Calculated size for Round 4: 6043.376950660099
# {'LR__C': 0.01}
# orr termination 0.03183952002257933 0.06995829939307618 0.038118779370496854
# remaining size for Round 5: 129972
# Calculated size for Round 5: 7148.324042458761
# {'LR__C': 1.0}
# orr termination 0.047718108842271165 0.07253103931683365 0.024812930474562483
# remaining size for last Round 6: 122824
# 83
# ['step1_rr: 82', 'step2_rr: 82', 'step3_rr: 82', 'step4_rr: 82', 'step5_rr: 82', 'step6_rr: 82']
# empirical response rate 0.05441095132743363
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4186.045338423161
# {'LR__C': 0.01}
# orr termination 0.032153533343492725 0.06665767304344813 0.03450413969995541
# remaining size for Round 3: 140966
# Calculated size for Round 3: 5093.700846903786
# {'LR__C': 0.01}
# orr termination 0.024159487247719977 0.07583703053564851 0.051677543287928535
# remaining size for Round 4: 135873
# Calculated size for Round 4: 6351.445181979568
# {'LR__C': 1.0}
# orr termination 0.004065852165070592 0.07904528812725056 0.07497943596217997
# remaining size for Round 5: 129522
# 84
# ['step1_rr: 83', 'step2_rr: 83', 'step3_rr: 83', 'step4_rr: 83', 'step5_rr: 83', 'step6_rr: 83']
# empirical response rate 0.05513689159292035
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4236.515296599448
# {'LR__C': 1.0}
# orr termination 0.02011017185847699 0.07104762081363733 0.050937448955160336
# remaining size for Round 3: 140916
# Calculated size for Round 3: 8241.797821579992
# {'LR__C': 0.01}
# orr termination 0.015821456302471986 0.059119983339885857 0.04329852703741387
# remaining size for Round 4: 132675
# 85
# ['step1_rr: 84', 'step2_rr: 84', 'step3_rr: 84', 'step4_rr: 84', 'step5_rr: 84', 'step6_rr: 84']
# empirical response rate 0.05513689159292035
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4236.515296599448
# {'LR__C': 0.01}
# orr termination 0.050404220986161444 0.06722095215254945 0.016816731166388002
# remaining size for Round 3: 140916
# Calculated size for Round 3: 5942.505021346307
# {'LR__C': 0.1}
# orr termination 0.05975414714340034 0.0705931098657386 0.010838962722338266
# remaining size for Round 4: 134974
# Calculated size for Round 4: 5782.969104676285
# {'LR__C': 1.0}
# orr termination 0.023786630811508176 0.07603435259064514 0.05224772177913697
# remaining size for Round 5: 129192
# Calculated size for Round 5: 5607.210342974238
# {'LR__C': 0.1}
# orr termination 0.01170709123261885 0.0826825289524547 0.07097543771983586
# remaining size for last Round 6: 123585
# 86
# ['step1_rr: 85', 'step2_rr: 85', 'step3_rr: 85', 'step4_rr: 85', 'step5_rr: 85', 'step6_rr: 85']
# empirical response rate 0.054134402654867256
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4166.8378574712715
# {'LR__C': 1.0}
# orr termination 0.052394050798109854 0.06402829568064122 0.01163424488253137
# remaining size for Round 3: 140986
# Calculated size for Round 3: 5000.439112866107
# {'LR__C': 1.0}
# orr termination 0.04148626585054446 0.06769956995179578 0.02621330410125132
# remaining size for Round 4: 135986
# Calculated size for Round 4: 4951.983063473102
# {'LR__C': 1.0}
# orr termination 0.015047828515819008 0.07344413224503206 0.05839630372921305
# remaining size for Round 5: 131035
# Calculated size for Round 5: 5692.20427361819
# {'LR__C': 0.01}
# orr termination 0.011666402234093178 0.06971856115335175 0.058052158919258565
# remaining size for last Round 6: 125343
# 87
# ['step1_rr: 86', 'step2_rr: 86', 'step3_rr: 86', 'step4_rr: 86', 'step5_rr: 86', 'step6_rr: 86']
# empirical response rate 0.05534430309734513
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4250.948665966841
# {'LR__C': 1.0}
# orr termination 0.027829423281432165 0.0721614696853069 0.04433204640387474
# remaining size for Round 3: 140902
# Calculated size for Round 3: 5356.4829694968585
# {'LR__C': 0.01}
# orr termination 0.021550575664081174 0.07526453202666021 0.053713956362579036
# remaining size for Round 4: 135546
# Calculated size for Round 4: 6838.03706945298
# {'LR__C': 1.0}
# orr termination 0.019213493920467443 0.07698925674741042 0.057775762826942974
# remaining size for Round 5: 128708
# Calculated size for Round 5: 7329.114477170552
# {'LR__C': 0.01}
# orr termination 0.047273476230548755 0.07150110582435239 0.024227629593803632
# remaining size for last Round 6: 121379
# 88
# ['step1_rr: 87', 'step2_rr: 87', 'step3_rr: 87', 'step4_rr: 87', 'step5_rr: 87', 'step6_rr: 87']
# empirical response rate 0.05527516592920354
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4246.136882198541
# {'LR__C': 1.0}
# orr termination 0.06358649298842017 0.06676417414878517 0.0031776811603650007
# remaining size for Round 3: 140906
# Calculated size for Round 3: 5400.089668873218
# {'LR__C': 1.0}
# orr termination 0.038930116927871315 0.07437687627531074 0.035446759347439426
# remaining size for Round 4: 135506
# Calculated size for Round 4: 5160.511054202908
# {'LR__C': 1.0}
# orr termination 0.006652613797599563 0.08309331291369318 0.07644069911609362
# remaining size for Round 5: 130346
# Calculated size for Round 5: 6005.339380352811
# {'LR__C': 0.01}
# orr termination 0.03602112725059747 0.07127844831582072 0.03525732106522325
# remaining size for last Round 6: 124341
# 89
# ['step1_rr: 88', 'step2_rr: 88', 'step3_rr: 88', 'step4_rr: 88', 'step5_rr: 88', 'step6_rr: 88']
# empirical response rate 0.054618362831858405
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4200.457890907699
# {'LR__C': 0.01}
# orr termination 0.004076171395080786 0.06590729451160013 0.061831123116519345
# remaining size for Round 3: 140952
# 90
# ['step1_rr: 89', 'step2_rr: 89', 'step3_rr: 89', 'step4_rr: 89', 'step5_rr: 89', 'step6_rr: 89']
# empirical response rate 0.05403069690265487
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4159.637779672868
# {'LR__C': 0.01}
# orr termination 0.007286949126537188 0.07229492068958202 0.06500797156304483
# remaining size for Round 3: 140993
# Calculated size for Round 3: 9299.371978319505
# {'LR__C': 0.01}
# orr termination 0.03752610406477604 0.07426794869557189 0.03674184463079585
# remaining size for Round 4: 131694
# 91
# ['step1_rr: 90', 'step2_rr: 90', 'step3_rr: 90', 'step4_rr: 90', 'step5_rr: 90', 'step6_rr: 90']
# empirical response rate 0.05596653761061947
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4294.284441919237
# {'LR__C': 0.1}
# orr termination 0.05644503133945589 0.07062526646342702 0.014180235123971138
# remaining size for Round 3: 140858
# Calculated size for Round 3: 5416.727789972042
# {'LR__C': 1.0}
# orr termination 0.024579699910314314 0.08099889306150393 0.056419193151189616
# remaining size for Round 4: 135442
# Calculated size for Round 4: 5598.851954690705
# {'LR__C': 1.0}
# orr termination 0.047402712519550076 0.07678029209387575 0.029377579574325678
# remaining size for Round 5: 129844
# Calculated size for Round 5: 7409.476637441421
# {'LR__C': 0.01}
# orr termination 0.004915000083183817 0.07762182710890202 0.07270682702571821
# remaining size for last Round 6: 122435
# 92
# ['step1_rr: 91', 'step2_rr: 91', 'step3_rr: 91', 'step4_rr: 91', 'step5_rr: 91', 'step6_rr: 91']
# empirical response rate 0.051991150442477874
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4018.338787935027
# {'LR__C': 1.0}
# orr termination 0.024885881097307612 0.07520317037532426 0.050317289278016646
# remaining size for Round 3: 141134
# Calculated size for Round 3: 6795.6046411653715
# {'LR__C': 0.01}
# orr termination 0.04180992726731083 0.0711193861443564 0.029309458877045565
# remaining size for Round 4: 134339
# Calculated size for Round 4: 7850.585608792045
# {'LR__C': 1.0}
# orr termination 0.0103590032256032 0.0836711651879085 0.0733121619623053
# remaining size for Round 5: 126489
# 93
# ['step1_rr: 92', 'step2_rr: 92', 'step3_rr: 92', 'step4_rr: 92', 'step5_rr: 92', 'step6_rr: 92']
# empirical response rate 0.05596653761061947
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4294.284441919237
# {'LR__C': 0.01}
# orr termination 0.051367008419362245 0.06579158352960801 0.014424575110245766
# remaining size for Round 3: 140858
# Calculated size for Round 3: 5290.000651291593
# {'LR__C': 1.0}
# orr termination 0.008560256174814769 0.0786271242274997 0.07006686805268494
# remaining size for Round 4: 135568
# Calculated size for Round 4: 5311.011208055901
# {'LR__C': 0.01}
# orr termination 0.03839697548905738 0.0770850076900991 0.03868803220104172
# remaining size for Round 5: 130257
# Calculated size for Round 5: 11068.13966197127
# {'LR__C': 0.01}
# orr termination 0.029876700642860597 0.0735468105019459 0.04367010985908531
# remaining size for last Round 6: 119189
# 94
# ['step1_rr: 93', 'step2_rr: 93', 'step3_rr: 93', 'step4_rr: 93', 'step5_rr: 93', 'step6_rr: 93']
# empirical response rate 0.05434181415929203
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4181.242476429084
# {'LR__C': 0.01}
# orr termination 0.043518799517473776 0.07348448792423042 0.02996568840675664
# remaining size for Round 3: 140971
# Calculated size for Round 3: 8140.958241449511
# {'LR__C': 1.0}
# orr termination 0.010531106643664398 0.07248417234069335 0.06195306569702895
# remaining size for Round 4: 132831
# Calculated size for Round 4: 6248.35831496403
# {'LR__C': 0.1}
# orr termination 0.024202538638225305 0.07236266722834231 0.04816012859011701
# remaining size for Round 5: 126583
# 95
# ['step1_rr: 94', 'step2_rr: 94', 'step3_rr: 94', 'step4_rr: 94', 'step5_rr: 94', 'step6_rr: 94']
# empirical response rate 0.05489491150442478
# {'LR__C': 0.1}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4219.683881321882
# {'LR__C': 0.01}
# orr termination 0.007667881533175402 0.06732187736607981 0.059653995832904406
# remaining size for Round 3: 140933
# Calculated size for Round 3: 5036.175275656907
# {'LR__C': 0.01}
# orr termination 0.014450682747709543 0.07751186267434906 0.06306117992663952
# remaining size for Round 4: 135897
# Calculated size for Round 4: 10247.82912604345
# {'LR__C': 0.1}
# orr termination 0.04829344664542623 0.07172567827041604 0.023432231624989808
# remaining size for Round 5: 125650
# Calculated size for Round 5: 6925.840617850817
# {'LR__C': 0.01}
# orr termination 0.03489940792906629 0.07033968043520515 0.03544027250613886
# remaining size for last Round 6: 118725
# 96
# ['step1_rr: 95', 'step2_rr: 95', 'step3_rr: 95', 'step4_rr: 95', 'step5_rr: 95', 'step6_rr: 95']
# empirical response rate 0.057280143805309734
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4385.946667669806
# {'LR__C': 0.1}
# orr termination 0.03731459523256393 0.07287805112874668 0.03556345589618275
# remaining size for Round 3: 140767
# Calculated size for Round 3: 5383.207205329378
# {'LR__C': 1.0}
# orr termination 0.011176601547961278 0.08355139244670651 0.07237479089874523
# remaining size for Round 4: 135384
# Calculated size for Round 4: 6091.445751203855
# {'LR__C': 0.01}
# orr termination 0.01735978048474831 0.07157760884971948 0.05421782836497117
# remaining size for Round 5: 129293
# Calculated size for Round 5: 8940.594468394991
# {'LR__C': 0.01}
# orr termination 0.03461905949941786 0.06923294185779656 0.0346138823583787
# remaining size for last Round 6: 120353
# 97
# ['step1_rr: 96', 'step2_rr: 96', 'step3_rr: 96', 'step4_rr: 96', 'step5_rr: 96', 'step6_rr: 96']
# empirical response rate 0.05482577433628318
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4214.876392356589
# {'LR__C': 1.0}
# orr termination 0.040829753038358604 0.06944265117931121 0.02861289814095261
# remaining size for Round 3: 140938
# Calculated size for Round 3: 5001.169538304005
# {'LR__C': 1.0}
# orr termination 0.01994772272473147 0.0764686896617945 0.05652096693706303
# remaining size for Round 4: 135937
# Calculated size for Round 4: 5671.765519089534
# {'LR__C': 0.01}
# orr termination 0.04532231665803405 0.07175529484603167 0.02643297818799762
# remaining size for Round 5: 130266
# Calculated size for Round 5: 7890.264920981903
# {'LR__C': 0.01}
# orr termination 0.037059287570302274 0.07433463955005867 0.0372753519797564
# remaining size for last Round 6: 122376
# 98
# ['step1_rr: 97', 'step2_rr: 97', 'step3_rr: 97', 'step4_rr: 97', 'step5_rr: 97', 'step6_rr: 97']
# empirical response rate 0.0546529314159292
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4202.860561387483
# {'LR__C': 0.01}
# orr termination 0.0021109984361675597 0.06811789113605912 0.06600689269989156
# remaining size for Round 3: 140950
# Calculated size for Round 3: 5873.949099195651
# {'LR__C': 0.01}
# orr termination 0.032915958177724275 0.06618182556576356 0.033265867388039286
# remaining size for Round 4: 135077
# 99
# ['step1_rr: 98', 'step2_rr: 98', 'step3_rr: 98', 'step4_rr: 98', 'step5_rr: 98', 'step6_rr: 98']
# empirical response rate 0.053512168141592924
# {'LR__C': 1.0}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4123.659712438602
# {'LR__C': 1.0}
# orr termination 0.019928293230676318 0.0697589458240355 0.04983065259335918
# remaining size for Round 3: 141029
# Calculated size for Round 3: 4951.633710628407
# {'LR__C': 1.0}
# orr termination 0.041419192549822806 0.07832836093229138 0.03690916838246858
# remaining size for Round 4: 136078
# Calculated size for Round 4: 7904.116504420597
# {'LR__C': 0.01}
# orr termination 0.03709247593533321 0.07817569195503007 0.04108321601969686
# remaining size for Round 5: 128174
# Calculated size for Round 5: 7214.179390014318
# {'LR__C': 0.1}
# orr termination 0.05827760732115028 0.07801199103730645 0.01973438371615617
# remaining size for last Round 6: 120960
# 100
# ['step1_rr: 99', 'step2_rr: 99', 'step3_rr: 99', 'step4_rr: 99', 'step5_rr: 99', 'step6_rr: 99']
# empirical response rate 0.055517146017699116
# {'LR__C': 0.01}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4262.981015401587
# {'LR__C': 1.0}
# orr termination 0.04520058596367311 0.06848592234344544 0.023285336379772335
# remaining size for Round 3: 140890
# Calculated size for Round 3: 5197.772781653086
# {'LR__C': 1.0}
# orr termination 0.06038851396186576 0.06962572672041714 0.009237212758551383
# remaining size for Round 4: 135693
# Calculated size for Round 4: 5571.574193981027
# {'LR__C': 1.0}
# orr termination 0.053886881719999086 0.06820228524499275 0.014315403524993664
# remaining size for Round 5: 130122
# Calculated size for Round 5: 5365.28011682024
# {'LR__C': 1.0}
# orr termination 0.02343162751885438 0.07876041440273554 0.05532878688388116
# remaining size for last Round 6: 124757

# %% [markdown]
# ### Results summary

# %%
rr_df = pd.DataFrame(rr_dict)
rr_df
# Out:
#     step1_rr  step2_rr  step3_rr  step4_rr  step5_rr  step6_rr
# 0      0.055  0.064535  0.068471  0.068471       NaN       NaN
# 1      0.055  0.061733  0.064146  0.068471  0.068471  0.068471
# 2      0.055  0.061287  0.065467  0.065890  0.068471  0.068471
# 3      0.055  0.064290  0.067729  0.068471  0.068471  0.068471
# 4      0.055  0.061436  0.068471  0.068471  0.068471  0.068471
# ..       ...       ...       ...       ...       ...       ...
# 95     0.055  0.061533  0.065446  0.068471  0.068471  0.068471
# 96     0.055  0.061175  0.065854  0.068471  0.068471  0.068471
# 97     0.055  0.061737  0.068471  0.068471       NaN       NaN
# 98     0.055  0.061193  0.068471  0.068471  0.068471  0.068471
# 99     0.055  0.061836  0.065092  0.064697  0.065825  0.068471
#
# [100 rows x 6 columns]

# %%
# Calculate average rounds:
row_non_nan_counts = rr_df.count(axis=1)

print(f"{np.mean(row_non_nan_counts):.1f} ({np.std(row_non_nan_counts):.1f})")
# Out:
# 5.5 (0.8)

# %%
# orr for each round:
result_dict = {}
for key, values in rr_df.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"

for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_rr: 0.055 (0.000)
# step2_rr: 0.061 (0.002)
# step3_rr: 0.066 (0.003)
# step4_rr: 0.067 (0.003)
# step5_rr: 0.068 (0.002)
# step6_rr: 0.068 (0.002)

# %%
# overall orr:
result_dict = np.array(orr_total) / total_n
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f}, StD: {std_result:.3f}")
# Out:
# Mean: 0.066, StD: 0.002

# %%
# better chance
np.mean([binomtest(int(x), n=total_n, p=0.055).pvalue < 0.05 for x in orr_total])
# Out:
# 0.96

# %%
# highest true rr:
mean_result=(np.mean(highest_true_rr))
std_result=(np.std(highest_true_rr))
print(f"Mean: {mean_result:.3f} ({std_result:.3f})")
# Out:
# Mean: 0.068 (0.000)

# %%
result_dict = np.array(orr_total_adaptive) / (total_n-34976)
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f}, StD: {std_result:.3f}")
# Out:
# Mean: 0.071, StD: 0.003

# %%
# average plan number for each round:
result_dict = {}
for key, values in plan_number_dict.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.1f} ({std_value:.1f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_plan_number: nan (nan)
# step2_plan_number: 93.4 (41.0)
# step3_plan_number: 43.0 (33.8)
# step4_plan_number: 16.2 (18.1)
# step5_plan_number: 6.2 (8.3)
# step6_plan_number: 2.3 (2.4)

# %%
# early stopping probabilities:
means = {key: np.mean(values) for key, values in stopping_dict.items()}
means
# Out:
# {'early_stopping': 0.31,
#  'early_stopping_plan': 0.31,
#  'early_stopping_orr': 0.0,
#  'early_stopping_size': 0.0}

# %%
# sample size for the last round:
print(np.mean(last_round_sample_size), np.std(last_round_sample_size))
# Out:
# 124136.01 4840.649331432715

# %%
# sample size for the last round:
np.mean(better_chance)
# Out:
# 0.96

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in sample_size_dict.items():
    mean_value = np.nanmean(values)
    std_value = np.nanstd(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_sample_size: 28928.000 (0.000)
# step2_sample_size: 4217.873 (88.452)
# step3_sample_size: 8557.131 (18943.585)
# step4_sample_size: 19836.461 (38239.027)
# step5_sample_size: 32977.896 (49233.014)
# step6_sample_size: 121621.043 (2016.705)

# %% [markdown]
# ## Random Forest

# %%
def ensemble_model_fit(data, data_pred):
    X_train, X_test, y_train, y_test = train_test_split(
        data.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1),
        data['response'],
        test_size=0.2,
        random_state=0
    )

    # Define the VotingClassifier with the individual classifiers
    voting_classifier = ensemble.VotingClassifier(
        estimators=[
            # ('LR', linear_model.LogisticRegression(max_iter=200, random_state=0))
#             ('Ridge', linear_model.LogisticRegression(penalty='l2', solver='lbfgs', max_iter=200, random_state=0))
                    # ('SVM', svm.SVC(kernel='linear', C=1.0, random_state=0, probability=True, class_weight='balanced'))
                    ('RF', ensemble.RandomForestClassifier(criterion='gini', random_state=0))
                    # ('XGB', XGBClassifier(n_estimators=50, learning_rate=0.1, random_state=0))
                   ],
        voting='soft'
    )

    # Define the hyperparameter grid to search
    # Best Hyperparameters: {'LR__C': 0.01, 'RF__n_estimators': 50, 'XGB__n_estimators': 50}
    param_grid = {
        # 'NB__alpha': [0.01, 0.05, 0.1],  # '__' is used to specify hyperparameters for individual classifiers
        # 'LR__C': [0.01] # [0.01, 0.05, 0.1]
        # 'Ridge__C': [0.01]
        # 'SVM__C': [0.01, 0.05, 0.1]
        'RF__n_estimators': [50, 100, 200]
#         'RF__max_depth': [10, 20, None]
        # 'XGB__n_estimators': [50]
    }

    # Create a GridSearchCV object
    # custom_scorer_auc = make_scorer(roc_auc_score, needs_proba=True)
    grid_search = GridSearchCV(voting_classifier, param_grid, cv=10, scoring='roc_auc')

    # Perform the grid search on the training data
    grid_search.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = grid_search.best_params_
    print(best_params)

    # Train the final VotingClassifier with the best hyperparameters on the full training set
    final_voting_classifier = grid_search.best_estimator_
    final_voting_classifier.fit(X_train, y_train)

    # Predict probabilities instead of binary outcomes on the test set
    y_pred_proba_test = final_voting_classifier.predict_proba(X_test)
    y_pred_test = final_voting_classifier.predict(X_test)
    X_dt = data_pred.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1)
    y_pred = final_voting_classifier.predict_proba(X_dt)

    return y_pred

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import train_test_split

# def ensemble_model_fit(data, data_pred):
#     # Split the data into training and testing sets
#     X_train, X_test, y_train, y_test = train_test_split(
#         data.drop(['recruitment_plan', 'plan_response_rate', 'group_size','response'], axis=1),
#         data['response'],
#         test_size=0.2,
#         random_state=0
#     )

#     # Define the Logistic Regression model
#     logistic_regression = LogisticRegression(C=0.01, max_iter=200,random_state=0)

#     # Fit the Logistic Regression model on the training data
#     logistic_regression.fit(X_train, y_train)

#     # Print out the coefficients of the logistic regression model
#     print("Coefficients:", logistic_regression.coef_)
#     print("Intercept:", logistic_regression.intercept_)
#     print("Coefficients shape:", logistic_regression.coef_.shape)

#     # Predict probabilities instead of binary outcomes on the test set
#     y_pred_proba_test = logistic_regression.predict_proba(X_test)
#     y_pred_test = logistic_regression.predict(X_test)

#     # You can also predict probabilities for the prediction data (data_pred)
#     X_dt = data_pred.drop(['recruitment_plan', 'plan_response_rate', 'group_size','response'], axis=1)
#     y_pred = logistic_regression.predict_proba(X_dt)

#     return y_pred

# # Call the function
# # ensemble_model_fit(data, data_pred)

# %% [markdown]
# ### Simulation starts

# %%
n_sim = 100
# create a list of random seeds
random.seed(42)
random_seeds = [random.randint(1, 100000) for _ in range(n_sim)]

design_list = [5,8,10]
patient_n_list = [5468,680,170] # n_patient_per_plan

n_design = 8
n_patient_per_plan = 680
n_rounds = 6
total_n = n_patient_per_plan * (2**n_design)

## sample size determination
beta = 0.2
power = 1 - beta
alpha = 0.05
delta = 0.01 # effect size

## early stopping
epsilon = 0.001

# %%
rr_dict = {"step{}_rr".format(r): [] for r in range(1, n_rounds + 1)}
plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
sample_size_dict = {"step{}_sample_size".format(r): [] for r in range(1, n_rounds + 1)}
last_round_sample_size = []
random_rr_dict = {"step{}_random_max_rr".format(r): [] for r in range(1, n_rounds + 1)}
random_rr_dict.update({
    "step{}_random_mean_rr".format(r): [] for r in range(1, n_rounds + 1)
})

stopping_dict = {"early_stopping": [],
                 "early_stopping_plan":[],
                 "early_stopping_orr":[],
                 "early_stopping_size":[]}
final_plan_number = []
highest_rr_overall = []

better_chance = []

orr_total = []
orr_total_adaptive = []



i = 0

for seed in random_seeds:
    i += 1
    print(i)

    print([f"{key}: {len(value)}" for key, value in rr_dict.items()])



    event_list = 0
    event_list_adaptive = 0
    max_rr = []

    # step 1:
    ## Generate dataset
    dt_design_5 = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed)
    print("empirical response rate", dt_design_5['response'].mean())
    ## save for benchmark results
    maxidx = np.argmax(dt_design_5['plan_response_rate'])
    random_rr_dict['step1_random_max_rr'].append(dt_design_5.iloc[maxidx,6])
    random_rr_dict['step1_random_mean_rr'].append(dt_design_5['plan_response_rate'].mean())

    ## Ensemble modelling:
    y_pred = ensemble_model_fit(data=dt_design_5, data_pred = dt_design_5)

    ## select recruitment plan
    pred_df = pd.DataFrame(np.hstack((dt_design_5,  y_pred[:, 1].reshape(-1, 1))),
                             columns=list(dt_design_5.columns) + ['predicted_response_rate'])
    pred_df_rr = pred_df.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

    x = pred_df_rr['predicted_response_rate'].values
    if len(x) <= 10:
        best_k = 2
    else:
        best_k = kmeans_fit(data = x)['best_k']
    kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

    merged_df = pd.merge(pred_df_rr, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
    cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
    highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
    highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)


    p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))
    highest_cluster['p_vec'] = p_vec_next
    highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

    # highest_cluster = pred_df_rr

    # highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')
    # highest_cluster['cluster_number'] = highest_cluster['recruitment_plan']

    ## prepare to chance of better performance:
    temp = dt_design_5[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
    event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print("step1", np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print(temp)
    p0 = (temp['plan_response_rate'].mean())

    rr_dict["step1_rr"].append(dt_design_5['plan_response_rate'].mean())
    sample_size_dict["step1_sample_size"].append(len(dt_design_5))

    for round in range(2, n_rounds+1):

        rr_dict["step"+str(round)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))
        plan_number_dict["step"+str(round)+"_plan_number"].append(len(p_vec_next))

        ## when it comes to the last round:
        if round == n_rounds:

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            if round == 2: # if the last round is round 2
                remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
            else:
                remaining_size -= len(dt_design_5_step2up)

            print("remaining size for last Round " + str(round) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            ## data generation, combine previous data:
            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, round=round,
                                                          design_number = n_design, n_rounds = n_rounds,
                                                          n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(0)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(len(temp), temp['plan_response_rate'].mean())
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break



        ## If haven't reached the last round:
        ## check remaining sample size:
        if round == 2:
            remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
        else:
            remaining_size -= len(dt_design_5_step2up)

        print("remaining size for Round " + str(round) + ": " + str(remaining_size))

        ## determine whether move on to step 2:
        if len(highest_cluster) == 1: # if there is only one plan left

            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size) # record the last round sample size
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(1)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        ## sample size determination:
        if round == 2:
            dt_design_5_step2up_overall = dt_design_5
        orr_1 = dt_design_5_step2up_overall['response'].mean() # observed overall response rates for previous rounds
        orr_2 = orr_1 + delta
        n_1 = len(dt_design_5_step2up_overall)

        size_step2up = sample_size_calc(orr_1, n_1, delta=delta, alpha=alpha, power=power) # total size for dataset
        if size_step2up > 0 and size_step2up < 1000:
            size_step2up = 1000 # if size in [0,1000], then it is 1000 for this round.
        elif size_step2up >= 1000:
            size_step2up = min(size_step2up, int(total_n/n_rounds)) # dataset size capped by the n_patient_per_plan
        else:
        # if size_step2up <= 0:
            # the process stops at this step
            print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up) + 'lt 0, break')
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(1)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up))

        sample_size_dict["step"+str(round)+"_sample_size"].append(size_step2up)

        ## save benchmark results for last round:
        dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                            n_patient_per_plan = n_patient_per_plan, seed=seed+round)
        maxidx = np.argmax(dt_benchmark['plan_response_rate'])
        random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
        random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

        ## data generation, combine previous data:
        dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                  design_number = n_design, n_rounds = n_rounds,
                                                  n_patient_per_plan = n_patient_per_plan, size = int(size_step2up), seed=seed)

        plan_list = dt_design_5_step2up['recruitment_plan'].unique()
        if round == 2:
            supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)]
        else:
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
        dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
        dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

        ## Ensemble model fitting:
        dt_design_5_step2up.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)
        y_pred2up = ensemble_model_fit(data = dt_design_5_step2up_overall, data_pred = dt_design_5_step2up)
        pred_df_step2up = pd.DataFrame(np.hstack((dt_design_5_step2up,  y_pred2up[:, 1].reshape(-1, 1))),
                                    columns=list(dt_design_5_step2up.columns) + ['predicted_response_rate'])
        pred_df_rr_step2up = pred_df_step2up.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

        ## select recruitment plans:
        x = pred_df_rr_step2up['predicted_response_rate'].values

        if len(x) <= 10:
            best_k = 2
        else:
            best_k = kmeans_fit(data = x)['best_k']
        kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

        ## match the cluster results back to the original data
        highest_cluster_previous = highest_cluster # save previous cluster results

        merged_df = pd.merge(pred_df_rr_step2up, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
        cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
        highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
        highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)

        # p_vec_previous = p_vec_next # save p_vec of previous round
        p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))

        highest_cluster['p_vec'] = p_vec_next

        highest_cluster = pd.merge(highest_cluster, dt_design_5_step2up[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

        ## prepare to chance of better performance:
        temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
        event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print(temp)

        ## check early stopping predicted ORR:
        orr_df = pd.merge(highest_cluster_previous, highest_cluster[['recruitment_plan','predicted_response_rate','p_vec']], on='recruitment_plan', how='left')
        orr_df.fillna(0, inplace=True)
        p_orr_1 = np.dot(np.array(orr_df['p_vec_x']), np.array(orr_df['predicted_response_rate_y']))
        p_orr_2 = np.dot(np.array(orr_df['p_vec_y']), np.array(orr_df['predicted_response_rate_y']))
        print("orr termination", p_orr_1, p_orr_2, p_orr_2 - p_orr_1)

        if (p_orr_2 - p_orr_1 < epsilon):
            # step 3 use the same strategy of step2
            print(i, p_orr_1, p_orr_2, "early stop at Round " + str(round))
            rr_dict["step"+str(round+1)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                                n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round+1)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round+1)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            ### update remaining size:
            remaining_size -= len(dt_design_5_step2up)
            print("early stop, remaining size for Round" + str(round + 1) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            for r in range(round+2, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(1)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            for r in range(round+2, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round+1), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break
# Out:
# 1
# ['step1_rr: 0', 'step2_rr: 0', 'step3_rr: 0', 'step4_rr: 0', 'step5_rr: 0', 'step6_rr: 0']
# empirical response rate 0.05295907079646018
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4085.324125976102
# {'RF__n_estimators': 100}
# orr termination 0.048293184326750345 0.08368479062356582 0.035391606296815474
# remaining size for Round 3: 141067
# Calculated size for Round 3: 9881.299459027116
# {'RF__n_estimators': 100}
# orr termination 0.03583852627335993 0.07703158419021709 0.041193057916857165
# remaining size for Round 4: 131186
# Calculated size for Round 4: 6235.480974022526
# {'RF__n_estimators': 200}
# orr termination 0.018977860891060884 0.07944314900211277 0.06046528811105189
# remaining size for Round 5: 124951
# Calculated size for Round 5: 6710.104801605472
# {'RF__n_estimators': 50}
# orr termination 0.03893929786771238 0.07661048378864778 0.0376711859209354
# remaining size for last Round 6: 118241
# 2
# ['step1_rr: 1', 'step2_rr: 1', 'step3_rr: 1', 'step4_rr: 1', 'step5_rr: 1', 'step6_rr: 1']
# empirical response rate 0.056312223451327435
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4318.382983229351
# {'RF__n_estimators': 200}
# orr termination 0.010135943846401641 0.11056531378596932 0.10042936993956768
# remaining size for Round 3: 140834
# Calculated size for Round 3: 5373.6791189733085
# {'RF__n_estimators': 50}
# orr termination 0.05852328703697941 0.07573011812709213 0.017206831090112715
# remaining size for Round 4: 135461
# Calculated size for Round 4: 12384.742578981843
# {'RF__n_estimators': 50}
# orr termination 0.05945758556604226 0.06833802394512221 0.008880438379079952
# remaining size for Round 5: 123077
# Calculated size for Round 5: 5618.017500042049
# {'RF__n_estimators': 50}
# orr termination 0.047832876707974245 0.07042466361543943 0.02259178690746519
# remaining size for last Round 6: 117459
# 3
# ['step1_rr: 2', 'step2_rr: 2', 'step3_rr: 2', 'step4_rr: 2', 'step5_rr: 2', 'step6_rr: 2']
# empirical response rate 0.053650442477876106
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4133.2502256140915
# {'RF__n_estimators': 50}
# orr termination 0.009016517181529023 0.11051734197683244 0.10150082479530342
# remaining size for Round 3: 141019
# Calculated size for Round 3: 4502.662272252863
# {'RF__n_estimators': 200}
# orr termination 0.019168874298563857 0.08313241054235715 0.06396353624379329
# remaining size for Round 4: 136517
# Calculated size for Round 4: 12427.086141900814
# {'RF__n_estimators': 100}
# orr termination 0.048785015183304255 0.07048633272461814 0.021701317541313887
# remaining size for Round 5: 124090
# Calculated size for Round 5: 5726.3418282983175
# {'RF__n_estimators': 50}
# orr termination 0.03667775993577806 0.0726924290835527 0.03601466914777463
# remaining size for last Round 6: 118364
# 4
# ['step1_rr: 3', 'step2_rr: 3', 'step3_rr: 3', 'step4_rr: 3', 'step5_rr: 3', 'step6_rr: 3']
# empirical response rate 0.05437638274336283
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4183.643824785205
# {'RF__n_estimators': 200}
# orr termination 0.026163535574165717 0.09648054954225294 0.07031701396808722
# remaining size for Round 3: 140969
# Calculated size for Round 3: 6409.269077680623
# {'RF__n_estimators': 100}
# orr termination 0.043528680896137734 0.07885804970553571 0.03532936880939798
# remaining size for Round 4: 134560
# Calculated size for Round 4: 7695.377555258512
# {'RF__n_estimators': 50}
# orr termination 0.007996768578990069 0.08891642436141456 0.0809196557824245
# remaining size for Round 5: 126865
# 5
# ['step1_rr: 4', 'step2_rr: 4', 'step3_rr: 4', 'step4_rr: 4', 'step5_rr: 4', 'step6_rr: 4']
# empirical response rate 0.05530973451327434
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4248.542691505998
# {'RF__n_estimators': 100}
# orr termination 0.025524887305867473 0.09667421636214346 0.071149329056276
# remaining size for Round 3: 140904
# Calculated size for Round 3: 5056.052727844807
# {'RF__n_estimators': 100}
# orr termination 0.002809164841851373 0.11588040629108497 0.1130712414492336
# remaining size for Round 4: 135848
# 6
# ['step1_rr: 5', 'step2_rr: 5', 'step3_rr: 5', 'step4_rr: 5', 'step5_rr: 5', 'step6_rr: 5']
# empirical response rate 0.05361587389380531
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4130.852349241689
# {'RF__n_estimators': 50}
# orr termination 0.01449311614229238 0.10233640634012162 0.08784329019782924
# remaining size for Round 3: 141022
# Calculated size for Round 3: 5396.14423374068
# {'RF__n_estimators': 100}
# orr termination 0.013641903685267623 0.10145087994760955 0.08780897626234194
# remaining size for Round 4: 135626
# Calculated size for Round 4: 9562.491625125827
# {'RF__n_estimators': 200}
# orr termination 0.03582817705878776 0.06920284223452161 0.03337466517573385
# remaining size for Round 5: 126064
# 7
# ['step1_rr: 6', 'step2_rr: 6', 'step3_rr: 6', 'step4_rr: 6', 'step5_rr: 6', 'step6_rr: 6']
# empirical response rate 0.05330475663716814
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4109.278904649849
# {'RF__n_estimators': 50}
# orr termination 0.029504293642651173 0.08844925523370945 0.058944961591058276
# remaining size for Round 3: 141043
# Calculated size for Round 3: 5822.970166395025
# {'RF__n_estimators': 50}
# orr termination 0.017953898133264895 0.08935630955999974 0.07140241142673484
# remaining size for Round 4: 135221
# Calculated size for Round 4: 7286.434423428252
# {'RF__n_estimators': 50}
# orr termination 0.0558045790636324 0.07823936727235428 0.022434788208721884
# remaining size for Round 5: 127935
# Calculated size for Round 5: 8918.721364801691
# {'RF__n_estimators': 50}
# orr termination 0.03333546906589734 0.08194600458606263 0.04861053552016529
# remaining size for last Round 6: 119017
# 8
# ['step1_rr: 7', 'step2_rr: 7', 'step3_rr: 7', 'step4_rr: 7', 'step5_rr: 7', 'step6_rr: 7']
# empirical response rate 0.055724557522123894
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4277.425283765311
# {'RF__n_estimators': 50}
# orr termination 0.02666660581913579 0.06987371503334196 0.04320710921420617
# remaining size for Round 3: 140875
# Calculated size for Round 3: 23557.28730301786
# {'RF__n_estimators': 50}
# orr termination 0.03318939131830504 0.06624013595546786 0.03305074463716282
# remaining size for Round 4: 117318
# 9
# ['step1_rr: 8', 'step2_rr: 8', 'step3_rr: 8', 'step4_rr: 8', 'step5_rr: 8', 'step6_rr: 8']
# empirical response rate 0.05676161504424779
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4349.735755102456
# {'RF__n_estimators': 100}
# orr termination 0.01702250496650586 0.08886462237441375 0.0718421174079079
# remaining size for Round 3: 140803
# Calculated size for Round 3: 17450.81912168399
# {'RF__n_estimators': 50}
# orr termination 0.04819012072011146 0.07112603325580039 0.022935912535688927
# remaining size for Round 4: 123353
# Calculated size for Round 4: 5566.621034460658
# {'RF__n_estimators': 200}
# orr termination 0.03683049343483587 0.07147687364250287 0.034646380207667
# remaining size for Round 5: 117787
# 10
# ['step1_rr: 9', 'step2_rr: 9', 'step3_rr: 9', 'step4_rr: 9', 'step5_rr: 9', 'step6_rr: 9']
# empirical response rate 0.053650442477876106
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4133.2502256140915
# {'RF__n_estimators': 200}
# orr termination 0.06220792793865616 0.07763609215241898 0.015428164213762821
# remaining size for Round 3: 141019
# Calculated size for Round 3: 5743.639845403812
# {'RF__n_estimators': 200}
# orr termination 0.021452079787896757 0.09477840425631215 0.07332632446841539
# remaining size for Round 4: 135276
# Calculated size for Round 4: 5632.545994137338
# {'RF__n_estimators': 100}
# orr termination 0.04300964840044102 0.07942784407928341 0.03641819567884239
# remaining size for Round 5: 129644
# Calculated size for Round 5: 8102.781794821713
# {'RF__n_estimators': 200}
# orr termination 0.06653266323845126 0.07390134392085791 0.0073686806824066475
# remaining size for last Round 6: 121542
# 11
# ['step1_rr: 10', 'step2_rr: 10', 'step3_rr: 10', 'step4_rr: 10', 'step5_rr: 10', 'step6_rr: 10']
# empirical response rate 0.05188744469026549
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4011.169485577855
# {'RF__n_estimators': 200}
# orr termination 0.0236940620669906 0.09530155807646393 0.07160749600947333
# remaining size for Round 3: 141141
# Calculated size for Round 3: 5520.575522788789
# {'RF__n_estimators': 200}
# orr termination 0.054609729406692016 0.0826068550276591 0.027997125620967088
# remaining size for Round 4: 135621
# Calculated size for Round 4: 8785.152097574803
# {'RF__n_estimators': 50}
# orr termination 0.050452450255007913 0.08238335360771792 0.03193090335271001
# remaining size for Round 5: 126836
# Calculated size for Round 5: 6703.898635886184
# {'RF__n_estimators': 100}
# orr termination 0.04323685599209327 0.08183818380366517 0.0386013278115719
# remaining size for last Round 6: 120133
# 12
# ['step1_rr: 11', 'step2_rr: 11', 'step3_rr: 11', 'step4_rr: 11', 'step5_rr: 11', 'step6_rr: 11']
# empirical response rate 0.05420353982300885
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4171.638735916014
# {'RF__n_estimators': 100}
# orr termination 0.036238566974209754 0.0964115370258245 0.060172970051614746
# remaining size for Round 3: 140981
# Calculated size for Round 3: 5417.604296188971
# {'RF__n_estimators': 200}
# orr termination 0.039314134360695606 0.0936487941976466 0.054334659836950995
# remaining size for Round 4: 135564
# Calculated size for Round 4: 7528.262083007384
# {'RF__n_estimators': 200}
# orr termination 0.05287352072750302 0.08265566802620217 0.029782147298699144
# remaining size for Round 5: 128036
# Calculated size for Round 5: 7392.967947493463
# {'RF__n_estimators': 50}
# orr termination 0.05315180037380295 0.08191124881240364 0.028759448438600684
# remaining size for last Round 6: 120644
# 13
# ['step1_rr: 12', 'step2_rr: 12', 'step3_rr: 12', 'step4_rr: 12', 'step5_rr: 12', 'step6_rr: 12']
# empirical response rate 0.05489491150442478
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4219.683881321882
# {'RF__n_estimators': 50}
# orr termination 0.0064212770328053205 0.1230623994437004 0.11664112241089508
# remaining size for Round 3: 140933
# 14
# ['step1_rr: 13', 'step2_rr: 13', 'step3_rr: 13', 'step4_rr: 13', 'step5_rr: 13', 'step6_rr: 13']
# empirical response rate 0.05496404867256637
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4224.492031131622
# {'RF__n_estimators': 100}
# orr termination 0.0631111634743889 0.07293173501641806 0.009820571542029158
# remaining size for Round 3: 140928
# Calculated size for Round 3: 17360.72362993987
# {'RF__n_estimators': 100}
# orr termination 0.04303917056186074 0.0712863005636813 0.028247130001820567
# remaining size for Round 4: 123568
# Calculated size for Round 4: 5183.525177443971
# {'RF__n_estimators': 50}
# orr termination 0.019936241000915424 0.0724560177167175 0.052519776715802075
# remaining size for Round 5: 118385
# 15
# ['step1_rr: 14', 'step2_rr: 14', 'step3_rr: 14', 'step4_rr: 14', 'step5_rr: 14', 'step6_rr: 14']
# empirical response rate 0.05620851769911504
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4311.151688005828
# {'RF__n_estimators': 50}
# orr termination 0.022032783034340572 0.10085796760873733 0.07882518457439676
# remaining size for Round 3: 140841
# Calculated size for Round 3: 7144.371372139633
# {'RF__n_estimators': 50}
# orr termination 0.022744607866928997 0.08114806491696952 0.05840345705004052
# remaining size for Round 4: 133697
# Calculated size for Round 4: 7327.753942897009
# {'RF__n_estimators': 50}
# orr termination 0.01800446063628578 0.07785016417972268 0.0598457035434369
# remaining size for Round 5: 126370
# 16
# ['step1_rr: 15', 'step2_rr: 15', 'step3_rr: 15', 'step4_rr: 15', 'step5_rr: 15', 'step6_rr: 15']
# empirical response rate 0.05399612831858407
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4157.238084390138
# {'RF__n_estimators': 50}
# orr termination 0.02739688486545391 0.09929324118923728 0.07189635632378337
# remaining size for Round 3: 140995
# Calculated size for Round 3: 6909.280462239539
# {'RF__n_estimators': 200}
# orr termination 0.05453168944737101 0.07673782065426786 0.02220613120689685
# remaining size for Round 4: 134086
# Calculated size for Round 4: 7675.211616491786
# {'RF__n_estimators': 50}
# orr termination 0.01824693677103957 0.08419488355075677 0.0659479467797172
# remaining size for Round 5: 126411
# Calculated size for Round 5: 6210.25372131827
# {'RF__n_estimators': 50}
# orr termination 0.05184118133491901 0.07579957190917855 0.02395839057425954
# remaining size for last Round 6: 120201
# 17
# ['step1_rr: 16', 'step2_rr: 16', 'step3_rr: 16', 'step4_rr: 16', 'step5_rr: 16', 'step6_rr: 16']
# empirical response rate 0.05517146017699115
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# {'RF__n_estimators': 100}
# orr termination 0.02419320827249851 0.09846986620480314 0.07427665793230462
# remaining size for Round 3: 140914
# Calculated size for Round 3: 6207.903997549528
# {'RF__n_estimators': 200}
# orr termination 0.01272549024773599 0.08275874605916023 0.07003325581142424
# remaining size for Round 4: 134707
# Calculated size for Round 4: 7422.635845837326
# {'RF__n_estimators': 100}
# orr termination 0.043272014938665025 0.06421644265737152 0.02094442771870649
# remaining size for Round 5: 127285
# Calculated size for Round 5: 7246.578278069159
# {'RF__n_estimators': 50}
# orr termination 0.03310692714881848 0.06591354392293361 0.03280661677411513
# remaining size for last Round 6: 120039
# 18
# ['step1_rr: 17', 'step2_rr: 17', 'step3_rr: 17', 'step4_rr: 17', 'step5_rr: 17', 'step6_rr: 17']
# empirical response rate 0.055240597345132744
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4243.731238049317
# {'RF__n_estimators': 50}
# orr termination 0.01102699508536538 0.11263346222914758 0.1016064671437822
# remaining size for Round 3: 140909
# Calculated size for Round 3: 6784.005809227904
# {'RF__n_estimators': 50}
# orr termination 0.04649476945522302 0.07428139889343735 0.027786629438214333
# remaining size for Round 4: 134125
# Calculated size for Round 4: 9256.531064478411
# {'RF__n_estimators': 200}
# orr termination 0.016011965780792187 0.07909448939042583 0.06308252360963365
# remaining size for Round 5: 124869
# 19
# ['step1_rr: 18', 'step2_rr: 18', 'step3_rr: 18', 'step4_rr: 18', 'step5_rr: 18', 'step6_rr: 18']
# empirical response rate 0.05610481194690266
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4303.921878005255
# {'RF__n_estimators': 100}
# orr termination 0.04971994865195718 0.09471070354825442 0.04499075489629724
# remaining size for Round 3: 140849
# Calculated size for Round 3: 8306.221629861038
# {'RF__n_estimators': 50}
# orr termination 0.007003211282567095 0.09929945777823673 0.09229624649566964
# remaining size for Round 4: 132543
# Calculated size for Round 4: 6725.710147129504
# {'RF__n_estimators': 50}
# orr termination 0.03516138242629203 0.0696955514387691 0.03453416901247707
# remaining size for Round 5: 125818
# 20
# ['step1_rr: 19', 'step2_rr: 19', 'step3_rr: 19', 'step4_rr: 19', 'step5_rr: 19', 'step6_rr: 19']
# empirical response rate 0.05669247787610619
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4344.910437079735
# {'RF__n_estimators': 50}
# orr termination 0.020902320058298108 0.09700121602767442 0.07609889596937632
# remaining size for Round 3: 140808
# Calculated size for Round 3: 10770.546900168816
# {'RF__n_estimators': 100}
# orr termination 0.06014496492617995 0.07184366427585417 0.011698699349674227
# remaining size for Round 4: 130038
# Calculated size for Round 4: 6673.09187701465
# {'RF__n_estimators': 200}
# orr termination 0.031203573784273516 0.0751342308550775 0.043930657070803986
# remaining size for Round 5: 123365
# Calculated size for Round 5: 5970.03553317397
# {'RF__n_estimators': 200}
# orr termination 0.035620058725817715 0.0704893867266755 0.034869328000857784
# remaining size for last Round 6: 117395
# 21
# ['step1_rr: 20', 'step2_rr: 20', 'step3_rr: 20', 'step4_rr: 20', 'step5_rr: 20', 'step6_rr: 20']
# empirical response rate 0.0547220685840708
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4207.666398075275
# {'RF__n_estimators': 200}
# orr termination 0.0021512052420265414 0.12010521581319993 0.11795401057117338
# remaining size for Round 3: 140945
# 22
# ['step1_rr: 21', 'step2_rr: 21', 'step3_rr: 21', 'step4_rr: 21', 'step5_rr: 21', 'step6_rr: 21']
# empirical response rate 0.05807522123893805
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4441.542106735752
# {'RF__n_estimators': 200}
# orr termination 0.01924191384778915 0.10073907043504879 0.08149715658725964
# remaining size for Round 3: 140711
# Calculated size for Round 3: 5631.251221514059
# {'RF__n_estimators': 100}
# orr termination 0.027729633562410313 0.09497230962024222 0.06724267605783191
# remaining size for Round 4: 135080
# Calculated size for Round 4: 9086.06099658003
# {'RF__n_estimators': 100}
# orr termination 0.061383891109477576 0.07304395786710803 0.011660066757630455
# remaining size for Round 5: 125994
# Calculated size for Round 5: 6735.398862948885
# {'RF__n_estimators': 50}
# orr termination 0.042513637251001074 0.07051517941354873 0.02800154216254766
# remaining size for last Round 6: 119259
# 23
# ['step1_rr: 22', 'step2_rr: 22', 'step3_rr: 22', 'step4_rr: 22', 'step5_rr: 22', 'step6_rr: 22']
# empirical response rate 0.054756637168141595
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4210.069564273832
# {'RF__n_estimators': 50}
# orr termination 0.04180693238643141 0.08268332373904266 0.04087639135261125
# remaining size for Round 3: 140942
# Calculated size for Round 3: 5325.803765915322
# {'RF__n_estimators': 50}
# orr termination 0.0067132280759574494 0.10391082721507984 0.09719759913912239
# remaining size for Round 4: 135617
# Calculated size for Round 4: 6049.062298179538
# {'RF__n_estimators': 50}
# orr termination 0.01679043103154743 0.07015392325680002 0.05336349222525259
# remaining size for Round 5: 129568
# 24
# ['step1_rr: 23', 'step2_rr: 23', 'step3_rr: 23', 'step4_rr: 23', 'step5_rr: 23', 'step6_rr: 23']
# empirical response rate 0.054756637168141595
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4210.069564273832
# {'RF__n_estimators': 100}
# orr termination 0.028742775039508537 0.09602912057259025 0.06728634553308172
# remaining size for Round 3: 140942
# Calculated size for Round 3: 7309.040138742402
# {'RF__n_estimators': 100}
# orr termination 0.058058902588579146 0.07545293243509718 0.017394029846518035
# remaining size for Round 4: 133633
# Calculated size for Round 4: 7653.805591085661
# {'RF__n_estimators': 100}
# orr termination 0.04149052632175602 0.0743855218652125 0.03289499554345648
# remaining size for Round 5: 125980
# Calculated size for Round 5: 6076.103127979107
# {'RF__n_estimators': 100}
# orr termination 0.05195278840829555 0.07214257844124321 0.020189790032947658
# remaining size for last Round 6: 119904
# 25
# ['step1_rr: 24', 'step2_rr: 24', 'step3_rr: 24', 'step4_rr: 24', 'step5_rr: 24', 'step6_rr: 24']
# empirical response rate 0.05406526548672566
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4162.037640283698
# {'RF__n_estimators': 100}
# orr termination 0.030594493969914316 0.10184353370800434 0.07124903973809002
# remaining size for Round 3: 140990
# Calculated size for Round 3: 10922.410127138917
# {'RF__n_estimators': 50}
# orr termination 0.05172703760738544 0.07775264122145858 0.026025603614073148
# remaining size for Round 4: 130068
# Calculated size for Round 4: 6626.512122086968
# {'RF__n_estimators': 50}
# orr termination 0.04857832519967058 0.07434881524828088 0.025770490048610303
# remaining size for Round 5: 123442
# Calculated size for Round 5: 6425.219507069802
# {'RF__n_estimators': 200}
# orr termination 0.03724368824351469 0.07398372631671812 0.03674003807320343
# remaining size for last Round 6: 117017
# 26
# ['step1_rr: 25', 'step2_rr: 25', 'step3_rr: 25', 'step4_rr: 25', 'step5_rr: 25', 'step6_rr: 25']
# empirical response rate 0.05254424778761062
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4056.600233593618
# {'RF__n_estimators': 50}
# orr termination 0.04750043193815923 0.08043946836028804 0.03293903642212881
# remaining size for Round 3: 141096
# Calculated size for Round 3: 4902.451038536624
# {'RF__n_estimators': 100}
# orr termination 0.05171958997637577 0.07625276725716085 0.02453317728078508
# remaining size for Round 4: 136194
# Calculated size for Round 4: 5758.878679452092
# {'RF__n_estimators': 50}
# orr termination 0.010136845672375794 0.09237449535581019 0.08223764968343439
# remaining size for Round 5: 130436
# Calculated size for Round 5: 5704.964928740111
# {'RF__n_estimators': 50}
# orr termination 0.06003925062396343 0.07215399079301926 0.01211474016905583
# remaining size for last Round 6: 124732
# 27
# ['step1_rr: 26', 'step2_rr: 26', 'step3_rr: 26', 'step4_rr: 26', 'step5_rr: 26', 'step6_rr: 26']
# empirical response rate 0.053201050884955754
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4102.090733905276
# {'RF__n_estimators': 100}
# orr termination 0.01751128104939332 0.10010425586791867 0.08259297481852534
# remaining size for Round 3: 141050
# Calculated size for Round 3: 5712.441364201446
# {'RF__n_estimators': 50}
# orr termination 0.058592193181664795 0.08158131954920969 0.022989126367544896
# remaining size for Round 4: 135338
# Calculated size for Round 4: 10146.826267226983
# {'RF__n_estimators': 50}
# orr termination 0.006360658177973544 0.08085396181910154 0.074493303641128
# remaining size for Round 5: 125192
# 28
# ['step1_rr: 27', 'step2_rr: 27', 'step3_rr: 27', 'step4_rr: 27', 'step5_rr: 27', 'step6_rr: 27']
# empirical response rate 0.05849004424778761
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4470.5830227383985
# {'RF__n_estimators': 200}
# orr termination 0.025712648880021484 0.10572611229649015 0.08001346341646867
# remaining size for Round 3: 140682
# Calculated size for Round 3: 11409.01625579704
# {'RF__n_estimators': 200}
# orr termination 0.06132485906025573 0.07427049176490577 0.012945632704650038
# remaining size for Round 4: 129273
# Calculated size for Round 4: 6606.072914015108
# {'RF__n_estimators': 200}
# orr termination 0.05276330844699343 0.07512448801654312 0.022361179569549687
# remaining size for Round 5: 122667
# Calculated size for Round 5: 6049.559323806515
# {'RF__n_estimators': 50}
# orr termination 0.019770548769864785 0.07820417461759258 0.058433625847727794
# remaining size for last Round 6: 116618
# 29
# ['step1_rr: 28', 'step2_rr: 28', 'step3_rr: 28', 'step4_rr: 28', 'step5_rr: 28', 'step6_rr: 28']
# empirical response rate 0.05537887168141593
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4253.354805576213
# {'RF__n_estimators': 50}
# orr termination 0.02302856433079717 0.09851140585687579 0.07548284152607862
# remaining size for Round 3: 140899
# Calculated size for Round 3: 5637.589209733208
# {'RF__n_estimators': 50}
# orr termination 0.03618183467892264 0.09422970090123889 0.058047866222316245
# remaining size for Round 4: 135262
# Calculated size for Round 4: 8574.468664186274
# {'RF__n_estimators': 200}
# orr termination 0.058325846253108965 0.07387118562258986 0.015545339369480896
# remaining size for Round 5: 126688
# Calculated size for Round 5: 6791.611666733473
# {'RF__n_estimators': 100}
# orr termination 0.03985460647026316 0.07630026718279434 0.03644566071253118
# remaining size for last Round 6: 119897
# 30
# ['step1_rr: 29', 'step2_rr: 29', 'step3_rr: 29', 'step4_rr: 29', 'step5_rr: 29', 'step6_rr: 29']
# empirical response rate 0.056173949115044246
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4308.741586307481
# {'RF__n_estimators': 200}
# orr termination 0.027943275663976523 0.09957358038387353 0.07163030471989701
# remaining size for Round 3: 140844
# Calculated size for Round 3: 6465.298209350452
# {'RF__n_estimators': 50}
# orr termination 0.04986149315575346 0.07926060854083111 0.029399115385077654
# remaining size for Round 4: 134379
# Calculated size for Round 4: 7587.521999955258
# {'RF__n_estimators': 100}
# orr termination 0.00657081176875584 0.08970638947185879 0.08313557770310294
# remaining size for Round 5: 126792
# 31
# ['step1_rr: 30', 'step2_rr: 30', 'step3_rr: 30', 'step4_rr: 30', 'step5_rr: 30', 'step6_rr: 30']
# empirical response rate 0.05517146017699115
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# {'RF__n_estimators': 200}
# orr termination 0.06083112580693144 0.08449677809573036 0.023665652288798925
# remaining size for Round 3: 140914
# Calculated size for Round 3: 8058.572623105206
# {'RF__n_estimators': 50}
# orr termination 0.02790990228167433 0.0869665981209094 0.05905669583923507
# remaining size for Round 4: 132856
# Calculated size for Round 4: 6255.391191072168
# {'RF__n_estimators': 50}
# orr termination 0.07099849240755607 0.07824378743920318 0.007245295031647114
# remaining size for Round 5: 126601
# Calculated size for Round 5: 7962.866461010032
# {'RF__n_estimators': 100}
# orr termination 0.05651870652241278 0.07882820467591475 0.022309498153501972
# remaining size for last Round 6: 118639
# 32
# ['step1_rr: 31', 'step2_rr: 31', 'step3_rr: 31', 'step4_rr: 31', 'step5_rr: 31', 'step6_rr: 31']
# empirical response rate 0.05544800884955752
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4258.167580221075
# {'RF__n_estimators': 50}
# orr termination 0.039809690738720885 0.08747873174368133 0.047669041004960444
# remaining size for Round 3: 140894
# Calculated size for Round 3: 7860.978888734241
# {'RF__n_estimators': 50}
# orr termination 0.008457700629570509 0.09068137802445012 0.08222367739487961
# remaining size for Round 4: 133034
# Calculated size for Round 4: 6568.050783202635
# {'RF__n_estimators': 50}
# orr termination 0.03496146095550494 0.07229276111369431 0.037331300158189376
# remaining size for Round 5: 126466
# 33
# ['step1_rr: 32', 'step2_rr: 32', 'step3_rr: 32', 'step4_rr: 32', 'step5_rr: 32', 'step6_rr: 32']
# empirical response rate 0.05482577433628318
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4214.876392356589
# {'RF__n_estimators': 100}
# orr termination 0.05462395940653071 0.07989623918810508 0.02527227978157437
# remaining size for Round 3: 140938
# Calculated size for Round 3: 4869.79382463809
# {'RF__n_estimators': 50}
# orr termination 0.06418541469598997 0.07965614980283378 0.015470735106843811
# remaining size for Round 4: 136069
# Calculated size for Round 4: 5633.085075707152
# {'RF__n_estimators': 200}
# orr termination 0.015251623500199377 0.09315154550735483 0.07789992200715545
# remaining size for Round 5: 130436
# Calculated size for Round 5: 5483.695351997853
# {'RF__n_estimators': 50}
# orr termination 0.007997027930158131 0.10064330705445515 0.09264627912429702
# remaining size for last Round 6: 124953
# 34
# ['step1_rr: 33', 'step2_rr: 33', 'step3_rr: 33', 'step4_rr: 33', 'step5_rr: 33', 'step6_rr: 33']
# empirical response rate 0.054756637168141595
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4210.069564273832
# {'RF__n_estimators': 50}
# orr termination 0.049964932080499236 0.08632349229030575 0.03635856020980652
# remaining size for Round 3: 140942
# Calculated size for Round 3: 6118.878724868427
# {'RF__n_estimators': 200}
# orr termination 0.0198093412503841 0.09501256498694215 0.07520322373655805
# remaining size for Round 4: 134824
# Calculated size for Round 4: 6622.450442342021
# {'RF__n_estimators': 200}
# orr termination 0.04772568375022248 0.07221024821299239 0.024484564462769913
# remaining size for Round 5: 128202
# Calculated size for Round 5: 7206.680163763531
# {'RF__n_estimators': 200}
# orr termination 0.058102144351720814 0.06593954559327883 0.007837401241558017
# remaining size for last Round 6: 120996
# 35
# ['step1_rr: 34', 'step2_rr: 34', 'step3_rr: 34', 'step4_rr: 34', 'step5_rr: 34', 'step6_rr: 34']
# empirical response rate 0.05548257743362832
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4260.5742152468165
# {'RF__n_estimators': 200}
# orr termination 0.05416048292014232 0.08232923002788113 0.028168747107738812
# remaining size for Round 3: 140892
# Calculated size for Round 3: 5494.166122477255
# {'RF__n_estimators': 200}
# orr termination 0.03661955594337993 0.08931088685357891 0.05269133091019898
# remaining size for Round 4: 135398
# Calculated size for Round 4: 6065.677517173843
# {'RF__n_estimators': 200}
# orr termination 0.006896268301524873 0.10245595801234292 0.09555968971081805
# remaining size for Round 5: 129333
# Calculated size for Round 5: 7120.03559403337
# {'RF__n_estimators': 50}
# orr termination 0.03691857002586173 0.07472840393126166 0.03780983390539994
# remaining size for last Round 6: 122213
# 36
# ['step1_rr: 35', 'step2_rr: 35', 'step3_rr: 35', 'step4_rr: 35', 'step5_rr: 35', 'step6_rr: 35']
# empirical response rate 0.05479120575221239
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4212.472895702519
# {'RF__n_estimators': 100}
# orr termination 0.006254201580260498 0.09441988428872083 0.08816568270846034
# remaining size for Round 3: 140940
# Calculated size for Round 3: 9500.834578084892
# {'RF__n_estimators': 50}
# orr termination 0.03534349222811273 0.07086372893723515 0.035520236709122424
# remaining size for Round 4: 131440
# 37
# ['step1_rr: 36', 'step2_rr: 36', 'step3_rr: 36', 'step4_rr: 36', 'step5_rr: 36', 'step6_rr: 36']
# empirical response rate 0.054272676991150445
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4176.440275580975
# {'RF__n_estimators': 100}
# orr termination 0.026429919514131005 0.1032342951248677 0.07680437561073669
# remaining size for Round 3: 140976
# Calculated size for Round 3: 8620.485380590995
# {'RF__n_estimators': 200}
# orr termination 0.029875917205276232 0.07542452449818055 0.04554860729290432
# remaining size for Round 4: 132356
# Calculated size for Round 4: 6741.003842422784
# {'RF__n_estimators': 100}
# orr termination 0.015576697249020846 0.0764172381091867 0.060840540860165854
# remaining size for Round 5: 125615
# 38
# ['step1_rr: 37', 'step2_rr: 37', 'step3_rr: 37', 'step4_rr: 37', 'step5_rr: 37', 'step6_rr: 37']
# empirical response rate 0.05333932522123894
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4111.675292416549
# {'RF__n_estimators': 50}
# orr termination 0.05629493010934331 0.0823190110399789 0.026024080930635594
# remaining size for Round 3: 141041
# Calculated size for Round 3: 8680.936443953382
# {'RF__n_estimators': 50}
# orr termination 0.008688075802147664 0.0860479198364528 0.07735984403430513
# remaining size for Round 4: 132361
# Calculated size for Round 4: 5594.067375596009
# {'RF__n_estimators': 100}
# orr termination 0.02476319041915354 0.0745877723976207 0.04982458197846716
# remaining size for Round 5: 126767
# 39
# ['step1_rr: 38', 'step2_rr: 38', 'step3_rr: 38', 'step4_rr: 38', 'step5_rr: 38', 'step6_rr: 38']
# empirical response rate 0.05278622787610619
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4073.3529413786146
# {'RF__n_estimators': 50}
# orr termination 0.026695860415787427 0.10113936918956255 0.07444350877377512
# remaining size for Round 3: 141079
# Calculated size for Round 3: 11826.390963425405
# {'RF__n_estimators': 100}
# orr termination 0.04539440572528207 0.07381302939737443 0.028418623672092358
# remaining size for Round 4: 129253
# Calculated size for Round 4: 6180.263282120472
# {'RF__n_estimators': 200}
# orr termination 0.016694621543375886 0.07543147942232034 0.058736857878944455
# remaining size for Round 5: 123073
# 40
# ['step1_rr: 39', 'step2_rr: 39', 'step3_rr: 39', 'step4_rr: 39', 'step5_rr: 39', 'step6_rr: 39']
# empirical response rate 0.05420353982300885
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4171.638735916014
# {'RF__n_estimators': 50}
# orr termination 0.04178044064576576 0.08702515779986422 0.04524471715409846
# remaining size for Round 3: 140981
# Calculated size for Round 3: 4975.50911586979
# {'RF__n_estimators': 200}
# orr termination 0.026776163290877994 0.09167446249697159 0.0648982992060936
# remaining size for Round 4: 136006
# Calculated size for Round 4: 6452.057375671068
# {'RF__n_estimators': 50}
# orr termination 0.04529234478243487 0.08017485932571694 0.03488251454328207
# remaining size for Round 5: 129554
# Calculated size for Round 5: 8118.438325581061
# {'RF__n_estimators': 200}
# orr termination 0.05290655389738634 0.07440967853877509 0.021503124641388746
# remaining size for last Round 6: 121436
# 41
# ['step1_rr: 40', 'step2_rr: 40', 'step3_rr: 40', 'step4_rr: 40', 'step5_rr: 40', 'step6_rr: 40']
# empirical response rate 0.058213495575221236
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4451.219776662242
# {'RF__n_estimators': 100}
# orr termination 0.04477138732835697 0.08234304058982483 0.037571653261467865
# remaining size for Round 3: 140701
# Calculated size for Round 3: 14150.683552004039
# {'RF__n_estimators': 200}
# orr termination 0.026317325019246975 0.07270533009879174 0.04638800507954476
# remaining size for Round 4: 126551
# Calculated size for Round 4: 5983.168374892504
# {'RF__n_estimators': 50}
# orr termination 0.04874243125641403 0.07434249464885581 0.02560006339244178
# remaining size for Round 5: 120568
# Calculated size for Round 5: 7035.186991899466
# {'RF__n_estimators': 100}
# orr termination 0.035736670466051765 0.07184164857414987 0.03610497810809811
# remaining size for last Round 6: 113533
# 42
# ['step1_rr: 41', 'step2_rr: 41', 'step3_rr: 41', 'step4_rr: 41', 'step5_rr: 41', 'step6_rr: 41']
# empirical response rate 0.05389242256637168
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4150.039990556384
# {'RF__n_estimators': 200}
# orr termination 0.0385239610047118 0.08940032539709353 0.050876364392381725
# remaining size for Round 3: 141002
# Calculated size for Round 3: 7583.077636081424
# {'RF__n_estimators': 100}
# orr termination 0.017059713368278363 0.08356644081950554 0.06650672745122718
# remaining size for Round 4: 133419
# Calculated size for Round 4: 6924.46103782606
# {'RF__n_estimators': 100}
# orr termination 0.01576971742075464 0.07675442139030196 0.06098470396954732
# remaining size for Round 5: 126495
# 43
# ['step1_rr: 42', 'step2_rr: 42', 'step3_rr: 42', 'step4_rr: 42', 'step5_rr: 42', 'step6_rr: 42']
# empirical response rate 0.053477599557522126
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4121.262497623935
# {'RF__n_estimators': 50}
# orr termination 0.02189338259088137 0.10163506652501268 0.07974168393413131
# remaining size for Round 3: 141031
# Calculated size for Round 3: 7798.883695694585
# {'RF__n_estimators': 50}
# orr termination 0.014512136948112795 0.08854958755937228 0.07403745061125949
# remaining size for Round 4: 133233
# Calculated size for Round 4: 7996.399637975929
# {'RF__n_estimators': 50}
# orr termination 0.04215447760369663 0.0771645615182551 0.03501008391455847
# remaining size for Round 5: 125237
# 44
# ['step1_rr: 43', 'step2_rr: 43', 'step3_rr: 43', 'step4_rr: 43', 'step5_rr: 43', 'step6_rr: 43']
# empirical response rate 0.055413440265486724
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4255.761110329247
# {'RF__n_estimators': 50}
# orr termination 0.043226035670861966 0.09562946320280762 0.05240342753194565
# remaining size for Round 3: 140897
# Calculated size for Round 3: 6553.811684448025
# {'RF__n_estimators': 200}
# orr termination 0.017456109764412 0.0934316069661821 0.0759754972017701
# remaining size for Round 4: 134344
# Calculated size for Round 4: 6942.425391284635
# {'RF__n_estimators': 200}
# orr termination 0.05414100110216864 0.07356158978883626 0.019420588686667614
# remaining size for Round 5: 127402
# Calculated size for Round 5: 7901.664863434945
# {'RF__n_estimators': 100}
# orr termination 0.015204368971808492 0.0743687332196563 0.05916436424784781
# remaining size for last Round 6: 119501
# 45
# ['step1_rr: 44', 'step2_rr: 44', 'step3_rr: 44', 'step4_rr: 44', 'step5_rr: 44', 'step6_rr: 44']
# empirical response rate 0.05579369469026549
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4282.241360696144
# {'RF__n_estimators': 200}
# orr termination 0.014292082820227309 0.10336081268934197 0.08906872986911465
# remaining size for Round 3: 140870
# Calculated size for Round 3: 6685.087827490209
# {'RF__n_estimators': 200}
# orr termination 0.018585415125451983 0.08759828607990525 0.06901287095445327
# remaining size for Round 4: 134185
# Calculated size for Round 4: 10087.23652706798
# {'RF__n_estimators': 50}
# orr termination 0.037417352829152484 0.07522674314422602 0.037809390315073535
# remaining size for Round 5: 124098
# 46
# ['step1_rr: 45', 'step2_rr: 45', 'step3_rr: 45', 'step4_rr: 45', 'step5_rr: 45', 'step6_rr: 45']
# empirical response rate 0.05486034292035398
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4217.280054231296
# {'RF__n_estimators': 50}
# orr termination 0.036933528211199176 0.09314950610657602 0.05621597789537684
# remaining size for Round 3: 140935
# Calculated size for Round 3: 8596.819455081415
# {'RF__n_estimators': 200}
# orr termination 0.01625413608551661 0.08932589826168001 0.0730717621761634
# remaining size for Round 4: 132339
# Calculated size for Round 4: 6932.335127453367
# {'RF__n_estimators': 200}
# orr termination 0.02602186416870775 0.07955112363256897 0.05352925946386122
# remaining size for Round 5: 125407
# 47
# ['step1_rr: 46', 'step2_rr: 46', 'step3_rr: 46', 'step4_rr: 46', 'step5_rr: 46', 'step6_rr: 46']
# empirical response rate 0.054307245575221236
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4178.841293359456
# {'RF__n_estimators': 50}
# orr termination 0.025531677067617997 0.10072762135327908 0.07519594428566108
# remaining size for Round 3: 140974
# Calculated size for Round 3: 12121.703718444922
# {'RF__n_estimators': 50}
# orr termination 0.062150396652355874 0.07131682468506485 0.009166428032708979
# remaining size for Round 4: 128853
# Calculated size for Round 4: 6199.627049527066
# {'RF__n_estimators': 50}
# orr termination 0.06208593193454675 0.07333801436486467 0.011252082430317924
# remaining size for Round 5: 122654
# Calculated size for Round 5: 5797.191365950343
# {'RF__n_estimators': 100}
# orr termination 0.030769477651233532 0.07635539084159995 0.04558591319036642
# remaining size for last Round 6: 116857
# 48
# ['step1_rr: 47', 'step2_rr: 47', 'step3_rr: 47', 'step4_rr: 47', 'step5_rr: 47', 'step6_rr: 47']
# empirical response rate 0.055862831858407076
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4287.058097965914
# {'RF__n_estimators': 200}
# orr termination 0.005424903186935032 0.11133438858985033 0.1059094854029153
# remaining size for Round 3: 140865
# Calculated size for Round 3: 5029.325103598418
# {'RF__n_estimators': 100}
# orr termination 0.05614186178790801 0.06817486279317164 0.012033001005263631
# remaining size for Round 4: 135836
# Calculated size for Round 4: 13071.590896133795
# {'RF__n_estimators': 200}
# orr termination 0.04352046266551421 0.06952369797290069 0.026003235307386477
# remaining size for Round 5: 122765
# Calculated size for Round 5: 5565.2988804170045
# {'RF__n_estimators': 50}
# orr termination 0.0236233268776973 0.07270143957807222 0.04907811270037492
# remaining size for last Round 6: 117200
# 49
# ['step1_rr: 48', 'step2_rr: 48', 'step3_rr: 48', 'step4_rr: 48', 'step5_rr: 48', 'step6_rr: 48']
# empirical response rate 0.05658877212389381
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4337.673697209837
# {'RF__n_estimators': 100}
# orr termination 0.039123148568194266 0.08024995322953016 0.04112680466133589
# remaining size for Round 3: 140815
# Calculated size for Round 3: 18267.40364915017
# {'RF__n_estimators': 50}
# orr termination 0.052243533715986536 0.07017503149506492 0.017931497779078383
# remaining size for Round 4: 122548
# Calculated size for Round 4: 5597.317965857806
# {'RF__n_estimators': 100}
# orr termination 0.04533312360197445 0.06886456078588246 0.02353143718390801
# remaining size for Round 5: 116951
# Calculated size for Round 5: 5488.648562246066
# {'RF__n_estimators': 50}
# orr termination 0.03477838054916746 0.0698964063822627 0.03511802583309524
# remaining size for last Round 6: 111463
# 50
# ['step1_rr: 49', 'step2_rr: 49', 'step3_rr: 49', 'step4_rr: 49', 'step5_rr: 49', 'step6_rr: 49']
# empirical response rate 0.05793694690265487
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4431.867072682371
# {'RF__n_estimators': 50}
# orr termination 0.037712453448216963 0.07232485798571082 0.03461240453749386
# remaining size for Round 3: 140721
# Calculated size for Round 3: 24126.464156322785
# {'RF__n_estimators': 100}
# orr termination 0.037203354811183253 0.07262462792160952 0.03542127311042627
# remaining size for Round 4: 116595
# 51
# ['step1_rr: 50', 'step2_rr: 50', 'step3_rr: 50', 'step4_rr: 50', 'step5_rr: 50', 'step6_rr: 50']
# empirical response rate 0.05548257743362832
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4260.5742152468165
# {'RF__n_estimators': 100}
# orr termination 0.05692802694602343 0.08707758816192722 0.030149561215903786
# remaining size for Round 3: 140892
# Calculated size for Round 3: 6380.164472620738
# {'RF__n_estimators': 200}
# orr termination 0.00792263317251555 0.10736773311895714 0.09944509994644159
# remaining size for Round 4: 134512
# Calculated size for Round 4: 6261.463861784778
# {'RF__n_estimators': 200}
# orr termination 0.053987036674282715 0.07168275392067441 0.0176957172463917
# remaining size for Round 5: 128251
# Calculated size for Round 5: 9936.268114858134
# {'RF__n_estimators': 200}
# orr termination 0.024264273647052744 0.0728182110364931 0.048553937389440346
# remaining size for last Round 6: 118315
# 52
# ['step1_rr: 51', 'step2_rr: 51', 'step3_rr: 51', 'step4_rr: 51', 'step5_rr: 51', 'step6_rr: 51']
# empirical response rate 0.05420353982300885
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4171.638735916014
# {'RF__n_estimators': 50}
# orr termination 0.030049059066173122 0.09470443345546567 0.06465537438929254
# remaining size for Round 3: 140981
# Calculated size for Round 3: 7463.46286995437
# {'RF__n_estimators': 50}
# orr termination 0.016058280886405457 0.09628583043848347 0.08022754955207802
# remaining size for Round 4: 133518
# Calculated size for Round 4: 7754.53607424668
# {'RF__n_estimators': 50}
# orr termination 0.04310051511580809 0.0698311448586525 0.026730629742844403
# remaining size for Round 5: 125764
# Calculated size for Round 5: 7640.210228651316
# {'RF__n_estimators': 50}
# orr termination 0.03571776594555994 0.07054534500088007 0.03482757905532013
# remaining size for last Round 6: 118124
# 53
# ['step1_rr: 52', 'step2_rr: 52', 'step3_rr: 52', 'step4_rr: 52', 'step5_rr: 52', 'step6_rr: 52']
# empirical response rate 0.055240597345132744
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4243.731238049317
# {'RF__n_estimators': 50}
# orr termination 0.046689317139762355 0.08969400806621819 0.043004690926455834
# remaining size for Round 3: 140909
# Calculated size for Round 3: 5736.934555803871
# {'RF__n_estimators': 50}
# orr termination 0.01244875389498385 0.11104055268134215 0.09859179878635829
# remaining size for Round 4: 135173
# Calculated size for Round 4: 6658.653794656726
# {'RF__n_estimators': 200}
# orr termination 0.026650634826687725 0.08244485610156535 0.055794221274877626
# remaining size for Round 5: 128515
# Calculated size for Round 5: 10115.686972045847
# {'RF__n_estimators': 50}
# orr termination 0.0365887906436155 0.0705374670362129 0.0339486763925974
# remaining size for last Round 6: 118400
# 54
# ['step1_rr: 53', 'step2_rr: 53', 'step3_rr: 53', 'step4_rr: 53', 'step5_rr: 53', 'step6_rr: 53']
# empirical response rate 0.05392699115044248
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4152.439189827319
# {'RF__n_estimators': 200}
# orr termination 0.015676682899508566 0.11114221177965641 0.09546552888014785
# remaining size for Round 3: 141000
# Calculated size for Round 3: 7234.576973140479
# {'RF__n_estimators': 100}
# orr termination 0.06306474189382816 0.07220873835689331 0.009143996463065157
# remaining size for Round 4: 133766
# Calculated size for Round 4: 7992.130334695566
# {'RF__n_estimators': 100}
# orr termination 0.022975014972909956 0.07511794932196567 0.05214293434905571
# remaining size for Round 5: 125774
# Calculated size for Round 5: 5974.822138001069
# {'RF__n_estimators': 50}
# orr termination 0.0375422019650609 0.07219613066240539 0.03465392869734449
# remaining size for last Round 6: 119800
# 55
# ['step1_rr: 54', 'step2_rr: 54', 'step3_rr: 54', 'step4_rr: 54', 'step5_rr: 54', 'step6_rr: 54']
# empirical response rate 0.055240597345132744
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4243.731238049317
# {'RF__n_estimators': 100}
# orr termination 0.011096845369760902 0.10276289043011559 0.0916660450603547
# remaining size for Round 3: 140909
# Calculated size for Round 3: 4932.981507438629
# {'RF__n_estimators': 50}
# orr termination 0.046504548505709356 0.0754124413659245 0.02890789286021514
# remaining size for Round 4: 135977
# Calculated size for Round 4: 12024.370381358438
# {'RF__n_estimators': 100}
# orr termination 0.024974190082095664 0.0756022596410609 0.05062806955896524
# remaining size for Round 5: 123953
# Calculated size for Round 5: 5916.870527756253
# {'RF__n_estimators': 50}
# orr termination 0.026143413546455423 0.07532090153042038 0.04917748798396496
# remaining size for last Round 6: 118037
# 56
# ['step1_rr: 55', 'step2_rr: 55', 'step3_rr: 55', 'step4_rr: 55', 'step5_rr: 55', 'step6_rr: 55']
# empirical response rate 0.05496404867256637
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4224.492031131622
# {'RF__n_estimators': 100}
# orr termination 0.036041541686066346 0.09239005831244859 0.056348516626382246
# remaining size for Round 3: 140928
# Calculated size for Round 3: 5205.39370623782
# {'RF__n_estimators': 200}
# orr termination 0.026848071253358165 0.09438886426375553 0.06754079301039737
# remaining size for Round 4: 135723
# Calculated size for Round 4: 7040.059739579536
# {'RF__n_estimators': 100}
# orr termination 0.013502131524831065 0.08830675850768432 0.07480462698285326
# remaining size for Round 5: 128683
# Calculated size for Round 5: 7724.813589678297
# {'RF__n_estimators': 50}
# orr termination 0.0370457401431748 0.07099889880439363 0.03395315866121883
# remaining size for last Round 6: 120959
# 57
# ['step1_rr: 56', 'step2_rr: 56', 'step3_rr: 56', 'step4_rr: 56', 'step5_rr: 56', 'step6_rr: 56']
# empirical response rate 0.05544800884955752
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4258.167580221075
# {'RF__n_estimators': 50}
# orr termination 0.022389588521976887 0.09743660897534287 0.07504702045336598
# remaining size for Round 3: 140894
# Calculated size for Round 3: 6284.319986109521
# {'RF__n_estimators': 50}
# orr termination 0.01322190178293204 0.10277465365746834 0.08955275187453629
# remaining size for Round 4: 134610
# Calculated size for Round 4: 8235.511752827339
# {'RF__n_estimators': 100}
# orr termination 0.037170693418512486 0.07599854609384117 0.038827852675328685
# remaining size for Round 5: 126375
# 58
# ['step1_rr: 57', 'step2_rr: 57', 'step3_rr: 57', 'step4_rr: 57', 'step5_rr: 57', 'step6_rr: 57']
# empirical response rate 0.05479120575221239
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4212.472895702519
# {'RF__n_estimators': 100}
# ...
# remaining size for Round 4: 134863
# Calculated size for Round 4: 6896.0393366010185
# {'RF__n_estimators': 200}
# orr termination 0.035426454266207996 0.07019427905506434 0.034767824788856344
# remaining size for Round 5: 127967
# Calculated size for Round 5: 7322.3404663877545
# {'RF__n_estimators': 200}
# orr termination 0.01842801733543376 0.0753042381586235 0.056876220823189744
# remaining size for last Round 6: 120645
# 82
# ['step1_rr: 81', 'step2_rr: 81', 'step3_rr: 81', 'step4_rr: 81', 'step5_rr: 81', 'step6_rr: 81']
# empirical response rate 0.0546529314159292
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4202.860561387483
# {'RF__n_estimators': 100}
# orr termination 0.027433164359939432 0.09572990621548805 0.06829674185554861
# remaining size for Round 3: 140950
# Calculated size for Round 3: 6739.241029409065
# {'RF__n_estimators': 100}
# orr termination 0.01280041196823736 0.09007209676005773 0.07727168479182037
# remaining size for Round 4: 134211
# Calculated size for Round 4: 7709.69493507043
# {'RF__n_estimators': 100}
# orr termination 0.04767825908081555 0.07163480136402846 0.02395654228321291
# remaining size for Round 5: 126502
# Calculated size for Round 5: 8373.007400685246
# {'RF__n_estimators': 50}
# orr termination 0.035362482162136555 0.07034836250502105 0.034985880342884496
# remaining size for last Round 6: 118129
# 83
# ['step1_rr: 82', 'step2_rr: 82', 'step3_rr: 82', 'step4_rr: 82', 'step5_rr: 82', 'step6_rr: 82']
# empirical response rate 0.05441095132743363
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4186.045338423161
# {'RF__n_estimators': 100}
# orr termination 0.022267860382265837 0.09788667837030204 0.07561881798803621
# remaining size for Round 3: 140966
# Calculated size for Round 3: 5884.716746060683
# {'RF__n_estimators': 100}
# orr termination 0.028729382526924092 0.08469202744786236 0.05596264492093827
# remaining size for Round 4: 135082
# Calculated size for Round 4: 8263.85967249534
# {'RF__n_estimators': 50}
# orr termination 0.05504857010897356 0.07210720467156453 0.017058634562590977
# remaining size for Round 5: 126819
# Calculated size for Round 5: 7123.359092576102
# {'RF__n_estimators': 100}
# orr termination 0.06161323302769456 0.07362075841120655 0.012007525383511991
# remaining size for last Round 6: 119696
# 84
# ['step1_rr: 83', 'step2_rr: 83', 'step3_rr: 83', 'step4_rr: 83', 'step5_rr: 83', 'step6_rr: 83']
# empirical response rate 0.05513689159292035
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4236.515296599448
# {'RF__n_estimators': 50}
# orr termination 0.008422203076365882 0.10544388273980289 0.097021679663437
# remaining size for Round 3: 140916
# Calculated size for Round 3: 8767.690687815066
# {'RF__n_estimators': 50}
# orr termination 0.04753984918196068 0.07339599449488327 0.025856145312922588
# remaining size for Round 4: 132149
# Calculated size for Round 4: 7659.319354751159
# {'RF__n_estimators': 50}
# orr termination 0.03648976123887358 0.07411977598895356 0.037630014750079974
# remaining size for Round 5: 124490
# 85
# ['step1_rr: 84', 'step2_rr: 84', 'step3_rr: 84', 'step4_rr: 84', 'step5_rr: 84', 'step6_rr: 84']
# empirical response rate 0.05513689159292035
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4236.515296599448
# {'RF__n_estimators': 200}
# orr termination 0.021839381382775608 0.1054027838003751 0.08356340241759949
# remaining size for Round 3: 140916
# Calculated size for Round 3: 9594.042500236286
# {'RF__n_estimators': 100}
# orr termination 0.012810234446231111 0.08848145343413097 0.07567121898789986
# remaining size for Round 4: 131322
# 86
# ['step1_rr: 85', 'step2_rr: 85', 'step3_rr: 85', 'step4_rr: 85', 'step5_rr: 85', 'step6_rr: 85']
# empirical response rate 0.054134402654867256
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4166.8378574712715
# {'RF__n_estimators': 50}
# orr termination 0.022063243788811117 0.09745570422330502 0.07539246043449391
# remaining size for Round 3: 140986
# Calculated size for Round 3: 5466.273009706987
# {'RF__n_estimators': 50}
# orr termination 0.03993378768987181 0.0851416605991303 0.045207872909258484
# remaining size for Round 4: 135520
# Calculated size for Round 4: 8417.39747940083
# {'RF__n_estimators': 100}
# orr termination 0.009294740969808674 0.08751003685542567 0.078215295885617
# remaining size for Round 5: 127103
# 87
# ['step1_rr: 86', 'step2_rr: 86', 'step3_rr: 86', 'step4_rr: 86', 'step5_rr: 86', 'step6_rr: 86']
# empirical response rate 0.05534430309734513
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4250.948665966841
# {'RF__n_estimators': 100}
# orr termination 0.014469943178008256 0.10759623951923833 0.09312629634123007
# remaining size for Round 3: 140902
# Calculated size for Round 3: 4654.1866525474625
# {'RF__n_estimators': 50}
# orr termination 0.012359894117439681 0.10678539550164663 0.09442550138420695
# remaining size for Round 4: 136248
# Calculated size for Round 4: 12000.366326405903
# {'RF__n_estimators': 50}
# orr termination 0.03606714459094003 0.06951514794157145 0.03344800335063142
# remaining size for Round 5: 124248
# 88
# ['step1_rr: 87', 'step2_rr: 87', 'step3_rr: 87', 'step4_rr: 87', 'step5_rr: 87', 'step6_rr: 87']
# empirical response rate 0.05527516592920354
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4246.136882198541
# {'RF__n_estimators': 50}
# orr termination 0.028354060440203617 0.09536821114401084 0.06701415070380723
# remaining size for Round 3: 140906
# Calculated size for Round 3: 6856.843717115917
# {'RF__n_estimators': 200}
# orr termination 0.0346949665030903 0.07924547049846138 0.04455050399537108
# remaining size for Round 4: 134050
# Calculated size for Round 4: 7104.676354938324
# {'RF__n_estimators': 50}
# orr termination 0.02380149454066987 0.08004474986913043 0.05624325532846056
# remaining size for Round 5: 126946
# Calculated size for Round 5: 7166.5606478812015
# {'RF__n_estimators': 50}
# orr termination 0.02392473789835133 0.07406998494526366 0.05014524704691234
# remaining size for last Round 6: 119780
# 89
# ['step1_rr: 88', 'step2_rr: 88', 'step3_rr: 88', 'step4_rr: 88', 'step5_rr: 88', 'step6_rr: 88']
# empirical response rate 0.054618362831858405
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4200.457890907699
# {'RF__n_estimators': 100}
# orr termination 0.03137376223528883 0.0942958847587932 0.06292212252350438
# remaining size for Round 3: 140952
# Calculated size for Round 3: 5313.833762512799
# {'RF__n_estimators': 100}
# orr termination 0.028490032850284498 0.10217956460526212 0.07368953175497762
# remaining size for Round 4: 135639
# Calculated size for Round 4: 7932.984920336157
# {'RF__n_estimators': 50}
# orr termination 0.03966311694526175 0.07648124951747844 0.03681813257221669
# remaining size for Round 5: 127707
# Calculated size for Round 5: 7592.2506366547195
# {'RF__n_estimators': 50}
# orr termination 0.04763049345406077 0.07851938865798237 0.0308888952039216
# remaining size for last Round 6: 120115
# 90
# ['step1_rr: 89', 'step2_rr: 89', 'step3_rr: 89', 'step4_rr: 89', 'step5_rr: 89', 'step6_rr: 89']
# empirical response rate 0.05403069690265487
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4159.637779672868
# {'RF__n_estimators': 50}
# orr termination 0.017636230184187064 0.09261310136258652 0.07497687117839946
# remaining size for Round 3: 140993
# Calculated size for Round 3: 7512.388955440153
# {'RF__n_estimators': 100}
# orr termination 0.03796801315144874 0.08518163721133223 0.0472136240598835
# remaining size for Round 4: 133481
# Calculated size for Round 4: 8205.30546031744
# {'RF__n_estimators': 200}
# orr termination 0.021391354597950704 0.08020136693860744 0.058810012340656734
# remaining size for Round 5: 125276
# 91
# ['step1_rr: 90', 'step2_rr: 90', 'step3_rr: 90', 'step4_rr: 90', 'step5_rr: 90', 'step6_rr: 90']
# empirical response rate 0.05596653761061947
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4294.284441919237
# {'RF__n_estimators': 50}
# orr termination 0.031911249755594256 0.09917795931781465 0.06726670956222039
# remaining size for Round 3: 140858
# Calculated size for Round 3: 5348.243450595981
# {'RF__n_estimators': 50}
# orr termination 0.028781368181462028 0.09265471788353166 0.06387334970206963
# remaining size for Round 4: 135510
# Calculated size for Round 4: 7784.013729157885
# {'RF__n_estimators': 50}
# orr termination 0.008003708455181585 0.08900586212361182 0.08100215366843024
# remaining size for Round 5: 127726
# 92
# ['step1_rr: 91', 'step2_rr: 91', 'step3_rr: 91', 'step4_rr: 91', 'step5_rr: 91', 'step6_rr: 91']
# empirical response rate 0.051991150442477874
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4018.338787935027
# {'RF__n_estimators': 50}
# orr termination 0.02598372864326875 0.08806129897882752 0.06207757033555877
# remaining size for Round 3: 141134
# Calculated size for Round 3: 5272.332399196311
# {'RF__n_estimators': 200}
# orr termination 0.009715109987954254 0.10621885759986283 0.09650374761190857
# remaining size for Round 4: 135862
# Calculated size for Round 4: 7688.363182816254
# {'RF__n_estimators': 50}
# orr termination 0.05426383205868776 0.07849805092048787 0.024234218861800105
# remaining size for Round 5: 128174
# Calculated size for Round 5: 9774.193846963417
# {'RF__n_estimators': 50}
# orr termination 0.038541680623858175 0.0761941904489151 0.03765250982505692
# remaining size for last Round 6: 118400
# 93
# ['step1_rr: 92', 'step2_rr: 92', 'step3_rr: 92', 'step4_rr: 92', 'step5_rr: 92', 'step6_rr: 92']
# empirical response rate 0.05596653761061947
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4294.284441919237
# {'RF__n_estimators': 100}
# orr termination 0.038469234084439925 0.07690369561223549 0.03843446152779557
# remaining size for Round 3: 140858
# Calculated size for Round 3: 17085.913201304997
# {'RF__n_estimators': 50}
# orr termination 0.03597673062598719 0.07017225516776707 0.034195524541779876
# remaining size for Round 4: 123773
# Calculated size for Round 4: 5318.547349415187
# {'RF__n_estimators': 50}
# orr termination 0.034000330588822326 0.06878506976136893 0.034784739172546604
# remaining size for Round 5: 118455
# 94
# ['step1_rr: 93', 'step2_rr: 93', 'step3_rr: 93', 'step4_rr: 93', 'step5_rr: 93', 'step6_rr: 93']
# empirical response rate 0.05434181415929203
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4181.242476429084
# {'RF__n_estimators': 100}
# orr termination 0.025698142431541192 0.09324562791770621 0.06754748548616502
# remaining size for Round 3: 140971
# Calculated size for Round 3: 4847.974739363617
# {'RF__n_estimators': 50}
# orr termination 0.010621038191617398 0.09530662666766115 0.08468558847604375
# remaining size for Round 4: 136124
# Calculated size for Round 4: 7898.2577173025975
# {'RF__n_estimators': 100}
# orr termination 0.04989030063333484 0.06705869425160546 0.01716839361827062
# remaining size for Round 5: 128226
# Calculated size for Round 5: 7664.812493241734
# {'RF__n_estimators': 100}
# orr termination 0.047465474027766706 0.07036073755976427 0.022895263531997563
# remaining size for last Round 6: 120562
# 95
# ['step1_rr: 94', 'step2_rr: 94', 'step3_rr: 94', 'step4_rr: 94', 'step5_rr: 94', 'step6_rr: 94']
# empirical response rate 0.05489491150442478
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4219.683881321882
# {'RF__n_estimators': 200}
# orr termination 0.022101509612510926 0.09472100325817412 0.0726194936456632
# remaining size for Round 3: 140933
# Calculated size for Round 3: 5436.590009992229
# {'RF__n_estimators': 100}
# orr termination 0.004055560984623166 0.1031965567369326 0.09914099575230943
# remaining size for Round 4: 135497
# 96
# ['step1_rr: 95', 'step2_rr: 95', 'step3_rr: 95', 'step4_rr: 95', 'step5_rr: 95', 'step6_rr: 95']
# empirical response rate 0.057280143805309734
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4385.946667669806
# {'RF__n_estimators': 200}
# orr termination 0.02065032880965366 0.11602044494575231 0.09537011613609865
# remaining size for Round 3: 140767
# Calculated size for Round 3: 8193.986119982905
# {'RF__n_estimators': 200}
# orr termination 0.039421720154827214 0.07793434807174628 0.03851262791691906
# remaining size for Round 4: 132574
# Calculated size for Round 4: 7784.453331283332
# {'RF__n_estimators': 100}
# orr termination 0.030377323336409755 0.07568777178755337 0.04531044845114361
# remaining size for Round 5: 124790
# Calculated size for Round 5: 6664.93804790334
# {'RF__n_estimators': 50}
# orr termination 0.038387448630573355 0.07508757404325915 0.036700125412685795
# remaining size for last Round 6: 118126
# 97
# ['step1_rr: 96', 'step2_rr: 96', 'step3_rr: 96', 'step4_rr: 96', 'step5_rr: 96', 'step6_rr: 96']
# empirical response rate 0.05482577433628318
# {'RF__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4214.876392356589
# {'RF__n_estimators': 50}
# orr termination 0.03365281836133502 0.08583595514509135 0.05218313678375633
# remaining size for Round 3: 140938
# Calculated size for Round 3: 12229.777347221176
# {'RF__n_estimators': 50}
# orr termination 0.025126250804175035 0.07492068354050534 0.0497944327363303
# remaining size for Round 4: 128709
# Calculated size for Round 4: 6157.162678156462
# {'RF__n_estimators': 100}
# orr termination 0.023509636706905344 0.06988514322597729 0.04637550651907195
# remaining size for Round 5: 122552
# 98
# ['step1_rr: 97', 'step2_rr: 97', 'step3_rr: 97', 'step4_rr: 97', 'step5_rr: 97', 'step6_rr: 97']
# empirical response rate 0.0546529314159292
# {'RF__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4202.860561387483
# {'RF__n_estimators': 50}
# orr termination 0.023200131663626063 0.09602603997879589 0.07282590831516983
# remaining size for Round 3: 140950
# Calculated size for Round 3: 6375.92096575004
# {'RF__n_estimators': 200}
# orr termination 0.041659394248767946 0.07780730502918443 0.03614791078041648
# remaining size for Round 4: 134575
# Calculated size for Round 4: 7976.917571788646
# {'RF__n_estimators': 50}
# orr termination 0.04590633735299427 0.07623017343220138 0.030323836079207113
# remaining size for Round 5: 126599
# Calculated size for Round 5: 6677.447702212007
# {'RF__n_estimators': 200}
# orr termination 0.06185946356335889 0.07381435882012682 0.011954895256767933
# remaining size for last Round 6: 119922
# 99
# ['step1_rr: 98', 'step2_rr: 98', 'step3_rr: 98', 'step4_rr: 98', 'step5_rr: 98', 'step6_rr: 98']
# empirical response rate 0.053512168141592924
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4123.659712438602
# {'RF__n_estimators': 200}
# orr termination 0.027218866549135686 0.0920898455073489 0.06487097895821321
# remaining size for Round 3: 141029
# Calculated size for Round 3: 5313.227767748776
# {'RF__n_estimators': 200}
# orr termination 0.009352063358781184 0.10403531117038214 0.09468324781160097
# remaining size for Round 4: 135716
# Calculated size for Round 4: 7759.377882222537
# {'RF__n_estimators': 50}
# orr termination 0.04251577919865214 0.06360648028535228 0.021090701086700137
# remaining size for Round 5: 127957
# Calculated size for Round 5: 6853.695600351136
# {'RF__n_estimators': 50}
# orr termination 0.03527587277361746 0.06617990463499974 0.030904031861382283
# remaining size for last Round 6: 121104
# 100
# ['step1_rr: 99', 'step2_rr: 99', 'step3_rr: 99', 'step4_rr: 99', 'step5_rr: 99', 'step6_rr: 99']
# empirical response rate 0.055517146017699116
# {'RF__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4262.981015401587
# {'RF__n_estimators': 50}
# orr termination 0.030151605837395876 0.09209783374940383 0.06194622791200796
# remaining size for Round 3: 140890
# Calculated size for Round 3: 16675.1309059897
# {'RF__n_estimators': 50}
# orr termination 0.014724240885882343 0.08295844885151347 0.06823420796563114
# remaining size for Round 4: 124215

# %% [markdown]
# ### Results summary

# %%
rr_df = pd.DataFrame(rr_dict)
rr_df
# Out:
#     step1_rr  step2_rr  step3_rr  step4_rr  step5_rr  step6_rr
# 0      0.055  0.061640  0.062863  0.064313  0.068471  0.068471
# 1      0.055  0.058775  0.065518  0.066788  0.068471  0.068471
# 2      0.055  0.057087  0.061874  0.064323  0.068471  0.068471
# 3      0.055  0.060335  0.061994  0.065077  0.068471       NaN
# 4      0.055  0.057650  0.060181  0.068471       NaN       NaN
# ..       ...       ...       ...       ...       ...       ...
# 95     0.055  0.060020  0.063125  0.068471  0.068471  0.068471
# 96     0.055  0.061341  0.067013  0.068471  0.068471       NaN
# 97     0.055  0.059805  0.062906  0.065931  0.068471  0.068471
# 98     0.055  0.058230  0.060300  0.059651  0.062180  0.068471
# 99     0.055  0.063271  0.068471  0.068471       NaN       NaN
#
# [100 rows x 6 columns]

# %%
# Calculate average rounds:
row_non_nan_counts = rr_df.count(axis=1)

print(f"{np.mean(row_non_nan_counts):.1f} ({np.std(row_non_nan_counts):.1f})")
# Out:
# 5.4 (0.7)

# %%
result_dict = {}
for key, values in rr_df.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"

for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_rr: 0.055 (0.000)
# step2_rr: 0.060 (0.002)
# step3_rr: 0.063 (0.003)
# step4_rr: 0.066 (0.002)
# step5_rr: 0.068 (0.001)
# step6_rr: 0.068 (0.000)

# %%
result_dict = np.array(orr_total) / total_n
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f} ({std_result:.3f})")
# Out:
# Mean: 0.066 (0.000)

# %%
mean_result=(np.mean(highest_true_rr))
std_result=(np.std(highest_true_rr))
print(f"Mean: {mean_result:.3f} ({std_result:.3f})")
# Out:
# Mean: 0.068 (0.000)

# %%
result_dict = np.array(orr_total_adaptive) / (145152)
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f} ({std_result:.3f})")
# Out:
# Mean: 0.068 (0.000)

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in plan_number_dict.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.1f} ({std_value:.1f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_plan_number: nan (nan)
# step2_plan_number: 95.9 (59.1)
# step3_plan_number: 24.2 (22.6)
# step4_plan_number: 7.5 (11.4)
# step5_plan_number: 3.1 (2.7)
# step6_plan_number: 2.3 (2.1)

# %%
means = {key: np.mean(values) for key, values in stopping_dict.items()}
means
# Out:
# {'early_stopping': 0.46,
#  'early_stopping_plan': 0.46,
#  'early_stopping_orr': 0.0,
#  'early_stopping_size': 0.0}

# %%
print(np.mean(last_round_sample_size), np.std(last_round_sample_size))
# Out:
# 122392.93 5521.034930617628

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in sample_size_dict.items():
    mean_value = np.nanmean(values)
    std_value = np.nanstd(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_sample_size: 28928.000 (0.000)
# step2_sample_size: 4217.873 (88.452)
# step3_sample_size: 10760.691 (19115.072)
# step4_sample_size: 20053.156 (36831.305)
# step5_sample_size: 52410.894 (57130.650)
# step6_sample_size: 119261.796 (2096.378)

# %%
np.mean(better_chance)
# Out:
# 1.0

# %% [markdown]
# ## XGBoost

# %%
def ensemble_model_fit(data, data_pred):
    X_train, X_test, y_train, y_test = train_test_split(
        data.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1),
        data['response'],
        test_size=0.2,
        random_state=0
    )

    # Define the VotingClassifier with the individual classifiers
    voting_classifier = ensemble.VotingClassifier(
        estimators=[
            # ('LR', linear_model.LogisticRegression(max_iter=200, random_state=0))
#             ('Ridge', linear_model.LogisticRegression(penalty='l2', solver='lbfgs', max_iter=200, random_state=0))
                    # ('SVM', svm.SVC(kernel='linear', C=1.0, random_state=0, probability=True, class_weight='balanced'))
#                     ('RF', ensemble.RandomForestClassifier(n_estimators=200, criterion='gini', random_state=0))
                    ('XGB', XGBClassifier(n_estimators=50, learning_rate=0.1, random_state=0))
                   ],
        voting='soft'
    )

    # Define the hyperparameter grid to search
    # Best Hyperparameters: {'LR__C': 0.01, 'RF__n_estimators': 50, 'XGB__n_estimators': 50}
    param_grid = {
        # 'NB__alpha': [0.01, 0.05, 0.1],  # '__' is used to specify hyperparameters for individual classifiers
        # 'LR__C': [0.01] # [0.01, 0.05, 0.1]
        # 'Ridge__C': [0.01]
        # 'SVM__C': [0.01, 0.05, 0.1]
#         'RF__n_estimators': [50] # [10, 30, 50]
        'XGB__learning_rate': [0.01, 0.1, 1],
        'XGB__n_estimators': [50, 100, 200]
    }

    # Create a GridSearchCV object
    # custom_scorer_auc = make_scorer(roc_auc_score, needs_proba=True)
    grid_search = GridSearchCV(voting_classifier, param_grid, cv=10, scoring='roc_auc')

    # Perform the grid search on the training data
    grid_search.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = grid_search.best_params_
    print("Best fit parameters:", best_params)

    # Train the final VotingClassifier with the best hyperparameters on the full training set
    final_voting_classifier = grid_search.best_estimator_
    final_voting_classifier.fit(X_train, y_train)

    # Predict probabilities instead of binary outcomes on the test set
    y_pred_proba_test = final_voting_classifier.predict_proba(X_test)
    y_pred_test = final_voting_classifier.predict(X_test)
    X_dt = data_pred.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1)
    y_pred = final_voting_classifier.predict_proba(X_dt)

    return y_pred

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import train_test_split

# def ensemble_model_fit(data, data_pred):
#     # Split the data into training and testing sets
#     X_train, X_test, y_train, y_test = train_test_split(
#         data.drop(['recruitment_plan', 'plan_response_rate', 'group_size','response'], axis=1),
#         data['response'],
#         test_size=0.2,
#         random_state=0
#     )

#     # Define the Logistic Regression model
#     logistic_regression = LogisticRegression(C=0.01, max_iter=200,random_state=0)

#     # Fit the Logistic Regression model on the training data
#     logistic_regression.fit(X_train, y_train)

#     # Print out the coefficients of the logistic regression model
#     print("Coefficients:", logistic_regression.coef_)
#     print("Intercept:", logistic_regression.intercept_)
#     print("Coefficients shape:", logistic_regression.coef_.shape)

#     # Predict probabilities instead of binary outcomes on the test set
#     y_pred_proba_test = logistic_regression.predict_proba(X_test)
#     y_pred_test = logistic_regression.predict(X_test)

#     # You can also predict probabilities for the prediction data (data_pred)
#     X_dt = data_pred.drop(['recruitment_plan', 'plan_response_rate', 'group_size','response'], axis=1)
#     y_pred = logistic_regression.predict_proba(X_dt)

#     return y_pred

# # Call the function
# # ensemble_model_fit(data, data_pred)

# %% [markdown]
# ### Simulation starts

# %%
n_sim = 100
# create a list of random seeds
random.seed(42)
random_seeds = [random.randint(1, 100000) for _ in range(n_sim)]

design_list = [5,8,10]
patient_n_list = [5468,680,170] # n_patient_per_plan

n_design = 8
n_patient_per_plan = 680
n_rounds = 6
total_n = n_patient_per_plan * (2**n_design)

## sample size determination
beta = 0.2
power = 1 - beta
alpha = 0.05
delta = 0.01 # effect size

## early stopping
epsilon = 0.001

# %%
rr_dict = {"step{}_rr".format(r): [] for r in range(1, n_rounds + 1)}
plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
sample_size_dict = {"step{}_sample_size".format(r): [] for r in range(1, n_rounds + 1)}
last_round_sample_size = []
random_rr_dict = {"step{}_random_max_rr".format(r): [] for r in range(1, n_rounds + 1)}
random_rr_dict.update({
    "step{}_random_mean_rr".format(r): [] for r in range(1, n_rounds + 1)
})

stopping_dict = {"early_stopping": [],
                 "early_stopping_plan":[],
                 "early_stopping_orr":[],
                 "early_stopping_size":[]}
final_plan_number = []
highest_rr_overall = []
highest_true_rr = []

better_chance = []

orr_total = []
orr_total_adaptive = []



i = 0

for seed in random_seeds:
    i += 1
    print(i)

    print([f"{key}: {len(value)}" for key, value in rr_dict.items()])



    event_list = 0
    event_list_adaptive = 0
    max_rr = []

    # step 1:
    ## Generate dataset
    dt_design_5 = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed)
    highest_true_rr.append(np.max(dt_design_5['plan_response_rate']))
    print("empirical response rate", dt_design_5['response'].mean())
    ## save for benchmark results
    maxidx = np.argmax(dt_design_5['plan_response_rate'])
    random_rr_dict['step1_random_max_rr'].append(dt_design_5.iloc[maxidx,6])
    random_rr_dict['step1_random_mean_rr'].append(dt_design_5['plan_response_rate'].mean())

    ## Ensemble modelling:
    y_pred = ensemble_model_fit(data=dt_design_5, data_pred = dt_design_5)

    ## select recruitment plan
    pred_df = pd.DataFrame(np.hstack((dt_design_5,  y_pred[:, 1].reshape(-1, 1))),
                             columns=list(dt_design_5.columns) + ['predicted_response_rate'])
    pred_df_rr = pred_df.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

    x = pred_df_rr['predicted_response_rate'].values
    if len(x) <= 10:
        best_k = 2
    else:
        best_k = kmeans_fit(data = x)['best_k']
    kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

    merged_df = pd.merge(pred_df_rr, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
    cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
    highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
    highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)


    p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))
    highest_cluster['p_vec'] = p_vec_next
    highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

    # highest_cluster = pred_df_rr

    # highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')
    # highest_cluster['cluster_number'] = highest_cluster['recruitment_plan']

    ## prepare to chance of better performance:
    temp = dt_design_5[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
    event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print("step1", np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print(temp)
    p0 = (temp['plan_response_rate'].mean())

    rr_dict["step1_rr"].append(dt_design_5['plan_response_rate'].mean())
    sample_size_dict["step1_sample_size"].append(len(dt_design_5))

    for round in range(2, n_rounds+1):

        rr_dict["step"+str(round)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))
        plan_number_dict["step"+str(round)+"_plan_number"].append(len(p_vec_next))

        ## when it comes to the last round:
        if round == n_rounds:

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            if round == 2: # if the last round is round 2
                remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
            else:
                remaining_size -= len(dt_design_5_step2up)

            print("remaining size for last Round " + str(round) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            ## data generation, combine previous data:
            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, round=round,
                                                          design_number = n_design, n_rounds = n_rounds,
                                                          n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(0)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(len(temp), temp['plan_response_rate'].mean())
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break



        ## If haven't reached the last round:
        ## check remaining sample size:
        if round == 2:
            remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
        else:
            remaining_size -= len(dt_design_5_step2up)

        print("remaining size for Round " + str(round) + ": " + str(remaining_size))

        ## determine whether move on to step 2:
        if len(highest_cluster) == 1: # if there is only one plan left

            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size) # record the last round sample size
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(1)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        ## sample size determination:
        if round == 2:
            dt_design_5_step2up_overall = dt_design_5
        orr_1 = dt_design_5_step2up_overall['response'].mean() # observed overall response rates for previous rounds
        orr_2 = orr_1 + delta
        n_1 = len(dt_design_5_step2up_overall)

        size_step2up = sample_size_calc(orr_1, n_1, delta=delta, alpha=alpha, power=power) # total size for dataset
        if size_step2up > 0 and size_step2up < 1000:
            size_step2up = 1000 # if size in [0,1000], then it is 1000 for this round.
        elif size_step2up >= 1000:
            size_step2up = min(size_step2up, int(total_n/n_rounds)) # dataset size capped by the n_patient_per_plan
        else:
        # if size_step2up <= 0:
            # the process stops at this step
            print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up) + 'lt 0, break')
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(1)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up))

        sample_size_dict["step"+str(round)+"_sample_size"].append(size_step2up)

        ## save benchmark results for last round:
        dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                            n_patient_per_plan = n_patient_per_plan, seed=seed+round)
        maxidx = np.argmax(dt_benchmark['plan_response_rate'])
        random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
        random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

        ## data generation, combine previous data:
        dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                  design_number = n_design, n_rounds = n_rounds,
                                                  n_patient_per_plan = n_patient_per_plan, size = int(size_step2up), seed=seed)

        plan_list = dt_design_5_step2up['recruitment_plan'].unique()
        if round == 2:
            supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)]
        else:
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
        dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
        dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

        ## Ensemble model fitting:
        dt_design_5_step2up.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)
        y_pred2up = ensemble_model_fit(data = dt_design_5_step2up_overall, data_pred = dt_design_5_step2up)
        pred_df_step2up = pd.DataFrame(np.hstack((dt_design_5_step2up,  y_pred2up[:, 1].reshape(-1, 1))),
                                    columns=list(dt_design_5_step2up.columns) + ['predicted_response_rate'])
        pred_df_rr_step2up = pred_df_step2up.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

        ## select recruitment plans:
        x = pred_df_rr_step2up['predicted_response_rate'].values

        if len(x) <= 10:
            best_k = 2
        else:
            best_k = kmeans_fit(data = x)['best_k']
        kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

        ## match the cluster results back to the original data
        highest_cluster_previous = highest_cluster # save previous cluster results

        merged_df = pd.merge(pred_df_rr_step2up, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
        cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
        highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
        highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)

        # p_vec_previous = p_vec_next # save p_vec of previous round
        p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))

        highest_cluster['p_vec'] = p_vec_next

        highest_cluster = pd.merge(highest_cluster, dt_design_5_step2up[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

        ## prepare to chance of better performance:
        temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
        event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print(temp)

        ## check early stopping predicted ORR:
        orr_df = pd.merge(highest_cluster_previous, highest_cluster[['recruitment_plan','predicted_response_rate','p_vec']], on='recruitment_plan', how='left')
        orr_df.fillna(0, inplace=True)
        p_orr_1 = np.dot(np.array(orr_df['p_vec_x']), np.array(orr_df['predicted_response_rate_y']))
        p_orr_2 = np.dot(np.array(orr_df['p_vec_y']), np.array(orr_df['predicted_response_rate_y']))
        print("orr termination", p_orr_1, p_orr_2, p_orr_2 - p_orr_1)

        if (p_orr_2 - p_orr_1 < epsilon):
            # step 3 use the same strategy of step2
            print(i, p_orr_1, p_orr_2, "early stop at Round " + str(round))
            rr_dict["step"+str(round+1)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                                n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round+1)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round+1)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            ### update remaining size:
            remaining_size -= len(dt_design_5_step2up)
            print("early stop, remaining size for Round" + str(round + 1) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            for r in range(round+2, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(1)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            for r in range(round+2, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round+1), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break
# Out:
# 1
# ['step1_rr: 0', 'step2_rr: 0', 'step3_rr: 0', 'step4_rr: 0', 'step5_rr: 0', 'step6_rr: 0']
# empirical response rate 0.05295907079646018
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4085.324125976102
# Best fit parameters: {'XGB__learning_rate': 1, 'XGB__n_estimators': 50}
# orr termination 0.0024932992265810283 0.10169291496276855 0.09919961573618753
# remaining size for Round 3: 141067
# 2
# ['step1_rr: 1', 'step2_rr: 1', 'step3_rr: 1', 'step4_rr: 1', 'step5_rr: 1', 'step6_rr: 1']
# empirical response rate 0.056312223451327435
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4318.382983229351
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.024621968277250744 0.2114297178521184 0.18680774957486765
# remaining size for Round 3: 140834
# Calculated size for Round 3: 5638.318204825274
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.021808809594865097 0.1068813433494553 0.0850725337545902
# remaining size for Round 4: 135196
# Calculated size for Round 4: 7586.785421068981
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.07349198277386851 0.10167529842172959 0.028183315647861085
# remaining size for Round 5: 127610
# Calculated size for Round 5: 7793.228864072376
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.015399636836936868 0.08917484432458878 0.0737752074876519
# remaining size for last Round 6: 119817
# 3
# ['step1_rr: 2', 'step2_rr: 2', 'step3_rr: 2', 'step4_rr: 2', 'step5_rr: 2', 'step6_rr: 2']
# empirical response rate 0.053650442477876106
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4133.2502256140915
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.013937480572554376 0.35105226472649637 0.33711478415394197
# remaining size for Round 3: 141019
# Calculated size for Round 3: 4330.986590478573
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.1309616510441226 0.38893725019569525 0.25797559915157264
# remaining size for Round 4: 136689
# Calculated size for Round 4: 12181.729572793842
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.004090890717856553 0.08644679933786392 0.08235590862000737
# remaining size for Round 5: 124508
# 4
# ['step1_rr: 3', 'step2_rr: 3', 'step3_rr: 3', 'step4_rr: 3', 'step5_rr: 3', 'step6_rr: 3']
# empirical response rate 0.05437638274336283
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4183.643824785205
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.010766561474273947 0.42008096674592416 0.4093144052716502
# remaining size for Round 3: 140969
# Calculated size for Round 3: 8798.726081124849
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.17421831449136746 0.11593257153775319 -0.05828574295361427
# 4 0.17421831449136746 0.11593257153775319 early stop at Round 3
# early stop, remaining size for Round4: 132171
# 5
# ['step1_rr: 4', 'step2_rr: 4', 'step3_rr: 4', 'step4_rr: 4', 'step5_rr: 4', 'step6_rr: 4']
# empirical response rate 0.05530973451327434
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4248.542691505998
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.010037049344370039 0.47154536816108944 0.4615083188167194
# remaining size for Round 3: 140904
# Calculated size for Round 3: 7412.925989333745
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.2117739868762068 0.11722548305988312 -0.09454850381632368
# 5 0.2117739868762068 0.11722548305988312 early stop at Round 3
# early stop, remaining size for Round4: 133492
# 6
# ['step1_rr: 5', 'step2_rr: 5', 'step3_rr: 5', 'step4_rr: 5', 'step5_rr: 5', 'step6_rr: 5']
# empirical response rate 0.05361587389380531
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4130.852349241689
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.14769787012016133 0.12257878164855115 -0.02511908847161018
# 6 0.14769787012016133 0.12257878164855115 early stop at Round 2
# early stop, remaining size for Round3: 141022
# 7
# ['step1_rr: 6', 'step2_rr: 6', 'step3_rr: 6', 'step4_rr: 6', 'step5_rr: 6', 'step6_rr: 6']
# empirical response rate 0.05330475663716814
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4109.278904649849
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.09495409337136287 0.19164279345863267 0.09668870008726979
# remaining size for Round 3: 141043
# Calculated size for Round 3: 5237.879941565319
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# orr termination 0.026840168542718146 0.24996421782833855 0.2231240492856204
# remaining size for Round 4: 135806
# Calculated size for Round 4: 7643.513866373337
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.010112308673237824 0.12581822276115417 0.11570591408791635
# remaining size for Round 5: 128163
# 8
# ['step1_rr: 7', 'step2_rr: 7', 'step3_rr: 7', 'step4_rr: 7', 'step5_rr: 7', 'step6_rr: 7']
# empirical response rate 0.055724557522123894
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4277.425283765311
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.031271404514528686 0.4156442400186565 0.3843728355041278
# remaining size for Round 3: 140875
# Calculated size for Round 3: 14063.785878321427
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.07790187660095772 0.19599111661445479 0.11808924001349706
# remaining size for Round 4: 126812
# Calculated size for Round 4: 5875.748527836411
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.03441147450640068 0.07045746594667435 0.036045991440273664
# remaining size for Round 5: 120937
# 9
# ['step1_rr: 8', 'step2_rr: 8', 'step3_rr: 8', 'step4_rr: 8', 'step5_rr: 8', 'step6_rr: 8']
# empirical response rate 0.05676161504424779
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4349.735755102456
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.011451527189880857 0.14945958629274447 0.13800805910286362
# remaining size for Round 3: 140803
# Calculated size for Round 3: 11766.427781744358
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.021353152307493083 0.08510750532150269 0.0637543530140096
# remaining size for Round 4: 129037
# 10
# ['step1_rr: 9', 'step2_rr: 9', 'step3_rr: 9', 'step4_rr: 9', 'step5_rr: 9', 'step6_rr: 9']
# empirical response rate 0.053650442477876106
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4133.2502256140915
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.14149168049946712 0.12129168623759738 -0.020199994261869733
# 10 0.14149168049946712 0.12129168623759738 early stop at Round 2
# early stop, remaining size for Round3: 141019
# 11
# ['step1_rr: 10', 'step2_rr: 10', 'step3_rr: 10', 'step4_rr: 10', 'step5_rr: 10', 'step6_rr: 10']
# empirical response rate 0.05188744469026549
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4011.169485577855
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.012772425348960276 0.4119851364207246 0.3992127110717643
# remaining size for Round 3: 141141
# Calculated size for Round 3: 6978.562765062238
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.0647041348600588 0.08965778983173263 0.02495365497167383
# remaining size for Round 4: 134163
# Calculated size for Round 4: 9816.395126986485
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.04871169170295104 0.12398517668394213 0.0752734849809911
# remaining size for Round 5: 124347
# Calculated size for Round 5: 6370.060353892352
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.06152922106193327 0.12188917398452759 0.060359952922594315
# remaining size for last Round 6: 117977
# 12
# ['step1_rr: 11', 'step2_rr: 11', 'step3_rr: 11', 'step4_rr: 11', 'step5_rr: 11', 'step6_rr: 11']
# empirical response rate 0.05420353982300885
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4171.638735916014
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.018718028613821047 0.421515138420218 0.40279710980639694
# remaining size for Round 3: 140981
# Calculated size for Round 3: 11486.513992447773
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.04828194244667766 0.07736670184736441 0.02908475940068675
# remaining size for Round 4: 129495
# Calculated size for Round 4: 7157.962349280021
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.11046911034634696 0.0857659872339549 -0.02470312311239206
# 12 0.11046911034634696 0.0857659872339549 early stop at Round 4
# early stop, remaining size for Round5: 122338
# 13
# ['step1_rr: 12', 'step2_rr: 12', 'step3_rr: 12', 'step4_rr: 12', 'step5_rr: 12', 'step6_rr: 12']
# empirical response rate 0.05489491150442478
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4219.683881321882
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.02220808862887803 0.5585813256145771 0.536373236985699
# remaining size for Round 3: 140933
# Calculated size for Round 3: 12480.127745191989
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.04312707809335685 0.08765311354022369 0.04452603544686684
# remaining size for Round 4: 128453
# Calculated size for Round 4: 7102.923702271822
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.25013431906700134 0.12506715953350067 -0.12506715953350067
# 13 0.25013431906700134 0.12506715953350067 early stop at Round 4
# early stop, remaining size for Round5: 121351
# 14
# ['step1_rr: 13', 'step2_rr: 13', 'step3_rr: 13', 'step4_rr: 13', 'step5_rr: 13', 'step6_rr: 13']
# empirical response rate 0.05496404867256637
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4224.492031131622
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.003906402961210999 0.12534348666667938 0.12143708370546838
# remaining size for Round 3: 140928
# 15
# ['step1_rr: 14', 'step2_rr: 14', 'step3_rr: 14', 'step4_rr: 14', 'step5_rr: 14', 'step6_rr: 14']
# empirical response rate 0.05620851769911504
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4311.151688005828
# Best fit parameters: {'XGB__learning_rate': 1, 'XGB__n_estimators': 50}
# orr termination 0.06105544965106945 0.29724947353803816 0.2361940238869687
# remaining size for Round 3: 140841
# Calculated size for Round 3: 9371.59998804382
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.05785949264876136 0.10852885010205161 0.05066935745329025
# remaining size for Round 4: 131470
# Calculated size for Round 4: 6283.599496080014
# Best fit parameters: {'XGB__learning_rate': 1, 'XGB__n_estimators': 50}
# orr termination 0.04042482636232776 0.09243054968749148 0.05200572332516372
# remaining size for Round 5: 125187
# Calculated size for Round 5: 6860.898129920294
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.043523622593884974 0.0767931864520788 0.03326956385819383
# remaining size for last Round 6: 118327
# 16
# ['step1_rr: 15', 'step2_rr: 15', 'step3_rr: 15', 'step4_rr: 15', 'step5_rr: 15', 'step6_rr: 15']
# empirical response rate 0.05399612831858407
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4157.238084390138
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# orr termination 0.03145026739591503 0.14205595395600487 0.11060568656008984
# remaining size for Round 3: 140995
# Calculated size for Round 3: 19087.697647936904
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.04515778159962066 0.0706676865122221 0.025509904912601446
# remaining size for Round 4: 121908
# Calculated size for Round 4: 5520.769501745905
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.09922080351118046 0.0810701282136042 -0.01815067529757626
# 16 0.09922080351118046 0.0810701282136042 early stop at Round 4
# early stop, remaining size for Round5: 116388
# 17
# ['step1_rr: 16', 'step2_rr: 16', 'step3_rr: 16', 'step4_rr: 16', 'step5_rr: 16', 'step6_rr: 16']
# empirical response rate 0.05517146017699115
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.1562142780426137 0.42031377624299565 0.2640994982003819
# remaining size for Round 3: 140914
# Calculated size for Round 3: 5693.864138620744
# Best fit parameters: {'XGB__learning_rate': 1, 'XGB__n_estimators': 50}
# orr termination 0.008821449846274445 0.15224167329547886 0.1434202234492044
# remaining size for Round 4: 135221
# Calculated size for Round 4: 5711.0065842580725
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# orr termination 0.043362912918482155 0.07633089396398599 0.03296798104550383
# remaining size for Round 5: 129510
# Calculated size for Round 5: 10691.01068094271
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.48243996500968933 0.12060999125242233 -0.361829973757267
# 17 0.48243996500968933 0.12060999125242233 early stop at Round 5
# early stop, remaining size for Round6: 118819
# 18
# ['step1_rr: 17', 'step2_rr: 17', 'step3_rr: 17', 'step4_rr: 17', 'step5_rr: 17', 'step6_rr: 17']
# empirical response rate 0.055240597345132744
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4243.731238049317
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.5856026682916908 0.40632968136035874 -0.1792729869313321
# 18 0.5856026682916908 0.40632968136035874 early stop at Round 2
# early stop, remaining size for Round3: 140909
# 19
# ['step1_rr: 18', 'step2_rr: 18', 'step3_rr: 18', 'step4_rr: 18', 'step5_rr: 18', 'step6_rr: 18']
# empirical response rate 0.05610481194690266
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4303.921878005255
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.20114951599560615 0.5855129881645357 0.3843634721689295
# remaining size for Round 3: 140849
# Calculated size for Round 3: 6819.95583394688
# Best fit parameters: {'XGB__learning_rate': 1, 'XGB__n_estimators': 50}
# orr termination 0.04930076422674291 0.2356156938907955 0.1863149296640526
# remaining size for Round 4: 134030
# Calculated size for Round 4: 7116.385122196073
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# orr termination 0.05943555230115639 0.07930715833140095 0.019871606030244564
# remaining size for Round 5: 126914
# Calculated size for Round 5: 6723.523933531844
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# orr termination 0.06612787685139448 0.07454859903758608 0.008420722186191595
# remaining size for last Round 6: 120191
# 20
# ['step1_rr: 19', 'step2_rr: 19', 'step3_rr: 19', 'step4_rr: 19', 'step5_rr: 19', 'step6_rr: 19']
# empirical response rate 0.05669247787610619
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4344.910437079735
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.04112015031988603 0.12837493717486856 0.08725478685498253
# remaining size for Round 3: 140808
# Calculated size for Round 3: 11298.346701087328
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.45589200713272837 0.12261752156279518 -0.3332744855699332
# 20 0.45589200713272837 0.12261752156279518 early stop at Round 3
# early stop, remaining size for Round4: 129510
# 21
# ['step1_rr: 20', 'step2_rr: 20', 'step3_rr: 20', 'step4_rr: 20', 'step5_rr: 20', 'step6_rr: 20']
# empirical response rate 0.0547220685840708
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4207.666398075275
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.40772269445292897 0.3336322746572036 -0.07409041979572539
# 21 0.40772269445292897 0.3336322746572036 early stop at Round 2
# early stop, remaining size for Round3: 140945
# 22
# ['step1_rr: 21', 'step2_rr: 21', 'step3_rr: 21', 'step4_rr: 21', 'step5_rr: 21', 'step6_rr: 21']
# empirical response rate 0.05807522123893805
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4441.542106735752
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.010415749544945192 0.4028163965153612 0.39240064697041604
# remaining size for Round 3: 140711
# Calculated size for Round 3: 6725.781951065888
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.02454334268224397 0.08331438079234703 0.05877103811010306
# remaining size for Round 4: 133986
# Calculated size for Round 4: 9673.730076499292
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.1591655437439468 0.11930525302886963 -0.039860290715077185
# 22 0.1591655437439468 0.11930525302886963 early stop at Round 4
# early stop, remaining size for Round5: 124313
# 23
# ['step1_rr: 22', 'step2_rr: 22', 'step3_rr: 22', 'step4_rr: 22', 'step5_rr: 22', 'step6_rr: 22']
# empirical response rate 0.054756637168141595
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4210.069564273832
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.010651263378898893 0.28997586562953476 0.2793246022506359
# remaining size for Round 3: 140942
# Calculated size for Round 3: 8798.616475905426
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.039195804959094194 0.07470918620193298 0.03551338124283879
# remaining size for Round 4: 132144
# Calculated size for Round 4: 7110.124540698503
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.037402029751670895 0.08011330664157867 0.04271127688990778
# remaining size for Round 5: 125034
# 24
# ['step1_rr: 23', 'step2_rr: 23', 'step3_rr: 23', 'step4_rr: 23', 'step5_rr: 23', 'step6_rr: 23']
# empirical response rate 0.054756637168141595
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4210.069564273832
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.014928395825036907 0.30458874184301565 0.28966034601797874
# remaining size for Round 3: 140942
# Calculated size for Round 3: 7643.250469245383
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.06476810272692116 0.11625369693570337 0.05148559420878221
# remaining size for Round 4: 133299
# Calculated size for Round 4: 9190.210635773195
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.06464742365148399 0.08299042646390237 0.01834300281241838
# remaining size for Round 5: 124109
# Calculated size for Round 5: 6105.982646244788
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.029962734836526644 0.08321023732423782 0.05324750248771118
# remaining size for last Round 6: 118004
# 25
# ['step1_rr: 24', 'step2_rr: 24', 'step3_rr: 24', 'step4_rr: 24', 'step5_rr: 24', 'step6_rr: 24']
# empirical response rate 0.05406526548672566
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4162.037640283698
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.9096341539436961 0.7395668256607131 -0.170067328282983
# 25 0.9096341539436961 0.7395668256607131 early stop at Round 2
# early stop, remaining size for Round3: 140990
# 26
# ['step1_rr: 25', 'step2_rr: 25', 'step3_rr: 25', 'step4_rr: 25', 'step5_rr: 25', 'step6_rr: 25']
# empirical response rate 0.05254424778761062
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4056.600233593618
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.2248412580014162 0.2543465341821466 0.0295052761807304
# remaining size for Round 3: 141096
# Calculated size for Round 3: 16414.29159045659
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.006780440386132375 0.10656472073803852 0.09978428035190615
# remaining size for Round 4: 124682
# Calculated size for Round 4: 4973.81923750335
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.041047515872555826 0.0820852667093277 0.04103775083677187
# remaining size for Round 5: 119709
# 27
# ['step1_rr: 26', 'step2_rr: 26', 'step3_rr: 26', 'step4_rr: 26', 'step5_rr: 26', 'step6_rr: 26']
# empirical response rate 0.053201050884955754
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4102.090733905276
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.0174383319748255 0.11891576579921292 0.10147743382438743
# remaining size for Round 3: 141050
# Calculated size for Round 3: 8813.433596561377
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.5233456078569736 0.12483919830526988 -0.3985064095517037
# 27 0.5233456078569736 0.12483919830526988 early stop at Round 3
# early stop, remaining size for Round4: 132237
# 28
# ['step1_rr: 27', 'step2_rr: 27', 'step3_rr: 27', 'step4_rr: 27', 'step5_rr: 27', 'step6_rr: 27']
# empirical response rate 0.05849004424778761
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4470.5830227383985
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.013084940833495581 0.16905067872906582 0.15596573789557022
# remaining size for Round 3: 140682
# Calculated size for Round 3: 8082.633873449475
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.04057439507696627 0.14701646816166303 0.10644207308469675
# remaining size for Round 4: 132600
# Calculated size for Round 4: 8763.63431652378
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.04856649205225501 0.07374585846953033 0.02517936641727532
# remaining size for Round 5: 123837
# Calculated size for Round 5: 6897.46326208204
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.24304932355880737 0.12152466177940369 -0.12152466177940369
# 28 0.24304932355880737 0.12152466177940369 early stop at Round 5
# early stop, remaining size for Round6: 116940
# 29
# ['step1_rr: 28', 'step2_rr: 28', 'step3_rr: 28', 'step4_rr: 28', 'step5_rr: 28', 'step6_rr: 28']
# empirical response rate 0.05537887168141593
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4253.354805576213
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.7316104168847719 0.12096703529776512 -0.6106433815870068
# 29 0.7316104168847719 0.12096703529776512 early stop at Round 2
# early stop, remaining size for Round3: 140899
# 30
# ['step1_rr: 29', 'step2_rr: 29', 'step3_rr: 29', 'step4_rr: 29', 'step5_rr: 29', 'step6_rr: 29']
# empirical response rate 0.056173949115044246
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4308.741586307481
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.4833332300186157 0.4833332300186157 0.0
# 30 0.4833332300186157 0.4833332300186157 early stop at Round 2
# early stop, remaining size for Round3: 140844
# 31
# ['step1_rr: 30', 'step2_rr: 30', 'step3_rr: 30', 'step4_rr: 30', 'step5_rr: 30', 'step6_rr: 30']
# empirical response rate 0.05517146017699115
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.026740591869956445 0.50315025699807 0.4764096651281136
# remaining size for Round 3: 140914
# Calculated size for Round 3: 5222.161723548463
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.017757105115395078 0.1509449816283855 0.1331878765129904
# remaining size for Round 4: 135692
# Calculated size for Round 4: 8467.987246588063
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.024104097915669597 0.0924235392068565 0.0683194412911869
# remaining size for Round 5: 127225
# Calculated size for Round 5: 7569.214652553387
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.06308473884873715 0.1233649030327797 0.06028016418404254
# remaining size for last Round 6: 119656
# 32
# ['step1_rr: 31', 'step2_rr: 31', 'step3_rr: 31', 'step4_rr: 31', 'step5_rr: 31', 'step6_rr: 31']
# empirical response rate 0.05544800884955752
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4258.167580221075
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.01173816777249629 0.13546599364406062 0.12372782587156433
# remaining size for Round 3: 140894
# Calculated size for Round 3: 9409.46034346927
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.34103652834892273 0.11367884278297424 -0.2273576855659485
# 32 0.34103652834892273 0.11367884278297424 early stop at Round 3
# early stop, remaining size for Round4: 131485
# 33
# ['step1_rr: 32', 'step2_rr: 32', 'step3_rr: 32', 'step4_rr: 32', 'step5_rr: 32', 'step6_rr: 32']
# empirical response rate 0.05482577433628318
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4214.876392356589
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# orr termination 0.016024725555561177 0.446395965931776 0.4303712403762148
# remaining size for Round 3: 140938
# Calculated size for Round 3: 6070.882633985182
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# orr termination 0.042528670673944016 0.09372014559336933 0.051191474919425314
# remaining size for Round 4: 134868
# Calculated size for Round 4: 9754.597470047704
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.05024597877787067 0.08833498239635454 0.03808900361848387
# remaining size for Round 5: 125114
# Calculated size for Round 5: 6698.339821895007
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.02192336055008141 0.10686514526605606 0.08494178471597465
# remaining size for last Round 6: 118416
# 34
# ['step1_rr: 33', 'step2_rr: 33', 'step3_rr: 33', 'step4_rr: 33', 'step5_rr: 33', 'step6_rr: 33']
# empirical response rate 0.054756637168141595
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4210.069564273832
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.09723292120776184 0.3059202341914936 0.20868731298373178
# remaining size for Round 3: 140942
# Calculated size for Round 3: 5472.480893308573
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.014899109969531643 0.14370887361689505 0.1288097636473634
# remaining size for Round 4: 135470
# Calculated size for Round 4: 5499.592296236887
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.055578813605515934 0.11980315774257841 0.06422434413706248
# remaining size for Round 5: 129971
# Calculated size for Round 5: 8539.106283703652
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.062241992615210864 0.10949862188989612 0.047256629274685255
# remaining size for last Round 6: 121432
# 35
# ['step1_rr: 34', 'step2_rr: 34', 'step3_rr: 34', 'step4_rr: 34', 'step5_rr: 34', 'step6_rr: 34']
# empirical response rate 0.05548257743362832
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4260.5742152468165
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.13405318462146917 0.1277089630035026 -0.006344221617966578
# 35 0.13405318462146917 0.1277089630035026 early stop at Round 2
# early stop, remaining size for Round3: 140892
# 36
# ['step1_rr: 35', 'step2_rr: 35', 'step3_rr: 35', 'step4_rr: 35', 'step5_rr: 35', 'step6_rr: 35']
# empirical response rate 0.05479120575221239
# Best fit parameters: {'XGB__learning_rate': 1, 'XGB__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4212.472895702519
# Best fit parameters: {'XGB__learning_rate': 1, 'XGB__n_estimators': 50}
# orr termination 0.019807574653807076 0.10406843182453704 0.08426085717072997
# remaining size for Round 3: 140940
# Calculated size for Round 3: 9141.33899146933
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.06106023284039391 0.07205799956666192 0.01099776672626801
# remaining size for Round 4: 131799
# Calculated size for Round 4: 6799.282269416522
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.05598253466424982 0.06636035359441735 0.010377818930167523
# remaining size for Round 5: 125000
# Calculated size for Round 5: 5605.576202218308
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.022327599360333867 0.1001569852232933 0.07782938586295944
# remaining size for last Round 6: 119395
# 37
# ['step1_rr: 36', 'step2_rr: 36', 'step3_rr: 36', 'step4_rr: 36', 'step5_rr: 36', 'step6_rr: 36']
# empirical response rate 0.054272676991150445
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4176.440275580975
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.35911862475847145 0.3456106559072259 -0.013507968851245555
# 37 0.35911862475847145 0.3456106559072259 early stop at Round 2
# early stop, remaining size for Round3: 140976
# 38
# ['step1_rr: 37', 'step2_rr: 37', 'step3_rr: 37', 'step4_rr: 37', 'step5_rr: 37', 'step6_rr: 37']
# empirical response rate 0.05333932522123894
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4111.675292416549
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.11937019403087262 0.46858719296021223 0.3492169989293396
# remaining size for Round 3: 141041
# Calculated size for Round 3: 7852.0251309891955
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.0060079125963598615 0.24866794049739838 0.24266002790103852
# remaining size for Round 4: 133189
# 39
# ['step1_rr: 38', 'step2_rr: 38', 'step3_rr: 38', 'step4_rr: 38', 'step5_rr: 38', 'step6_rr: 38']
# empirical response rate 0.05278622787610619
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4073.3529413786146
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 200}
# orr termination 0.016776193661110782 0.2526603845213554 0.23588419086024465
# remaining size for Round 3: 141079
# Calculated size for Round 3: 8755.600017250303
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.0416110706108513 0.08646332337186044 0.04485225276100914
# remaining size for Round 4: 132324
# Calculated size for Round 4: 7685.097457931104
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.01773524770927339 0.07037893682718277 0.052643689117909384
# remaining size for Round 5: 124639
# 40
# ['step1_rr: 39', 'step2_rr: 39', 'step3_rr: 39', 'step4_rr: 39', 'step5_rr: 39', 'step6_rr: 39']
# empirical response rate 0.05420353982300885
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4171.638735916014
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# orr termination 0.007992294199240028 0.19096167385578156 0.18296937965654153
# remaining size for Round 3: 140981
# 41
# ['step1_rr: 40', 'step2_rr: 40', 'step3_rr: 40', 'step4_rr: 40', 'step5_rr: 40', 'step6_rr: 40']
# empirical response rate 0.058213495575221236
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4451.219776662242
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.16067367030855884 0.12112324515095045 -0.039550425157608385
# 41 0.16067367030855884 0.12112324515095045 early stop at Round 2
# early stop, remaining size for Round3: 140701
# 42
# ['step1_rr: 41', 'step2_rr: 41', 'step3_rr: 41', 'step4_rr: 41', 'step5_rr: 41', 'step6_rr: 41']
# empirical response rate 0.05389242256637168
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4150.039990556384
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.014018450706712822 0.2387195334492004 0.2247010827424876
# remaining size for Round 3: 141002
# Calculated size for Round 3: 6687.281086861952
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.05658921076443956 0.19184157680501362 0.13525236604057406
# remaining size for Round 4: 134315
# Calculated size for Round 4: 11550.7021576398
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.03507669490482174 0.07376331451273517 0.03868661960791343
# remaining size for Round 5: 122765
# Calculated size for Round 5: 6064.772834393846
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.052114848589914456 0.10249533504247665 0.0503804864525622
# remaining size for last Round 6: 116701
# 43
# ['step1_rr: 42', 'step2_rr: 42', 'step3_rr: 42', 'step4_rr: 42', 'step5_rr: 42', 'step6_rr: 42']
# empirical response rate 0.053477599557522126
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4121.262497623935
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.008371118505732982 0.12989077802766158 0.1215196595219286
# remaining size for Round 3: 141031
# Calculated size for Round 3: 7535.857617573148
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.3636253997683525 0.20201411098241806 -0.16161128878593445
# 43 0.3636253997683525 0.20201411098241806 early stop at Round 3
# early stop, remaining size for Round4: 133496
# 44
# ['step1_rr: 43', 'step2_rr: 43', 'step3_rr: 43', 'step4_rr: 43', 'step5_rr: 43', 'step6_rr: 43']
# empirical response rate 0.055413440265486724
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4255.761110329247
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.012645078159227385 0.13036855125748575 0.11772347309825837
# remaining size for Round 3: 140897
# Calculated size for Round 3: 11548.762792838943
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.06061040826921861 0.1214928925037384 0.06088248423451979
# remaining size for Round 4: 129349
# 45
# ['step1_rr: 44', 'step2_rr: 44', 'step3_rr: 44', 'step4_rr: 44', 'step5_rr: 44', 'step6_rr: 44']
# empirical response rate 0.05579369469026549
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4282.241360696144
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.007842024353761821 0.13734589936569624 0.12950387501193442
# remaining size for Round 3: 140870
# Calculated size for Round 3: 6468.535978364956
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.018706727630871545 0.09332074970006943 0.07461402206919789
# remaining size for Round 4: 134402
# 46
# ['step1_rr: 45', 'step2_rr: 45', 'step3_rr: 45', 'step4_rr: 45', 'step5_rr: 45', 'step6_rr: 45']
# empirical response rate 0.05486034292035398
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4217.280054231296
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.19310896803981115 0.2141498561051952 0.021040888065384067
# remaining size for Round 3: 140935
# Calculated size for Round 3: 8315.77519266085
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.006603236739342776 0.19683652213516603 0.19023328539582327
# remaining size for Round 4: 132620
# Calculated size for Round 4: 6154.92028192048
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.24401947855949402 0.12200973927974701 -0.12200973927974701
# 46 0.24401947855949402 0.12200973927974701 early stop at Round 4
# early stop, remaining size for Round5: 126466
# 47
# ['step1_rr: 46', 'step2_rr: 46', 'step3_rr: 46', 'step4_rr: 46', 'step5_rr: 46', 'step6_rr: 46']
# empirical response rate 0.054307245575221236
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4178.841293359456
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.021628341362252362 0.13925768075943423 0.11762933939718187
# remaining size for Round 3: 140974
# Calculated size for Round 3: 10239.616142774683
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.3184670631038137 0.1903872429798348 -0.12807982012397887
# 47 0.3184670631038137 0.1903872429798348 early stop at Round 3
# early stop, remaining size for Round4: 130735
# 48
# ['step1_rr: 47', 'step2_rr: 47', 'step3_rr: 47', 'step4_rr: 47', 'step5_rr: 47', 'step6_rr: 47']
# empirical response rate 0.055862831858407076
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4287.058097965914
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.03367670975080505 0.12654672529437785 0.0928700155435728
# remaining size for Round 3: 140865
# Calculated size for Round 3: 5726.981709665779
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.040152914225994416 0.2184529912031018 0.17830007697710737
# remaining size for Round 4: 135139
# Calculated size for Round 4: 8644.818905001104
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.058431074869449574 0.09931608188199176 0.040885007012542184
# remaining size for Round 5: 126495
# Calculated size for Round 5: 6938.216723966128
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.16215967092681866 0.12168680131435394 -0.04047286961246471
# 48 0.16215967092681866 0.12168680131435394 early stop at Round 5
# early stop, remaining size for Round6: 119557
# 49
# ['step1_rr: 48', 'step2_rr: 48', 'step3_rr: 48', 'step4_rr: 48', 'step5_rr: 48', 'step6_rr: 48']
# empirical response rate 0.05658877212389381
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4337.673697209837
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.02238817981743689 0.2689760634843488 0.24658788366691192
# remaining size for Round 3: 140815
# Calculated size for Round 3: 10328.441664265862
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.07929847818276493 0.19733081357291565 0.11803233539015072
# remaining size for Round 4: 130487
# Calculated size for Round 4: 6770.240661741892
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.2369966357946396 0.1184983178973198 -0.1184983178973198
# 49 0.2369966357946396 0.1184983178973198 early stop at Round 4
# early stop, remaining size for Round5: 123717
# 50
# ['step1_rr: 49', 'step2_rr: 49', 'step3_rr: 49', 'step4_rr: 49', 'step5_rr: 49', 'step6_rr: 49']
# empirical response rate 0.05793694690265487
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4431.867072682371
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.05474687181413174 0.2928143947230165 0.23806752290888478
# remaining size for Round 3: 140721
# Calculated size for Round 3: 29013
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.2019069638356818 0.12022775942832375 -0.08167920440735804
# 50 0.2019069638356818 0.12022775942832375 early stop at Round 3
# early stop, remaining size for Round4: 111708
# 51
# ['step1_rr: 50', 'step2_rr: 50', 'step3_rr: 50', 'step4_rr: 50', 'step5_rr: 50', 'step6_rr: 50']
# empirical response rate 0.05548257743362832
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4260.5742152468165
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# orr termination 0.03261191652359994 0.10326931504713568 0.07065739852353575
# remaining size for Round 3: 140892
# Calculated size for Round 3: 8103.500693158688
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.021915402122578028 0.08740603350242651 0.06549063137984848
# remaining size for Round 4: 132789
# Calculated size for Round 4: 7346.340433454681
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.034012154475208875 0.08346396953030995 0.04945181505510107
# remaining size for Round 5: 125443
# Calculated size for Round 5: 7145.586847253888
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.24367006123065948 0.12183503061532974 -0.12183503061532974
# 51 0.24367006123065948 0.12183503061532974 early stop at Round 5
# early stop, remaining size for Round6: 118298
# 52
# ['step1_rr: 51', 'step2_rr: 51', 'step3_rr: 51', 'step4_rr: 51', 'step5_rr: 51', 'step6_rr: 51']
# empirical response rate 0.05420353982300885
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4171.638735916014
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.03185444697737694 0.509671151638031 0.47781670466065407
# remaining size for Round 3: 140981
# 53
# ['step1_rr: 52', 'step2_rr: 52', 'step3_rr: 52', 'step4_rr: 52', 'step5_rr: 52', 'step6_rr: 52']
# empirical response rate 0.055240597345132744
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4243.731238049317
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.05939217068283727 0.16883611144383448 0.10944394076099721
# remaining size for Round 3: 140909
# Calculated size for Round 3: 6910.510523684109
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.010716245237458549 0.12929710745811462 0.11858086222065607
# remaining size for Round 4: 133999
# Calculated size for Round 4: 6453.410217664419
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# orr termination 0.03850093483924866 0.15400373935699463 0.11550280451774597
# remaining size for Round 5: 127546
# 54
# ['step1_rr: 53', 'step2_rr: 53', 'step3_rr: 53', 'step4_rr: 53', 'step5_rr: 53', 'step6_rr: 53']
# empirical response rate 0.05392699115044248
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4152.439189827319
# Best fit parameters: {'XGB__learning_rate': 1, 'XGB__n_estimators': 50}
# orr termination 0.032881530219467825 1.5963354988278118 1.563453968608344
# remaining size for Round 3: 141000
# Calculated size for Round 3: 7684.979830233924
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.1457179277808288 0.12478614754638857 -0.020931780234440214
# 54 0.1457179277808288 0.12478614754638857 early stop at Round 3
# early stop, remaining size for Round4: 133316
# 55
# ['step1_rr: 54', 'step2_rr: 54', 'step3_rr: 54', 'step4_rr: 54', 'step5_rr: 54', 'step6_rr: 54']
# empirical response rate 0.055240597345132744
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4243.731238049317
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.031771739163469016 0.4688461047850073 0.4370743656215383
# remaining size for Round 3: 140909
# Calculated size for Round 3: 6641.109148570929
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# ...
# empirical response rate 0.055689988938053096
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4275.017492939368
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.06245077165663622 0.12706536375036248 0.06461459209372626
# remaining size for Round 3: 140877
# Calculated size for Round 3: 12350.44683059045
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.0738911365848394 0.10214338191813357 0.02825224533329418
# remaining size for Round 4: 128527
# Calculated size for Round 4: 5851.9018940982405
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.05553205315102784 0.08345065114531298 0.027918597994285144
# remaining size for Round 5: 122676
# Calculated size for Round 5: 5889.884624587467
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.5062341590729351 0.11779540450037924 -0.3884387545725559
# 75 0.5062341590729351 0.11779540450037924 early stop at Round 5
# early stop, remaining size for Round6: 116787
# 76
# ['step1_rr: 75', 'step2_rr: 75', 'step3_rr: 75', 'step4_rr: 75', 'step5_rr: 75', 'step6_rr: 75']
# empirical response rate 0.0537195796460177
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4138.04647448891
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.017785102190616138 0.25111396393953733 0.2333288617489212
# remaining size for Round 3: 141014
# Calculated size for Round 3: 8368.030381866318
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.448129647985856 0.11929213503560132 -0.32883751295025465
# 76 0.448129647985856 0.11929213503560132 early stop at Round 3
# early stop, remaining size for Round4: 132646
# 77
# ['step1_rr: 76', 'step2_rr: 76', 'step3_rr: 76', 'step4_rr: 76', 'step5_rr: 76', 'step6_rr: 76']
# empirical response rate 0.05441095132743363
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4186.045338423161
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.027547625603471893 0.20669199701643756 0.17914437141296566
# remaining size for Round 3: 140966
# Calculated size for Round 3: 10815.514156886606
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# orr termination 0.01765556650608355 0.08041846806379432 0.06276290155771078
# remaining size for Round 4: 130151
# Calculated size for Round 4: 6846.630995106093
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.05983519171546901 0.12327639013528824 0.06344119841981923
# remaining size for Round 5: 123305
# 78
# ['step1_rr: 77', 'step2_rr: 77', 'step3_rr: 77', 'step4_rr: 77', 'step5_rr: 77', 'step6_rr: 77']
# empirical response rate 0.05437638274336283
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4183.643824785205
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.041101866965004626 0.23361777138401282 0.1925159044190082
# remaining size for Round 3: 140969
# Calculated size for Round 3: 7822.317905309181
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.032616350468234565 0.10023152778560213 0.06761517731736756
# remaining size for Round 4: 133147
# Calculated size for Round 4: 6791.581531304317
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# orr termination 0.0465103647940878 0.07886716087548026 0.03235679608139246
# remaining size for Round 5: 126356
# Calculated size for Round 5: 7437.876884027376
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.0657898054872374 0.08602982964565278 0.020240024158415387
# remaining size for last Round 6: 118919
# 79
# ['step1_rr: 78', 'step2_rr: 78', 'step3_rr: 78', 'step4_rr: 78', 'step5_rr: 78', 'step6_rr: 78']
# empirical response rate 0.05520602876106195
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4241.325759063171
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.018078914554440807 0.31107191063271855 0.2929929960782777
# remaining size for Round 3: 140911
# Calculated size for Round 3: 5607.934518630059
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.11231875997047602 0.12722906115024768 0.014910301179771657
# remaining size for Round 4: 135304
# Calculated size for Round 4: 9590.430213970023
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.04134157338266209 0.1576153208435419 0.11627374746087982
# remaining size for Round 5: 125714
# Calculated size for Round 5: 6971.3826695264315
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.061587665580817325 0.07540842179728502 0.013820756216467694
# remaining size for last Round 6: 118743
# 80
# ['step1_rr: 79', 'step2_rr: 79', 'step3_rr: 79', 'step4_rr: 79', 'step5_rr: 79', 'step6_rr: 79']
# empirical response rate 0.057591261061946904
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4407.691021764351
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.027800666090598898 0.34678159307255096 0.3189809269819521
# remaining size for Round 3: 140745
# Calculated size for Round 3: 5777.208367058775
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.012886697132895125 0.190170940555965 0.1772842434230699
# remaining size for Round 4: 134968
# Calculated size for Round 4: 9917.942979009524
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.06015688124150897 0.1171698048710823 0.05701292362957334
# remaining size for Round 5: 125051
# 81
# ['step1_rr: 80', 'step2_rr: 80', 'step3_rr: 80', 'step4_rr: 80', 'step5_rr: 80', 'step6_rr: 80']
# empirical response rate 0.05489491150442478
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4219.683881321882
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.24557684160062784 0.2248798076066779 -0.020697033993949954
# 81 0.24557684160062784 0.2248798076066779 early stop at Round 2
# early stop, remaining size for Round3: 140933
# 82
# ['step1_rr: 81', 'step2_rr: 81', 'step3_rr: 81', 'step4_rr: 81', 'step5_rr: 81', 'step6_rr: 81']
# empirical response rate 0.0546529314159292
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4202.860561387483
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 3.0525988029161186 0.3569905999058414 -2.695608203010277
# 82 3.0525988029161186 0.3569905999058414 early stop at Round 2
# early stop, remaining size for Round3: 140950
# 83
# ['step1_rr: 82', 'step2_rr: 82', 'step3_rr: 82', 'step4_rr: 82', 'step5_rr: 82', 'step6_rr: 82']
# empirical response rate 0.05441095132743363
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4186.045338423161
# Best fit parameters: {'XGB__learning_rate': 1, 'XGB__n_estimators': 50}
# orr termination 0.04111576893924243 0.37333186285734926 0.3322160939181068
# remaining size for Round 3: 140966
# Calculated size for Round 3: 5196.5200965967215
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.09858326955832833 0.12392143620192743 0.0253381666435991
# remaining size for Round 4: 135770
# Calculated size for Round 4: 5925.871398474284
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.10212489486009457 0.20793666581761144 0.10581177095751687
# remaining size for Round 5: 129845
# Calculated size for Round 5: 6814.299661361296
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.014234662778742952 0.17071040825506612 0.15647574547632317
# remaining size for last Round 6: 123031
# 84
# ['step1_rr: 83', 'step2_rr: 83', 'step3_rr: 83', 'step4_rr: 83', 'step5_rr: 83', 'step6_rr: 83']
# empirical response rate 0.05513689159292035
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4236.515296599448
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.03001149428463447 0.3245680346767385 0.29455654039210405
# remaining size for Round 3: 140916
# Calculated size for Round 3: 5279.193035478832
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.022781605310546054 0.09957649866589391 0.07679489335534785
# remaining size for Round 4: 135637
# Calculated size for Round 4: 6666.521011098026
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.03543186806634594 0.11140842908502217 0.07597656101867623
# remaining size for Round 5: 128971
# Calculated size for Round 5: 8107.413371354514
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.01766848119152043 0.07089578360319138 0.053227302411670945
# remaining size for last Round 6: 120864
# 85
# ['step1_rr: 84', 'step2_rr: 84', 'step3_rr: 84', 'step4_rr: 84', 'step5_rr: 84', 'step6_rr: 84']
# empirical response rate 0.05513689159292035
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4236.515296599448
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.03142107239245316 0.0918570840778748 0.060436011685421634
# remaining size for Round 3: 140916
# Calculated size for Round 3: 13358.143173802078
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.4209943670581988 0.1749089489789539 -0.24608541807924492
# 85 0.4209943670581988 0.1749089489789539 early stop at Round 3
# early stop, remaining size for Round4: 127558
# 86
# ['step1_rr: 85', 'step2_rr: 85', 'step3_rr: 85', 'step4_rr: 85', 'step5_rr: 85', 'step6_rr: 85']
# empirical response rate 0.054134402654867256
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4166.8378574712715
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.056028903346788235 0.29751909945996957 0.24149019611318134
# remaining size for Round 3: 140986
# Calculated size for Round 3: 6676.260171957849
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.03140179705529107 0.12876897919689878 0.09736718214160771
# remaining size for Round 4: 134310
# Calculated size for Round 4: 6453.850046261625
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.05586816392429355 0.12268004452927116 0.06681188060497761
# remaining size for Round 5: 127857
# Calculated size for Round 5: 9001.43041424069
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.02567530754045457 0.12342315912246704 0.09774785158201246
# remaining size for last Round 6: 118856
# 87
# ['step1_rr: 86', 'step2_rr: 86', 'step3_rr: 86', 'step4_rr: 86', 'step5_rr: 86', 'step6_rr: 86']
# empirical response rate 0.05534430309734513
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4250.948665966841
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.05918805203662208 0.09135196073767544 0.032163908701053366
# remaining size for Round 3: 140902
# Calculated size for Round 3: 15403.401520958072
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.059474000896559805 0.0762020741523445 0.016728073255784702
# remaining size for Round 4: 125499
# Calculated size for Round 4: 5901.1996904051375
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 50}
# orr termination 0.06471363879016515 0.075752111138636 0.011038472348470857
# remaining size for Round 5: 119598
# Calculated size for Round 5: 5867.888467392215
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.057325613605918 0.08661870962829044 0.029293096022372435
# remaining size for last Round 6: 113731
# 88
# ['step1_rr: 87', 'step2_rr: 87', 'step3_rr: 87', 'step4_rr: 87', 'step5_rr: 87', 'step6_rr: 87']
# empirical response rate 0.05527516592920354
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4246.136882198541
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 200}
# orr termination 0.036034568221944015 0.2973217296717555 0.2612871614498115
# remaining size for Round 3: 140906
# Calculated size for Round 3: 6646.005788498249
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.04851315864888037 0.12535513983712782 0.07684198118824745
# remaining size for Round 4: 134260
# Calculated size for Round 4: 7164.288592710603
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.1670639656534628 0.19646465318075504 0.029400687527292246
# remaining size for Round 5: 127096
# Calculated size for Round 5: 7432.081300412493
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.4910850274993593 0.20120956935477063 -0.28987545814458865
# 88 0.4910850274993593 0.20120956935477063 early stop at Round 5
# early stop, remaining size for Round6: 119664
# 89
# ['step1_rr: 88', 'step2_rr: 88', 'step3_rr: 88', 'step4_rr: 88', 'step5_rr: 88', 'step6_rr: 88']
# empirical response rate 0.054618362831858405
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4200.457890907699
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 100}
# orr termination 0.009371145991894834 0.2387592997493415 0.22938815375744667
# remaining size for Round 3: 140952
# Calculated size for Round 3: 7929.812881982416
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.12001364938097868 0.11655362695455551 -0.0034600224264231677
# 89 0.12001364938097868 0.11655362695455551 early stop at Round 3
# early stop, remaining size for Round4: 133023
# 90
# ['step1_rr: 89', 'step2_rr: 89', 'step3_rr: 89', 'step4_rr: 89', 'step5_rr: 89', 'step6_rr: 89']
# empirical response rate 0.05403069690265487
# Best fit parameters: {'XGB__learning_rate': 0.1, 'XGB__n_estimators': 100}
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4159.637779672868
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.022980148818134944 0.13051078965921042 0.10753064084107548
# remaining size for Round 3: 140993
# Calculated size for Round 3: 7526.984599865798
# Best fit parameters: {'XGB__learning_rate': 0.01, 'XGB__n_estimators': 50}
# orr termination 0.2004506578108024 0.15006738636892664 -0.050383271441875765
# 90 0.2004506578108024 0.15006738636892664 early stop at Round 3
# early stop, remaining size for Round4: 133467
# 91
# ['step1_rr: 90', 'step2_rr: 90', 'step3_rr: 90', 'step4_rr: 90', 'step5_rr: 90', 'step6_rr: 90']
# empirical response rate 0.05596653761061947

# %% [markdown]
# ### Results summary

# %%
rr_df = pd.DataFrame(rr_dict)
rr_df

# %%
# Calculate average rounds:
row_non_nan_counts = rr_df.count(axis=1)

print(f"{np.mean(row_non_nan_counts):.1f} ({np.std(row_non_nan_counts):.1f})")

# %%
result_dict = {}
for key, values in rr_df.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"

for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")

# %%
result_dict = np.array(orr_total) / total_n
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f}, StD: {std_result:.3f}")

# %%
print(np.mean(highest_rr_overall))
print(np.std(highest_rr_overall))

# %%
result_dict = np.array(orr_total_adaptive) / (total_n-34976)
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f}, StD: {std_result:.3f}")

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in plan_number_dict.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.1f} ({std_value:.1f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")

# %%
means = {key: np.mean(values) for key, values in stopping_dict.items()}
means

# %%
print(np.mean(last_round_sample_size), np.std(last_round_sample_size))

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in sample_size_dict.items():
    mean_value = np.nanmean(values)
    std_value = np.nanstd(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")

# %% [markdown]
# ## Ensemble learning - 3 methods

# %%
# def ensemble_model_fit(data, data_pred):
#     X_train, X_test, y_train, y_test = train_test_split(
#         data.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1),
#         data['response'],
#         test_size=0.2,
#         random_state=0
#     )

#     # Define the VotingClassifier with the individual classifiers
#     voting_classifier = ensemble.VotingClassifier(
#         estimators=[
#             ('LR', linear_model.LogisticRegression(max_iter=200, random_state=0)),
# #             ('Ridge', linear_model.LogisticRegression(penalty='l2', solver='lbfgs', max_iter=200, random_state=0))
#                     # ('SVM', svm.SVC(kernel='linear', C=1.0, random_state=0, probability=True, class_weight='balanced'))
#                     ('RF', ensemble.RandomForestClassifier(criterion='gini', random_state=0)),
#                     ('XGB', XGBClassifier(learning_rate=0.1, random_state=0))
#                    ],
#         voting='soft'
#     )

#     # Define the hyperparameter grid to search
#     # Best Hyperparameters: {'LR__C': 0.01, 'RF__n_estimators': 50, 'XGB__n_estimators': 50}
#     param_grid = {
#         # 'NB__alpha': [0.01, 0.05, 0.1],  # '__' is used to specify hyperparameters for individual classifiers
#         'LR__C': [0.01, 0.05, 0.1],
#         # 'Ridge__C': [0.01]
#         # 'SVM__C': [0.01, 0.05, 0.1]
#         'RF__n_estimators': [50, 100, 200],
#         'XGB__n_estimators': [50, 100, 200]
#     }

#     # Create a GridSearchCV object
#     # custom_scorer_auc = make_scorer(roc_auc_score, needs_proba=True)
#     grid_search = GridSearchCV(voting_classifier, param_grid, cv=10, scoring='roc_auc')

#     # Perform the grid search on the training data
#     grid_search.fit(X_train, y_train)

#     # Get the best hyperparameters
#     best_params = grid_search.best_params_
#     # Print the best fitted parameters
#     print("Best fitted parameters:")
#     print(best_params)

#     # Train the final VotingClassifier with the best hyperparameters on the full training set
#     final_voting_classifier = grid_search.best_estimator_
#     final_voting_classifier.fit(X_train, y_train)

#     # Predict probabilities instead of binary outcomes on the test set
#     y_pred_proba_test = final_voting_classifier.predict_proba(X_test)
#     y_pred_test = final_voting_classifier.predict(X_test)
#     X_dt = data_pred.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1)
#     y_pred = final_voting_classifier.predict_proba(X_dt)

#     return y_pred

# %%
def ensemble_model_fit(data, data_pred):
    X_train, X_test, y_train, y_test = train_test_split(
        data.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1),
        data['response'],
        test_size=0.2,
        random_state=0
    )

    # Define the VotingClassifier with the individual classifiers
    voting_classifier = ensemble.VotingClassifier(
        estimators=[
            ('LR', linear_model.LogisticRegression(max_iter=200, random_state=0)),
#             ('Ridge', linear_model.LogisticRegression(penalty='l2', solver='lbfgs', max_iter=200, random_state=0))
                    # ('SVM', svm.SVC(kernel='linear', C=1.0, random_state=0, probability=True, class_weight='balanced'))
                    ('RF', ensemble.RandomForestClassifier(criterion='gini', random_state=0)),
                    ('XGB', XGBClassifier(learning_rate=0.1, random_state=0))
                   ],
        voting='soft'
    )

    # Define the hyperparameter grid to search
    # Best Hyperparameters: {'LR__C': 0.01, 'RF__n_estimators': 50, 'XGB__n_estimators': 50}
    param_grid = {
        # 'NB__alpha': [0.01, 0.05, 0.1],  # '__' is used to specify hyperparameters for individual classifiers
        'LR__C': [0.05],
        # 'Ridge__C': [0.01]
        # 'SVM__C': [0.05]
        'RF__n_estimators': [100],
        'XGB__n_estimators': [50]
    }

    # Create a GridSearchCV object
    # custom_scorer_auc = make_scorer(roc_auc_score, needs_proba=True)
    grid_search = GridSearchCV(voting_classifier, param_grid, cv=10, scoring='roc_auc')

    # Perform the grid search on the training data
    grid_search.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = grid_search.best_params_

    # Train the final VotingClassifier with the best hyperparameters on the full training set
    final_voting_classifier = grid_search.best_estimator_
    final_voting_classifier.fit(X_train, y_train)

    # Predict probabilities instead of binary outcomes on the test set
    y_pred_proba_test = final_voting_classifier.predict_proba(X_test)
    y_pred_test = final_voting_classifier.predict(X_test)
    X_dt = data_pred.drop(['recruitment_plan','plan_response_rate','group_size','response'], axis=1)
    y_pred = final_voting_classifier.predict_proba(X_dt)

    return y_pred

# %%
# from sklearn.linear_model import LogisticRegression
# from sklearn.model_selection import train_test_split

# def ensemble_model_fit(data, data_pred):
#     # Split the data into training and testing sets
#     X_train, X_test, y_train, y_test = train_test_split(
#         data.drop(['recruitment_plan', 'plan_response_rate', 'group_size','response'], axis=1),
#         data['response'],
#         test_size=0.2,
#         random_state=0
#     )

#     # Define the Logistic Regression model
#     logistic_regression = LogisticRegression(C=0.01, max_iter=200,random_state=0)

#     # Fit the Logistic Regression model on the training data
#     logistic_regression.fit(X_train, y_train)

#     # Print out the coefficients of the logistic regression model
#     print("Coefficients:", logistic_regression.coef_)
#     print("Intercept:", logistic_regression.intercept_)
#     print("Coefficients shape:", logistic_regression.coef_.shape)

#     # Predict probabilities instead of binary outcomes on the test set
#     y_pred_proba_test = logistic_regression.predict_proba(X_test)
#     y_pred_test = logistic_regression.predict(X_test)

#     # You can also predict probabilities for the prediction data (data_pred)
#     X_dt = data_pred.drop(['recruitment_plan', 'plan_response_rate', 'group_size','response'], axis=1)
#     y_pred = logistic_regression.predict_proba(X_dt)

#     return y_pred

# # Call the function
# # ensemble_model_fit(data, data_pred)

# %% [markdown]
# ### Simulation starts

# %%
n_sim = 100
# create a list of random seeds
random.seed(42)
random_seeds = [random.randint(1, 100000) for _ in range(n_sim)]

design_list = [5,8,10]
patient_n_list = [5468,680,170] # n_patient_per_plan

n_design = 8
n_patient_per_plan = 680
n_rounds = 6
total_n = n_patient_per_plan * (2**n_design)

## sample size determination
beta = 0.2
power = 1 - beta
alpha = 0.05
delta = 0.01 # effect size

## early stopping
epsilon = 0.001

# %%
rr_dict = {"step{}_rr".format(r): [] for r in range(1, n_rounds + 1)}
plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
sample_size_dict = {"step{}_sample_size".format(r): [] for r in range(1, n_rounds + 1)}
last_round_sample_size = []
random_rr_dict = {"step{}_random_max_rr".format(r): [] for r in range(1, n_rounds + 1)}
random_rr_dict.update({
    "step{}_random_mean_rr".format(r): [] for r in range(1, n_rounds + 1)
})

stopping_dict = {"early_stopping": [],
                 "early_stopping_plan":[],
                 "early_stopping_orr":[],
                 "early_stopping_size":[]}
final_plan_number = []
highest_rr_overall = []

better_chance = []

orr_total = []
orr_total_adaptive = []



i = 0

for seed in random_seeds:
    i += 1
    print(i)

    print([f"{key}: {len(value)}" for key, value in rr_dict.items()])



    event_list = 0
    event_list_adaptive = 0
    max_rr = []

    # step 1:
    ## Generate dataset
    dt_design_5 = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed)
    print("empirical response rate", dt_design_5['response'].mean())
    ## save for benchmark results
    maxidx = np.argmax(dt_design_5['plan_response_rate'])
    random_rr_dict['step1_random_max_rr'].append(dt_design_5.iloc[maxidx,6])
    random_rr_dict['step1_random_mean_rr'].append(dt_design_5['plan_response_rate'].mean())

    ## Ensemble modelling:
    y_pred = ensemble_model_fit(data=dt_design_5, data_pred = dt_design_5)

    ## select recruitment plan
    pred_df = pd.DataFrame(np.hstack((dt_design_5,  y_pred[:, 1].reshape(-1, 1))),
                             columns=list(dt_design_5.columns) + ['predicted_response_rate'])
    pred_df_rr = pred_df.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

    x = pred_df_rr['predicted_response_rate'].values
    if len(x) <= 10:
        best_k = 2
    else:
        best_k = kmeans_fit(data = x)['best_k']
    kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

    merged_df = pd.merge(pred_df_rr, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
    cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
    highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
    highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)


    p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))
    highest_cluster['p_vec'] = p_vec_next
    highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

    # highest_cluster = pred_df_rr

    # highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')
    # highest_cluster['cluster_number'] = highest_cluster['recruitment_plan']

    ## prepare to chance of better performance:
    temp = dt_design_5[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
    event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print("step1", np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print(temp)
    p0 = (temp['plan_response_rate'].mean())

    rr_dict["step1_rr"].append(dt_design_5['plan_response_rate'].mean())
    sample_size_dict["step1_sample_size"].append(len(dt_design_5))

    for round in range(2, n_rounds+1):

        rr_dict["step"+str(round)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))
        plan_number_dict["step"+str(round)+"_plan_number"].append(len(p_vec_next))

        ## when it comes to the last round:
        if round == n_rounds:

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            if round == 2: # if the last round is round 2
                remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
            else:
                remaining_size -= len(dt_design_5_step2up)

            print("remaining size for last Round " + str(round) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            ## data generation, combine previous data:
            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, round=round,
                                                          design_number = n_design, n_rounds = n_rounds,
                                                          n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(0)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(len(temp), temp['plan_response_rate'].mean())
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break



        ## If haven't reached the last round:
        ## check remaining sample size:
        if round == 2:
            remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
        else:
            remaining_size -= len(dt_design_5_step2up)

        print("remaining size for Round " + str(round) + ": " + str(remaining_size))

        ## determine whether move on to step 2:
        if len(highest_cluster) == 1: # if there is only one plan left

            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size) # record the last round sample size
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(1)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        ## sample size determination:
        if round == 2:
            dt_design_5_step2up_overall = dt_design_5
        orr_1 = dt_design_5_step2up_overall['response'].mean() # observed overall response rates for previous rounds
        orr_2 = orr_1 + delta
        n_1 = len(dt_design_5_step2up_overall)

        size_step2up = sample_size_calc(orr_1, n_1, delta=delta, alpha=alpha, power=power) # total size for dataset
        if size_step2up > 0 and size_step2up < 1000:
            size_step2up = 1000 # if size in [0,1000], then it is 1000 for this round.
        elif size_step2up >= 1000:
            size_step2up = min(size_step2up, int(total_n/n_rounds)) # dataset size capped by the n_patient_per_plan
        else:
        # if size_step2up <= 0:
            # the process stops at this step
            print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up) + 'lt 0, break')
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(1)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up))

        sample_size_dict["step"+str(round)+"_sample_size"].append(size_step2up)

        ## save benchmark results for last round:
        dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                            n_patient_per_plan = n_patient_per_plan, seed=seed+round)
        maxidx = np.argmax(dt_benchmark['plan_response_rate'])
        random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
        random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

        ## data generation, combine previous data:
        dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                  design_number = n_design, n_rounds = n_rounds,
                                                  n_patient_per_plan = n_patient_per_plan, size = int(size_step2up), seed=seed)

        plan_list = dt_design_5_step2up['recruitment_plan'].unique()
        if round == 2:
            supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)]
        else:
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
        dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
        dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

        ## Ensemble model fitting:
        dt_design_5_step2up.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)
        y_pred2up = ensemble_model_fit(data = dt_design_5_step2up_overall, data_pred = dt_design_5_step2up)
        pred_df_step2up = pd.DataFrame(np.hstack((dt_design_5_step2up,  y_pred2up[:, 1].reshape(-1, 1))),
                                    columns=list(dt_design_5_step2up.columns) + ['predicted_response_rate'])
        pred_df_rr_step2up = pred_df_step2up.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

        ## select recruitment plans:
        x = pred_df_rr_step2up['predicted_response_rate'].values

        if len(x) <= 10:
            best_k = 2
        else:
            best_k = kmeans_fit(data = x)['best_k']
        kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

        ## match the cluster results back to the original data
        highest_cluster_previous = highest_cluster # save previous cluster results

        merged_df = pd.merge(pred_df_rr_step2up, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
        cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
        highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
        highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)

        # p_vec_previous = p_vec_next # save p_vec of previous round
        p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))

        highest_cluster['p_vec'] = p_vec_next

        highest_cluster = pd.merge(highest_cluster, dt_design_5_step2up[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

        ## prepare to chance of better performance:
        temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
        event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print(temp)

        ## check early stopping predicted ORR:
        orr_df = pd.merge(highest_cluster_previous, highest_cluster[['recruitment_plan','predicted_response_rate','p_vec']], on='recruitment_plan', how='left')
        orr_df.fillna(0, inplace=True)
        p_orr_1 = np.dot(np.array(orr_df['p_vec_x']), np.array(orr_df['predicted_response_rate_y']))
        p_orr_2 = np.dot(np.array(orr_df['p_vec_y']), np.array(orr_df['predicted_response_rate_y']))
        print("orr termination", p_orr_1, p_orr_2, p_orr_2 - p_orr_1)

        if (p_orr_2 - p_orr_1 < epsilon):
            # step 3 use the same strategy of step2
            print(i, p_orr_1, p_orr_2, "early stop at Round " + str(round))
            rr_dict["step"+str(round+1)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                                n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round+1)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round+1)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            ### update remaining size:
            remaining_size -= len(dt_design_5_step2up)
            print("early stop, remaining size for Round" + str(round + 1) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            for r in range(round+2, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(1)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            for r in range(round+2, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round+1), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break
# Out:
# 1
# ['step1_rr: 0', 'step2_rr: 0', 'step3_rr: 0', 'step4_rr: 0', 'step5_rr: 0', 'step6_rr: 0']
# empirical response rate 0.05295907079646018
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4085.324125976102
# orr termination 0.01463903137611023 0.08982638556159091 0.07518735418548067
# remaining size for Round 3: 141067
# Calculated size for Round 3: 12223.008371224478
# orr termination 0.04002275760035494 0.07963577136267834 0.0396130137623234
# remaining size for Round 4: 128844
# Calculated size for Round 4: 6247.398449996775
# orr termination 0.03923737112962387 0.0783287470927136 0.03909137596308974
# remaining size for Round 5: 122597
# 2
# ['step1_rr: 1', 'step2_rr: 1', 'step3_rr: 1', 'step4_rr: 1', 'step5_rr: 1', 'step6_rr: 1']
# empirical response rate 0.056312223451327435
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4318.382983229351
# orr termination 0.017924446255585827 0.09104622071737775 0.07312177446179192
# remaining size for Round 3: 140834
# Calculated size for Round 3: 5718.128381379243
# orr termination 0.040306703718607305 0.08667108980654788 0.04636438608794057
# remaining size for Round 4: 135116
# Calculated size for Round 4: 8916.750412423204
# orr termination 0.046851056897978 0.07743572237688473 0.03058466547890673
# remaining size for Round 5: 126200
# Calculated size for Round 5: 6510.72133824719
# orr termination 0.06388288046473661 0.07632006391560639 0.012437183450869777
# remaining size for last Round 6: 119690
# 3
# ['step1_rr: 2', 'step2_rr: 2', 'step3_rr: 2', 'step4_rr: 2', 'step5_rr: 2', 'step6_rr: 2']
# empirical response rate 0.053650442477876106
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4133.2502256140915
# orr termination 0.02015360137647995 0.0919677816476127 0.07181418027113275
# remaining size for Round 3: 141019
# Calculated size for Round 3: 15624.850946718137
# orr termination 0.04007622445210515 0.07815084838376332 0.03807462393165817
# remaining size for Round 4: 125395
# Calculated size for Round 4: 5792.280570468397
# orr termination 0.037547688785286505 0.07506344793881695 0.03751575915353044
# remaining size for Round 5: 119603
# 4
# ['step1_rr: 3', 'step2_rr: 3', 'step3_rr: 3', 'step4_rr: 3', 'step5_rr: 3', 'step6_rr: 3']
# empirical response rate 0.05437638274336283
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4183.643824785205
# orr termination 0.004395994021198427 0.09204535111510277 0.08764935709390434
# remaining size for Round 3: 140969
# Calculated size for Round 3: 7223.464933855546
# orr termination 0.051674077626912535 0.0773565867105952 0.025682509083682664
# remaining size for Round 4: 133746
# Calculated size for Round 4: 8730.1327884196
# orr termination 0.03950838927299412 0.07836044988374656 0.03885206061075244
# remaining size for Round 5: 125016
# 5
# ['step1_rr: 4', 'step2_rr: 4', 'step3_rr: 4', 'step4_rr: 4', 'step5_rr: 4', 'step6_rr: 4']
# empirical response rate 0.05530973451327434
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4248.542691505998
# orr termination 0.01743284435704994 0.0819063385275588 0.06447349417050885
# remaining size for Round 3: 140904
# Calculated size for Round 3: 5351.96348913825
# orr termination 0.006525535029203116 0.09306854799886848 0.08654301296966536
# remaining size for Round 4: 135553
# Calculated size for Round 4: 8227.195412358325
# orr termination 0.04071518167995408 0.07882753446180514 0.03811235278185106
# remaining size for Round 5: 127326
# 6
# ['step1_rr: 5', 'step2_rr: 5', 'step3_rr: 5', 'step4_rr: 5', 'step5_rr: 5', 'step6_rr: 5']
# empirical response rate 0.05361587389380531
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4130.852349241689
# orr termination 0.0743136160131711 0.08025710914403389 0.005943493130862787
# remaining size for Round 3: 141022
# Calculated size for Round 3: 10725.170676779477
# orr termination 0.04794789491102959 0.07594576182504889 0.0279978669140193
# remaining size for Round 4: 130297
# Calculated size for Round 4: 5350.952446570766
# orr termination 0.05124033379693129 0.0736636900435641 0.02242335624663281
# remaining size for Round 5: 124947
# Calculated size for Round 5: 5554.684804991452
# orr termination 0.014945692698110715 0.07918146658292462 0.0642357738848139
# remaining size for last Round 6: 119393
# 7
# ['step1_rr: 6', 'step2_rr: 6', 'step3_rr: 6', 'step4_rr: 6', 'step5_rr: 6', 'step6_rr: 6']
# empirical response rate 0.05330475663716814
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4109.278904649849
# orr termination 0.054202570552889864 0.07703178754977669 0.022829216996886822
# remaining size for Round 3: 141043
# Calculated size for Round 3: 5615.567352336217
# orr termination 0.03785088210816335 0.08182479862476973 0.04397391651660638
# remaining size for Round 4: 135428
# Calculated size for Round 4: 5839.648180903657
# orr termination 0.009249745153768096 0.08495381932844326 0.07570407417467516
# remaining size for Round 5: 129589
# Calculated size for Round 5: 6347.187836727134
# orr termination 0.022731839321405514 0.09056509173191553 0.06783325241051001
# remaining size for last Round 6: 123242
# 8
# ['step1_rr: 7', 'step2_rr: 7', 'step3_rr: 7', 'step4_rr: 7', 'step5_rr: 7', 'step6_rr: 7']
# empirical response rate 0.055724557522123894
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4277.425283765311
# orr termination 0.019755070300457894 0.08429619201104492 0.06454112171058703
# remaining size for Round 3: 140875
# Calculated size for Round 3: 5672.534200910178
# orr termination 0.006806435164619946 0.09368225622142069 0.08687582105680075
# remaining size for Round 4: 135203
# Calculated size for Round 4: 8650.535765547784
# orr termination 0.04264007363833668 0.08514402809571031 0.04250395445737363
# remaining size for Round 5: 126553
# 9
# ['step1_rr: 8', 'step2_rr: 8', 'step3_rr: 8', 'step4_rr: 8', 'step5_rr: 8', 'step6_rr: 8']
# empirical response rate 0.05676161504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4349.735755102456
# orr termination 0.013300539325691023 0.09482077447006886 0.08152023514437784
# remaining size for Round 3: 140803
# Calculated size for Round 3: 10831.84030483925
# orr termination 0.020984821399152753 0.08077529656082968 0.05979047516167693
# remaining size for Round 4: 129972
# 10
# ['step1_rr: 9', 'step2_rr: 9', 'step3_rr: 9', 'step4_rr: 9', 'step5_rr: 9', 'step6_rr: 9']
# empirical response rate 0.053650442477876106
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4133.2502256140915
# orr termination 0.03896070922696773 0.08727670783109936 0.04831599860413163
# remaining size for Round 3: 141019
# Calculated size for Round 3: 7590.29664629535
# orr termination 0.011518913984582175 0.08489352885223955 0.07337461486765738
# remaining size for Round 4: 133429
# Calculated size for Round 4: 6696.616334856957
# orr termination 0.06103546242938954 0.08055794223674191 0.019522479807352368
# remaining size for Round 5: 126733
# Calculated size for Round 5: 9427.326350002697
# orr termination 0.02616350232801233 0.07721811817671674 0.05105461584870441
# remaining size for last Round 6: 117306
# 11
# ['step1_rr: 10', 'step2_rr: 10', 'step3_rr: 10', 'step4_rr: 10', 'step5_rr: 10', 'step6_rr: 10']
# empirical response rate 0.05188744469026549
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4011.169485577855
# orr termination 0.002953832971592669 0.0997043554525431 0.09675052248095042
# remaining size for Round 3: 141141
# 12
# ['step1_rr: 11', 'step2_rr: 11', 'step3_rr: 11', 'step4_rr: 11', 'step5_rr: 11', 'step6_rr: 11']
# empirical response rate 0.05420353982300885
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4171.638735916014
# orr termination 0.005214296182607318 0.10935291449269748 0.10413861831009016
# remaining size for Round 3: 140981
# 13
# ['step1_rr: 12', 'step2_rr: 12', 'step3_rr: 12', 'step4_rr: 12', 'step5_rr: 12', 'step6_rr: 12']
# empirical response rate 0.05489491150442478
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4219.683881321882
# orr termination 0.014035970438225031 0.10323113163647285 0.08919516119824782
# remaining size for Round 3: 140933
# Calculated size for Round 3: 22299.841720145923
# orr termination 0.03904662451602793 0.07671495439288235 0.03766832987685442
# remaining size for Round 4: 118634
# 14
# ['step1_rr: 13', 'step2_rr: 13', 'step3_rr: 13', 'step4_rr: 13', 'step5_rr: 13', 'step6_rr: 13']
# empirical response rate 0.05496404867256637
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4224.492031131622
# orr termination 0.027940292605448377 0.08170765407663771 0.05376736147118934
# remaining size for Round 3: 140928
# 15
# ['step1_rr: 14', 'step2_rr: 14', 'step3_rr: 14', 'step4_rr: 14', 'step5_rr: 14', 'step6_rr: 14']
# empirical response rate 0.05620851769911504
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4311.151688005828
# orr termination 0.025834569548754446 0.0919865529759307 0.06615198342717625
# remaining size for Round 3: 140841
# Calculated size for Round 3: 9351.639216141153
# orr termination 0.018505772393804583 0.08200033153782561 0.06349455914402102
# remaining size for Round 4: 131490
# Calculated size for Round 4: 6821.669035844617
# orr termination 0.02695076429015501 0.08172922613382849 0.05477846184367348
# remaining size for Round 5: 124669
# 16
# ['step1_rr: 15', 'step2_rr: 15', 'step3_rr: 15', 'step4_rr: 15', 'step5_rr: 15', 'step6_rr: 15']
# empirical response rate 0.05399612831858407
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4157.238084390138
# orr termination 0.06586054006057154 0.08258541540620307 0.016724875345631524
# remaining size for Round 3: 140995
# Calculated size for Round 3: 10933.164238519112
# orr termination 0.01922732161053939 0.08675320364451933 0.06752588203397994
# remaining size for Round 4: 130062
# Calculated size for Round 4: 6237.3281405960215
# orr termination 0.028007583837399118 0.08425745715527728 0.05624987331787817
# remaining size for Round 5: 123825
# Calculated size for Round 5: 8077.419872529448
# orr termination 0.04155300156424887 0.0807909908144614 0.039237989250212525
# remaining size for last Round 6: 115748
# 17
# ['step1_rr: 16', 'step2_rr: 16', 'step3_rr: 16', 'step4_rr: 16', 'step5_rr: 16', 'step6_rr: 16']
# empirical response rate 0.05517146017699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# orr termination 0.0048398372877387075 0.08880185950369825 0.08396202221595954
# remaining size for Round 3: 140914
# Calculated size for Round 3: 6628.466470468904
# orr termination 0.019544118333528118 0.07921027290835413 0.059666154574826005
# remaining size for Round 4: 134286
# 18
# ['step1_rr: 17', 'step2_rr: 17', 'step3_rr: 17', 'step4_rr: 17', 'step5_rr: 17', 'step6_rr: 17']
# empirical response rate 0.055240597345132744
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4243.731238049317
# orr termination 0.025784165387304502 0.0824280648559399 0.05664389946863539
# remaining size for Round 3: 140909
# Calculated size for Round 3: 5638.867914285751
# orr termination 0.024685122198106167 0.08761440945038095 0.06292928725227478
# remaining size for Round 4: 135271
# Calculated size for Round 4: 7338.874067447645
# orr termination 0.06315808951233054 0.07887415866625572 0.015716069153925177
# remaining size for Round 5: 127933
# Calculated size for Round 5: 7248.501030491282
# orr termination 0.04156121599959238 0.08080064471405259 0.039239428714460206
# remaining size for last Round 6: 120685
# 19
# ['step1_rr: 18', 'step2_rr: 18', 'step3_rr: 18', 'step4_rr: 18', 'step5_rr: 18', 'step6_rr: 18']
# empirical response rate 0.05610481194690266
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4303.921878005255
# orr termination 0.014756212989965831 0.09259376865915221 0.07783755566918638
# remaining size for Round 3: 140849
# Calculated size for Round 3: 7264.205673453908
# orr termination 0.021537735958232558 0.08587505522047544 0.06433731926224287
# remaining size for Round 4: 133585
# Calculated size for Round 4: 7546.591511600057
# orr termination 0.05342346649094302 0.07948476990212744 0.02606130341118442
# remaining size for Round 5: 126039
# Calculated size for Round 5: 7295.7375878932335
# orr termination 0.04076278377237198 0.07916253693202188 0.0383997531596499
# remaining size for last Round 6: 118744
# 20
# ['step1_rr: 19', 'step2_rr: 19', 'step3_rr: 19', 'step4_rr: 19', 'step5_rr: 19', 'step6_rr: 19']
# empirical response rate 0.05669247787610619
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4344.910437079735
# orr termination 0.015309967999816057 0.09366382737338291 0.07835385937356686
# remaining size for Round 3: 140808
# Calculated size for Round 3: 11007.899226789285
# orr termination 0.06396222229073165 0.07995039185152744 0.015988169560795795
# remaining size for Round 4: 129801
# Calculated size for Round 4: 6861.797594778204
# orr termination 0.05980664987633133 0.0792725068786234 0.019465857002292072
# remaining size for Round 5: 122940
# Calculated size for Round 5: 6068.519794693602
# orr termination 0.05144882961704841 0.07732257675175588 0.025873747134707477
# remaining size for last Round 6: 116872
# 21
# ['step1_rr: 20', 'step2_rr: 20', 'step3_rr: 20', 'step4_rr: 20', 'step5_rr: 20', 'step6_rr: 20']
# empirical response rate 0.0547220685840708
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4207.666398075275
# orr termination 0.037238254525384394 0.08653046475999909 0.0492922102346147
# remaining size for Round 3: 140945
# Calculated size for Round 3: 14133.657395692368
# orr termination 0.06595865224577926 0.07452622565685826 0.008567573411079
# remaining size for Round 4: 126812
# Calculated size for Round 4: 5671.1752595814
# orr termination 0.0577024430053681 0.07707461943079168 0.019372176425423576
# remaining size for Round 5: 121141
# Calculated size for Round 5: 5493.265082648677
# orr termination 0.02637673730274221 0.07840127424454736 0.05202453694180515
# remaining size for last Round 6: 115648
# 22
# ['step1_rr: 21', 'step2_rr: 21', 'step3_rr: 21', 'step4_rr: 21', 'step5_rr: 21', 'step6_rr: 21']
# empirical response rate 0.05807522123893805
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4441.542106735752
# orr termination 0.06980882787386525 0.0803508034268865 0.010541975553021249
# remaining size for Round 3: 140711
# Calculated size for Round 3: 5946.496232051208
# orr termination 0.011398941201011967 0.08665872538953212 0.07525978418852015
# remaining size for Round 4: 134765
# Calculated size for Round 4: 5610.034130565348
# orr termination 0.007423130833853182 0.09301902120103747 0.08559589036718429
# remaining size for Round 5: 129155
# 23
# ['step1_rr: 22', 'step2_rr: 22', 'step3_rr: 22', 'step4_rr: 22', 'step5_rr: 22', 'step6_rr: 22']
# empirical response rate 0.054756637168141595
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4210.069564273832
# orr termination 0.009097878639446614 0.08617243939843175 0.07707456075898514
# remaining size for Round 3: 140942
# Calculated size for Round 3: 6221.284187340418
# orr termination 0.04562795434674449 0.08239303232777684 0.036765077981032346
# remaining size for Round 4: 134721
# Calculated size for Round 4: 9852.122578300894
# orr termination 0.01678014343322323 0.082594528197975 0.06581438476475177
# remaining size for Round 5: 124869
# 24
# ['step1_rr: 23', 'step2_rr: 23', 'step3_rr: 23', 'step4_rr: 23', 'step5_rr: 23', 'step6_rr: 23']
# empirical response rate 0.054756637168141595
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4210.069564273832
# orr termination 0.007990967534240207 0.09349097026077871 0.0855000027265385
# remaining size for Round 3: 140942
# Calculated size for Round 3: 8269.890838381825
# orr termination 0.04230065183229173 0.08418835667976635 0.041887704847474616
# remaining size for Round 4: 132673
# Calculated size for Round 4: 8499.645855584527
# orr termination 0.04378884372200037 0.08160423034263432 0.03781538662063395
# remaining size for Round 5: 124174
# 25
# ['step1_rr: 24', 'step2_rr: 24', 'step3_rr: 24', 'step4_rr: 24', 'step5_rr: 24', 'step6_rr: 24']
# empirical response rate 0.05406526548672566
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4162.037640283698
# orr termination 0.004817544759208968 0.09258569830797618 0.08776815354876721
# remaining size for Round 3: 140990
# Calculated size for Round 3: 6931.190133737486
# orr termination 0.017656793156957798 0.07106803088613775 0.05341123772917995
# remaining size for Round 4: 134059
# 26
# ['step1_rr: 25', 'step2_rr: 25', 'step3_rr: 25', 'step4_rr: 25', 'step5_rr: 25', 'step6_rr: 25']
# empirical response rate 0.05254424778761062
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4056.600233593618
# orr termination 0.02313588015559224 0.08294129281237346 0.059805412656781215
# remaining size for Round 3: 141096
# Calculated size for Round 3: 5689.059384032625
# orr termination 0.01330855265603486 0.08755445446450559 0.07424590180847074
# remaining size for Round 4: 135407
# Calculated size for Round 4: 7710.92755544418
# orr termination 0.0485574913184518 0.0818196347630299 0.033262143444578104
# remaining size for Round 5: 127697
# Calculated size for Round 5: 8655.09963725973
# orr termination 0.05561177754321246 0.08391913925884632 0.02830736171563386
# remaining size for last Round 6: 119042
# 27
# ['step1_rr: 26', 'step2_rr: 26', 'step3_rr: 26', 'step4_rr: 26', 'step5_rr: 26', 'step6_rr: 26']
# empirical response rate 0.053201050884955754
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4102.090733905276
# orr termination 0.04588659748557805 0.08946263145299457 0.04357603396741652
# remaining size for Round 3: 141050
# Calculated size for Round 3: 8295.5385246966
# orr termination 0.003992207247334813 0.09952403977246142 0.0955318325251266
# remaining size for Round 4: 132755
# 28
# ['step1_rr: 27', 'step2_rr: 27', 'step3_rr: 27', 'step4_rr: 27', 'step5_rr: 27', 'step6_rr: 27']
# empirical response rate 0.05849004424778761
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4470.5830227383985
# orr termination 0.00394642209676904 0.09781916423378204 0.093872742137013
# remaining size for Round 3: 140682
# 29
# ['step1_rr: 28', 'step2_rr: 28', 'step3_rr: 28', 'step4_rr: 28', 'step5_rr: 28', 'step6_rr: 28']
# empirical response rate 0.05537887168141593
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4253.354805576213
# orr termination 0.06898630597266067 0.08749845771979238 0.018512151747131708
# remaining size for Round 3: 140899
# Calculated size for Round 3: 8936.023078430095
# orr termination 0.006601694693562559 0.08764421379943216 0.0810425191058696
# remaining size for Round 4: 131963
# Calculated size for Round 4: 6398.609761031833
# orr termination 0.025845256611114437 0.07717053720574608 0.05132528059463165
# remaining size for Round 5: 125565
# 30
# ['step1_rr: 29', 'step2_rr: 29', 'step3_rr: 29', 'step4_rr: 29', 'step5_rr: 29', 'step6_rr: 29']
# empirical response rate 0.056173949115044246
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4308.741586307481
# orr termination 0.06678021413328672 0.08708023267479362 0.020300018541506898
# remaining size for Round 3: 140844
# Calculated size for Round 3: 9113.941467107303
# orr termination 0.01780230068613028 0.08653735263420703 0.06873505194807675
# remaining size for Round 4: 131731
# Calculated size for Round 4: 6209.048142865786
# orr termination 0.013665067962040577 0.08149857292138488 0.0678335049593443
# remaining size for Round 5: 125522
# 31
# ['step1_rr: 30', 'step2_rr: 30', 'step3_rr: 30', 'step4_rr: 30', 'step5_rr: 30', 'step6_rr: 30']
# empirical response rate 0.05517146017699115
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4238.9204452449385
# orr termination 0.009856063255279362 0.09017523523747753 0.08031917198219816
# remaining size for Round 3: 140914
# Calculated size for Round 3: 6411.972215938765
# orr termination 0.04584150390611751 0.08332057843440374 0.03747907452828623
# remaining size for Round 4: 134503
# Calculated size for Round 4: 9178.860757786053
# orr termination 0.04986709146298908 0.08093286918240986 0.031065777719420776
# remaining size for Round 5: 125325
# Calculated size for Round 5: 6676.973309108944
# orr termination 0.026991625926019263 0.0816247006698916 0.05463307474387233
# remaining size for last Round 6: 118649
# 32
# ['step1_rr: 31', 'step2_rr: 31', 'step3_rr: 31', 'step4_rr: 31', 'step5_rr: 31', 'step6_rr: 31']
# empirical response rate 0.05544800884955752
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4258.167580221075
# orr termination 0.06573411089470646 0.0802315198566809 0.014497408961974434
# remaining size for Round 3: 140894
# Calculated size for Round 3: 17094.04040193991
# orr termination 0.026350744878073925 0.08080821729518806 0.05445747241711413
# remaining size for Round 4: 123800
# Calculated size for Round 4: 5457.04316130475
# orr termination 0.05216600966768911 0.07832864587818752 0.026162636210498413
# remaining size for Round 5: 118343
# Calculated size for Round 5: 6975.521019808589
# orr termination 0.040062460067611216 0.08069818914831144 0.04063572908070022
# remaining size for last Round 6: 111368
# 33
# ['step1_rr: 32', 'step2_rr: 32', 'step3_rr: 32', 'step4_rr: 32', 'step5_rr: 32', 'step6_rr: 32']
# empirical response rate 0.05482577433628318
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4214.876392356589
# orr termination 0.04423674438415236 0.08106270464822257 0.036825960264070215
# remaining size for Round 3: 140938
# Calculated size for Round 3: 5913.138957694819
# orr termination 0.03682448705773587 0.08673510462978962 0.04991061757205375
# remaining size for Round 4: 135025
# Calculated size for Round 4: 6833.963026943897
# orr termination 0.017861461330188552 0.09309672922052001 0.07523526789033146
# remaining size for Round 5: 128192
# Calculated size for Round 5: 7287.371570464351
# orr termination 0.015786528112335965 0.07973620082515656 0.0639496727128206
# remaining size for last Round 6: 120905
# 34
# ['step1_rr: 33', 'step2_rr: 33', 'step3_rr: 33', 'step4_rr: 33', 'step5_rr: 33', 'step6_rr: 33']
# empirical response rate 0.054756637168141595
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4210.069564273832
# orr termination 0.01938847307537347 0.09085404680201897 0.0714655737266455
# remaining size for Round 3: 140942
# Calculated size for Round 3: 7474.126080904512
# orr termination 0.027316249159460463 0.08942814024199969 0.06211189108253923
# remaining size for Round 4: 133468
# Calculated size for Round 4: 8385.267426157208
# orr termination 0.040350049823420095 0.08139239553696781 0.041042345713547715
# remaining size for Round 5: 125083
# Calculated size for Round 5: 7187.021809489564
# orr termination 0.039017254104602966 0.07714421200929351 0.03812695790469055
# remaining size for last Round 6: 117896
# 35
# ['step1_rr: 34', 'step2_rr: 34', 'step3_rr: 34', 'step4_rr: 34', 'step5_rr: 34', 'step6_rr: 34']
# empirical response rate 0.05548257743362832
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4260.5742152468165
# orr termination 0.019056349702121844 0.08663246626231805 0.0675761165601962
# remaining size for Round 3: 140892
# Calculated size for Round 3: 6224.273530784704
# orr termination 0.00853914481317107 0.09228213393647092 0.08374298912329985
# remaining size for Round 4: 134668
# Calculated size for Round 4: 8531.401552402327
# orr termination 0.03899285945177209 0.08248708840665235 0.04349422895488026
# remaining size for Round 5: 126137
# 36
# ['step1_rr: 35', 'step2_rr: 35', 'step3_rr: 35', 'step4_rr: 35', 'step5_rr: 35', 'step6_rr: 35']
# empirical response rate 0.05479120575221239
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4212.472895702519
# orr termination 0.06007615466175291 0.0807241867769951 0.020648032115242188
# remaining size for Round 3: 140940
# Calculated size for Round 3: 9770.067209390303
# orr termination 0.021787952027956522 0.08399522918781265 0.06220727715985612
# remaining size for Round 4: 131170
# Calculated size for Round 4: 5885.013804762182
# orr termination 0.054639268648008776 0.0808727765413059 0.02623350789329712
# remaining size for Round 5: 125285
# Calculated size for Round 5: 7697.126111691387
# orr termination 0.04021901045040584 0.08052567886127154 0.040306668410865706
# remaining size for last Round 6: 117588
# 37
# ['step1_rr: 36', 'step2_rr: 36', 'step3_rr: 36', 'step4_rr: 36', 'step5_rr: 36', 'step6_rr: 36']
# empirical response rate 0.054272676991150445
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4176.440275580975
# orr termination 0.014102539163276178 0.08921882846390836 0.07511628930063217
# remaining size for Round 3: 140976
# Calculated size for Round 3: 9440.643038689903
# orr termination 0.03823840728827009 0.07755495196801578 0.039316544679745685
# remaining size for Round 4: 131536
# Calculated size for Round 4: 6812.570726374139
# orr termination 0.04864127999816137 0.07214909704219878 0.023507817044037413
# remaining size for Round 5: 124724
# Calculated size for Round 5: 6255.09767331702
# orr termination 0.03717271311334281 0.07587888603677735 0.03870617292343454
# remaining size for last Round 6: 118469
# 38
# ['step1_rr: 37', 'step2_rr: 37', 'step3_rr: 37', 'step4_rr: 37', 'step5_rr: 37', 'step6_rr: 37']
# empirical response rate 0.05333932522123894
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4111.675292416549
# orr termination 0.012687358675598986 0.08627001338018214 0.07358265470458315
# remaining size for Round 3: 141041
# Calculated size for Round 3: 6455.104721519871
# orr termination 0.04160171454472711 0.08390082299887194 0.042299108454144835
# remaining size for Round 4: 134586
# Calculated size for Round 4: 8424.475606962782
# orr termination 0.01410129057837051 0.08384395217126141 0.0697426615928909
# remaining size for Round 5: 126162
# 39
# ['step1_rr: 38', 'step2_rr: 38', 'step3_rr: 38', 'step4_rr: 38', 'step5_rr: 38', 'step6_rr: 38']
# empirical response rate 0.05278622787610619
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4073.3529413786146
# orr termination 0.046942085718252397 0.08619130095704383 0.039249215238791435
# remaining size for Round 3: 141079
# Calculated size for Round 3: 9390.543846882434
# orr termination 0.036291932253515485 0.08481853218685949 0.048526599933344
# remaining size for Round 4: 131689
# Calculated size for Round 4: 6496.764747007734
# orr termination 0.03507391309717248 0.0862037607558761 0.051129847658703625
# remaining size for Round 5: 125193
# Calculated size for Round 5: 6926.700514576033
# orr termination 0.059153279533318524 0.07877131431788896 0.019618034784570436
# remaining size for last Round 6: 118267
# 40
# ['step1_rr: 39', 'step2_rr: 39', 'step3_rr: 39', 'step4_rr: 39', 'step5_rr: 39', 'step6_rr: 39']
# empirical response rate 0.05420353982300885
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4171.638735916014
# orr termination 0.020160023007035007 0.08763002443971246 0.06747000143267745
# remaining size for Round 3: 140981
# Calculated size for Round 3: 19727.85101440339
# orr termination 0.050822731072314234 0.07714270534992167 0.026319974277607433
# remaining size for Round 4: 121254
# Calculated size for Round 4: 5601.434602206985
# orr termination 0.040361943555807134 0.07881597129330312 0.03845402773749598
# remaining size for Round 5: 115653
# 41
# ['step1_rr: 40', 'step2_rr: 40', 'step3_rr: 40', 'step4_rr: 40', 'step5_rr: 40', 'step6_rr: 40']
# empirical response rate 0.058213495575221236
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4451.219776662242
# orr termination 0.046952591392264306 0.07854585685150169 0.03159326545923738
# remaining size for Round 3: 140701
# Calculated size for Round 3: 5367.555282266309
# orr termination 0.0141058245735625 0.08751289104940413 0.07340706647584162
# remaining size for Round 4: 135334
# Calculated size for Round 4: 6135.228050310592
# orr termination 0.03420516845108222 0.08040870122127532 0.046203532770193095
# remaining size for Round 5: 129199
# Calculated size for Round 5: 8188.783511238502
# orr termination 0.0673210501021016 0.07995855322388469 0.012637503121783092
# remaining size for last Round 6: 121011
# 42
# ['step1_rr: 41', 'step2_rr: 41', 'step3_rr: 41', 'step4_rr: 41', 'step5_rr: 41', 'step6_rr: 41']
# empirical response rate 0.05389242256637168
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4150.039990556384
# orr termination 0.010402840373512544 0.10183105721048602 0.09142821683697347
# remaining size for Round 3: 141002
# Calculated size for Round 3: 11897.344519647018
# orr termination 0.046661913592944734 0.07438563169666282 0.027723718103718084
# remaining size for Round 4: 129105
# Calculated size for Round 4: 5998.399890896615
# orr termination 0.04277649770167117 0.079652806225374 0.036876308523702835
# remaining size for Round 5: 123107
# 43
# ['step1_rr: 42', 'step2_rr: 42', 'step3_rr: 42', 'step4_rr: 42', 'step5_rr: 42', 'step6_rr: 42']
# empirical response rate 0.053477599557522126
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4121.262497623935
# orr termination 0.016003372225736202 0.08585522622716779 0.0698518540014316
# remaining size for Round 3: 141031
# Calculated size for Round 3: 7270.561944591308
# orr termination 0.06594157285868033 0.08023159459116247 0.014290021732482144
# remaining size for Round 4: 133761
# Calculated size for Round 4: 8449.512298867661
# orr termination 0.05219535414814214 0.07958761961811744 0.027392265469975308
# remaining size for Round 5: 125312
# Calculated size for Round 5: 6028.751878432362
# orr termination 0.01542210802109626 0.08821173565732024 0.07278962763622399
# remaining size for last Round 6: 119284
# 44
# ['step1_rr: 43', 'step2_rr: 43', 'step3_rr: 43', 'step4_rr: 43', 'step5_rr: 43', 'step6_rr: 43']
# empirical response rate 0.055413440265486724
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4255.761110329247
# orr termination 0.006714948262086432 0.09834515609675877 0.09163020783467234
# remaining size for Round 3: 140897
# Calculated size for Round 3: 7643.549687851616
# orr termination 0.040699704384510996 0.0823183290460542 0.0416186246615432
# remaining size for Round 4: 133254
# Calculated size for Round 4: 8903.806444060507
# orr termination 0.04171065770923851 0.08014302745353215 0.038432369744293635
# remaining size for Round 5: 124351
# 45
# ['step1_rr: 44', 'step2_rr: 44', 'step3_rr: 44', 'step4_rr: 44', 'step5_rr: 44', 'step6_rr: 44']
# empirical response rate 0.05579369469026549
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4282.241360696144
# orr termination 0.0207661411509096 0.08892724998771484 0.06816110883680523
# remaining size for Round 3: 140870
# Calculated size for Round 3: 5981.455822945045
# orr termination 0.011539934636982524 0.09218306807546116 0.08064313343847863
# remaining size for Round 4: 134889
# Calculated size for Round 4: 8659.355362589198
# orr termination 0.05556946637461995 0.08217656688899425 0.026607100514374295
# remaining size for Round 5: 126230
# Calculated size for Round 5: 7725.921416496434
# orr termination 0.0379649663961186 0.07792145240040915 0.03995648600429055
# remaining size for last Round 6: 118505
# 46
# ['step1_rr: 45', 'step2_rr: 45', 'step3_rr: 45', 'step4_rr: 45', 'step5_rr: 45', 'step6_rr: 45']
# empirical response rate 0.05486034292035398
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4217.280054231296
# orr termination 0.01073926282611856 0.09155813325138104 0.08081887042526248
# remaining size for Round 3: 140935
# Calculated size for Round 3: 11540.526718802541
# orr termination 0.0523305328983275 0.07917742591594676 0.026846893017619257
# remaining size for Round 4: 129395
# Calculated size for Round 4: 7022.849681000544
# orr termination 0.03779372339084864 0.07642222125976814 0.0386284978689195
# remaining size for Round 5: 122373
# 47
# ['step1_rr: 46', 'step2_rr: 46', 'step3_rr: 46', 'step4_rr: 46', 'step5_rr: 46', 'step6_rr: 46']
# empirical response rate 0.054307245575221236
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4178.841293359456
# orr termination 0.008697201991472225 0.094424452196092 0.08572725020461977
# remaining size for Round 3: 140974
# Calculated size for Round 3: 15310.443802626482
# orr termination 0.038085075837981354 0.07506661807145612 0.036981542233474766
# remaining size for Round 4: 125664
# 48
# ['step1_rr: 47', 'step2_rr: 47', 'step3_rr: 47', 'step4_rr: 47', 'step5_rr: 47', 'step6_rr: 47']
# empirical response rate 0.055862831858407076
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4287.058097965914
# orr termination 0.0070435735017049085 0.08559601451725804 0.07855244101555313
# remaining size for Round 3: 140865
# Calculated size for Round 3: 5361.76733336676
# orr termination 0.00867686008828573 0.09336668558315607 0.08468982549487034
# remaining size for Round 4: 135504
# 49
# ['step1_rr: 48', 'step2_rr: 48', 'step3_rr: 48', 'step4_rr: 48', 'step5_rr: 48', 'step6_rr: 48']
# empirical response rate 0.05658877212389381
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4337.673697209837
# orr termination 0.05895342187501872 0.0863528583149821 0.027399436439963377
# remaining size for Round 3: 140815
# Calculated size for Round 3: 12681.930772120268
# orr termination 0.015001299952955403 0.08325807706323399 0.06825677711027858
# remaining size for Round 4: 128134
# Calculated size for Round 4: 6025.396449800016
# orr termination 0.054391810027911436 0.08099658135160802 0.026604771323696583
# remaining size for Round 5: 122109
# Calculated size for Round 5: 8195.420450602865
# orr termination 0.03968209869452981 0.07924122898431901 0.039559130289789204
# remaining size for last Round 6: 113914
# 50
# ['step1_rr: 49', 'step2_rr: 49', 'step3_rr: 49', 'step4_rr: 49', 'step5_rr: 49', 'step6_rr: 49']
# empirical response rate 0.05793694690265487
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4431.867072682371
# orr termination 0.008501645420442887 0.09318969545998154 0.08468805003953865
# remaining size for Round 3: 140721
# Calculated size for Round 3: 14204.828912288724
# orr termination 0.04135697162934141 0.0826902346124143 0.04133326298307289
# remaining size for Round 4: 126517
# 51
# ['step1_rr: 50', 'step2_rr: 50', 'step3_rr: 50', 'step4_rr: 50', 'step5_rr: 50', 'step6_rr: 50']
# empirical response rate 0.05548257743362832
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4260.5742152468165
# orr termination 0.013931131601184667 0.09171918090403462 0.07778804930284995
# remaining size for Round 3: 140892
# Calculated size for Round 3: 13906.972756462172
# orr termination 0.025669177670304882 0.07629832505487244 0.05062914738456756
# remaining size for Round 4: 126986
# 52
# ['step1_rr: 51', 'step2_rr: 51', 'step3_rr: 51', 'step4_rr: 51', 'step5_rr: 51', 'step6_rr: 51']
# empirical response rate 0.05420353982300885
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4171.638735916014
# orr termination 0.015270506279558407 0.09163846287919844 0.07636795659964003
# remaining size for Round 3: 140981
# Calculated size for Round 3: 18812.345354726618
# orr termination 0.02457115428436841 0.07385032002452298 0.04927916574015457
# remaining size for Round 4: 122169
# 53
# ['step1_rr: 52', 'step2_rr: 52', 'step3_rr: 52', 'step4_rr: 52', 'step5_rr: 52', 'step6_rr: 52']
# empirical response rate 0.055240597345132744
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4243.731238049317
# orr termination 0.013281250345769874 0.09118557051628502 0.07790432017051514
# remaining size for Round 3: 140909
# Calculated size for Round 3: 14928.373119222108
# orr termination 0.04896231612530637 0.07368092970929997 0.024718613583993604
# remaining size for Round 4: 125981
# Calculated size for Round 4: 5727.642269710711
# orr termination 0.039964653054196636 0.07771115009025983 0.0377464970360632
# remaining size for Round 5: 120254
# 54
# ['step1_rr: 53', 'step2_rr: 53', 'step3_rr: 53', 'step4_rr: 53', 'step5_rr: 53', 'step6_rr: 53']
# empirical response rate 0.05392699115044248
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4152.439189827319
# orr termination 0.020079946257738804 0.09498587564086523 0.07490592938312643
# remaining size for Round 3: 141000
# Calculated size for Round 3: 29013
# orr termination 0.03847089746722375 0.07647648023066887 0.03800558276344512
# remaining size for Round 4: 111987
# 55
# ['step1_rr: 54', 'step2_rr: 54', 'step3_rr: 54', 'step4_rr: 54', 'step5_rr: 54', 'step6_rr: 54']
# empirical response rate 0.055240597345132744
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4243.731238049317
# orr termination 0.041776069459208684 0.07949929161844219 0.0377232221592335
# remaining size for Round 3: 140909
# Calculated size for Round 3: 5628.071466692092
# orr termination 0.01753700658850299 0.09139130039991585 0.07385429381141285
# remaining size for Round 4: 135281
# Calculated size for Round 4: 6692.767176490766
# orr termination 0.007186022906687985 0.08765266707064966 0.08046664416396167
# remaining size for Round 5: 128589
# 56
# ['step1_rr: 55', 'step2_rr: 55', 'step3_rr: 55', 'step4_rr: 55', 'step5_rr: 55', 'step6_rr: 55']
# empirical response rate 0.05496404867256637
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4224.492031131622
# orr termination 0.016840629105186113 0.0950661405280294 0.07822551142284329
# remaining size for Round 3: 140928
# Calculated size for Round 3: 17329.038301755394
# orr termination 0.05346371389644277 0.07835439186193875 0.02489067796549598
# remaining size for Round 4: 123599
# Calculated size for Round 4: 5700.640242042334
# orr termination 0.04068892838702494 0.07967395177212395 0.038985023385099016
# remaining size for Round 5: 117899
# 57
# ['step1_rr: 56', 'step2_rr: 56', 'step3_rr: 56', 'step4_rr: 56', 'step5_rr: 56', 'step6_rr: 56']
# empirical response rate 0.05544800884955752
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4258.167580221075
# orr termination 0.05196544837590037 0.08200798537498825 0.030042536999087883
# remaining size for Round 3: 140894
# Calculated size for Round 3: 6181.507632319288
# orr termination 0.017289233653807586 0.0877515265787952 0.07046229292498762
# remaining size for Round 4: 134713
# Calculated size for Round 4: 6307.8158170419665
# orr termination 0.04524797223566723 0.08409767015491737 0.03884969791925014
# remaining size for Round 5: 128406
# Calculated size for Round 5: 9103.525154689205
# orr termination 0.056484218950128576 0.08315004117078076 0.026665822220652183
# remaining size for last Round 6: 119303
# 58
# ['step1_rr: 57', 'step2_rr: 57', 'step3_rr: 57', 'step4_rr: 57', 'step5_rr: 57', 'step6_rr: 57']
# empirical response rate 0.05479120575221239
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4212.472895702519
# orr termination 0.04040911531496494 0.0739571407900071 0.03354802547504217
# remaining size for Round 3: 140940
# Calculated size for Round 3: 5283.490753464238
# orr termination 0.01969959666168649 0.08646467161306703 0.06676507495138054
# remaining size for Round 4: 135657
# Calculated size for Round 4: 6213.570111928406
# orr termination 0.07476016311641806 0.07998367743750587 0.005223514321087808
# remaining size for Round 5: 129444
# Calculated size for Round 5: 8358.870878700836
# orr termination 0.02234247833540091 0.08232512093660511 0.0599826426012042
# remaining size for last Round 6: 121086
# 59
# ['step1_rr: 58', 'step2_rr: 58', 'step3_rr: 58', 'step4_rr: 58', 'step5_rr: 58', 'step6_rr: 58']
# empirical response rate 0.0537195796460177
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4138.04647448891
# orr termination 0.020708027676142476 0.08399595477733178 0.0632879271011893
# remaining size for Round 3: 141014
# Calculated size for Round 3: 10506.113984955662
# orr termination 0.043577205518623506 0.07131663003339578 0.027739424514772272
# remaining size for Round 4: 130508
# Calculated size for Round 4: 5883.567349100248
# orr termination 0.05169773995576264 0.07690616438675464 0.025208424430992
# remaining size for Round 5: 124625
# Calculated size for Round 5: 6326.47754559272
# orr termination 0.03693818993492353 0.07500366378121096 0.038065473846287425
# remaining size for last Round 6: 118299
# 60
# ['step1_rr: 59', 'step2_rr: 59', 'step3_rr: 59', 'step4_rr: 59', 'step5_rr: 59', 'step6_rr: 59']
# empirical response rate 0.05607024336283186
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4301.512271411428
# orr termination 0.049911464535276034 0.08402377807888838 0.03411231354361234
# remaining size for Round 3: 140851
# Calculated size for Round 3: 6388.693266378505
# orr termination 0.013089236385146604 0.0904799468341288 0.0773907104489822
# remaining size for Round 4: 134463
# Calculated size for Round 4: 6505.128145475443
# orr termination 0.031050921163721535 0.08392041900093249 0.052869497837210955
# remaining size for Round 5: 127958
# Calculated size for Round 5: 8577.306739742304
# orr termination 0.05325024379214172 0.07771754143131666 0.02446729763917494
# remaining size for last Round 6: 119381
# 61
# ['step1_rr: 60', 'step2_rr: 60', 'step3_rr: 60', 'step4_rr: 60', 'step5_rr: 60', 'step6_rr: 60']
# empirical response rate 0.053961559734513276
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4154.838554440094
# orr termination 0.04396566515052956 0.08368392031191832 0.03971825516138876
# remaining size for Round 3: 140998
# Calculated size for Round 3: 8967.050880378813
# orr termination 0.06539671270097955 0.07655855625429003 0.011161843553310485
# remaining size for Round 4: 132031
# Calculated size for Round 4: 6225.016873509544
# orr termination 0.022056499913619906 0.07998537447157172 0.057928874557951815
# remaining size for Round 5: 125806
# Calculated size for Round 5: 5564.596340606486
# orr termination 0.033445822891820645 0.08339381709666677 0.04994799420484612
# remaining size for last Round 6: 120242
# 62
# ['step1_rr: 61', 'step2_rr: 61', 'step3_rr: 61', 'step4_rr: 61', 'step5_rr: 61', 'step6_rr: 61']
# empirical response rate 0.05389242256637168
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4150.039990556384
# orr termination 0.06213457961499561 0.08618644961549944 0.02405187000050383
# remaining size for Round 3: 141002
# Calculated size for Round 3: 10724.34058741702
# orr termination 0.01156169279053623 0.08782717632661381 0.07626548353607758
# remaining size for Round 4: 130278
# Calculated size for Round 4: 6504.84080687743
# orr termination 0.055216384604090445 0.08248878995166176 0.02727240534757131
# remaining size for Round 5: 123774
# Calculated size for Round 5: 9030.928634531761
# orr termination 0.040250631568230194 0.08014739470386703 0.03989676313563684
# remaining size for last Round 6: 114744
# 63
# ['step1_rr: 62', 'step2_rr: 62', 'step3_rr: 62', 'step4_rr: 62', 'step5_rr: 62', 'step6_rr: 62']
# empirical response rate 0.053512168141592924
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4123.659712438602
# orr termination 0.004291854850097657 0.09138272950120996 0.0870908746511123
# remaining size for Round 3: 141029
# Calculated size for Round 3: 7207.484500066751
# orr termination 0.04899054640567488 0.07413977439077014 0.025149227985095265
# remaining size for Round 4: 133822
# Calculated size for Round 4: 8192.792157494046
# orr termination 0.0431709286113833 0.07989580129678471 0.03672487268540141
# remaining size for Round 5: 125630
# 64
# ['step1_rr: 63', 'step2_rr: 63', 'step3_rr: 63', 'step4_rr: 63', 'step5_rr: 63', 'step6_rr: 63']
# empirical response rate 0.055413440265486724
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4255.761110329247
# orr termination 0.06465077685953374 0.08781072337580123 0.023159946516267488
# remaining size for Round 3: 140897
# Calculated size for Round 3: 16685.823585823666
# orr termination 0.013634175882509772 0.0859905928046252 0.07235641692211543
# remaining size for Round 4: 124212
# Calculated size for Round 4: 5690.588062382495
# orr termination 0.03870697364876146 0.07820541967137767 0.039498446022616214
# remaining size for Round 5: 118522
# 65
# ['step1_rr: 64', 'step2_rr: 64', 'step3_rr: 64', 'step4_rr: 64', 'step5_rr: 64', 'step6_rr: 64']
# empirical response rate 0.053373893805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4114.071845601768
# orr termination 0.03967594208365509 0.08836516120991013 0.04868921912625504
# remaining size for Round 3: 141038
# Calculated size for Round 3: 14222.833741805436
# orr termination 0.008208981045847356 0.08619784205001131 0.07798886100416395
# remaining size for Round 4: 126816
# 66
# ['step1_rr: 65', 'step2_rr: 65', 'step3_rr: 65', 'step4_rr: 65', 'step5_rr: 65', 'step6_rr: 65']
# empirical response rate 0.05579369469026549
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4282.241360696144
# orr termination 0.01513043215279827 0.09923533738531021 0.08410490523251193
# remaining size for Round 3: 140870
# Calculated size for Round 3: 13223.802646442751
# orr termination 0.06245411554288084 0.08248515893547632 0.020031043392595482
# remaining size for Round 4: 127647
# Calculated size for Round 4: 6586.011059697395
# orr termination 0.026938856259041737 0.07988880061660335 0.05294994435756161
# remaining size for Round 5: 121061
# 67
# ['step1_rr: 66', 'step2_rr: 66', 'step3_rr: 66', 'step4_rr: 66', 'step5_rr: 66', 'step6_rr: 66']
# empirical response rate 0.05651963495575221
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4332.850028799209
# orr termination 0.017566899896697928 0.08234750672849103 0.0647806068317931
# remaining size for Round 3: 140820
# Calculated size for Round 3: 5203.660945468123
# orr termination 0.016944906282739137 0.09394575530403625 0.07700084902129711
# remaining size for Round 4: 135617
# Calculated size for Round 4: 8539.63630638633
# orr termination 0.05319896272869244 0.08005651728962256 0.026857554560930114
# remaining size for Round 5: 127078
# Calculated size for Round 5: 7394.643408649884
# orr termination 0.04049265368809514 0.07779632451464635 0.03730367082655121
# remaining size for last Round 6: 119684
# 68
# ['step1_rr: 67', 'step2_rr: 67', 'step3_rr: 67', 'step4_rr: 67', 'step5_rr: 67', 'step6_rr: 67']
# empirical response rate 0.05548257743362832
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4260.5742152468165
# orr termination 0.03445866766002001 0.08269026312574933 0.04823159546572932
# remaining size for Round 3: 140892
# Calculated size for Round 3: 5715.147033001084
# orr termination 0.0508600173910246 0.08520771039604477 0.03434769300502017
# remaining size for Round 4: 135177
# Calculated size for Round 4: 6831.145764522802
# orr termination 0.028842296720366513 0.08546524084277038 0.056622944122403866
# remaining size for Round 5: 128346
# Calculated size for Round 5: 6642.495999858417
# orr termination 0.07093981928404733 0.07887907558741092 0.00793925630336359
# remaining size for last Round 6: 121704
# 69
# ['step1_rr: 68', 'step2_rr: 68', 'step3_rr: 68', 'step4_rr: 68', 'step5_rr: 68', 'step6_rr: 68']
# empirical response rate 0.05344303097345133
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4118.865448209925
# orr termination 0.048042399539451865 0.07429345030884921 0.026251050769397342
# remaining size for Round 3: 141034
# Calculated size for Round 3: 5165.6076360486795
# orr termination 0.017647838050130767 0.08109054163689394 0.06344270358676318
# remaining size for Round 4: 135869
# Calculated size for Round 4: 5748.727163591258
# orr termination 0.03773182894549215 0.08432507568507003 0.046593246739577876
# remaining size for Round 5: 130121
# Calculated size for Round 5: 8317.5745325401
# orr termination 0.020333555709532068 0.08040062650315005 0.060067070793617984
# remaining size for last Round 6: 121804
# 70
# ['step1_rr: 69', 'step2_rr: 69', 'step3_rr: 69', 'step4_rr: 69', 'step5_rr: 69', 'step6_rr: 69']
# empirical response rate 0.05285536504424779
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4078.140918781554
# orr termination 0.03152346146706721 0.0856866625819964 0.0541632011149292
# remaining size for Round 3: 141074
# Calculated size for Round 3: 8423.251755266283
# orr termination 0.0183985991606688 0.07789947333225287 0.059500874171584076
# remaining size for Round 4: 132651
# Calculated size for Round 4: 6512.552683836519
# orr termination 0.021003139829270618 0.08261322982783252 0.06161008999856191
# remaining size for Round 5: 126139
# 71
# ['step1_rr: 70', 'step2_rr: 70', 'step3_rr: 70', 'step4_rr: 70', 'step5_rr: 70', 'step6_rr: 70']
# empirical response rate 0.05392699115044248
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4152.439189827319
# orr termination 0.031561587480597286 0.0758939743452822 0.04433238686468491
# remaining size for Round 3: 141000
# Calculated size for Round 3: 4913.574662153634
# orr termination 0.02822195831800889 0.08530225226876645 0.05708029395075756
# remaining size for Round 4: 136087
# ...
# remaining size for Round 5: 127094
# Calculated size for Round 5: 6146.147241779417
# orr termination 0.031315012974551255 0.08677841317907717 0.05546340020452591
# remaining size for last Round 6: 120948
# 78
# ['step1_rr: 77', 'step2_rr: 77', 'step3_rr: 77', 'step4_rr: 77', 'step5_rr: 77', 'step6_rr: 77']
# empirical response rate 0.05437638274336283
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4183.643824785205
# orr termination 0.014659388994020365 0.09022406189702839 0.07556467290300803
# remaining size for Round 3: 140969
# Calculated size for Round 3: 7106.9016238745835
# orr termination 0.015099584438221333 0.08321176180595312 0.06811217736773179
# remaining size for Round 4: 133863
# Calculated size for Round 4: 7843.739727475616
# orr termination 0.039898224319725076 0.08006536293492546 0.04016713861520038
# remaining size for Round 5: 126020
# 79
# ['step1_rr: 78', 'step2_rr: 78', 'step3_rr: 78', 'step4_rr: 78', 'step5_rr: 78', 'step6_rr: 78']
# empirical response rate 0.05520602876106195
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4241.325759063171
# orr termination 0.033604193236058455 0.08542272200397281 0.05181852876791436
# remaining size for Round 3: 140911
# Calculated size for Round 3: 6744.514870476228
# orr termination 0.05592390448991551 0.08224268833919625 0.02631878384928074
# remaining size for Round 4: 134167
# Calculated size for Round 4: 7057.414863038674
# orr termination 0.016763871329790375 0.08602722172349395 0.06926335039370357
# remaining size for Round 5: 127110
# Calculated size for Round 5: 6403.948413582297
# orr termination 0.06066250758490861 0.08036938204828087 0.019706874463372256
# remaining size for last Round 6: 120707
# 80
# ['step1_rr: 79', 'step2_rr: 79', 'step3_rr: 79', 'step4_rr: 79', 'step5_rr: 79', 'step6_rr: 79']
# empirical response rate 0.057591261061946904
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4407.691021764351
# orr termination 0.0069607954177378605 0.08938178753487627 0.08242099211713841
# remaining size for Round 3: 140745
# Calculated size for Round 3: 5688.900396918554
# orr termination 0.03534990659895111 0.08097508642026717 0.04562517982131606
# remaining size for Round 4: 135057
# Calculated size for Round 4: 10199.147641441788
# orr termination 0.01888406660980744 0.07708973855141431 0.05820567194160687
# remaining size for Round 5: 124858
# 81
# ['step1_rr: 80', 'step2_rr: 80', 'step3_rr: 80', 'step4_rr: 80', 'step5_rr: 80', 'step6_rr: 80']
# empirical response rate 0.05489491150442478
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4219.683881321882
# orr termination 0.011944305677246405 0.0799255629228066 0.0679812572455602
# remaining size for Round 3: 140933
# Calculated size for Round 3: 6199.169429371816
# orr termination 0.006845112817509576 0.07956763782978066 0.07272252501227108
# remaining size for Round 4: 134734
# 82
# ['step1_rr: 81', 'step2_rr: 81', 'step3_rr: 81', 'step4_rr: 81', 'step5_rr: 81', 'step6_rr: 81']
# empirical response rate 0.0546529314159292
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4202.860561387483
# orr termination 0.015724264428123757 0.0914968657580249 0.07577260132990114
# remaining size for Round 3: 140950
# Calculated size for Round 3: 9763.612312944668
# orr termination 0.04788516911856737 0.0794827853604259 0.03159761624185853
# remaining size for Round 4: 131187
# Calculated size for Round 4: 7058.310288102639
# orr termination 0.05271486905967339 0.07828583931689115 0.02557097025721776
# remaining size for Round 5: 124129
# Calculated size for Round 5: 6375.252866076509
# orr termination 0.03783026523211054 0.07572854790536361 0.03789828267325307
# remaining size for last Round 6: 117754
# 83
# ['step1_rr: 82', 'step2_rr: 82', 'step3_rr: 82', 'step4_rr: 82', 'step5_rr: 82', 'step6_rr: 82']
# empirical response rate 0.05441095132743363
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4186.045338423161
# orr termination 0.0470002869073308 0.07640633282219647 0.029406045914865668
# remaining size for Round 3: 140966
# Calculated size for Round 3: 5388.460183483045
# orr termination 0.05349435585372293 0.08144475661245427 0.027950400758731342
# remaining size for Round 4: 135578
# Calculated size for Round 4: 6068.9792635637805
# orr termination 0.03616994868502223 0.08782515622727793 0.05165520754225571
# remaining size for Round 5: 129510
# Calculated size for Round 5: 6088.2851972160515
# orr termination 0.053751479341832734 0.08834224913073137 0.034590769788898634
# remaining size for last Round 6: 123422
# 84
# ['step1_rr: 83', 'step2_rr: 83', 'step3_rr: 83', 'step4_rr: 83', 'step5_rr: 83', 'step6_rr: 83']
# empirical response rate 0.05513689159292035
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4236.515296599448
# orr termination 0.04541681077332342 0.08121368053425455 0.03579686976093113
# remaining size for Round 3: 140916
# Calculated size for Round 3: 9335.43539919975
# orr termination 0.04076082016453783 0.07758862659832821 0.03682780643379038
# remaining size for Round 4: 131581
# Calculated size for Round 4: 6135.876997353323
# orr termination 0.048737235361130365 0.08070599463310983 0.031968759271979466
# remaining size for Round 5: 125446
# Calculated size for Round 5: 6677.910948420592
# orr termination 0.04078830679296599 0.08294248578997376 0.042154178997007775
# remaining size for last Round 6: 118769
# 85
# ['step1_rr: 84', 'step2_rr: 84', 'step3_rr: 84', 'step4_rr: 84', 'step5_rr: 84', 'step6_rr: 84']
# empirical response rate 0.05513689159292035
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4236.515296599448
# orr termination 0.01282249346146164 0.09429934807884169 0.08147685461738005
# remaining size for Round 3: 140916
# Calculated size for Round 3: 13300.76631536682
# orr termination 0.02776134552804767 0.08152812136723157 0.053766775839183906
# remaining size for Round 4: 127616
# 86
# ['step1_rr: 85', 'step2_rr: 85', 'step3_rr: 85', 'step4_rr: 85', 'step5_rr: 85', 'step6_rr: 85']
# empirical response rate 0.054134402654867256
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4166.8378574712715
# orr termination 0.003039136650170831 0.09757248712728345 0.09453335047711262
# remaining size for Round 3: 140986
# Calculated size for Round 3: 7566.040680228515
# orr termination 0.03129011959193795 0.0609187064891272 0.029628586897189252
# remaining size for Round 4: 133420
# 87
# ['step1_rr: 86', 'step2_rr: 86', 'step3_rr: 86', 'step4_rr: 86', 'step5_rr: 86', 'step6_rr: 86']
# empirical response rate 0.05534430309734513
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4250.948665966841
# orr termination 0.020458180238989432 0.08924782941089171 0.06878964917190228
# remaining size for Round 3: 140902
# Calculated size for Round 3: 14182.666194566322
# orr termination 0.06075589242823007 0.08139653663724718 0.02064064420901711
# remaining size for Round 4: 126720
# Calculated size for Round 4: 6385.5427624257945
# orr termination 0.027281692704137238 0.07978318077912773 0.05250148807499049
# remaining size for Round 5: 120335
# 88
# ['step1_rr: 87', 'step2_rr: 87', 'step3_rr: 87', 'step4_rr: 87', 'step5_rr: 87', 'step6_rr: 87']
# empirical response rate 0.05527516592920354
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4246.136882198541
# orr termination 0.034383291911113924 0.08830360011957704 0.053920308208463115
# remaining size for Round 3: 140906
# Calculated size for Round 3: 15812.864040644781
# orr termination 0.0129478070304375 0.08717187935987716 0.07422407232943966
# remaining size for Round 4: 125094
# 89
# ['step1_rr: 88', 'step2_rr: 88', 'step3_rr: 88', 'step4_rr: 88', 'step5_rr: 88', 'step6_rr: 88']
# empirical response rate 0.054618362831858405
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4200.457890907699
# orr termination 0.04801401055252412 0.08386708238107858 0.03585307182855446
# remaining size for Round 3: 140952
# Calculated size for Round 3: 7483.982633471046
# orr termination 0.0419437350569202 0.08588693400566222 0.04394319894874202
# remaining size for Round 4: 133469
# Calculated size for Round 4: 6690.211028415575
# orr termination 0.024548294246242636 0.08273373992590052 0.05818544567965789
# remaining size for Round 5: 126779
# Calculated size for Round 5: 6773.272196522334
# orr termination 0.051720333834794796 0.08576814615505929 0.03404781232026449
# remaining size for last Round 6: 120006
# 90
# ['step1_rr: 89', 'step2_rr: 89', 'step3_rr: 89', 'step4_rr: 89', 'step5_rr: 89', 'step6_rr: 89']
# empirical response rate 0.05403069690265487
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4159.637779672868
# orr termination 0.055861044169045186 0.08576596896017383 0.02990492479112864
# remaining size for Round 3: 140993
# Calculated size for Round 3: 8132.374812453789
# orr termination 0.06902127994411439 0.07871087523624573 0.009689595292131342
# remaining size for Round 4: 132861
# Calculated size for Round 4: 6351.5727358259055
# orr termination 0.02471227532837587 0.08422131224531926 0.059509036916943384
# remaining size for Round 5: 126510
# Calculated size for Round 5: 5800.498485318905
# orr termination 0.013437898861607685 0.08814420479112081 0.07470630592951313
# remaining size for last Round 6: 120710
# 91
# ['step1_rr: 90', 'step2_rr: 90', 'step3_rr: 90', 'step4_rr: 90', 'step5_rr: 90', 'step6_rr: 90']
# empirical response rate 0.05596653761061947
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4294.284441919237
# orr termination 0.029522647381792708 0.08505411201539764 0.055531464633604935
# remaining size for Round 3: 140858
# Calculated size for Round 3: 5628.131735981581
# orr termination 0.016253555814511225 0.09097436403013606 0.07472080821562484
# remaining size for Round 4: 135230
# Calculated size for Round 4: 7482.381884457639
# orr termination 0.050612535629116884 0.08108880229890125 0.03047626666978437
# remaining size for Round 5: 127748
# Calculated size for Round 5: 7920.4661915435645
# orr termination 0.017760231972547925 0.08594864420272606 0.06818841223017813
# remaining size for last Round 6: 119828
# 92
# ['step1_rr: 91', 'step2_rr: 91', 'step3_rr: 91', 'step4_rr: 91', 'step5_rr: 91', 'step6_rr: 91']
# empirical response rate 0.051991150442477874
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4018.338787935027
# orr termination 0.004986125312910817 0.09423678388573842 0.0892506585728276
# remaining size for Round 3: 141134
# Calculated size for Round 3: 9030.870617643504
# orr termination 0.03959136753531339 0.08115460204862877 0.04156323451331538
# remaining size for Round 4: 132104
# 93
# ['step1_rr: 92', 'step2_rr: 92', 'step3_rr: 92', 'step4_rr: 92', 'step5_rr: 92', 'step6_rr: 92']
# empirical response rate 0.05596653761061947
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4294.284441919237
# orr termination 0.058031180981526265 0.07254030621198572 0.014509125230459455
# remaining size for Round 3: 140858
# Calculated size for Round 3: 19696.54446592666
# orr termination 0.01966799681071887 0.08080821340820418 0.06114021659748531
# remaining size for Round 4: 121162
# 94
# ['step1_rr: 93', 'step2_rr: 93', 'step3_rr: 93', 'step4_rr: 93', 'step5_rr: 93', 'step6_rr: 93']
# empirical response rate 0.05434181415929203
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4181.242476429084
# orr termination 0.05221814231409828 0.08098562728980521 0.028767484975706935
# remaining size for Round 3: 140971
# Calculated size for Round 3: 7098.164855779578
# orr termination 0.015496640643369091 0.08593813222438935 0.07044149158102027
# remaining size for Round 4: 133873
# Calculated size for Round 4: 6424.389225182556
# orr termination 0.04215941022815675 0.08285757870533875 0.040698168477181995
# remaining size for Round 5: 127449
# Calculated size for Round 5: 8686.561056995437
# orr termination 0.041511747886041096 0.0822835272480155 0.04077177936197441
# remaining size for last Round 6: 118763
# 95
# ['step1_rr: 94', 'step2_rr: 94', 'step3_rr: 94', 'step4_rr: 94', 'step5_rr: 94', 'step6_rr: 94']
# empirical response rate 0.05489491150442478
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4219.683881321882
# orr termination 0.002531957503588043 0.09575895689505612 0.09322699939146807
# remaining size for Round 3: 140933
# Calculated size for Round 3: 6893.7459803057445
# orr termination 0.0417280995179295 0.08394144706830302 0.042213347550373516
# remaining size for Round 4: 134040
# 96
# ['step1_rr: 95', 'step2_rr: 95', 'step3_rr: 95', 'step4_rr: 95', 'step5_rr: 95', 'step6_rr: 95']
# empirical response rate 0.057280143805309734
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4385.946667669806
# orr termination 0.05544598190899061 0.08993852720283117 0.03449254529384056
# remaining size for Round 3: 140767
# Calculated size for Round 3: 12280.198058795737
# orr termination 0.05441916524142 0.0795031984835999 0.025084033242179893
# remaining size for Round 4: 128487
# Calculated size for Round 4: 5989.292220007683
# orr termination 0.025678612271276206 0.08128191364832843 0.055603301377052224
# remaining size for Round 5: 122498
# Calculated size for Round 5: 5947.176410889069
# orr termination 0.06063395649262765 0.08070718880718752 0.020073232314559875
# remaining size for last Round 6: 116551
# 97
# ['step1_rr: 96', 'step2_rr: 96', 'step3_rr: 96', 'step4_rr: 96', 'step5_rr: 96', 'step6_rr: 96']
# empirical response rate 0.05482577433628318
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4214.876392356589
# orr termination 0.02537988586047664 0.08789315060486377 0.06251326474438713
# remaining size for Round 3: 140938
# Calculated size for Round 3: 6901.273937014006
# orr termination 0.02993870561508754 0.08195640749735462 0.052017701882267085
# remaining size for Round 4: 134037
# Calculated size for Round 4: 7743.3859345770215
# orr termination 0.05885241190704561 0.07922910292849948 0.02037669102145387
# remaining size for Round 5: 126294
# Calculated size for Round 5: 6963.558056286575
# orr termination 0.05288864052654476 0.07852018691041412 0.025631546383869365
# remaining size for last Round 6: 119331
# 98
# ['step1_rr: 97', 'step2_rr: 97', 'step3_rr: 97', 'step4_rr: 97', 'step5_rr: 97', 'step6_rr: 97']
# empirical response rate 0.0546529314159292
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4202.860561387483
# orr termination 0.016079368092380288 0.08641764044033051 0.07033827234795023
# remaining size for Round 3: 140950
# Calculated size for Round 3: 5538.098084678245
# orr termination 0.00855662956088633 0.09556895721555604 0.08701232765466971
# remaining size for Round 4: 135412
# Calculated size for Round 4: 8672.817698871022
# orr termination 0.038665861410406274 0.08175038934145727 0.043084527931051
# remaining size for Round 5: 126740
# 99
# ['step1_rr: 98', 'step2_rr: 98', 'step3_rr: 98', 'step4_rr: 98', 'step5_rr: 98', 'step6_rr: 98']
# empirical response rate 0.053512168141592924
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4123.659712438602
# orr termination 0.012706627920944761 0.07939392989424637 0.06668730197330161
# remaining size for Round 3: 141029
# Calculated size for Round 3: 5510.92804820547
# orr termination 0.009705725990973475 0.08801293147827191 0.07830720548729844
# remaining size for Round 4: 135519
# Calculated size for Round 4: 10438.229960360452
# orr termination 0.03996681313304921 0.07861773846826627 0.03865092533521706
# remaining size for Round 5: 125081
# 100
# ['step1_rr: 99', 'step2_rr: 99', 'step3_rr: 99', 'step4_rr: 99', 'step5_rr: 99', 'step6_rr: 99']
# empirical response rate 0.055517146017699116
# remaining size for Round 2: 145152
# Calculated size for Round 2: 4262.981015401587
# orr termination 0.026027866881726026 0.09763420112471788 0.07160633424299186
# remaining size for Round 3: 140890
# Calculated size for Round 3: 11892.44077664004
# orr termination 0.04760544404415851 0.08429385082156299 0.03668840677740448
# remaining size for Round 4: 128998
# Calculated size for Round 4: 6910.4921685265035
# orr termination 0.06577938959959095 0.08204267872058317 0.016263289120992216
# remaining size for Round 5: 122088
# Calculated size for Round 5: 6703.445987771323
# orr termination 0.04248128186325295 0.08239653049290313 0.03991524862965018
# remaining size for last Round 6: 115385

# %% [markdown]
# ### Results summary

# %%
rr_df = pd.DataFrame(rr_dict)
rr_df
# Out:
#     step1_rr  step2_rr  step3_rr  step4_rr  step5_rr  step6_rr
# 0      0.055  0.067462  0.065137  0.068471  0.068471       NaN
# 1      0.055  0.061899  0.065524  0.068471  0.068471  0.068471
# 2      0.055  0.063692  0.065209  0.068471  0.068471       NaN
# 3      0.055  0.065569  0.068471  0.068471  0.068471       NaN
# 4      0.055  0.060871  0.063912  0.068471  0.068471       NaN
# ..       ...       ...       ...       ...       ...       ...
# 95     0.055  0.063298  0.065608  0.066469  0.068471  0.068471
# 96     0.055  0.063416  0.064060  0.065011  0.066209  0.065256
# 97     0.055  0.061289  0.062022  0.068471  0.068471       NaN
# 98     0.055  0.061218  0.064074  0.068471  0.068471       NaN
# 99     0.055  0.066163  0.068471  0.068471  0.068471  0.068471
#
# [100 rows x 6 columns]

# %%
# Calculate average rounds:
row_non_nan_counts = rr_df.count(axis=1)

print(f"{np.mean(row_non_nan_counts):.1f} ({np.std(row_non_nan_counts):.1f})")
# Out:
# 5.2 (0.9)

# %%
result_dict = {}
for key, values in rr_df.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"

for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_rr: 0.055 (0.000)
# step2_rr: 0.064 (0.003)
# step3_rr: 0.065 (0.003)
# step4_rr: 0.067 (0.003)
# step5_rr: 0.068 (0.001)
# step6_rr: 0.068 (0.001)

# %%
result_dict = np.array(orr_total) / total_n
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f}, StD: {std_result:.3f}")
# Out:
# Mean: 0.066, StD: 0.002

# %%
print(np.mean(highest_rr_overall))
print(np.std(highest_rr_overall))
# Out:
# 0.06806641063923788
# 0.0022978996707203243

# %%
result_dict = np.array(orr_total_adaptive) / (total_n-34976)
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f}, StD: {std_result:.3f}")
# Out:
# Mean: 0.071, StD: 0.002

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in plan_number_dict.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.1f} ({std_value:.1f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_plan_number: nan (nan)
# step2_plan_number: 63.2 (42.8)
# step3_plan_number: 20.8 (22.8)
# step4_plan_number: 6.9 (8.8)
# step5_plan_number: 3.4 (3.4)
# step6_plan_number: 2.4 (2.1)

# %%
means = {key: np.mean(values) for key, values in stopping_dict.items()}
means
# Out:
# {'early_stopping': 0.54,
#  'early_stopping_plan': 0.54,
#  'early_stopping_orr': 0.0,
#  'early_stopping_size': 0.0}

# %%
print(np.mean(last_round_sample_size), np.std(last_round_sample_size))
# Out:
# 123036.39 6263.472333929481

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in sample_size_dict.items():
    mean_value = np.nanmean(values)
    std_value = np.nanstd(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
# Out:
# step1_sample_size: 28928.000 (0.000)
# step2_sample_size: 4217.873 (88.452)
# step3_sample_size: 14793.484 (26112.962)
# step4_sample_size: 31024.123 (48303.331)
# step5_sample_size: 54188.328 (57322.855)
# step6_sample_size: 118769.652 (2391.621)

# %% [markdown]
# ## Ensemble learning - 7 methods

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn import ensemble, linear_model
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier

def ensemble_model_fit(data, data_pred):
    X_train, X_test, y_train, y_test = train_test_split(
        data.drop(['recruitment_plan', 'plan_response_rate', 'group_size', 'response'], axis=1),
        data['response'],
        test_size=0.2,
        random_state=0
    )

    # Define the VotingClassifier with the individual classifiers
    voting_classifier = ensemble.VotingClassifier(
        estimators=[
            ('LR', linear_model.LogisticRegression(penalty = 'none', max_iter=200, random_state=0)),
            ('Lasso', linear_model.LogisticRegression(penalty = "l1", max_iter=200, random_state=0,
                                                     solver="liblinear")),
            ('Ridge', linear_model.LogisticRegression(penalty = "l2", max_iter=200, random_state=0)),
            ('GBM', ensemble.GradientBoostingClassifier(random_state=0)),
            ('RF', ensemble.RandomForestClassifier(random_state=0)),
            ('XGB', XGBClassifier(random_state=0)),
            ('NN', MLPClassifier(random_state=0))
        ],
        voting='soft'
    )

    # Define the hyperparameter grid to search
#     param_grid = {
# #         'LR__C': [0.01, 0.1, 1.0],  # Regularization parameter for logistic regression
#         'Lasso__C': [0.01, 0.1, 1.0],  # Regularization parameter for lasso regression
#         'Ridge__C': [0.01, 0.1, 1.0],  # Regularization parameter for ridge regression
#         'GBM__learning_rate': [0.01, 0.1, 0.5],  # Learning rate for gradient boosting machine
#         'GBM__n_estimators': [50, 100, 200],  # Number of trees for gradient boosting machine
#         'RF__n_estimators': [50, 100, 200],  # Number of trees for random forest
# #         'RF__max_depth': [10, 20],  # Maximum depth of trees for random forest
#         'XGB__learning_rate': [0.01, 0.1, 0.5],  # Learning rate for XGBoost
#         'XGB__n_estimators': [50, 100, 200],  # Number of trees for XGBoost
#         'NN__hidden_layer_sizes': [(50,), (100,), (50, 50)],  # Size of hidden layers for neural networks
#         'NN__alpha': [0.0001, 0.001, 0.01]  # Regularization parameter for neural networks
#     }
    param_grid = {
#         'LR__C': [0.01, 0.1, 1.0],  # Regularization parameter for logistic regression
        'Lasso__C': [0.1],  # Regularization parameter for lasso regression
        'Ridge__C': [0.01],  # Regularization parameter for ridge regression
        'GBM__learning_rate': [0.01],  # Learning rate for gradient boosting machine
        'GBM__n_estimators': [50],  # Number of trees for gradient boosting machine
        'RF__n_estimators': [50],  # Number of trees for random forest
#         'RF__max_depth': [10, 20],  # Maximum depth of trees for random forest
        'XGB__learning_rate': [0.01],  # Learning rate for XGBoost
        'XGB__n_estimators': [50],  # Number of trees for XGBoost
        'NN__hidden_layer_sizes': [(50,)],  # Size of hidden layers for neural networks
        'NN__alpha': [0.01]  # Regularization parameter for neural networks
    }

    # Create a GridSearchCV object
    grid_search = GridSearchCV(voting_classifier, param_grid, cv=10, scoring='roc_auc')

    # Perform the grid search on the training data
    grid_search.fit(X_train, y_train)

    # Get the best hyperparameters
    best_params = grid_search.best_params_
#     print("Best fit parameters:", best_params)

    # Train the final VotingClassifier with the best hyperparameters on the full training set
    final_voting_classifier = grid_search.best_estimator_
    final_voting_classifier.fit(X_train, y_train)

    # Predict probabilities instead of binary outcomes on the test set
    y_pred_proba_test = final_voting_classifier.predict_proba(X_test)
    y_pred_test = final_voting_classifier.predict(X_test)
    X_dt = data_pred.drop(['recruitment_plan', 'plan_response_rate', 'group_size', 'response'], axis=1)
    y_pred = final_voting_classifier.predict_proba(X_dt)

    return y_pred

# %%
# ensemble_model_fit(dt_design_5, dt_design_5)

# %% [markdown]
# ### Simulation starts

# %%
n_sim = 100
# create a list of random seeds
random.seed(42)
random_seeds = [random.randint(1, 100000) for _ in range(n_sim)]

design_list = [5,8,10]
patient_n_list = [5468,680,170] # n_patient_per_plan

n_design = 6
n_patient_per_plan = 680
n_rounds = 8
total_n = n_patient_per_plan * (2**n_design)

## sample size determination
beta = 0.2
power = 1 - beta
alpha = 0.05
delta = 0.01 # effect size

## early stopping
epsilon = 0.001

# %%
rr_dict = {"step{}_rr".format(r): [] for r in range(1, n_rounds + 1)}
plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
sample_size_dict = {"step{}_sample_size".format(r): [] for r in range(1, n_rounds + 1)}
last_round_sample_size = []
random_rr_dict = {"step{}_random_max_rr".format(r): [] for r in range(1, n_rounds + 1)}
random_rr_dict.update({
    "step{}_random_mean_rr".format(r): [] for r in range(1, n_rounds + 1)
})

stopping_dict = {"early_stopping": [],
                 "early_stopping_plan":[],
                 "early_stopping_orr":[],
                 "early_stopping_size":[]}
final_plan_number = []
highest_rr_overall = []
highest_true_rr = []

better_chance = []

orr_total = []
orr_total_adaptive = []



i = 0

for seed in random_seeds:
    i += 1
    print(i)

    print([f"{key}: {len(value)}" for key, value in rr_dict.items()])



    event_list = 0
    event_list_adaptive = 0
    max_rr = []

    # step 1:
    ## Generate dataset
    dt_design_5 = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed)
    highest_true_rr.append(np.max(dt_design_5['plan_response_rate']))
    print("empirical response rate", dt_design_5['response'].mean())
    ## save for benchmark results
    maxidx = np.argmax(dt_design_5['plan_response_rate'])
    random_rr_dict['step1_random_max_rr'].append(dt_design_5.iloc[maxidx,6])
    random_rr_dict['step1_random_mean_rr'].append(dt_design_5['plan_response_rate'].mean())

    ## Ensemble modelling:
    y_pred = ensemble_model_fit(data=dt_design_5, data_pred = dt_design_5)

    ## select recruitment plan
    pred_df = pd.DataFrame(np.hstack((dt_design_5,  y_pred[:, 1].reshape(-1, 1))),
                             columns=list(dt_design_5.columns) + ['predicted_response_rate'])
    pred_df_rr = pred_df.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

    x = pred_df_rr['predicted_response_rate'].values
    if len(x) <= 10:
        best_k = 2
    else:
        best_k = kmeans_fit(data = x)['best_k']
    kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

    merged_df = pd.merge(pred_df_rr, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
    cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
    highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
    highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)


    p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))
    highest_cluster['p_vec'] = p_vec_next
    highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

    # highest_cluster = pred_df_rr

    # highest_cluster = pd.merge(highest_cluster, dt_design_5[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')
    # highest_cluster['cluster_number'] = highest_cluster['recruitment_plan']

    ## prepare to chance of better performance:
    temp = dt_design_5[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
    event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print("step1", np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
    # print(temp)
    p0 = (temp['plan_response_rate'].mean())

    rr_dict["step1_rr"].append(dt_design_5['plan_response_rate'].mean())
    sample_size_dict["step1_sample_size"].append(len(dt_design_5))

    for round in range(2, n_rounds+1):

        rr_dict["step"+str(round)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))
        plan_number_dict["step"+str(round)+"_plan_number"].append(len(p_vec_next))

        ## when it comes to the last round:
        if round == n_rounds:

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            if round == 2: # if the last round is round 2
                remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
            else:
                remaining_size -= len(dt_design_5_step2up)

            print("remaining size for last Round " + str(round) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            ## data generation, combine previous data:
            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, round=round,
                                                          design_number = n_design, n_rounds = n_rounds,
                                                          n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(0)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(len(temp), temp['plan_response_rate'].mean())
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break



        ## If haven't reached the last round:
        ## check remaining sample size:
        if round == 2:
            remaining_size = total_n - len(dt_design_5) # apply to the rest of the patients
        else:
            remaining_size -= len(dt_design_5_step2up)

        print("remaining size for Round " + str(round) + ": " + str(remaining_size))

        ## determine whether move on to step 2:
        if len(highest_cluster) == 1: # if there is only one plan left

            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size) # record the last round sample size
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(1)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        ## sample size determination:
        if round == 2:
            dt_design_5_step2up_overall = dt_design_5
        orr_1 = dt_design_5_step2up_overall['response'].mean() # observed overall response rates for previous rounds
        orr_2 = orr_1 + delta
        n_1 = len(dt_design_5_step2up_overall)

        size_step2up = sample_size_calc(orr_1, n_1, delta=delta, alpha=alpha, power=power) # total size for dataset
        if size_step2up > 0 and size_step2up < 1000:
            size_step2up = 1000 # if size in [0,1000], then it is 1000 for this round.
        elif size_step2up >= 1000:
            size_step2up = min(size_step2up, int(total_n/n_rounds)) # dataset size capped by the n_patient_per_plan
        else:
        # if size_step2up <= 0:
            # the process stops at this step
            print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up) + 'lt 0, break')
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)
            for r in range(round+1, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                      n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_step2up['recruitment_plan'].unique()
            if round == 2:
                supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)] # data from step 1
            else:
                # step from previous rounds
                supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]

            dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(0)
            stopping_dict['early_stopping_size'].append(1)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_step2up_overall['plan_response_rate']))

            for r in range(round+1, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare for chance of better performance:
            temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)
            break

        print('Calculated size for Round ' + str(round) + ': ' + str(size_step2up))

        sample_size_dict["step"+str(round)+"_sample_size"].append(size_step2up)

        ## save benchmark results for last round:
        dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                            n_patient_per_plan = n_patient_per_plan, seed=seed+round)
        maxidx = np.argmax(dt_benchmark['plan_response_rate'])
        random_rr_dict["step"+str(round)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
        random_rr_dict["step"+str(round)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

        ## data generation, combine previous data:
        dt_design_5_step2up = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next,round=round,
                                                  design_number = n_design, n_rounds = n_rounds,
                                                  n_patient_per_plan = n_patient_per_plan, size = int(size_step2up), seed=seed)

        plan_list = dt_design_5_step2up['recruitment_plan'].unique()
        if round == 2:
            supp = dt_design_5[dt_design_5['recruitment_plan'].isin(plan_list)]
        else:
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
        dt_design_5_step2up_overall = pd.concat([dt_design_5_step2up, supp.reset_index(drop=True)], axis = 0)
        dt_design_5_step2up_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

        ## Ensemble model fitting:
        dt_design_5_step2up.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)
        y_pred2up = ensemble_model_fit(data = dt_design_5_step2up_overall, data_pred = dt_design_5_step2up)
        pred_df_step2up = pd.DataFrame(np.hstack((dt_design_5_step2up,  y_pred2up[:, 1].reshape(-1, 1))),
                                    columns=list(dt_design_5_step2up.columns) + ['predicted_response_rate'])
        pred_df_rr_step2up = pred_df_step2up.groupby([f'Design_Feature_{i+1}' for i in range(n_design)]+['recruitment_plan'])['predicted_response_rate'].mean().reset_index(name='predicted_response_rate')

        ## select recruitment plans:
        x = pred_df_rr_step2up['predicted_response_rate'].values

        if len(x) <= 10:
            best_k = 2
        else:
            best_k = kmeans_fit(data = x)['best_k']
        kmeans_results = kmeans_bhattacharyya(data=x, k=best_k)

        ## match the cluster results back to the original data
        highest_cluster_previous = highest_cluster # save previous cluster results

        merged_df = pd.merge(pred_df_rr_step2up, kmeans_results['clusters'][['predicted_response_rate', 'cluster_number']], on='predicted_response_rate')
        cluster_with_highest_rate = kmeans_results['clusters'].groupby('cluster_number')['predicted_response_rate'].mean().idxmax()
        highest_cluster = merged_df[merged_df['cluster_number']==cluster_with_highest_rate].reset_index(drop=True)
        highest_cluster.sort_values(by='predicted_response_rate', ascending=False, inplace=True)

        # p_vec_previous = p_vec_next # save p_vec of previous round
        p_vec_next = np.array(highest_cluster['predicted_response_rate']/np.sum(highest_cluster['predicted_response_rate']))

        highest_cluster['p_vec'] = p_vec_next

        highest_cluster = pd.merge(highest_cluster, dt_design_5_step2up[['recruitment_plan','plan_response_rate']].drop_duplicates(), how='left', on='recruitment_plan')

        ## prepare to chance of better performance:
        temp = dt_design_5_step2up[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
        event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print("step"+str(round), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
        # print(temp)

        ## check early stopping predicted ORR:
        orr_df = pd.merge(highest_cluster_previous, highest_cluster[['recruitment_plan','predicted_response_rate','p_vec']], on='recruitment_plan', how='left')
        orr_df.fillna(0, inplace=True)
        p_orr_1 = np.dot(np.array(orr_df['p_vec_x']), np.array(orr_df['predicted_response_rate_y']))
        p_orr_2 = np.dot(np.array(orr_df['p_vec_y']), np.array(orr_df['predicted_response_rate_y']))
        print("orr termination", p_orr_1, p_orr_2, p_orr_2 - p_orr_1)

        if (p_orr_2 - p_orr_1 < epsilon):
            # step 3 use the same strategy of step2
            print(i, p_orr_1, p_orr_2, "early stop at Round " + str(round))
            rr_dict["step"+str(round+1)+"_rr"].append(np.dot(np.array(highest_cluster['p_vec']), np.array(highest_cluster['plan_response_rate'])))

            ## save benchmark results for last round:
            dt_benchmark = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
                                                n_patient_per_plan = n_patient_per_plan, seed=seed+round)
            maxidx = np.argmax(dt_benchmark['plan_response_rate'])
            random_rr_dict["step"+str(round+1)+'_random_max_rr'].append(dt_benchmark.iloc[maxidx,6])
            random_rr_dict["step"+str(round+1)+'_random_mean_rr'].append(dt_benchmark['plan_response_rate'].mean())

            ### update remaining size:
            remaining_size -= len(dt_design_5_step2up)
            print("early stop, remaining size for Round" + str(round + 1) + ": " + str(remaining_size))
            sample_size_dict["step"+str(round)+"_sample_size"].append(remaining_size)
            last_round_sample_size.append(remaining_size)

            for r in range(round+2, n_rounds+1):
                sample_size_dict["step"+str(r)+"_sample_size"].append(np.nan)

            dt_design_5_rest = generate_data_step2up(highest_cluster=highest_cluster, p_vec = p_vec_next, round=round,
                                                      design_number = n_design, n_rounds = n_rounds,
                                                      n_patient_per_plan = n_patient_per_plan, size = int(remaining_size), seed=seed)
            plan_list = dt_design_5_rest['recruitment_plan'].unique()
            supp = dt_design_5_step2up_overall[dt_design_5_step2up_overall['recruitment_plan'].isin(plan_list)]
            dt_design_5_rest_overall = pd.concat([dt_design_5_rest, supp.reset_index(drop=True)], axis = 0)
            dt_design_5_rest_overall.drop(['predicted_response_rate','cluster_number','p_vec'], axis=1, inplace=True)

            stopping_dict['early_stopping'].append(1)
            stopping_dict['early_stopping_plan'].append(0)
            stopping_dict['early_stopping_orr'].append(1)
            stopping_dict['early_stopping_size'].append(0)

            ## record final plan number
            final_plan_number.append(len(p_vec_next))

            ## record highest responserate overall
            highest_rr_overall.append(np.max(dt_design_5_rest_overall['plan_response_rate']))

            for r in range(round+2, n_rounds+1):
                rr_dict["step"+str(r)+"_rr"].append(np.nan)

            ## prepare to chance of better performance:
            temp = dt_design_5_rest[['recruitment_plan','plan_response_rate', 'group_size']].drop_duplicates()
            event_list += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            event_list_adaptive += (np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print("step"+str(round+1), np.dot(temp['plan_response_rate'].values, temp['group_size'].values))
            # print(temp)

            result = binomtest(int(event_list), n=total_n, p=p0)
            # print(int(event_list), total_n, p0)
            orr_total.append(event_list)
            orr_total_adaptive.append(event_list_adaptive)
            better_chance.append(1 if result.pvalue < 0.05 else 0)
            # print(result.pvalue)

            break
# Out:
# 1
# ['step1_rr: 0', 'step2_rr: 0', 'step3_rr: 0', 'step4_rr: 0', 'step5_rr: 0', 'step6_rr: 0', 'step7_rr: 0', 'step8_rr: 0']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-e05ec0a8a37a> in <module>
#      39     # step 1:
#      40     ## Generate dataset
# ---> 41     dt_design_5 = generate_data_step1(design_number = n_design, n_rounds = n_rounds,
#      42                                       n_patient_per_plan = n_patient_per_plan, seed=seed)
#      43     highest_true_rr.append(np.max(dt_design_5['plan_response_rate']))
#
# <ipython-input-33-a5027bbd520e> in generate_data_step1(design_number, n_rounds, n_patient_per_plan, seed)
#      34   # impact_rates = np.array([random.uniform(0.6, 1.5) for _ in range(n_design)])
#      35   impact_rates = np.array([-0.5, 0, 0, 0, 0, 0, 0, 0, 1]) # design 2 has the highest rr
# ---> 36   response_rate_list = np.dot(np.array(design_feature_df.iloc[:,:(n_design+1)]), impact_rates)
#      37   # normalize to [0,1]
#      38   # normalized_values = normalize_to_0_1(response_rate_list) * 0.115
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (64,7) and (9,) not aligned: 7 (dim 1) != 9 (dim 0)

# %% [markdown]
# ### Results summary

# %%
rr_df = pd.DataFrame(rr_dict)
rr_df

# %%
# Calculate average rounds:
row_non_nan_counts = rr_df.count(axis=1)

print(f"{np.mean(row_non_nan_counts):.1f} ({np.std(row_non_nan_counts):.1f})")

# %%
# orr for each round:
result_dict = {}
for key, values in rr_df.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"

for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")

# %%
# overall orr:
result_dict = np.array(orr_total) / total_n
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f}, StD: {std_result:.3f}")

# %%
# highest true rr:
print(np.mean(highest_true_rr))
print(np.std(highest_true_rr))

# %%
# adaptive learning orr:
result_dict = np.array(orr_total_adaptive) / (total_n-34976)
mean_result = np.mean(result_dict)
std_result = np.std(result_dict)

print(f"Mean: {mean_result:.3f}, StD: {std_result:.3f}")

# %%
# average plan number for each round:
result_dict = {}
for key, values in plan_number_dict.items():
    mean_value = np.mean(values)
    std_value = np.std(values)
    result_dict[key] = f"{mean_value:.1f} ({std_value:.1f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")

# %%
means = {key: np.mean(values) for key, values in stopping_dict.items()}
means

# %%
print(np.mean(last_round_sample_size), np.std(last_round_sample_size))

# %%
# plan_number_dict = {"step{}_plan_number".format(r): [] for r in range(1, n_rounds + 1)}
result_dict = {}
for key, values in sample_size_dict.items():
    mean_value = np.nanmean(values)
    std_value = np.nanstd(values)
    result_dict[key] = f"{mean_value:.3f} ({std_value:.3f})"
#     result_dict[key + "_std"] = std_value
for key, value in list(result_dict.items())[:12]:
    print(f"{key}: {value}")
